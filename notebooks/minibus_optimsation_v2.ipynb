# %%
import sys
from pathlib import Path
import pandas as pd

# Add repo root to PYTHONPATH
HERE = Path().resolve()
PROJECT_ROOT = HERE.parents[0]   # notebooks → repo root
sys.path.insert(0, str(PROJECT_ROOT))

from prm_opt.run_s25_s26_v2 import run_s25_s26_v2
from prm_opt.optimise_prm_fleet_v2 import OptimiserConfig

# %%
VEHICLE_MODELS = {
    # ---------------- Ambulifts (current fleet) ----------------
    "AMB_14111": {"type": "Amb", "seatcap": 6, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_14112": {"type": "Amb", "seatcap": 6, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_OMN135": {"type": "Amb", "seatcap": 3, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_OMN079": {"type": "Amb", "seatcap": 6, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_OMN080": {"type": "Amb", "seatcap": 6, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_14161": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_14162": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_14163": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79803": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79802": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79801": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79804": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79805": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79900": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},

    # ---------------- Minibuses (current fleet) ----------------
    "MB_WJ160DR": {"type": "Mini", "seatcap": 6, "wccap": 2, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": False},
    "MB_WJ160DT": {"type": "Mini", "seatcap": 6, "wccap": 2, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": False},
    "MB_WJ160FD": {"type": "Mini", "seatcap": 6, "wccap": 2, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": False},

    # ---------------- Future purchase options ----------------
    "MB_EV_10": {"type": "Mini", "seatcap": 10, "wccap": 1, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": True},
    "MB_EV_18": {"type": "Mini", "seatcap": 18, "wccap": 1, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": True},
}


config = OptimiserConfig(
    tau_amb_solo_mins=19,
    tau_amb_comb_mins=14,
    tau_mini_mins=14,
    tau_push_mins=15,
    handover_buffer_mins=5,
    arrival_sla_target_pct=0.98,
    arrival_sla_target_mins=20,
    boarding_offset_mins=40,
    staff_amb=2,
    staff_mini=2,
    staff_per_prm_push=1,
    max_future_copies_per_model=5,
    solver_relative_gap=0.005,
)

# %%
results = run_s25_s26_v2(
    run_s25=True,
    s25_start="2025-04-01",
    s25_end="2025-04-30",

    run_s26=False,

    vehicle_models=VEHICLE_MODELS,
    config=config,

    output_dir="outputs/prm_v2",
    output_xlsx_name="prm_v2_s25_outputs.xlsx",

    run_p100=True,
    run_p90=True,
    run_fleet_report=False,

    max_ev10=5,
    max_ev18=5,
)
# Out:
#     ✓ S25 ingest complete (12,649 passengers)   [62.29s]
#     ✓ Passenger dataset combined (12,649 passenger rows)   [0.00s]
#     ✓ P100 built (5,380 flights)   [0.34s]
#     P100 demand summary: 12,649 PRMs across 5,380 flights
#     ✓ prepare_model_data started | flights=5,380   [0.00s]
#     ✓ vehicle expansion complete | vehicles=27   [0.03s]
#     ✓ ambulift intervals built | flights=5,380 ambulifts=14   [0.33s]
#     ✓ minibus intervals built | minibuses=13   [0.05s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=1,745,269   [320.96s]
#     ✓ minibus overlaps built | overlaps=718,965   [116.13s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.01s]
#     ✓ prepare_model_data complete | total=437.53s   [0.00s]
#     ✓ sets built | F=5,380 AMB=14 MINI=13   [0.00s]
#     ✓ variables built | x=26,900 amb=225,960 mini=139,880   [0.69s]
#     ✓ ambulift overlap constraints built | 1,745,269   [16.22s]
#     ✓ minibus overlap constraints built | 718,965   [4.09s]
#     ✓ build_pyomo_model complete | total=21.07s   [0.07s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=5,380 Vehicles=27
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 3142124 rows; 430437 cols; 6791850 nonzeros; 392777 integer variables (392777 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 806156 rows, 185800 cols, 1797714 nonzeros 4s
# 384959 rows, 153985 cols, 1188146 nonzeros 22s
# 384959 rows, 153985 cols, 1188146 nonzeros 54s
# Presolve reductions: rows 384959(-2757165); columns 153985(-276452); nonzeros 1188146(-5603704)
#
# Solving MIP model with:
#    384959 rows
#    153985 cols (142908 binary, 0 integer, 11077 implied int., 0 continuous, 0 domain fixed)
#    1188146 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            1982427015.881     Large        0      0      0         0    67.5s
#  R       0       0         0   0.00%   190680.179119   994190664.2968    99.98%        0      0      0     45787   330.0s
#          0       0         0   0.00%   190762.879119   994190664.2968    99.98%     1302    161      0     46570   359.5s
#          0       0         0   0.00%   191067.136694   994190664.2968    99.98%     1524    315      0     47337   368.0s
#          0       0         0   0.00%   191673.015982   994190664.2968    99.98%     1659    440      0     48107   378.3s
#          0       0         0   0.00%   191904.015982   994190664.2968    99.98%     1691    493      0     50202   399.1s
#          0       0         0   0.00%   192003.515982   994190664.2968    99.98%     1783    497   3247     50341   419.1s
#          0       0         0   0.00%   192114.862633   994190664.2968    99.98%     2022    518   3247     52352   566.3s
#          0       0         0   0.00%   192177.2793     994190664.2968    99.98%     2108    524   3247     52719   574.1s
#          0       0         0   0.00%   192231.390411   994190664.2968    99.98%     2154    529   3247     52962   579.5s
#          0       0         0   0.00%   192237.890411   994190664.2968    99.98%     2301    532   3247     52983   610.3s
#          0       0         0   0.00%   192255.890411   994190664.2968    99.98%     2401    536   3247     53067   634.1s
#          0       0         0   0.00%   192416.557078   994190664.2968    99.98%     2517    542   3247     53231   652.5s
#          0       0         0   0.00%   192418.7793     994190664.2968    99.98%     2577    547   3247     53667   666.5s
#          0       0         0   0.00%   192457.2793     994190664.2968    99.98%     2627    556   3247     54430   680.3s
#          0       0         0   0.00%   192457.2793     994190664.2968    99.98%     2760    564   3247     54481   713.3s
#          0       0         0   0.00%   192457.2793     994190664.2968    99.98%     2854    500   3247     54513   729.3s
#          0       0         0   0.00%   192503.2793     994190664.2968    99.98%     2901    505   3247     54681   741.2s
#          0       0         0   0.00%   192547.2793     994190664.2968    99.98%     2981    508   3247     54696   752.5s
#          0       0         0   0.00%   192553.7793     994190664.2968    99.98%     3054    512   3247     54735   767.5s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   192553.7793     994190664.2968    99.98%     3136    515   3247     54749   780.3s
#          0       0         0   0.00%   192553.7793     994190664.2968    99.98%     3198    509   3247     54763   793.1s
#          0       0         0   0.00%   192553.7793     994190664.2968    99.98%     3350    511   3247     54790   830.1s
#  L       0       0         0   0.00%   192553.7793     193096.296804      0.28%     3350    511   3247     54790  1481.1s
#          0       0         0   0.00%   192553.7793     193096.296804      0.28%     3446    515   3247     84456  1517.9s
#
# 37.7% inactive integer columns, restarting
# Model after restart has 180432 rows, 87412 cols (87412 bin., 0 int., 0 impl., 0 cont., 0 dom.fix.), and 619228 nonzeros
#
#          0       0         0   0.00%   192553.7793     193096.296804      0.28%      445      0      0     84456  1532.2s
#          0       0         0   0.00%   192553.7793     193096.296804      0.28%      445    173     38    135659  1652.7s
#          0       0         0   0.00%   192891.157078   193096.296804      0.11%     1472    177     38    136733  1670.4s
#          0       0         0   0.00%   192895.557078   193096.296804      0.10%     2292    183     38    137440  1688.0s
#          0       0         0   0.00%   192895.557078   193096.296804      0.10%     2422    186     38    137462  1694.2s
#          0       0         0   0.00%   192895.557078   193096.296804      0.10%     2514    187     38    137474  1702.0s
#          0       0         0   0.00%   192895.557078   193096.296804      0.10%     2675    188     38    137475  1713.1s
#          0       0         0   0.00%   192895.557078   193096.296804      0.10%     2757    189     38    137483  1722.1s
#          0       0         0   0.00%   192895.557078   193096.296804      0.10%     2871    191     38    137501  1730.4s
#          0       0         0   0.00%   192895.557078   193096.296804      0.10%     3064    194     38    137543  1746.0s
#          0       0         0   0.00%   192895.557078   193096.296804      0.10%     3166    195     38    137554  1754.7s
#          0       0         0   0.00%   192895.557078   193096.296804      0.10%     3337    197     38    137597  1767.2s
#          0       0         0   0.00%   192895.557078   193096.296804      0.10%     3487    200     38    137636  1781.5s
#
# Symmetry detection completed in 57.9s
# Found 971 generator(s) and 295 full orbitope(s) acting on 5925 columns
#
#  T       0       0         0   0.00%   192895.557078   192920.388128      0.01%     3487    198     59    137636  2687.4s
#         65       9         1   0.29%   192895.557078   192920.388128      0.01%     3490    198     92    313448  2712.9s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  L      65       7         1   0.39%   192895.557078   192918.388128      0.01%     4504    231     94    315132  2841.3s
#         71      12         1   0.42%   192895.557078   192918.388128      0.01%     4504    231     94    344906  2855.4s
#         88      27         1   0.42%   192895.557078   192918.388128      0.01%     5515    219    112    377947  2939.1s
#         88      26         1   0.81%   192895.557078   192918.388128      0.01%     7522    266    113    382922  2951.9s
#         89      24         2   5.49%   192895.557078   192918.388128      0.01%     8525    280    113    393657  2979.6s
#         90      23         2  17.99%   192895.557078   192918.388128      0.01%    10286    336    113    415170  3037.5s
#         91      22         2  42.99%   192895.557078   192918.388128      0.01%    11292    363    114    427774  3063.1s
#         92      21         3  49.24%   192895.557078   192918.388128      0.01%    11292    363    114    433001  3074.1s
#         93      20         4  49.29%   192895.557078   192918.388128      0.01%    11292    363    114    435757  3079.5s
#         96      17         6  74.59%   192895.557078   192918.388128      0.01%     8447    371    114    443753  3094.5s
#         97      16         7  74.98%   192895.557078   192918.388128      0.01%     8447    371    114    448030  3101.1s
#         98      15         8  87.48%   192895.557078   192918.388128      0.01%     8448    371    114    456425  3120.3s
#        101      12        11  96.88%   192897.557078   192918.388128      0.01%     8448    371    124    460857  3128.4s
#        102      11        12  96.88%   192897.557078   192918.388128      0.01%     8448    371    124    464538  3134.4s
#        108       5        18  96.97%   192897.557078   192918.388128      0.01%     8448    371    124    466041  3140.6s
#        113       0        23 100.00%   192899.362253   192918.388128      0.01%     8448    371    124    466099  3142.9s
#
# Solving report
#   Status            Optimal
#   Primal bound      192918.388128
#   Dual bound        192899.365297
#   Gap               0.00986% (tolerance: 0.01%)
#   P-D integral      1412.19223172
#   Solution status   feasible
#                     192918.388128 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            3142.89
#   Max sub-MIP depth 3
#   Nodes             113
#   Repair LPs        0
#   LP iterations     466099
#                     169387 (strong br.)
#                     39067 (separation)
#                     68105 (heuristics)
#     ✓ P100 optimisation complete   [3707.04s]
#
# [P100 fleet utilisation]
#      vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0    Amb_3seat_1wc          Amb        3      1                  1
# 1    Amb_6seat_1wc          Amb        6      1                  4
# 2    Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_10seat_1wc         Mini       10      1                  0
# 4  Mini_18seat_1wc         Mini       18      1                  0
# 5   Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   0                     0
# 1                            0                   3                     3
# 2                            0                   4                     4
# 3                            5                   0                     0
# 4                            5                   0                     0
# 5                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      0               0                   1              0
# 1                      3               0                   1              0
# 2                      4               0                   5              0
# 3                      0               0                   0              0
# 4                      0               0                   0              0
# 5                      3               0                   0              0
#     ✓ P90 built (5,380 flights)   [0.90s]
#     P90 demand summary: 11,552 PRMs across 5,380 flights
#     ✓ prepare_model_data started | flights=5,380   [0.00s]
#     ✓ vehicle expansion complete | vehicles=27   [0.07s]
#     ✓ ambulift intervals built | flights=5,380 ambulifts=14   [0.56s]
#     ✓ minibus intervals built | minibuses=13   [0.06s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=1,689,108   [467.48s]
#     ✓ minibus overlaps built | overlaps=717,847   [120.20s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=588.40s   [0.00s]
#     ✓ sets built | F=5,380 AMB=14 MINI=13   [0.00s]
#     ✓ variables built | x=26,900 amb=225,960 mini=139,880   [0.28s]
#     ✓ ambulift overlap constraints built | 1,689,108   [27.10s]
#     ✓ minibus overlap constraints built | 717,847   [5.47s]
#     ✓ build_pyomo_model complete | total=32.97s   [0.11s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=5,380 Vehicles=27
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 3084845 rows; 430437 cols; 6677292 nonzeros; 392777 integer variables (392777 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 804196 rows, 185800 cols, 1793794 nonzeros 8s
# 384421 rows, 153985 cols, 1184968 nonzeros 25s
# 384421 rows, 153985 cols, 1184968 nonzeros 45s
# Presolve reductions: rows 384421(-2700424); columns 153985(-276452); nonzeros 1184968(-5492324)
#
# Solving MIP model with:
#    384421 rows
#    153985 cols (142908 binary, 0 integer, 11077 implied int., 0 continuous, 0 domain fixed)
#    1184968 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            1960410092.881     Large        0      0      0         0    54.1s
#  R       0       0         0   0.00%   186337.913336   628186360.0502    99.97%        0      0      0     43178   179.5s
#          0       0         0   0.00%   186339.29376    628186360.0502    99.97%     1196     40      0     60472   417.1s
#          0       0         0   0.00%   186341.049315   628186360.0502    99.97%     2233     79      0     62037   433.9s
#          0       0         0   0.00%   186444.057078   628186360.0502    99.97%     2390    118      0     66372   459.0s
#          0       0         0   0.00%   186600.557078   628186360.0502    99.97%     3428    153      0     66940   474.1s
#          0       0         0   0.00%   186609.057078   628186360.0502    99.97%     3643    159   1703     67442   506.2s
#          0       0         0   0.00%   186621.890411   628186360.0502    99.97%     3702    164   1703     67514   514.7s
#          0       0         0   0.00%   186631.557078   628186360.0502    99.97%     4006    167   1703     67524   533.8s
#          0       0         0   0.00%   186632.557078   628186360.0502    99.97%     4224    170   1703     67566   546.7s
#          0       0         0   0.00%   186632.557078   628186360.0502    99.97%     4560    171   1703     67604   565.4s
#          0       0         0   0.00%   186632.557078   628186360.0502    99.97%     4836    172   1703     67618   584.7s
#          0       0         0   0.00%   186632.557078   628186360.0502    99.97%     5099    173   1703     67621   613.4s
#          0       0         0   0.00%   186632.557078   628186360.0502    99.97%     5179    174   1703     67636   634.7s
#  L       0       0         0   0.00%   186632.557078   186831.296804      0.11%     5179    174   1703     67636  1031.7s
#          0       0         0   0.00%   186632.557078   186831.296804      0.11%     5207    176   1703    112669  1037.8s
#
# 38.8% inactive integer columns, restarting
# Model after restart has 176975 rows, 86013 cols (86013 bin., 0 int., 0 impl., 0 cont., 0 dom.fix.), and 602922 nonzeros
#
#          0       0         0   0.00%   186632.557078   186831.296804      0.11%      124      0      0    112669  1047.7s
#          0       0         0   0.00%   186632.557078   186831.296804      0.11%      124     51      5    167934  1138.2s
#          0       0         0   0.00%   186632.557078   186831.296804      0.11%     1148     63      5    168236  1150.3s
#          0       0         0   0.00%   186632.557078   186831.296804      0.11%     1384     68      5    168303  1156.3s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   186632.557078   186831.296804      0.11%     1474     78      5    169087  1167.2s
#          0       0         0   0.00%   186632.557078   186831.296804      0.11%     1670     94      5    169444  1173.7s
#          0       0         0   0.00%   186632.557078   186831.296804      0.11%     1850     99      5    169476  1179.0s
#          0       0         0   0.00%   186632.557078   186831.296804      0.11%     1931    101      5    169510  1186.6s
#
# Symmetry detection completed in 45.9s
# Found 1082 generator(s) and 276 full orbitope(s) acting on 6087 columns
#
#  T       0       0         0   0.00%   186632.557078   186655.388128      0.01%     1931     86     26    169510  1753.8s
#         59       5         1   4.69%   186632.557078   186655.388128      0.01%     1934     86     30    353521  1811.5s
#         64       8         1   5.08%   186632.557078   186655.388128      0.01%     2951    120     32    367356  1838.3s
#         68      10         1   6.64%   186632.557078   186655.388128      0.01%     3954    109     34    380347  1867.1s
#         72      12         1   9.77%   186632.557078   186655.388128      0.01%     4959    119     36    394461  1896.4s
#         79      17         1  10.55%   186632.557078   186655.388128      0.01%     6049    127     38    426168  1961.5s
#         88      24         1  10.60%   186632.557078   186655.388128      0.01%     7051    134     38    446370  2015.7s
#         89      23         1  12.16%   186632.557078   186655.388128      0.01%     9062    137     40    455572  2033.4s
#         90      22         1  15.28%   186632.557078   186655.388128      0.01%    10065    152     40    460559  2045.1s
#         94      24         1  15.30%   186632.557078   186655.388128      0.01%     9723    186     42    490283  2099.7s
#         95      23         1  15.49%   186632.557078   186655.388128      0.01%    10821    204     44    494123  2111.0s
#         97      21         3  19.01%   186632.557078   186655.388128      0.01%    10821    204     44    498071  2118.8s
#        109      31         3  19.01%   186632.557078   186655.388128      0.01%     8984    153     46    519984  2169.6s
#        110      30         3  19.01%   186632.557078   186655.388128      0.01%    10998    192     46    523474  2179.6s
#        113      31         3  25.26%   186632.557078   186655.388128      0.01%     6739    197     46    538067  2211.0s
#        114      30         4  25.27%   186632.557078   186655.388128      0.01%     6739    197     46    542591  2219.2s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#        116      28         5  25.30%   186632.557078   186655.388128      0.01%     7745    214     48    545615  2227.0s
#        120      24         9  26.04%   186632.557078   186655.388128      0.01%     7745    214     50    548077  2233.6s
#        123      21        12  42.44%   186632.557078   186655.388128      0.01%     7748    214     50    560497  2257.1s
#        124      20        13  48.69%   186632.557078   186655.388128      0.01%     7749    214     50    563730  2262.3s
#        126      18        15  55.72%   186632.557078   186655.388128      0.01%     7750    214     50    567724  2269.4s
#        129      15        18  76.04%   186632.557078   186655.388128      0.01%     7751    214     50    573425  2279.6s
#        131      13        20  79.16%   186632.557078   186655.388128      0.01%     7752    214     50    576384  2287.4s
#        133      11        22  85.46%   186633.451446   186655.388128      0.01%     7752    214     50    580725  2295.4s
#        136       8        25  89.76%   186634.459665   186655.388128      0.01%     7752    214     50    585363  2301.5s
#        139       5        28  98.35%   186634.799685   186655.388128      0.01%     7752    214     50    589172  2306.8s
#        141       3        30  99.96%   186636.362253   186655.388128      0.01%     7752    214     50    594732  2314.7s
#        143       1        32  99.98%   186636.554795   186655.388128      0.01%     7752    214     51    599874  2320.4s
#        144       0        33 100.00%   186636.722202   186655.388128      0.01%     7752    214     52    601214  2322.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      186655.388128
#   Dual bound        186636.726027
#   Gap               0.01% (tolerance: 0.01%)
#   P-D integral      977.061821507
#   Solution status   feasible
#                     186655.388128 (objective)
#                     0 (bound viol.)
#                     1.59872115546e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            2322.11
#   Max sub-MIP depth 2
#   Nodes             144
#   Repair LPs        0
#   LP iterations     601214
#                     230802 (strong br.)
#                     54523 (separation)
#                     44891 (heuristics)
#     ✓ P90 optimisation complete   [3039.92s]
#
# [P90 fleet utilisation]
#      vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0    Amb_3seat_1wc          Amb        3      1                  1
# 1    Amb_6seat_1wc          Amb        6      1                  4
# 2    Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_10seat_1wc         Mini       10      1                  0
# 4  Mini_18seat_1wc         Mini       18      1                  0
# 5   Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   1                     1
# 2                            0                   5                     5
# 3                            5                   0                     0
# 4                            5                   0                     0
# 5                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      1               0                   3              0
# 2                      5               0                   4              0
# 3                      0               0                   0              0
# 4                      0               0                   0              0
# 5                      3               0                   0              0
#     ✓ Excel outputs written to outputs\prm_v2\prm_v2_s25_outputs.xlsx   [32.32s]

# %%
results = run_s25_s26_v2(
    run_s25=False,

    run_s26=True,
    s26_start="2026-04-01",
    s26_end="2026-10-31",

    penetration_rates=penetration_rates,
    ssr_mix=ssr_mix,
    stand_actuals=stand_actuals,
    stand_dist=stand_dist,

    penetration_uplift=1.0,

    vehicle_models=VEHICLE_MODELS,
    config=config,

    output_dir="outputs/prm_v2",
    output_xlsx_name="prm_v2_s26_outputs.xlsx",

    run_p100=True,
    run_p90=True,
    run_fleet_report=True,

    max_ev10=5,
    max_ev18=5,
)

# %%
results["output_workbook_path"]
# Out:
# 'outputs\\prm_v2\\prm_v2_s25_outputs.xlsx'

# %%
results["outputs_p100"]["sla_summary"]
# Out:
#    arrival_flights  arrival_breached_flights  arrival_prms  \
# 0             2934                         0          7547
#
#    arrival_prm_breaches  arrival_sla_pct  arrival_target_pct  \
# 0                     0            100.0                98.0
#
#    arrival_meets_target  arrival_sla_target_mins  departure_flights  \
# 0                     1                     20.0               2446
#
#    departure_prms  departure_prm_breaches  departure_sla_pct
# 0            5102                       0              100.0

# %%
results["outputs_p90"]["sla_summary"]
# Out:
#    arrival_flights  arrival_breached_flights  arrival_prms  \
# 0             2934                         0          6801
#
#    arrival_prm_breaches  arrival_sla_pct  arrival_target_pct  \
# 0                     0            100.0                98.0
#
#    arrival_meets_target  arrival_sla_target_mins  departure_flights  \
# 0                     1                     20.0               2446
#
#    departure_prms  departure_prm_breaches  departure_sla_pct
# 0            4751                       0              100.0

# %%
results["fleet_requirements_p100"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 results["fleet_requirements_p100"]
#
# KeyError: 'fleet_requirements_p100'

# %%
results["recommended_p100"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 results["recommended_p100"]
#
# KeyError: 'recommended_p100'

# %%
results["fleet_requirements_p90"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 results["fleet_requirements_p90"]
#
# KeyError: 'fleet_requirements_p90'

# %%
results["recommended_p90"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 results["recommended_p90"]
#
# KeyError: 'recommended_p90'

# %%
from datetime import date, timedelta
from calendar import monthrange
from pathlib import Path

import pandas as pd


MONTHS_TO_RUN = [
    (2025, 6),
    (2025, 7),
    (2025, 8),
    (2025, 9),
    (2025, 10),

    (2026, 4),
    (2026, 5),
    (2026, 6),
    (2026, 7),
    (2026, 8),
    (2026, 9),
    (2026, 10),
]

today = date.today()

monthly_rows = []

monthly_dir = Path(
    "outputs/prm_v2/monthly_summary"
)

monthly_dir.mkdir(
    parents=True,
    exist_ok=True,
)


for year, month in MONTHS_TO_RUN:

    month_start = date(year, month, 1)

    month_end = date(
        year,
        month,
        monthrange(year, month)[1],
    )

    print(
        "\n"
        + "=" * 80
    )

    print(
        f"Running {month_start:%Y-%m}"
    )

    try:

        kwargs = {}

        run_s25 = False
        run_s26 = False

        # --------------------------------------------------
        # Fully historical month
        # --------------------------------------------------

        if month_end < today:

            run_s25 = True

            kwargs["s25_start"] = str(month_start)
            kwargs["s25_end"] = str(month_end)

        # --------------------------------------------------
        # Fully future month
        # --------------------------------------------------

        elif month_start > today:

            run_s26 = True

            kwargs["s26_start"] = str(month_start)
            kwargs["s26_end"] = str(month_end)

        # --------------------------------------------------
        # Current month split
        # --------------------------------------------------

        else:

            yesterday = today - timedelta(days=1)

            run_s25 = True
            run_s26 = True

            kwargs["s25_start"] = str(month_start)
            kwargs["s25_end"] = str(yesterday)

            kwargs["s26_start"] = str(today)
            kwargs["s26_end"] = str(month_end)

        result = run_s25_s26_v2(

            run_s25=run_s25,
            run_s26=run_s26,

            vehicle_models=VEHICLE_MODELS,
            config=config,

            run_p100=True,
            run_p90=True,

            run_fleet_report=True,

            fleet_report_policy="if_needed",
            current_fleet_only_first=True,

            output_dir=str(monthly_dir),
            output_xlsx_name=f"{year}_{month:02d}.xlsx",

            max_ev10=5,
            max_ev18=5,

            **kwargs,
        )

        # ==========================================
        # P100
        # ==========================================

        p100 = result["outputs_p100"]

        p100_fleet = p100["fleet_utilisation"]

        monthly_rows.append(
            {
                "month": month_start.strftime("%Y-%m"),
                "mode": "P100",

                "arrival_sla_pct":
                    float(
                        p100["sla_summary"]
                        .iloc[0]["arrival_sla_pct"]
                    ),

                "peak_amb":
                    int(
                        p100_fleet.loc[
                            p100_fleet["vehicle_type"] == "Amb",
                            "required_for_schedule"
                        ].sum()
                    ),

                "peak_mini":
                    int(
                        p100_fleet.loc[
                            p100_fleet["vehicle_type"] == "Mini",
                            "required_for_schedule"
                        ].sum()
                    ),

                "peak_staff":
                    float(
                        p100["staff_summary"][
                            "staff_required"
                        ].max()
                    ),

                "fleet_expansion_required":
                    int(
                        result.get(
                            "p100_base_check",
                            pd.DataFrame(
                                [{"needs_fleet_expansion": 0}]
                            )
                        ).iloc[0]["needs_fleet_expansion"]
                    ),

                "current_fleet_sufficient":
                    int(
                        result.get(
                            "p100_base_check",
                            pd.DataFrame(
                                [{"current_fleet_sufficient": 1}]
                            )
                        ).iloc[0]["current_fleet_sufficient"]
                    ),

                "recommended_scenario":
                    (
                        result["recommended_p100"]
                        .iloc[0]["scenario"]
                    )
                    if (
                        "recommended_p100" in result
                        and len(result["recommended_p100"]) > 0
                        and "scenario" in result["recommended_p100"].columns
                    )
                    else "CURRENT_FLEET_OK",
            }
        )

        # ==========================================
        # P90
        # ==========================================

        p90 = result["outputs_p90"]

        p90_fleet = p90["fleet_utilisation"]

        monthly_rows.append(
            {
                "month": month_start.strftime("%Y-%m"),
                "mode": "P90",

                "arrival_sla_pct":
                    float(
                        p90["sla_summary"]
                        .iloc[0]["arrival_sla_pct"]
                    ),

                "peak_amb":
                    int(
                        p90_fleet.loc[
                            p90_fleet["vehicle_type"] == "Amb",
                            "required_for_schedule"
                        ].sum()
                    ),

                "peak_mini":
                    int(
                        p90_fleet.loc[
                            p90_fleet["vehicle_type"] == "Mini",
                            "required_for_schedule"
                        ].sum()
                    ),

                "peak_staff":
                    float(
                        p90["staff_summary"][
                            "staff_required"
                        ].max()
                    ),

                "fleet_expansion_required":
                    int(
                        result.get(
                            "p90_base_check",
                            pd.DataFrame(
                                [{"needs_fleet_expansion": 0}]
                            )
                        ).iloc[0]["needs_fleet_expansion"]
                    ),

                "current_fleet_sufficient":
                    int(
                        result.get(
                            "p90_base_check",
                            pd.DataFrame(
                                [{"current_fleet_sufficient": 1}]
                            )
                        ).iloc[0]["current_fleet_sufficient"]
                    ),

                "recommended_scenario":
                    (
                        result["recommended_p90"]
                        .iloc[0]["scenario"]
                    )
                    if (
                        "recommended_p90" in result
                        and len(result["recommended_p90"]) > 0
                        and "scenario" in result["recommended_p90"].columns
                    )
                    else "CURRENT_FLEET_OK",
            }
        )

        # --------------------------------------
        # SAVE AFTER EVERY MONTH
        # --------------------------------------

        pd.DataFrame(
            monthly_rows
        ).to_excel(
            monthly_dir /
            "monthly_summary.xlsx",
            index=False,
        )

        print(
            f"Completed {month_start:%Y-%m}"
        )

    except Exception as e:

        print(
            f"FAILED {month_start:%Y-%m}"
        )

        print(e)

        # Save progress even if a month fails

        pd.DataFrame(
            monthly_rows
        ).to_excel(
            monthly_dir /
            "monthly_summary.xlsx",
            index=False,
        )

        continue


monthly_summary = pd.DataFrame(
    monthly_rows
)

monthly_summary
# Out:
# ================================================================================
# Running 2025-06
#     ✓ S25 ingest complete (16,899 passengers)   [75.28s]
#     ✓ Passenger dataset combined (16,899 passenger rows)   [0.00s]
#     ✓ P100 built (6,692 flights)   [0.25s]
#     P100 demand summary: 16,899 PRMs across 6,692 flights
#     ✓ prepare_model_data started | flights=6,692   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.04s]
#     ✓ ambulift intervals built | flights=6,692 ambulifts=14   [0.56s]
#     ✓ minibus intervals built | minibuses=3   [0.09s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=2,730,272   [1215.31s]
#     ✓ minibus overlaps built | overlaps=255,306   [68.97s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.04s]
#     ✓ prepare_model_data complete | total=1285.03s   [0.00s]
#     ✓ sets built | F=6,692 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=33,460 amb=281,064 mini=40,152   [1.42s]
#     ✓ ambulift overlap constraints built | 2,730,272   [37.88s]
#     ✓ minibus overlap constraints built | 255,306   [1.77s]
#     ✓ build_pyomo_model complete | total=41.25s   [0.17s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,692 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 3427250 rows; 401537 cols; 7218586 nonzeros; 354693 integer variables (354693 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 520977 rows, 142890 cols, 1166103 nonzeros 9s
# 261442 rows, 125876 cols, 927189 nonzeros 43s
# 261442 rows, 125876 cols, 927189 nonzeros 63s
# Presolve reductions: rows 261442(-3165808); columns 125876(-275661); nonzeros 927189(-6291397)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    261442 rows
#    125876 cols (111830 binary, 0 integer, 14046 implied int., 0 continuous, 0 domain fixed)
#    927189 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2494318404.479     Large        0      0      0         0    68.0s
#  R       0       0         0   0.00%   247457.245527   1172246789.466    99.98%        0      0      0     56009   154.7s
#          0       0         0   0.00%   247699.245527   1172246789.466    99.98%      822    189      0     56329   162.6s
#          0       0         0   0.00%   248872.439849   1172246789.466    99.98%     1127    429      0     56765   168.7s
#  C       0       0         0   0.00%   250237.666424   875246929.2968    99.97%     1194    614      0     60867   185.0s
#          0       0         0   0.00%   250543.916424   875246929.2968    99.97%     1372    649      0     60931   192.1s
#          0       0         0   0.00%   250655.738646   875246929.2968    99.97%     1404    700      0     61115   198.4s
#          0       0         0   0.00%   250735.238646   875246929.2968    99.97%     1465    722      0     61162   206.3s
#          0       0         0   0.00%   250747.57198    875246929.2968    99.97%     1514    726      0     61193   211.3s
#          0       0         0   0.00%   250750.529699   875246929.2968    99.97%     1549    731      0     70585   237.6s
#          0       0         0   0.00%   250932.488619   875246929.2968    99.97%     2462    640      0     75480   251.9s
#          0       0         0   0.00%   250948.214741   875246929.2968    99.97%     2637    657      0     79566   268.4s
#          0       0         0   0.00%   250970.972603   875246929.2968    99.97%     3107    665      0    125609   470.5s
#          0       0         0   0.00%   250970.972603   875246929.2968    99.97%     3526    670      0    125856   480.1s
#          0       0         0   0.00%   250970.972603   875246929.2968    99.97%     3651    677      0    126252   487.5s
#          0       0         0   0.00%   250970.972603   875246929.2968    99.97%     3805    676      0    126533   496.6s
#          0       0         0   0.00%   250970.972603   875246929.2968    99.97%     3953    682      0    126851   505.1s
#          0       0         0   0.00%   250970.972603   875246929.2968    99.97%     4167    690      0    126933   519.6s
#          0       0         0   0.00%   250970.972603   875246929.2968    99.97%     4257    694      0    127080   528.1s
#  L       0       0         0   0.00%   250970.972603   251079.296804      0.04%     4257    694      0    127080   702.6s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          1       0         1 100.00%   250970.972603   251079.296804      0.04%     4257    694      0    211976   702.8s
#
# Solving report
#   Status            Optimal
#   Primal bound      251079.296804
#   Dual bound        250970.972603
#   Gap               0.0431% (tolerance: 0.5%)
#   P-D integral      633.95199704
#   Solution status   feasible
#                     251079.296804 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            702.77
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     211976
#                     0 (strong br.)
#                     71071 (separation)
#                     84896 (heuristics)
#     ✓ P100 optimisation complete   [2194.21s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     4
# 2                            0                   9                     6
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      4               0                   0              0
# 2                      6               0                   3              0
# 3                      3               0                   0              0
#
# [P100] Current fleet meets SLA and has no current-fleet gap. Skipping fleet expansion search.
#     ✓ P90 built (6,692 flights)   [0.47s]
#     P90 demand summary: 15,678 PRMs across 6,692 flights
#     ✓ prepare_model_data started | flights=6,692   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.03s]
#     ✓ ambulift intervals built | flights=6,692 ambulifts=14   [0.36s]
#     ✓ minibus intervals built | minibuses=3   [0.08s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=2,621,485   [537.57s]
#     ✓ minibus overlaps built | overlaps=255,696   [38.37s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=576.44s   [0.00s]
#     ✓ sets built | F=6,692 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=33,460 amb=281,064 mini=40,152   [0.28s]
#     ✓ ambulift overlap constraints built | 2,621,485   [23.83s]
#     ✓ minibus overlap constraints built | 255,696   [0.97s]
#     ✓ build_pyomo_model complete | total=25.21s   [0.13s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,692 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 3318853 rows; 401537 cols; 7001792 nonzeros; 354693 integer variables (354693 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 1e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 511984 rows, 142890 cols, 1148117 nonzeros 3s
# 259287 rows, 125876 cols, 913341 nonzeros 19s
# 259287 rows, 125876 cols, 913341 nonzeros 40s
# Presolve reductions: rows 259287(-3059566); columns 125876(-275661); nonzeros 913341(-6088451)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    259287 rows
#    125876 cols (111830 binary, 0 integer, 14046 implied int., 0 continuous, 0 domain fixed)
#    913341 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2574298392.479     Large        0      0      0         0    44.9s
#  R       0       0         0   0.00%   238470.415957   877238393.4658    99.97%        0      0      0     45709   173.1s
#          0       0         0   0.00%   238491.74929    877238393.4658    99.97%      590    118      0     45976   182.5s
#          0       0         0   0.00%   239216.26805    877238393.4658    99.97%      803    333      0     50239   195.8s
#  C       0       0         0   0.00%   239747.76805    576238157.4658    99.96%      964    409      0     50474   202.8s
#          0       0         0   0.00%   239770.079042   576238157.4658    99.96%      992    413      0     60839   235.7s
#          0       0         0   0.00%   239965.273486   576238157.4658    99.96%     1731    433      0     61178   241.9s
#          0       0         0   0.00%   239969.525637   576238157.4658    99.96%     1943    442      0     61802   312.8s
#          0       0         0   0.00%   239970.192304   576238157.4658    99.96%     1973    445      0     61834   324.9s
#          0       0         0   0.00%   239971.666763   576238157.4658    99.96%     2154    449      0     67487   410.5s
#          0       0         0   0.00%   239971.666763   576238157.4658    99.96%     2870    452      0     67595   420.1s
#          0       0         0   0.00%   239972.033227   576238157.4658    99.96%     2900    455      0     79223   456.5s
#          0       0         0   0.00%   239972.033227   576238157.4658    99.96%     3902    462      0     79930   462.6s
#          0       0         0   0.00%   239979.972603   576238157.4658    99.96%     3905    381      0    121744   589.5s
#          0       0         0   0.00%   239979.972603   576238157.4658    99.96%     4910    395      0    121997   594.7s
#          0       0         0   0.00%   239979.972603   576238157.4658    99.96%     5134    406      0    122147   603.2s
#          0       0         0   0.00%   239979.972603   576238157.4658    99.96%     5217    411      0    122680   609.0s
#          0       0         0   0.00%   239979.972603   576238157.4658    99.96%     5405    423      0    123523   617.2s
#          0       0         0   0.00%   239979.972603   576238157.4658    99.96%     5556    428      0    123677   623.9s
#          0       0         0   0.00%   239979.972603   576238157.4658    99.96%     5669    420      0    124167   630.5s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   239979.972603   576238157.4658    99.96%     5825    425      0    124263   639.1s
#          0       0         0   0.00%   239979.972603   576238157.4658    99.96%     5986    439      0    124985   644.9s
#  L       0       0         0   0.00%   239979.972603   240116.296804      0.06%     5986    439      0    124985   821.4s
#          1       0         1 100.00%   239979.972603   240116.296804      0.06%     5648    439      0    193571   821.6s
#
# Solving report
#   Status            Optimal
#   Primal bound      240116.296804
#   Dual bound        239979.972603
#   Gap               0.0568% (tolerance: 0.5%)
#   P-D integral      775.786020221
#   Solution status   feasible
#                     240116.296804 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            821.59
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     193571
#                     0 (strong br.)
#                     79276 (separation)
#                     68586 (heuristics)
#     ✓ P90 optimisation complete   [1513.97s]
#
# [P90 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     3
# 2                            0                   9                     7
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      3               0                   1              0
# 2                      7               0                   2              0
# 3                      3               0                   0              0
#
# [P90] Current fleet meets SLA and has no current-fleet gap. Skipping fleet expansion search.
#     ✓ Excel outputs written to outputs\prm_v2\monthly_summary\2025_06.xlsx   [15.84s]
# Completed 2025-06
#
# ================================================================================
# Running 2025-07
#     ✓ S25 ingest complete (16,371 passengers)   [80.28s]
#     ✓ Passenger dataset combined (16,371 passenger rows)   [0.00s]
#     ✓ P100 built (6,983 flights)   [0.14s]
#     P100 demand summary: 16,371 PRMs across 6,983 flights
#     ✓ prepare_model_data started | flights=6,983   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.03s]
#     ✓ ambulift intervals built | flights=6,983 ambulifts=14   [0.28s]
#     ✓ minibus intervals built | minibuses=3   [0.06s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=2,796,715   [563.59s]
#     ✓ minibus overlaps built | overlaps=268,896   [43.83s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.03s]
#     ✓ prepare_model_data complete | total=607.82s   [0.00s]
#     ✓ sets built | F=6,983 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=34,915 amb=293,286 mini=41,898   [0.79s]
#     ✓ ambulift overlap constraints built | 2,796,715   [18.09s]
#     ✓ minibus overlap constraints built | 268,896   [0.79s]
#     ✓ build_pyomo_model complete | total=19.78s   [0.11s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,983 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 3526489 rows; 418997 cols; 7432508 nonzeros; 370116 integer variables (370116 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 491160 rows, 142626 cols, 1105151 nonzeros 6s
# 255329 rows, 125677 cols, 881058 nonzeros 20s
# 255329 rows, 125677 cols, 881058 nonzeros 42s
# Presolve reductions: rows 255329(-3271160); columns 125677(-293320); nonzeros 881058(-6551450)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    255329 rows
#    125677 cols (111568 binary, 0 integer, 14109 implied int., 0 continuous, 0 domain fixed)
#    881058 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2469322297.479     Large        0      0      0         0    47.3s
#  R       0       0         0   0.00%   253249.864378   1151252729.297    99.98%        0      0      0     42027   188.1s
#          0       0         0   0.00%   253315.231044   1151252729.297    99.98%     1072    188      0     42841   197.5s
#          0       0         0   0.00%   254956.361492   1151252729.297    99.98%     1452    515      0     44073   204.0s
#  C       0       0         0   0.00%   255670.472603   333252690.2968    99.92%     1579    601      0     44569   210.6s
#          0       0         0   0.00%   255670.472603   333252690.2968    99.92%     1653    605      0     45125   221.4s
#          0       0         0   0.00%   255704.139269   333252690.2968    99.92%     1759    616      0     45434   228.0s
#          0       0         0   0.00%   255740.472603   333252690.2968    99.92%     1819    622      0     45588   235.6s
#          0       0         0   0.00%   255740.472603   333252690.2968    99.92%     2015    627      0     45760   244.5s
#          0       0         0   0.00%   255740.472603   333252690.2968    99.92%     2055    634      0     47340   252.3s
#          0       0         0   0.00%   255757.972603   333252690.2968    99.92%     2297    640      0     47361   269.2s
#          0       0         0   0.00%   255762.305936   333252690.2968    99.92%     2349    645      0     47508   284.8s
#          0       0         0   0.00%   255762.305936   333252690.2968    99.92%     2456    650      0     47689   308.8s
#          0       0         0   0.00%   255762.305936   333252690.2968    99.92%     2717    568      0     47782   331.0s
#          0       0         0   0.00%   255822.305936   333252690.2968    99.92%     2839    575      0     47832   371.1s
#          0       0         0   0.00%   255868.639269   333252690.2968    99.92%     3055    580      0     47877   398.6s
#          0       0         0   0.00%   255868.639269   333252690.2968    99.92%     3183    582      0     47915   420.4s
#          0       0         0   0.00%   255868.639269   333252690.2968    99.92%     3264    584      0     47941   428.7s
#          0       0         0   0.00%   255868.639269   333252690.2968    99.92%     3337    586      0     47952   438.5s
#  L       0       0         0   0.00%   255868.639269   256015.296804      0.06%     3337    586      0     47952   676.2s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          1       0         1 100.00%   255868.639269   256015.296804      0.06%     3337    586      0     71381   676.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      256015.296804
#   Dual bound        255868.639269
#   Gap               0.0573% (tolerance: 0.5%)
#   P-D integral      628.218759693
#   Solution status   feasible
#                     256015.296804 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            676.38
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     71381
#                     0 (strong br.)
#                     5925 (separation)
#                     23429 (heuristics)
#     ✓ P100 optimisation complete   [1389.83s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     4
# 2                            0                   9                     6
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      4               0                   0              0
# 2                      6               0                   3              0
# 3                      3               0                   0              0
#
# [P100] Current fleet meets SLA and has no current-fleet gap. Skipping fleet expansion search.
#     ✓ P90 built (6,983 flights)   [0.64s]
#     P90 demand summary: 14,973 PRMs across 6,983 flights
#     ✓ prepare_model_data started | flights=6,983   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.06s]
#     ✓ ambulift intervals built | flights=6,983 ambulifts=14   [0.35s]
#     ✓ minibus intervals built | minibuses=3   [0.07s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=2,676,808   [678.18s]
#     ✓ minibus overlaps built | overlaps=268,752   [65.53s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.05s]
#     ✓ prepare_model_data complete | total=744.26s   [0.00s]
#     ✓ sets built | F=6,983 AMB=14 MINI=3   [0.04s]
#     ✓ variables built | x=34,915 amb=293,286 mini=41,898   [0.49s]
#     ✓ ambulift overlap constraints built | 2,676,808   [50.44s]
#     ✓ minibus overlap constraints built | 268,752   [2.99s]
#     ✓ build_pyomo_model complete | total=54.11s   [0.15s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,983 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 3406438 rows; 418997 cols; 7192406 nonzeros; 370116 integer variables (370116 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 9e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 482327 rows, 142626 cols, 1087485 nonzeros 7s
# 253234 rows, 125677 cols, 867732 nonzeros 33s
# 253234 rows, 125677 cols, 867737 nonzeros 80s
# Presolve reductions: rows 253234(-3153204); columns 125677(-293320); nonzeros 867737(-6324669)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    253234 rows
#    125677 cols (111568 binary, 0 integer, 14109 implied int., 0 continuous, 0 domain fixed)
#    867737 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2520298913.479     Large        0      0      0         0    87.0s
#  R       0       0         0   0.00%   244798.907697   861244760.2968    99.97%        0      0      0     33779   242.9s
#          0       0         0   0.00%   244798.907697   861244760.2968    99.97%     1111     59      0     34097   252.6s
#          0       0         0   0.00%   244953.26484    861244760.2968    99.97%     1207    118      0     35704   261.4s
#          0       0         0   0.00%   245349.76484    861244760.2968    99.97%     1439    209      0     35982   331.0s
#          0       0         0   0.00%   245417.26484    861244760.2968    99.97%     1620    214   2935     36008   409.5s
#          0       0         0   0.00%   245430.26484    861244760.2968    99.97%     1675    216   2935     36036   429.5s
#          0       0         0   0.00%   245430.26484    861244760.2968    99.97%     1730    217   2935     36040   442.9s
#          0       0         0   0.00%   245430.26484    861244760.2968    99.97%     1742    219   2935     36443   452.4s
#          0       0         0   0.00%   245430.26484    861244760.2968    99.97%     1789    221   2935     36702   466.3s
#          0       0         0   0.00%   245430.26484    861244760.2968    99.97%     1879    223   2935     36831   488.8s
#          0       0         0   0.00%   245430.26484    861244760.2968    99.97%     1960    225   2935     36920   515.5s
#          0       0         0   0.00%   245430.26484    861244760.2968    99.97%     2021    227   2935     36960   522.8s
#          0       0         0   0.00%   245430.26484    861244760.2968    99.97%     2079    229   2935     37425   530.9s
#          0       0         0   0.00%   245430.26484    861244760.2968    99.97%     2205    231   2935     37431   556.7s
#  L       0       0         0   0.00%   245430.26484    246188.050228      0.31%     2205    231   2935     37431   701.2s
#          1       0         1 100.00%   245430.26484    246188.050228      0.31%     2205    231   2935     71010   701.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      246188.050228
#   Dual bound        245430.26484
#   Gap               0.308% (tolerance: 0.5%)
#   P-D integral      613.39713666
#   Solution status   feasible
#                     246188.050228 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            701.37
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     71010
#                     0 (strong br.)
#                     3652 (separation)
#                     33579 (heuristics)
#     ✓ P90 optimisation complete   [1627.83s]
#
# [P90 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   3                     2
# 2                            0                   7                     4
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      2               0                   2              0
# 2                      4               0                   5              0
# 3                      3               0                   0              0
#
# [P90] Current fleet meets SLA and has no current-fleet gap. Skipping fleet expansion search.
#     ✓ Excel outputs written to outputs\prm_v2\monthly_summary\2025_07.xlsx   [13.34s]
# Completed 2025-07
#
# ================================================================================
# Running 2025-08
#     ✓ S25 ingest complete (15,945 passengers)   [93.88s]
#     ✓ Passenger dataset combined (15,945 passenger rows)   [0.00s]
#     ✓ P100 built (6,814 flights)   [0.14s]
#     P100 demand summary: 15,945 PRMs across 6,814 flights
#     ✓ prepare_model_data started | flights=6,814   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.03s]
#     ✓ ambulift intervals built | flights=6,814 ambulifts=14   [0.27s]
#     ✓ minibus intervals built | minibuses=3   [0.07s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=2,654,014   [389.83s]
#     ✓ minibus overlaps built | overlaps=255,576   [30.94s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=421.16s   [0.00s]
#     ✓ sets built | F=6,814 AMB=14 MINI=3   [0.01s]
#     ✓ variables built | x=34,070 amb=286,188 mini=40,884   [0.24s]
#     ✓ ambulift overlap constraints built | 2,654,014   [28.36s]
#     ✓ minibus overlap constraints built | 255,576   [0.79s]
#     ✓ build_pyomo_model complete | total=29.49s   [0.10s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,814 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 3359314 rows; 408857 cols; 7089046 nonzeros; 361159 integer variables (361159 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 468718 rows, 138081 cols, 1056393 nonzeros 2s
# 246696 rows, 121890 cols, 850068 nonzeros 15s
# 246696 rows, 121890 cols, 850068 nonzeros 36s
# Presolve reductions: rows 246696(-3112618); columns 121890(-286967); nonzeros 850068(-6238978)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    246696 rows
#    121890 cols (108140 binary, 0 integer, 13750 implied int., 0 continuous, 0 domain fixed)
#    850068 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2479312789.479     Large        0      0      0         0    40.2s
#  R       0       0         0   0.00%   1244527.915858  984243991.4658    99.87%        0      0      0     46798   178.2s
#          0       0         0   0.00%   1244650.375454  984243991.4658    99.87%     1255    161      0     47159   186.3s
#          0       0         0   0.00%   1244742.628708  984243991.4658    99.87%     1403    316      0     51604   202.4s
#          0       0         0   0.00%   1245816.841705  984243991.4658    99.87%     1641    532      0     52732   210.4s
#          0       0         0   0.00%   1245886.508371  984243991.4658    99.87%     1666    542   1386     53098   219.2s
#          0       0         0   0.00%   1246053.758371  984243991.4658    99.87%     1965    579   1386     53660   334.2s
#          0       0         0   0.00%   1246180.175038  984243991.4658    99.87%     2297    599   1386     54500   468.8s
#          0       0         0   0.00%   1246196.508371  984243991.4658    99.87%     2352    619   1386     56070   478.3s
#          0       0         0   0.00%   1246287.792998  984243991.4658    99.87%     2404    624   1386     59617   493.6s
#          0       0         0   0.00%   1246319.028919  984243991.4658    99.87%     2675    630   1386     62385   506.4s
#          0       0         0   0.00%   1246319.028919  984243991.4658    99.87%     2774    634   1386     62498   513.5s
#          0       0         0   0.00%   1246319.028919  984243991.4658    99.87%     2797    636   1386     62641   521.8s
#          0       0         0   0.00%   1246319.028919  984243991.4658    99.87%     2941    556   1386     63166   531.1s
#          0       0         0   0.00%   1246319.028919  984243991.4658    99.87%     3169    559   1386     63288   539.3s
#          0       0         0   0.00%   1246319.504566  984243991.4658    99.87%     3347    562   1386     63989   548.0s
#          0       0         0   0.00%   1246320.297311  984243991.4658    99.87%     3399    566   1386     67168   562.8s
#          0       0         0   0.00%   1246321.370566  984243991.4658    99.87%     3572    569   1386     70402   573.6s
#          0       0         0   0.00%   1246322.358447  984243991.4658    99.87%     3694    561   1386     75075   588.3s
#          0       0         0   0.00%   1246322.358447  984243991.4658    99.87%     3886    571   1386     75397   595.5s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   1246322.516996  984243991.4658    99.87%     3960    575   1386     76550   603.9s
#          0       0         0   0.00%   1246323.234639  984243991.4658    99.87%     4047    579   1386     78706   612.1s
#          0       0         0   0.00%   1246323.234639  984243991.4658    99.87%     4191    587   1386     78886   617.9s
#          0       0         0   0.00%   1246323.284707  984243991.4658    99.87%     4514    588   1386     79419   629.2s
#          0       0         0   0.00%   1246323.48498   984243991.4658    99.87%     4565    593   1386     80938   637.0s
#          0       0         0   0.00%   1246323.635184  984243991.4658    99.87%     4676    597   1386     83409   645.5s
#  L       0       0         0   0.00%   1246323.635184  1246495.296804     0.01%     4676    597   1386     83409   862.9s
#          1       0         1 100.00%   1246323.635184  1246495.296804     0.01%     4130    597   1386    119997   863.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      1246495.2968
#   Dual bound        1246323.63927
#   Gap               0.0138% (tolerance: 0.5%)
#   P-D integral      821.597590883
#   Solution status   feasible
#                     1246495.2968 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            863.09
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     119997
#                     0 (strong br.)
#                     36611 (separation)
#                     36588 (heuristics)
#     ✓ P100 optimisation complete   [1385.87s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     4
# 2                            0                   9                     6
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      4               0                   0              0
# 2                      6               0                   3              0
# 3                      3               0                   0              0
#
# [P100] Running fleet expansion scenario: +1 future copy per future model
#     ✓ prepare_model_data started | flights=6,814   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.03s]
#     ✓ ambulift intervals built | flights=6,814 ambulifts=14   [0.30s]
#     ✓ minibus intervals built | minibuses=5   [0.07s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=2,654,014   [469.15s]
#     ✓ minibus overlaps built | overlaps=425,960   [54.81s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.01s]
#     ✓ prepare_model_data complete | total=524.38s   [0.00s]
#     ✓ sets built | F=6,814 AMB=14 MINI=5   [0.00s]
#     ✓ variables built | x=34,070 amb=286,188 mini=68,140   [0.19s]
#     ✓ ambulift overlap constraints built | 2,654,014   [18.61s]
#     ✓ minibus overlap constraints built | 425,960   [1.54s]
#     ✓ build_pyomo_model complete | total=20.48s   [0.13s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,814 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 3611468 rows; 436117 cols; 7647866 nonzeros; 388419 integer variables (388419 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 589326 rows, 156185 cols, 1319491 nonzeros 4s
# 293356 rows, 135522 cols, 981437 nonzeros 18s
# 293356 rows, 135522 cols, 981437 nonzeros 37s
# Presolve reductions: rows 293356(-3318112); columns 135522(-300595); nonzeros 981437(-6666429)
#
# Solving MIP model with:
#    293356 rows
#    135522 cols (121772 binary, 0 integer, 13750 implied int., 0 continuous, 0 domain fixed)
#    981437 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2436678089.936     Large        0      0      0         0    42.4s
#  R       0       0         0   0.00%   423812.889269   899423842.5251    99.95%        0      0      0     34473   201.2s
#          0       0         0   0.00%   423812.889269   899423842.5251    99.95%      478     89      0     34664   219.1s
#          0       0         0   0.00%   423911.590563   899423842.5251    99.95%      616    184      0     38515   240.5s
#          0       0         0   0.00%   423958.340563   899423842.5251    99.95%      875    213   1086     38584   251.2s
#          0       0         0   0.00%   423959.101598   899423842.5251    99.95%      877    219   1086     39345   261.9s
#          0       0         0   0.00%   423990.243151   899423842.5251    99.95%      907    224   1086     41112   270.1s
#          0       0         0   0.00%   424001.993151   899423842.5251    99.95%     1019    228   1086     42580   277.6s
#          0       0         0   0.00%   424027.707436   899423842.5251    99.95%     1251    233   1086     42625   286.4s
#          0       0         0   0.00%   424035.54077    899423842.5251    99.95%     1515    237   1086     42648   337.3s
#          0       0         0   0.00%   424043.374103   899423842.5251    99.95%     1717    240   1086     42662   387.2s
#          0       0         0   0.00%   424044.832436   899423842.5251    99.95%     1750    242   1086     42678   394.6s
#          0       0         0   0.00%   424045.207436   899423842.5251    99.95%     1784    245   1086     42720   401.7s
#          0       0         0   0.00%   424045.207436   899423842.5251    99.95%     1836    246   1086     42721   409.3s
#          0       0         0   0.00%   424045.207436   899423842.5251    99.95%     1904    223   1086     42746   423.3s
#          0       0         0   0.00%   424050.207436   899423842.5251    99.95%     1964    226   1086     44034   435.3s
#          0       0         0   0.00%   424055.915199   899423842.5251    99.95%     2154    234   1086     44745   441.1s
#          0       0         0   0.00%   424055.915199   899423842.5251    99.95%     2395    231   1086     44976   446.3s
#  L       0       0         0   0.00%   424055.915199   424155.525114      0.02%     2395    231   1086     44976   548.0s
#          1       0         1 100.00%   424055.915199   424155.525114      0.02%     2395    231   1086     80345   548.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      424155.525114
#   Dual bound        424055.915199
#   Gap               0.0235% (tolerance: 0.5%)
#   P-D integral      505.058016932
#   Solution status   feasible
#                     424155.525114 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            548.21
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     80345
#                     0 (strong br.)
#                     10503 (separation)
#                     35369 (heuristics)
# [P100] Stopping fleet expansion: scenario +1 meets SLA and has no shortfall.
#     ✓ P100 fleet expansion search complete   [1181.89s]
#     ✓ P90 built (6,814 flights)   [0.48s]
#     P90 demand summary: 14,710 PRMs across 6,814 flights
#     ✓ prepare_model_data started | flights=6,814   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.03s]
#     ✓ ambulift intervals built | flights=6,814 ambulifts=14   [0.29s]
#     ✓ minibus intervals built | minibuses=3   [0.06s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=2,579,686   [450.77s]
#     ✓ minibus overlaps built | overlaps=255,441   [31.97s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=483.15s   [0.00s]
#     ✓ sets built | F=6,814 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=34,070 amb=286,188 mini=40,884   [0.19s]
#     ✓ ambulift overlap constraints built | 2,579,686   [22.92s]
#     ✓ minibus overlap constraints built | 255,441   [0.75s]
#     ✓ build_pyomo_model complete | total=25.07s   [1.21s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,814 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 3284851 rows; 408857 cols; 6940120 nonzeros; 361159 integer variables (361159 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 8e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 463827 rows, 138081 cols, 1046611 nonzeros 2s
# 245504 rows, 121890 cols, 842478 nonzeros 15s
# 245504 rows, 121890 cols, 842478 nonzeros 36s
# Presolve reductions: rows 245504(-3039347); columns 121890(-286967); nonzeros 842478(-6097642)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    245504 rows
#    121890 cols (108140 binary, 0 integer, 13750 implied int., 0 continuous, 0 domain fixed)
#    842478 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2460292278.479     Large        0      0      0         0    41.0s
#  R       0       0         0   0.00%   1238695.445967  779238827.2968    99.84%        0      0      0     36690   163.8s
#          0       0         0   0.00%   1238706.7793    779238827.2968    99.84%     1176     41      0     37964   210.6s
#          0       0         0   0.00%   1238905.557078  779238827.2968    99.84%     1314    112      0     38144   218.9s
#          0       0         0   0.00%   1238983.557078  779238827.2968    99.84%     1439    141   2016     38343   237.7s
#          0       0         0   0.00%   1238983.557078  779238827.2968    99.84%     1474    142   2016     38362   247.2s
#          0       0         0   0.00%   1238983.557078  779238827.2968    99.84%     1584    143   2016     38369   256.2s
#          0       0         0   0.00%   1238983.557078  779238827.2968    99.84%     1639    144   2016     38381   264.8s
#          0       0         0   0.00%   1238983.557078  779238827.2968    99.84%     1676    145   2016     38435   273.0s
#          0       0         0   0.00%   1238983.557078  779238827.2968    99.84%     1748    146   2016     38514   286.4s
#          0       0         0   0.00%   1238983.557078  779238827.2968    99.84%     1817    149   2016     38534   310.4s
#          0       0         0   0.00%   1238983.557078  779238827.2968    99.84%     2033    152   2016     38584   348.4s
#  L       0       0         0   0.00%   1238983.557078  1239086.296804     0.01%     2033    152   2016     38584   702.4s
#          1       0         1 100.00%   1238983.557078  1239086.296804     0.01%     2033    152   2016     63855   702.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      1239086.2968
#   Dual bound        1238983.55708
#   Gap               0.00829% (tolerance: 0.5%)
#   P-D integral      660.185913928
#   Solution status   feasible
#                     1239086.2968 (objective)
# ...
#          0       0         0   0.00%   419508.785388   859419543.5251    99.95%     1571     49    882     33970   252.5s
#          0       0         0   0.00%   419508.785388   859419543.5251    99.95%     1870     50    882     33978   292.4s
#          0       0         0   0.00%   419508.785388   859419543.5251    99.95%     2067     51    882     33988   316.9s
#          0       0         0   0.00%   419508.785388   859419543.5251    99.95%     2271     52    882     33992   343.7s
#          0       0         0   0.00%   419508.785388   859419543.5251    99.95%     2421     54    882     34010   369.4s
#          0       0         0   0.00%   419508.785388   859419543.5251    99.95%     2665     55    882     34023   398.4s
#          0       0         0   0.00%   419508.785388   859419543.5251    99.95%     3044     56    882     34029   437.7s
#          0       0         0   0.00%   419508.785388   859419543.5251    99.95%     3348     57    882     34044   464.3s
#          0       0         0   0.00%   419508.785388   859419543.5251    99.95%     3656     58    882     34046   512.4s
#  L       0       0         0   0.00%   419508.785388   419611.525114      0.02%     3656     58    882     34046   870.0s
#          1       0         1 100.00%   419508.785388   419611.525114      0.02%     3656     58    882     66941   870.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      419611.525114
#   Dual bound        419508.785388
#   Gap               0.0245% (tolerance: 0.5%)
#   P-D integral      817.772646915
#   Solution status   feasible
#                     419611.525114 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            870.13
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     66941
#                     0 (strong br.)
#                     721 (separation)
#                     32895 (heuristics)
# [P90] Stopping fleet expansion: scenario +1 meets SLA and has no shortfall.
#     ✓ P90 fleet expansion search complete   [1518.14s]
#     ✓ Excel outputs written to outputs\prm_v2\monthly_summary\2025_08.xlsx   [14.76s]
# Completed 2025-08
#
# ================================================================================
# Running 2025-09
# FAILED 2025-09
# (pyodbc.Error) ('FA004', "[FA004] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Failed to authenticate the user 'jamie_douglas@edinburghairport.com' in Active Directory (Authentication option is 'ActiveDirectoryIntegrated').\r\nError code 0xCAA2000C; state 10\r\nAADSTS50076: Due to a configuration change made by your administrator, or because you moved to a new location, you must use multi-factor authentication to access '022907d3-0f1b-48f7-badc-1ba6abab6d66'. Trace ID: 05dc9b1b-e9ef-4dd7-8657-1d28961c4600 Correlation ID: b3eaef5a-8431-4731-94b5-8c9cface86b7 Timestamp: 2026-07-14 10:51:31Z (0) (SQLDriverConnect); [FA004] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Failed to authenticate the user 'jamie_douglas@edinburghairport.com' in Active Directory (Authentication option is 'ActiveDirectoryIntegrated').\r\nError code 0xCAA2000C; state 10\r\nAADSTS50076: Due to a configuration change made by your administrator, or because you moved to a new location, you must use multi-factor authentication to access '022907d3-0f1b-48f7-badc-1ba6abab6d66'. Trace ID: 05dc9b1b-e9ef-4dd7-8657-1d28961c4600 Correlation ID: b3eaef5a-8431-4731-94b5-8c9cface86b7 Timestamp: 2026-07-14 10:51:31Z (0)")
# (Background on this error at: https://sqlalche.me/e/20/dbapi)
#
# ================================================================================
# Running 2025-10
# FAILED 2025-10
# (pyodbc.Error) ('FA004', "[FA004] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Failed to authenticate the user 'jamie_douglas@edinburghairport.com' in Active Directory (Authentication option is 'ActiveDirectoryIntegrated').\r\nError code 0xCAA2000C; state 10\r\nAADSTS50076: Due to a configuration change made by your administrator, or because you moved to a new location, you must use multi-factor authentication to access '022907d3-0f1b-48f7-badc-1ba6abab6d66'. Trace ID: 1c1bd6be-d637-4c70-b5a2-9e3445753200 Correlation ID: a8bf0d39-f2bb-4a4c-a1bb-dc4ba379c2bf Timestamp: 2026-07-14 10:51:33Z (0) (SQLDriverConnect); [FA004] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Failed to authenticate the user 'jamie_douglas@edinburghairport.com' in Active Directory (Authentication option is 'ActiveDirectoryIntegrated').\r\nError code 0xCAA2000C; state 10\r\nAADSTS50076: Due to a configuration change made by your administrator, or because you moved to a new location, you must use multi-factor authentication to access '022907d3-0f1b-48f7-badc-1ba6abab6d66'. Trace ID: 1c1bd6be-d637-4c70-b5a2-9e3445753200 Correlation ID: a8bf0d39-f2bb-4a4c-a1bb-dc4ba379c2bf Timestamp: 2026-07-14 10:51:33Z (0)")
# (Background on this error at: https://sqlalche.me/e/20/dbapi)
#
# ================================================================================
# Running 2026-04
# FAILED 2026-04
# (pyodbc.Error) ('FA004', "[FA004] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Failed to authenticate the user 'jamie_douglas@edinburghairport.com' in Active Directory (Authentication option is 'ActiveDirectoryIntegrated').\r\nError code 0xCAA2000C; state 10\r\nAADSTS50076: Due to a configuration change made by your administrator, or because you moved to a new location, you must use multi-factor authentication to access '022907d3-0f1b-48f7-badc-1ba6abab6d66'. Trace ID: 05dc9b1b-e9ef-4dd7-8657-1d28961c4600 Correlation ID: b3eaef5a-8431-4731-94b5-8c9cface86b7 Timestamp: 2026-07-14 10:51:31Z (0) (SQLDriverConnect); [FA004] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Failed to authenticate the user 'jamie_douglas@edinburghairport.com' in Active Directory (Authentication option is 'ActiveDirectoryIntegrated').\r\nError code 0xCAA2000C; state 10\r\nAADSTS50076: Due to a configuration change made by your administrator, or because you moved to a new location, you must use multi-factor authentication to access '022907d3-0f1b-48f7-badc-1ba6abab6d66'. Trace ID: 05dc9b1b-e9ef-4dd7-8657-1d28961c4600 Correlation ID: b3eaef5a-8431-4731-94b5-8c9cface86b7 Timestamp: 2026-07-14 10:51:31Z (0)")
# (Background on this error at: https://sqlalche.me/e/20/dbapi)
#
# ================================================================================
# Running 2026-05
# FAILED 2026-05
# (pyodbc.Error) ('FA004', "[FA004] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Failed to authenticate the user 'jamie_douglas@edinburghairport.com' in Active Directory (Authentication option is 'ActiveDirectoryIntegrated').\r\nError code 0xCAA2000C; state 10\r\nAADSTS50076: Due to a configuration change made by your administrator, or because you moved to a new location, you must use multi-factor authentication to access '022907d3-0f1b-48f7-badc-1ba6abab6d66'. Trace ID: 05dc9b1b-e9ef-4dd7-8657-1d28961c4600 Correlation ID: b3eaef5a-8431-4731-94b5-8c9cface86b7 Timestamp: 2026-07-14 10:51:31Z (0) (SQLDriverConnect); [FA004] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Failed to authenticate the user 'jamie_douglas@edinburghairport.com' in Active Directory (Authentication option is 'ActiveDirectoryIntegrated').\r\nError code 0xCAA2000C; state 10\r\nAADSTS50076: Due to a configuration change made by your administrator, or because you moved to a new location, you must use multi-factor authentication to access '022907d3-0f1b-48f7-badc-1ba6abab6d66'. Trace ID: 05dc9b1b-e9ef-4dd7-8657-1d28961c4600 Correlation ID: b3eaef5a-8431-4731-94b5-8c9cface86b7 Timestamp: 2026-07-14 10:51:31Z (0)")
# (Background on this error at: https://sqlalche.me/e/20/dbapi)
#
# ================================================================================
# Running 2026-06
# FAILED 2026-06
# (pyodbc.Error) ('FA004', "[FA004] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Failed to authenticate the user 'jamie_douglas@edinburghairport.com' in Active Directory (Authentication option is 'ActiveDirectoryIntegrated').\r\nError code 0xCAA2000C; state 10\r\nAADSTS50076: Due to a configuration change made by your administrator, or because you moved to a new location, you must use multi-factor authentication to access '022907d3-0f1b-48f7-badc-1ba6abab6d66'. Trace ID: 05dc9b1b-e9ef-4dd7-8657-1d28961c4600 Correlation ID: b3eaef5a-8431-4731-94b5-8c9cface86b7 Timestamp: 2026-07-14 10:51:31Z (0) (SQLDriverConnect); [FA004] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Failed to authenticate the user 'jamie_douglas@edinburghairport.com' in Active Directory (Authentication option is 'ActiveDirectoryIntegrated').\r\nError code 0xCAA2000C; state 10\r\nAADSTS50076: Due to a configuration change made by your administrator, or because you moved to a new location, you must use multi-factor authentication to access '022907d3-0f1b-48f7-badc-1ba6abab6d66'. Trace ID: 05dc9b1b-e9ef-4dd7-8657-1d28961c4600 Correlation ID: b3eaef5a-8431-4731-94b5-8c9cface86b7 Timestamp: 2026-07-14 10:51:31Z (0)")
# (Background on this error at: https://sqlalche.me/e/20/dbapi)
#
# ================================================================================
# Running 2026-07
# FAILED 2026-07
# (pyodbc.Error) ('FA004', "[FA004] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Failed to authenticate the user 'jamie_douglas@edinburghairport.com' in Active Directory (Authentication option is 'ActiveDirectoryIntegrated').\r\nError code 0xCAA2000C; state 10\r\nAADSTS50076: Due to a configuration change made by your administrator, or because you moved to a new location, you must use multi-factor authentication to access '022907d3-0f1b-48f7-badc-1ba6abab6d66'. Trace ID: 05dc9b1b-e9ef-4dd7-8657-1d28961c4600 Correlation ID: b3eaef5a-8431-4731-94b5-8c9cface86b7 Timestamp: 2026-07-14 10:51:31Z (0) (SQLDriverConnect); [FA004] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Failed to authenticate the user 'jamie_douglas@edinburghairport.com' in Active Directory (Authentication option is 'ActiveDirectoryIntegrated').\r\nError code 0xCAA2000C; state 10\r\nAADSTS50076: Due to a configuration change made by your administrator, or because you moved to a new location, you must use multi-factor authentication to access '022907d3-0f1b-48f7-badc-1ba6abab6d66'. Trace ID: 05dc9b1b-e9ef-4dd7-8657-1d28961c4600 Correlation ID: b3eaef5a-8431-4731-94b5-8c9cface86b7 Timestamp: 2026-07-14 10:51:31Z (0)")
# (Background on this error at: https://sqlalche.me/e/20/dbapi)
#
# ================================================================================
# Running 2026-08
#
# [V2] Building assumptions using historical data through 2026-07-13
# FAILED 2026-08
# (pyodbc.Error) ('FA004', "[FA004] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Failed to authenticate the user 'jamie_douglas@edinburghairport.com' in Active Directory (Authentication option is 'ActiveDirectoryIntegrated').\r\nError code 0xCAA2000C; state 10\r\nAADSTS50076: Due to a configuration change made by your administrator, or because you moved to a new location, you must use multi-factor authentication to access '022907d3-0f1b-48f7-badc-1ba6abab6d66'. Trace ID: 05dc9b1b-e9ef-4dd7-8657-1d28961c4600 Correlation ID: b3eaef5a-8431-4731-94b5-8c9cface86b7 Timestamp: 2026-07-14 10:51:31Z (0) (SQLDriverConnect); [FA004] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Failed to authenticate the user 'jamie_douglas@edinburghairport.com' in Active Directory (Authentication option is 'ActiveDirectoryIntegrated').\r\nError code 0xCAA2000C; state 10\r\nAADSTS50076: Due to a configuration change made by your administrator, or because you moved to a new location, you must use multi-factor authentication to access '022907d3-0f1b-48f7-badc-1ba6abab6d66'. Trace ID: 05dc9b1b-e9ef-4dd7-8657-1d28961c4600 Correlation ID: b3eaef5a-8431-4731-94b5-8c9cface86b7 Timestamp: 2026-07-14 10:51:31Z (0)")
# (Background on this error at: https://sqlalche.me/e/20/dbapi)
#
# ================================================================================
# Running 2026-09
#
# [V2] Building assumptions using historical data through 2026-07-13
# FAILED 2026-09
# (pyodbc.Error) ('FA004', "[FA004] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Failed to authenticate the user 'jamie_douglas@edinburghairport.com' in Active Directory (Authentication option is 'ActiveDirectoryIntegrated').\r\nError code 0xCAA2000C; state 10\r\nAADSTS50076: Due to a configuration change made by your administrator, or because you moved to a new location, you must use multi-factor authentication to access '022907d3-0f1b-48f7-badc-1ba6abab6d66'. Trace ID: 05dc9b1b-e9ef-4dd7-8657-1d28961c4600 Correlation ID: b3eaef5a-8431-4731-94b5-8c9cface86b7 Timestamp: 2026-07-14 10:51:31Z (0) (SQLDriverConnect); [FA004] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Failed to authenticate the user 'jamie_douglas@edinburghairport.com' in Active Directory (Authentication option is 'ActiveDirectoryIntegrated').\r\nError code 0xCAA2000C; state 10\r\nAADSTS50076: Due to a configuration change made by your administrator, or because you moved to a new location, you must use multi-factor authentication to access '022907d3-0f1b-48f7-badc-1ba6abab6d66'. Trace ID: 05dc9b1b-e9ef-4dd7-8657-1d28961c4600 Correlation ID: b3eaef5a-8431-4731-94b5-8c9cface86b7 Timestamp: 2026-07-14 10:51:31Z (0)")
# (Background on this error at: https://sqlalche.me/e/20/dbapi)
#
# ================================================================================
# Running 2026-10
#
# [V2] Building assumptions using historical data through 2026-07-13
# FAILED 2026-10
# (pyodbc.Error) ('FA004', "[FA004] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Failed to authenticate the user 'jamie_douglas@edinburghairport.com' in Active Directory (Authentication option is 'ActiveDirectoryIntegrated').\r\nError code 0xCAA2000C; state 10\r\nAADSTS50076: Due to a configuration change made by your administrator, or because you moved to a new location, you must use multi-factor authentication to access '022907d3-0f1b-48f7-badc-1ba6abab6d66'. Trace ID: 05dc9b1b-e9ef-4dd7-8657-1d28961c4600 Correlation ID: b3eaef5a-8431-4731-94b5-8c9cface86b7 Timestamp: 2026-07-14 10:51:31Z (0) (SQLDriverConnect); [FA004] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Failed to authenticate the user 'jamie_douglas@edinburghairport.com' in Active Directory (Authentication option is 'ActiveDirectoryIntegrated').\r\nError code 0xCAA2000C; state 10\r\nAADSTS50076: Due to a configuration change made by your administrator, or because you moved to a new location, you must use multi-factor authentication to access '022907d3-0f1b-48f7-badc-1ba6abab6d66'. Trace ID: 05dc9b1b-e9ef-4dd7-8657-1d28961c4600 Correlation ID: b3eaef5a-8431-4731-94b5-8c9cface86b7 Timestamp: 2026-07-14 10:51:31Z (0)")
# (Background on this error at: https://sqlalche.me/e/20/dbapi)
#      month  mode  arrival_sla_pct  peak_amb  peak_mini  peak_staff  \
# 0  2025-06  P100            100.0        11          3        64.0
# 1  2025-06   P90            100.0        11          3        47.0
# 2  2025-07  P100            100.0        11          3        37.0
# 3  2025-07   P90            100.0         7          3        30.0
# 4  2025-08  P100            100.0        11          3        38.0
# 5  2025-08   P90            100.0        10          3        33.0
#
#    fleet_expansion_required  current_fleet_sufficient recommended_scenario
# 0                         0                         1     CURRENT_FLEET_OK
# 1                         0                         1     CURRENT_FLEET_OK
# 2                         0                         1     CURRENT_FLEET_OK
# 3                         0                         1     CURRENT_FLEET_OK
# 4                         1                         0   p100_future_plus_1
# 5                         1                         0    p90_future_plus_1

# %%
from datetime import date, timedelta
from calendar import monthrange
from pathlib import Path

import pandas as pd


MONTHS_TO_RUN = [
    (2025, 9),
    (2025, 10),

    (2026, 4),
    (2026, 5),
    (2026, 6),
    (2026, 7),
    (2026, 8),
    (2026, 9),
    (2026, 10),
]

today = date.today()

monthly_rows = []

monthly_dir = Path(
    "outputs/prm_v2/monthly_summary"
)

monthly_dir.mkdir(
    parents=True,
    exist_ok=True,
)


for year, month in MONTHS_TO_RUN:

    month_start = date(year, month, 1)

    month_end = date(
        year,
        month,
        monthrange(year, month)[1],
    )

    print(
        "\n"
        + "=" * 80
    )

    print(
        f"Running {month_start:%Y-%m}"
    )

    try:

        kwargs = {}

        run_s25 = False
        run_s26 = False

        # --------------------------------------------------
        # Fully historical month
        # --------------------------------------------------

        if month_end < today:

            run_s25 = True

            kwargs["s25_start"] = str(month_start)
            kwargs["s25_end"] = str(month_end)

        # --------------------------------------------------
        # Fully future month
        # --------------------------------------------------

        elif month_start > today:

            run_s26 = True

            kwargs["s26_start"] = str(month_start)
            kwargs["s26_end"] = str(month_end)

        # --------------------------------------------------
        # Current month split
        # --------------------------------------------------

        else:

            yesterday = today - timedelta(days=1)

            run_s25 = True
            run_s26 = True

            kwargs["s25_start"] = str(month_start)
            kwargs["s25_end"] = str(yesterday)

            kwargs["s26_start"] = str(today)
            kwargs["s26_end"] = str(month_end)

        result = run_s25_s26_v2(

            run_s25=run_s25,
            run_s26=run_s26,

            vehicle_models=VEHICLE_MODELS,
            config=config,

            run_p100=True,
            run_p90=True,

            run_fleet_report=True,

            fleet_report_policy="if_needed",
            current_fleet_only_first=True,

            output_dir=str(monthly_dir),
            output_xlsx_name=f"{year}_{month:02d}.xlsx",

            max_ev10=5,
            max_ev18=5,

            **kwargs,
        )

        # ==========================================
        # P100
        # ==========================================

        p100 = result["outputs_p100"]

        p100_fleet = p100["fleet_utilisation"]

        monthly_rows.append(
            {
                "month": month_start.strftime("%Y-%m"),
                "mode": "P100",

                "arrival_sla_pct":
                    float(
                        p100["sla_summary"]
                        .iloc[0]["arrival_sla_pct"]
                    ),

                "peak_amb":
                    int(
                        p100_fleet.loc[
                            p100_fleet["vehicle_type"] == "Amb",
                            "required_for_schedule"
                        ].sum()
                    ),

                "peak_mini":
                    int(
                        p100_fleet.loc[
                            p100_fleet["vehicle_type"] == "Mini",
                            "required_for_schedule"
                        ].sum()
                    ),

                "peak_staff":
                    float(
                        p100["staff_summary"][
                            "staff_required"
                        ].max()
                    ),

                "fleet_expansion_required":
                    int(
                        result.get(
                            "p100_base_check",
                            pd.DataFrame(
                                [{"needs_fleet_expansion": 0}]
                            )
                        ).iloc[0]["needs_fleet_expansion"]
                    ),

                "current_fleet_sufficient":
                    int(
                        result.get(
                            "p100_base_check",
                            pd.DataFrame(
                                [{"current_fleet_sufficient": 1}]
                            )
                        ).iloc[0]["current_fleet_sufficient"]
                    ),

                "recommended_scenario":
                    (
                        result["recommended_p100"]
                        .iloc[0]["scenario"]
                    )
                    if (
                        "recommended_p100" in result
                        and len(result["recommended_p100"]) > 0
                        and "scenario" in result["recommended_p100"].columns
                    )
                    else "CURRENT_FLEET_OK",
            }
        )

        # ==========================================
        # P90
        # ==========================================

        p90 = result["outputs_p90"]

        p90_fleet = p90["fleet_utilisation"]

        monthly_rows.append(
            {
                "month": month_start.strftime("%Y-%m"),
                "mode": "P90",

                "arrival_sla_pct":
                    float(
                        p90["sla_summary"]
                        .iloc[0]["arrival_sla_pct"]
                    ),

                "peak_amb":
                    int(
                        p90_fleet.loc[
                            p90_fleet["vehicle_type"] == "Amb",
                            "required_for_schedule"
                        ].sum()
                    ),

                "peak_mini":
                    int(
                        p90_fleet.loc[
                            p90_fleet["vehicle_type"] == "Mini",
                            "required_for_schedule"
                        ].sum()
                    ),

                "peak_staff":
                    float(
                        p90["staff_summary"][
                            "staff_required"
                        ].max()
                    ),

                "fleet_expansion_required":
                    int(
                        result.get(
                            "p90_base_check",
                            pd.DataFrame(
                                [{"needs_fleet_expansion": 0}]
                            )
                        ).iloc[0]["needs_fleet_expansion"]
                    ),

                "current_fleet_sufficient":
                    int(
                        result.get(
                            "p90_base_check",
                            pd.DataFrame(
                                [{"current_fleet_sufficient": 1}]
                            )
                        ).iloc[0]["current_fleet_sufficient"]
                    ),

                "recommended_scenario":
                    (
                        result["recommended_p90"]
                        .iloc[0]["scenario"]
                    )
                    if (
                        "recommended_p90" in result
                        and len(result["recommended_p90"]) > 0
                        and "scenario" in result["recommended_p90"].columns
                    )
                    else "CURRENT_FLEET_OK",
            }
        )

        # --------------------------------------
        # SAVE AFTER EVERY MONTH
        # --------------------------------------

        pd.DataFrame(
            monthly_rows
        ).to_excel(
            monthly_dir /
            "monthly_summary.xlsx",
            index=False,
        )

        print(
            f"Completed {month_start:%Y-%m}"
        )

    except Exception as e:

        print(
            f"FAILED {month_start:%Y-%m}"
        )

        print(e)

        # Save progress even if a month fails

        pd.DataFrame(
            monthly_rows
        ).to_excel(
            monthly_dir /
            "monthly_summary.xlsx",
            index=False,
        )

        continue


monthly_summary = pd.DataFrame(
    monthly_rows
)

monthly_summary
# Out:
# ================================================================================
# Running 2025-09
#     ✓ S25 ingest complete (18,866 passengers)   [122.13s]
#     ✓ Passenger dataset combined (18,866 passenger rows)   [0.00s]
#     ✓ P100 built (6,933 flights)   [0.69s]
#     P100 demand summary: 18,866 PRMs across 6,933 flights
#     ✓ prepare_model_data started | flights=6,933   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.13s]
#     ✓ ambulift intervals built | flights=6,933 ambulifts=14   [0.98s]
#     ✓ minibus intervals built | minibuses=3   [0.17s]
#     ✓ staff intervals built   [0.05s]
#     ✓ ambulift overlaps built | overlaps=3,060,178   [1163.29s]
#     ✓ minibus overlaps built | overlaps=283,077   [34.80s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1199.42s   [0.00s]
#     ✓ sets built | F=6,933 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=34,665 amb=291,186 mini=41,598   [0.56s]
#     ✓ ambulift overlap constraints built | 3,060,178   [16.94s]
#     ✓ minibus overlap constraints built | 283,077   [0.80s]
#     ✓ build_pyomo_model complete | total=18.37s   [0.07s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,933 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 3800833 rows; 415997 cols; 7978994 nonzeros; 367466 integer variables (367466 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 582358 rows, 148225 cols, 1293719 nonzeros 4s
# 274250 rows, 130494 cols, 1005175 nonzeros 21s
# 274250 rows, 130494 cols, 1005175 nonzeros 44s
# Presolve reductions: rows 274250(-3526583); columns 130494(-285503); nonzeros 1005175(-6973819)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    274250 rows
#    130494 cols (115875 binary, 0 integer, 14619 implied int., 0 continuous, 0 domain fixed)
#    1005175 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2560350358.479     Large        0      0      0         0    48.7s
#  R       0       0         0   0.00%   268114.456062   1318267167.297    99.98%        0      0      0     35739   136.3s
#          0       0         0   0.00%   268170.039395   1318267167.297    99.98%      994    231      0     36454   145.4s
#          0       0         0   0.00%   270423.054622   1318267167.297    99.98%     1428    609      0     44009   173.2s
#          0       0         0   0.00%   270567.287955   1318267167.297    99.98%     1677    629      0     46093   182.0s
#  C       0       0         0   0.00%   271765.320635   1207267079.297    99.98%     1745    797      0     53991   216.5s
#          0       0         0   0.00%   272585.372222   1207267079.297    99.98%     2145    886      0     55024   221.7s
#          0       0         0   0.00%   272716.11883    1207267079.297    99.98%     2236    916      0     56080   227.4s
#          0       0         0   0.00%   272787.166286   1207267079.297    99.98%     2319    942      0     57024   233.6s
#          0       0         0   0.00%   272798.821461   1207267079.297    99.98%     2410    950      0     59927   242.8s
#          0       0         0   0.00%   272809.054795   1207267079.297    99.98%     2662    959      0     60910   263.7s
#          0       0         0   0.00%   272809.054795   1207267079.297    99.98%     2752    836      0     62373   270.4s
#          0       0         0   0.00%   272873.803653   1207267079.297    99.98%     3107    852      0     64038   282.3s
#  L       0       0         0   0.00%   272873.803653   273117.050228      0.09%     3339    833      0     64289   433.4s
#          1       0         1 100.00%   272873.803653   273117.050228      0.09%     3339    833      0    109004   433.6s
#
# Solving report
#   Status            Optimal
#   Primal bound      273117.050228
#   Dual bound        272873.803653
#   Gap               0.0891% (tolerance: 0.5%)
#   P-D integral      384.196179639
#   Solution status   feasible
#                     273117.050228 (objective)
#                     0 (bound viol.)
#                     2.22044604925e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            433.58
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     109004
#                     0 (strong br.)
#                     28550 (separation)
#                     44715 (heuristics)
#     ✓ P100 optimisation complete   [1743.80s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   2                     2
# 2                            0                   8                     8
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      2               0                   2              0
# 2                      8               0                   1              0
# 3                      3               0                   0              0
#
# [P100] Current fleet meets SLA and has no current-fleet gap. Skipping fleet expansion search.
#     ✓ P90 built (6,933 flights)   [0.45s]
#     P90 demand summary: 17,554 PRMs across 6,933 flights
#     ✓ prepare_model_data started | flights=6,933   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.03s]
#     ✓ ambulift intervals built | flights=6,933 ambulifts=14   [0.31s]
#     ✓ minibus intervals built | minibuses=3   [0.06s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=2,955,568   [450.52s]
#     ✓ minibus overlaps built | overlaps=283,134   [31.63s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.01s]
#     ✓ prepare_model_data complete | total=482.57s   [0.00s]
#     ✓ sets built | F=6,933 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=34,665 amb=291,186 mini=41,598   [0.19s]
#     ✓ ambulift overlap constraints built | 2,955,568   [22.65s]
#     ✓ minibus overlap constraints built | 283,134   [1.04s]
#     ✓ build_pyomo_model complete | total=24.05s   [0.17s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,933 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 3696280 rows; 415997 cols; 7769888 nonzeros; 367466 integer variables (367466 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 1e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 572194 rows, 148225 cols, 1273391 nonzeros 4s
# 272361 rows, 130494 cols, 990144 nonzeros 22s
# 272361 rows, 130494 cols, 990144 nonzeros 47s
# Presolve reductions: rows 272361(-3423919); columns 130494(-285503); nonzeros 990144(-6779744)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    272361 rows
#    130494 cols (115875 binary, 0 integer, 14619 implied int., 0 continuous, 0 domain fixed)
#    990144 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2593329375.653     Large        0      0      0         0    52.0s
#  R       0       0         0   0.00%   258886.562948   954258407.2968    99.97%        0      0      0     42007   164.3s
#          0       0         0   0.00%   258886.562948   954258407.2968    99.97%     1098     66      0     42175   174.2s
#          0       0         0   0.00%   259134.376114   954258407.2968    99.97%     1264    267      0     45690   189.6s
#          0       0         0   0.00%   259868.882758   954258407.2968    99.97%     1472    405      0     57213   221.5s
#          0       0         0   0.00%   260799.299425   954258407.2968    99.97%     1843    484   1877     57706   228.0s
#          0       0         0   0.00%   261020.986628   954258407.2968    99.97%     1907    526   1877     71145   270.6s
#          0       0         0   0.00%   261174.673842   954258407.2968    99.97%     2913    542   1877     72579   278.3s
#          0       0         0   0.00%   261192.388128   954258407.2968    99.97%     3109    556   1877     74423   285.2s
#          0       0         0   0.00%   261192.388128   954258407.2968    99.97%     3217    559   1877     77899   296.8s
#          0       0         0   0.00%   261192.388128   954258407.2968    99.97%     3408    563   1877     78217   302.4s
#          0       0         0   0.00%   261192.388128   954258407.2968    99.97%     3558    566   1877     79036   315.1s
#  L       0       0         0   0.00%   261192.388128   261276.296804      0.03%     3558    566   1877     79036   664.4s
#          1       0         1 100.00%   261192.388128   261276.296804      0.03%     3558    566   1877    151196   664.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      261276.296804
#   Dual bound        261192.388128
#   Gap               0.0321% (tolerance: 0.5%)
#   P-D integral      611.807816863
#   Solution status   feasible
#                     261276.296804 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            664.51
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     151196
#                     0 (strong br.)
#                     37029 (separation)
#                     72160 (heuristics)
#     ✓ P90 optimisation complete   [1260.84s]
#
# [P90 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     3
# 2                            0                   9                     8
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      3               0                   1              0
# 2                      8               0                   1              0
# 3                      3               0                   0              0
#
# [P90] Current fleet meets SLA and has no current-fleet gap. Skipping fleet expansion search.
#     ✓ Excel outputs written to outputs\prm_v2\monthly_summary\2025_09.xlsx   [18.96s]
# Completed 2025-09
#
# ================================================================================
# Running 2025-10
#     ✓ S25 ingest complete (17,480 passengers)   [80.70s]
#     ✓ Passenger dataset combined (17,480 passenger rows)   [0.00s]
#     ✓ P100 built (6,565 flights)   [0.14s]
#     P100 demand summary: 17,480 PRMs across 6,565 flights
#     ✓ prepare_model_data started | flights=6,565   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.03s]
#     ✓ ambulift intervals built | flights=6,565 ambulifts=14   [0.32s]
#     ✓ minibus intervals built | minibuses=3   [0.05s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=2,680,562   [391.47s]
#     ✓ minibus overlaps built | overlaps=245,583   [27.56s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.01s]
#     ✓ prepare_model_data complete | total=419.45s   [0.00s]
#     ✓ sets built | F=6,565 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=32,825 amb=275,730 mini=39,390   [0.58s]
#     ✓ ambulift overlap constraints built | 2,680,562   [14.74s]
#     ✓ minibus overlap constraints built | 245,583   [0.71s]
#     ✓ build_pyomo_model complete | total=16.13s   [0.09s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,565 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 3359435 rows; 393917 cols; 7076044 nonzeros; 347962 integer variables (347962 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 513897 rows, 138657 cols, 1148252 nonzeros 2s
# 252916 rows, 122191 cols, 907344 nonzeros 15s
# 252916 rows, 122191 cols, 907344 nonzeros 32s
# Presolve reductions: rows 252916(-3106519); columns 122191(-271726); nonzeros 907344(-6168700)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    252916 rows
#    122191 cols (108500 binary, 0 integer, 13691 implied int., 0 continuous, 0 domain fixed)
#    907344 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2407323321.479     Large        0      0      0         0    36.9s
#  R       0       0         0   0.00%   247529.86158    935246741.2192    99.97%        0      0      0     35038    88.2s
#          0       0         0   0.00%   247880.076782   935246741.2192    99.97%      982    344      0     35662    93.6s
#  C       0       0         0   0.00%   250015.81669    467246716.2968    99.95%     1182    640      0     39768   103.6s
#          0       0         0   0.00%   250411.21669    467246716.2968    99.95%     1398    674      0     40096   109.8s
#          0       0         0   0.00%   250411.21669    467246716.2968    99.95%     1401    675      0     40223   115.3s
#          0       0         0   0.00%   250724.288913   467246716.2968    99.95%     1403    736      0     40433   121.3s
#          0       0         0   0.00%   250889.802036   467246716.2968    99.95%     1471    807      0     46716   135.9s
#          0       0         0   0.00%   251129.440925   467246716.2968    99.95%     2070    719      0     46825   168.0s
#          0       0         0   0.00%   251158.893306   467246716.2968    99.95%     2246    726      0     46847   198.7s
#          0       0         0   0.00%   251196.073176   467246716.2968    99.95%     2302    748      0     61344   224.7s
#          0       0         0   0.00%   251255.721461   467246716.2968    99.95%     2837    764      0     93630   349.9s
#          0       0         0   0.00%   251269.071461   467246716.2968    99.95%     3971    760      0     93700   384.3s
#          0       0         0   0.00%   251295.721461   467246716.2968    99.95%     4162    775      0     94132   391.2s
#          0       0         0   0.00%   251295.721461   467246716.2968    99.95%     4247    780      0     94456   396.8s
#          0       0         0   0.00%   251295.721461   467246716.2968    99.95%     4442    762      0     94708   402.6s
#          0       0         0   0.00%   251295.721461   467246716.2968    99.95%     4652    774      0     95179   408.7s
#  L       0       0         0   0.00%   251295.721461   251576.465753      0.11%     4726    782      0     95456   537.9s
#          1       0         1 100.00%   251295.721461   251576.465753      0.11%     4480    782      0    127333   538.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      251576.465753
#   Dual bound        251295.721461
#   Gap               0.112% (tolerance: 0.5%)
#   P-D integral      500.43136343
#   Solution status   feasible
#                     251576.465753 (objective)
#                     0 (bound viol.)
#                     2.22044604925e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            538.05
#   Max sub-MIP depth 3
#   Nodes             1
#   Repair LPs        0
#   LP iterations     127333
#                     0 (strong br.)
#                     60418 (separation)
#                     31877 (heuristics)
#     ✓ P100 optimisation complete   [1040.39s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   3                     2
# 2                            0                   8                     8
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      2               0                   2              0
# 2                      8               0                   1              0
# 3                      3               0                   0              0
#
# [P100] Current fleet meets SLA and has no current-fleet gap. Skipping fleet expansion search.
#     ✓ P90 built (6,565 flights)   [0.55s]
#     P90 demand summary: 16,345 PRMs across 6,565 flights
#     ✓ prepare_model_data started | flights=6,565   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.02s]
#     ✓ ambulift intervals built | flights=6,565 ambulifts=14   [0.26s]
#     ✓ minibus intervals built | minibuses=3   [0.06s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=2,578,903   [529.46s]
#     ✓ minibus overlaps built | overlaps=245,997   [38.84s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=568.67s   [0.00s]
#     ✓ sets built | F=6,565 AMB=14 MINI=3   [0.01s]
#     ✓ variables built | x=32,825 amb=275,730 mini=39,390   [0.29s]
#     ✓ ambulift overlap constraints built | 2,578,903   [27.33s]
#     ✓ minibus overlap constraints built | 245,997   [0.95s]
#     ✓ build_pyomo_model complete | total=28.69s   [0.12s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,565 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 3258190 rows; 393917 cols; 6873552 nonzeros; 347962 integer variables (347962 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 1e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 505461 rows, 138656 cols, 1131377 nonzeros 3s
# 251214 rows, 122190 cols, 895196 nonzeros 22s
# 251214 rows, 122190 cols, 895196 nonzeros 52s
# Presolve reductions: rows 251214(-3006976); columns 122190(-271727); nonzeros 895196(-5978356)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    251214 rows
#    122190 cols (108500 binary, 0 integer, 13690 implied int., 0 continuous, 0 domain fixed)
#    895196 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2456304833.479     Large        0      0      0         0    58.0s
#  R       0       0         0   0.00%   1238881.153867  979238876.2968    99.87%        0      0      0     52419   184.5s
#          0       0         0   0.00%   1238973.623564  979238876.2968    99.87%     1273    151      0     53046   195.3s
#          0       0         0   0.00%   1240019.420091  979238876.2968    99.87%     1544    413      0     54058   202.8s
#          0       0         0   0.00%   1240726.253425  979238876.2968    99.87%     1602    493   1706     54591   218.5s
#          0       0         0   0.00%   1240851.253425  979238876.2968    99.87%     1850    505   1706     54773   282.1s
#          0       0         0   0.00%   1240865.253425  979238876.2968    99.87%     1885    510   1706     55028   297.8s
#          0       0         0   0.00%   1240911.680365  979238876.2968    99.87%     1988    515   1706     58340   335.8s
#          0       0         0   0.00%   1240925.680365  979238876.2968    99.87%     2364    520   1706     58688   352.7s
#          0       0         0   0.00%   1240925.680365  979238876.2968    99.87%     2451    521   1706     58689   373.3s
#          0       0         0   0.00%   1240925.680365  979238876.2968    99.87%     2477    523   1706     58728   391.0s
#          0       0         0   0.00%   1240925.680365  979238876.2968    99.87%     2571    524   1706     58731   409.4s
#          0       0         0   0.00%   1240925.680365  979238876.2968    99.87%     2648    526   1706     59151   429.7s
#          0       0         0   0.00%   1240931.388128  979238876.2968    99.87%     2872    429   1706     60145   450.0s
#          0       0         0   0.00%   1240931.388128  979238876.2968    99.87%     3016    433   1706     60427   456.0s
#          0       0         0   0.00%   1240931.388128  979238876.2968    99.87%     3300    444   1706     61308   475.5s
#          0       0         0   0.00%   1240931.388128  979238876.2968    99.87%     3373    440   1706     61426   481.5s
#          0       0         0   0.00%   1240931.388128  979238876.2968    99.87%     3446    446   1706     61619   487.4s
#          0       0         0   0.00%   1240931.388128  979238876.2968    99.87%     3621    450   1706     61682   499.7s
#  L       0       0         0   0.00%   1240931.388128  1241090.296804     0.01%     3621    450   1706     61682   822.6s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          1       0         1 100.00%   1240931.388128  1241090.296804     0.01%     3621    450   1706     87561   822.8s
#
# Solving report
#   Status            Optimal
#   Primal bound      1241090.2968
#   Dual bound        1240931.38813
#   Gap               0.0128% (tolerance: 0.5%)
#   P-D integral      763.329032194
#   Solution status   feasible
#                     1241090.2968 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            822.76
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     87561
#                     0 (strong br.)
#                     9263 (separation)
#                     25879 (heuristics)
#     ✓ P90 optimisation complete   [1510.49s]
#
# [P90 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     4
# 2                            0                   9                     7
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      4               0                   0              0
# 2                      7               0                   2              0
# 3                      3               0                   0              0
#
# [P90] Running fleet expansion scenario: +1 future copy per future model
#     ✓ prepare_model_data started | flights=6,565   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.03s]
#     ✓ ambulift intervals built | flights=6,565 ambulifts=14   [0.33s]
#     ✓ minibus intervals built | minibuses=5   [0.07s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=2,578,903   [507.83s]
#     ✓ minibus overlaps built | overlaps=409,995   [67.07s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=575.37s   [0.00s]
#     ✓ sets built | F=6,565 AMB=14 MINI=5   [0.01s]
#     ✓ variables built | x=32,825 amb=275,730 mini=65,650   [0.26s]
#     ✓ ambulift overlap constraints built | 2,578,903   [26.42s]
#     ✓ minibus overlap constraints built | 409,995   [2.94s]
#     ✓ build_pyomo_model complete | total=29.76s   [0.13s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,565 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 3500970 rows; 420181 cols; 7411632 nonzeros; 374226 integer variables (374226 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 625125 rows, 156324 cols, 1392571 nonzeros 4s
# 296411 rows, 135324 cols, 1022639 nonzeros 26s
# 296411 rows, 135324 cols, 1022639 nonzeros 61s
# Presolve reductions: rows 296411(-3204559); columns 135324(-284857); nonzeros 1022639(-6388993)
#
# Solving MIP model with:
#    296411 rows
#    135324 cols (121634 binary, 0 integer, 13690 implied int., 0 continuous, 0 domain fixed)
#    1022639 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2441487481.881     Large        0      0      0         0    68.2s
#  R       0       0         0   0.00%   419078.534247   736419133.5251    99.94%        0      0      0     44877   310.4s
#          0       0         0   0.00%   419078.534247   736419133.5251    99.94%      883     82      0     45951   332.9s
#          0       0         0   0.00%   419081.312024   736419133.5251    99.94%     1029    146      0     46078   338.4s
#          0       0         0   0.00%   419126.312024   736419133.5251    99.94%     1084    198      0     46237   343.6s
#          0       0         0   0.00%   419138.625913   736419133.5251    99.94%     1440    233      0     46456   425.5s
#  C       0       0         0   0.00%   419151.534247   557601779.9269    99.92%     1534    289      0     46554   435.9s
#          0       0         0   0.00%   419170.86758    557601779.9269    99.92%     1589    305      0     46601   441.2s
#          0       0         0   0.00%   419198.200913   557601779.9269    99.92%     1681    315      0     47216   451.0s
#          0       0         0   0.00%   419221.700913   557601779.9269    99.92%     1765    325      0     47308   461.0s
#          0       0         0   0.00%   419230.200913   557601779.9269    99.92%     1868    327      0     47313   479.1s
#          0       0         0   0.00%   419230.200913   557601779.9269    99.92%     1914    328      0     47540   499.0s
#          0       0         0   0.00%   419230.200913   557601779.9269    99.92%     2033    331      0     47571   527.6s
#          0       0         0   0.00%   419230.200913   557601779.9269    99.92%     2278    333      0     47586   577.8s
#          0       0         0   0.00%   419230.200913   557601779.9269    99.92%     2385    293      0     47606   601.6s
#  L       0       0         0   0.00%   419230.200913   419321.525114      0.02%     2385    293      0     47606   890.0s
#          1       0         1 100.00%   419230.200913   419321.525114      0.02%     2385    293      0     80550   890.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      419321.525114
#   Dual bound        419230.200913
#   Gap               0.0218% (tolerance: 0.5%)
#   P-D integral      820.598979674
#   Solution status   feasible
#                     419321.525114 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            890.18
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     80550
#                     0 (strong br.)
#                     2729 (separation)
#                     32944 (heuristics)
# [P90] Stopping fleet expansion: scenario +1 meets SLA and has no shortfall.
#     ✓ P90 fleet expansion search complete   [1612.19s]
#     ✓ Excel outputs written to outputs\prm_v2\monthly_summary\2025_10.xlsx   [23.52s]
# Completed 2025-10
#
# ================================================================================
# Running 2026-04
#     ✓ S25 ingest complete (14,386 passengers)   [113.70s]
#     ✓ Passenger dataset combined (14,386 passenger rows)   [0.00s]
#     ✓ P100 built (5,857 flights)   [0.15s]
#     P100 demand summary: 14,386 PRMs across 5,857 flights
#     ✓ prepare_model_data started | flights=5,857   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.03s]
#     ✓ ambulift intervals built | flights=5,857 ambulifts=14   [0.25s]
#     ✓ minibus intervals built | minibuses=3   [0.07s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=2,089,844   [328.29s]
#     ✓ minibus overlaps built | overlaps=196,080   [23.02s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=351.68s   [0.00s]
#     ✓ sets built | F=5,857 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=29,285 amb=245,994 mini=35,142   [0.16s]
#     ✓ ambulift overlap constraints built | 2,089,844   [18.83s]
#     ✓ minibus overlap constraints built | 196,080   [0.64s]
#     ✓ build_pyomo_model complete | total=19.72s   [0.08s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=5,857 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 2672486 rows; 351437 cols; 5663372 nonzeros; 310438 integer variables (310438 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 400410 rows, 122978 cols, 907222 nonzeros 2s
# 217357 rows, 108310 cols, 742140 nonzeros 12s
# 217357 rows, 108310 cols, 742140 nonzeros 28s
# Presolve reductions: rows 217357(-2455129); columns 108310(-243127); nonzeros 742140(-4921232)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    217357 rows
#    108310 cols (96254 binary, 0 integer, 12056 implied int., 0 continuous, 0 domain fixed)
#    742140 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2306267745.479     Large        0      0      0         0    32.7s
#  R       0       0         0   0.00%   1712543.264938  1083211869.297    99.84%        0      0      0     25509   123.5s
#          0       0         0   0.00%   2212701.493369  1083211869.297    99.80%     1336    186      0     25820   131.8s
#          0       0         0   0.00%   2214713.890411  1083211869.297    99.80%     1775    588      0     26720   138.8s
#          0       0         0   0.00%   2214752.390411  1083211869.297    99.80%     1818    602   1607     26978   146.6s
#          0       0         0   0.00%   2214907.590411  1083211869.297    99.80%     2354    626   1607     27381   180.8s
#          0       0         0   0.00%   2214915.257078  1083211869.297    99.80%     2405    631   1607     27922   192.3s
#          0       0         0   0.00%   2214933.457078  1083211869.297    99.80%     2485    638   1607     28008   200.8s
#          0       0         0   0.00%   2215094.507078  1083211869.297    99.80%     2583    648   1607     28093   210.4s
#          0       0         0   0.00%   2215124.257078  1083211869.297    99.80%     2631    653   1607     28129   219.1s
#          0       0         0   0.00%   2215124.757078  1083211869.297    99.80%     2727    656   1607     28222   229.5s
#          0       0         0   0.00%   2215124.757078  1083211869.297    99.80%     2795    658   1607     28278   237.2s
#  L       0       0         0   0.00%   2215124.757078  2216044.881279     0.04%     2795    658   1607     28278   381.3s
#          1       0         1 100.00%   2215124.757078  2216044.881279     0.04%     2795    658   1607     52385   381.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      2216044.88128
#   Dual bound        2215124.75799
#   Gap               0.0415% (tolerance: 0.5%)
#   P-D integral      347.773706563
#   Solution status   feasible
#                     2216044.88128 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            381.41
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     52385
#                     0 (strong br.)
#                     2769 (separation)
#                     24107 (heuristics)
#     ✓ P100 optimisation complete   [812.25s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   3                     3
# 2                            0                   9                     5
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      3               0                   1              0
# 2                      5               0                   4              0
# 3                      3               0                   0              0
#
# [P100] Running fleet expansion scenario: +1 future copy per future model
#     ✓ prepare_model_data started | flights=5,857   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.02s]
#     ✓ ambulift intervals built | flights=5,857 ambulifts=14   [0.26s]
#     ✓ minibus intervals built | minibuses=5   [0.06s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=2,089,844   [312.62s]
#     ✓ minibus overlaps built | overlaps=326,800   [37.27s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.01s]
#     ✓ prepare_model_data complete | total=350.26s   [0.00s]
#     ✓ sets built | F=5,857 AMB=14 MINI=5   [0.00s]
#     ✓ variables built | x=29,285 amb=245,994 mini=58,570   [0.17s]
#     ✓ ambulift overlap constraints built | 2,089,844   [16.00s]
#     ✓ minibus overlap constraints built | 326,800   [0.95s]
#     ✓ build_pyomo_model complete | total=17.21s   [0.09s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=5,857 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 2873492 rows; 374869 cols; 6112240 nonzeros; 333870 integer variables (333870 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 500094 rows, 138710 cols, 1125814 nonzeros 3s
# 257414 rows, 120028 cols, 853761 nonzeros 15s
# 257414 rows, 120028 cols, 853761 nonzeros 33s
# Presolve reductions: rows 257414(-2616078); columns 120028(-254841); nonzeros 853761(-5258479)
#
# Solving MIP model with:
#    257414 rows
#    120028 cols (107972 binary, 0 integer, 12056 implied int., 0 continuous, 0 domain fixed)
#    853761 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2178633045.936     Large        0      0      0         0    37.5s
#  R       0       0         0   0.00%   391857.582358   872391887.5251    99.96%        0      0      0     24099   124.2s
#          0       0         0   0.00%   391867.978612   872391887.5251    99.96%     1135     93      0     25666   135.2s
#          0       0         0   0.00%   391867.978612   872391887.5251    99.96%     1288    158      0     25802   142.7s
#          0       0         0   0.00%   392068.481359   872391887.5251    99.96%     1400    248      0     26108   155.9s
#          0       0         0   0.00%   392088.737769   872391887.5251    99.96%     1456    265   1310     26130   161.5s
#          0       0         0   0.00%   392152.785388   872391887.5251    99.96%     1472    282   1310     26234   166.8s
#          0       0         0   0.00%   392184.785388   872391887.5251    99.96%     1650    291   1310     27217   179.5s
#          0       0         0   0.00%   392185.785388   872391887.5251    99.96%     1850    295   1310     27592   189.9s
#          0       0         0   0.00%   392186.403035   872391887.5251    99.96%     1934    298   1310     27652   202.9s
#          0       0         0   0.00%   392186.403035   872391887.5251    99.96%     1990    301   1310     28099   211.5s
#          0       0         0   0.00%   392186.403035   872391887.5251    99.96%     2100    303   1310     28129   220.9s
#          0       0         0   0.00%   392189.569702   872391887.5251    99.96%     2331    306   1310     28196   231.0s
#          0       0         0   0.00%   392189.569702   872391887.5251    99.96%     2469    279   1310     28246   245.0s
#          0       0         0   0.00%   392192.778035   872391887.5251    99.96%     2573    285   1310     28268   251.2s
#          0       0         0   0.00%   392192.903035   872391887.5251    99.96%     2665    289   1310     28278   261.9s
#          0       0         0   0.00%   392194.903035   872391887.5251    99.96%     2761    293   1310     28335   268.6s
#          0       0         0   0.00%   392236.857581   872391887.5251    99.96%     2889    264   1310     28440   280.6s
#          0       0         0   0.00%   392238.903035   872391887.5251    99.96%     2935    269   1310     28604   289.4s
#          0       0         0   0.00%   392238.903035   872391887.5251    99.96%     2999    273   1310     28670   297.8s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   392238.903035   872391887.5251    99.96%     3133    278   1310     28697   306.9s
#          0       0         0   0.00%   392238.903035   872391887.5251    99.96%     3355    281   1310     28717   316.8s
#  L       0       0         0   0.00%   392238.903035   392730.109589      0.13%     3355    281   1310     28717   416.6s
#          1       0         1 100.00%   392238.903035   392730.109589      0.13%     3355    281   1310     50563   416.7s
#
# Solving report
#   Status            Optimal
#   Primal bound      392730.109589
#   Dual bound        392238.903035
#   Gap               0.125% (tolerance: 0.5%)
#   P-D integral      378.676142172
#   Solution status   feasible
#                     392730.109589 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            416.70
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     50563
#                     0 (strong br.)
#                     4618 (separation)
#                     21846 (heuristics)
# [P100] Stopping fleet expansion: scenario +1 meets SLA and has no shortfall.
#     ✓ P100 fleet expansion search complete   [846.20s]
#     ✓ P90 built (5,857 flights)   [0.36s]
#     P90 demand summary: 13,128 PRMs across 5,857 flights
#     ✓ prepare_model_data started | flights=5,857   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.03s]
#     ✓ ambulift intervals built | flights=5,857 ambulifts=14   [0.24s]
#     ✓ minibus intervals built | minibuses=3   [0.05s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=2,021,757   [294.33s]
#     ✓ minibus overlaps built | overlaps=196,611   [22.93s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.01s]
#     ✓ prepare_model_data complete | total=317.61s   [0.00s]
#     ✓ sets built | F=5,857 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=29,285 amb=245,994 mini=35,142   [0.15s]
#     ✓ ambulift overlap constraints built | 2,021,757   [14.41s]
#     ✓ minibus overlap constraints built | 196,611   [0.57s]
#     ✓ build_pyomo_model complete | total=15.22s   [0.09s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=5,857 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 2604930 rows; 351437 cols; 5528260 nonzeros; 310438 integer variables (310438 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 8e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 396982 rows, 122978 cols, 900366 nonzeros 2s
# 216199 rows, 108310 cols, 735845 nonzeros 11s
# 216199 rows, 108310 cols, 735851 nonzeros 26s
# Presolve reductions: rows 216199(-2388731); columns 108310(-243127); nonzeros 735851(-4792409)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    216199 rows
#    108310 cols (96254 binary, 0 integer, 12056 implied int., 0 continuous, 0 domain fixed)
#    735851 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2277248994.479     Large        0      0      0         0    29.5s
# ...
#          0       0         0   0.00%   627210.979452   328626845.7534    99.81%     7768    534      0    184385   920.2s
#          0       0         0   0.00%   627212.406393   328626845.7534    99.81%     7345    500      0    186287   926.8s
#          0       0         0   0.00%   627212.977169   328626845.7534    99.81%     7708    507      0    188499   935.8s
#          0       0         0   0.00%   627215.260274   328626845.7534    99.81%     7200    515      0    190098   948.6s
#          0       0         0   0.00%   627220.152642   328626845.7534    99.81%     7311    529      0    191262   954.3s
#          0       0         0   0.00%   627226.675799   328626845.7534    99.81%     6843    467      0    192582   962.0s
#  L       0       0         0   0.00%   627226.675799   627425.506849      0.03%     6638    470      0    192664  1124.1s
#  T       0       0         0   0.00%   627226.675799   627226.675799      0.00%     6638    470      0    246139  1124.5s
#          1       0         1 100.00%   627226.675799   627226.675799      0.00%     5925    470      0    246139  1124.6s
#
# Solving report
#   Status            Optimal
#   Primal bound      627226.675799
#   Dual bound        627226.675799
#   Gap               0% (tolerance: 0.5%)
#   P-D integral      1050.69838428
#   Solution status   feasible
#                     627226.675799 (objective)
#                     0 (bound viol.)
#                     7.63211716048e-12 (int. viol.)
#                     0 (row viol.)
#   Timing            1124.55
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     246139
#                     0 (strong br.)
#                     134331 (separation)
#                     53475 (heuristics)
# [P100] Stopping fleet expansion: scenario +1 meets SLA and has no shortfall.
#     ✓ P100 fleet expansion search complete   [1934.39s]
#     ✓ P90 built (6,877 flights)   [0.65s]
#     P90 demand summary: 17,407 PRMs across 6,877 flights
#     ✓ prepare_model_data started | flights=6,877   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.04s]
#     ✓ ambulift intervals built | flights=6,877 ambulifts=14   [0.37s]
#     ✓ minibus intervals built | minibuses=3   [0.06s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=2,794,602   [612.34s]
#     ✓ minibus overlaps built | overlaps=268,044   [45.15s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.04s]
#     ✓ prepare_model_data complete | total=658.00s   [0.00s]
#     ✓ sets built | F=6,877 AMB=14 MINI=3   [0.03s]
#     ✓ variables built | x=34,385 amb=288,834 mini=41,262   [0.32s]
#     ✓ ambulift overlap constraints built | 2,794,602   [58.24s]
#     ✓ minibus overlap constraints built | 268,044   [0.85s]
#     ✓ build_pyomo_model complete | total=59.56s   [0.12s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,877 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 3516528 rows; 412637 cols; 7407202 nonzeros; 364498 integer variables (364498 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 1e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 533755 rows, 148531 cols, 1196356 nonzeros 5s
# 271582 rows, 130599 cols, 953736 nonzeros 24s
# 271582 rows, 130599 cols, 953736 nonzeros 50s
# Presolve reductions: rows 271582(-3244946); columns 130599(-282038); nonzeros 953736(-6453466)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    271582 rows
#    130599 cols (116072 binary, 0 integer, 14527 implied int., 0 continuous, 0 domain fixed)
#    953736 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2759325280.479     Large        0      0      0         0    55.0s
#  R       0       0         0   0.00%   2259985.659645  1084259750.297    99.79%        0      0      0     38274   151.4s
#          0       0         0   0.00%   2260104.427175  1084259750.297    99.79%     1332    181      0     44522   185.0s
#          0       0         0   0.00%   2260553.163079  1084259750.297    99.79%     1719    359      0     51626   213.8s
#          0       0         0   0.00%   2262413.111492  1084259750.297    99.79%     2099    619      0     52620   221.2s
#  C       0       0         0   0.00%   2262734.472603  1083260529.297    99.79%     2136    644      0     52986   224.9s
#          0       0         0   0.00%   2262772.639269  1083260529.297    99.79%     2484    654      0     54466   307.9s
#          0       0         0   0.00%   2262840.472603  1083260529.297    99.79%     2568    666      0     55083   316.2s
#          0       0         0   0.00%   2262840.972603  1083260529.297    99.79%     2702    670      0     55167   330.5s
#          0       0         0   0.00%   2262840.972603  1083260529.297    99.79%     2754    672      0     55668   347.4s
#          0       0         0   0.00%   2262840.972603  1083260529.297    99.79%     2838    674      0     55672   356.4s
#          0       0         0   0.00%   2262840.972603  1083260529.297    99.79%     2939    676      0     55739   369.8s
#  L       0       0         0   0.00%   2262840.972603  2263835.296804     0.04%     2939    676      0     55739   527.3s
#          1       0         1 100.00%   2262840.972603  2263835.296804     0.04%     2939    676      0     76845   527.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      2263835.2968
#   Dual bound        2262840.9726
#   Gap               0.0439% (tolerance: 0.5%)
#   P-D integral      471.161874109
#   Solution status   feasible
#                     2263835.2968 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            527.44
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     76845
#                     0 (strong br.)
#                     17465 (separation)
#                     21106 (heuristics)
#     ✓ P90 optimisation complete   [1324.92s]
#
# [P90 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     3
# 2                            0                   9                     5
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      3               0                   1              0
# 2                      5               0                   4              0
# 3                      3               0                   0              0
#
# [P90] Running fleet expansion scenario: +1 future copy per future model
#     ✓ prepare_model_data started | flights=6,877   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.04s]
#     ✓ ambulift intervals built | flights=6,877 ambulifts=14   [0.30s]
#     ✓ minibus intervals built | minibuses=5   [0.06s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=2,794,602   [430.86s]
#     ✓ minibus overlaps built | overlaps=446,740   [51.16s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.01s]
#     ✓ prepare_model_data complete | total=482.45s   [0.00s]
#     ✓ sets built | F=6,877 AMB=14 MINI=5   [0.00s]
#     ✓ variables built | x=34,385 amb=288,834 mini=68,770   [0.20s]
#     ✓ ambulift overlap constraints built | 2,794,602   [22.08s]
#     ✓ minibus overlap constraints built | 446,740   [2.53s]
#     ✓ build_pyomo_model complete | total=24.92s   [0.10s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,877 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 3777750 rows; 440149 cols; 7984662 nonzeros; 392010 integer variables (392010 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 662727 rows, 167249 cols, 1477448 nonzeros 5s
# 318319 rows, 144357 cols, 1086062 nonzeros 23s
# 318319 rows, 144357 cols, 1086064 nonzeros 46s
# Presolve reductions: rows 318319(-3459431); columns 144357(-295792); nonzeros 1086064(-6898598)
#
# Solving MIP model with:
#    318319 rows
#    144357 cols (129830 binary, 0 integer, 14527 implied int., 0 continuous, 0 domain fixed)
#    1086064 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2826507930.708     Large        0      0      0         0    51.7s
#  R       0       0         0   0.00%   620891.048402   766620989.7534    99.92%        0      0      0     40359   136.8s
#          0       0         0   0.00%   620891.048402   766620989.7534    99.92%     1103     80      0     41791   154.8s
#          0       0         0   0.00%   620893.142009   766620989.7534    99.92%     1211    123      0     43108   162.9s
#          0       0         0   0.00%   620924.429224   766620989.7534    99.92%     1258    161      0     44939   171.0s
#          0       0         0   0.00%   620937.929224   766620989.7534    99.92%     1395    189      0     45138   188.2s
#  C       0       0         0   0.00%   620949.09589    742620957.7534    99.92%     1626    207      0     45294   247.0s
#          0       0         0   0.00%   620989.762557   742620957.7534    99.92%     1909    224      0     45380   314.8s
#          0       0         0   0.00%   620989.762557   742620957.7534    99.92%     2169    228      0     45447   373.5s
#          0       0         0   0.00%   620989.762557   742620957.7534    99.92%     2299    232      0     45523   396.4s
#          0       0         0   0.00%   621000.429224   742620957.7534    99.92%     2416    241      0     45634   415.0s
#          0       0         0   0.00%   621019.429224   742620957.7534    99.92%     2601    247      0     45714   440.0s
#          0       0         0   0.00%   621019.429224   742620957.7534    99.92%     2659    248      0     45730   455.9s
#          0       0         0   0.00%   621019.429224   742620957.7534    99.92%     2763    250      0     45754   473.1s
#  L       0       0         0   0.00%   621019.429224   621218.675799      0.03%     2763    250      0     45754   614.2s
#          1       0         1 100.00%   621019.429224   621218.675799      0.03%     2763    250      0     75616   614.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      621218.675799
#   Dual bound        621019.429224
#   Gap               0.0321% (tolerance: 0.5%)
#   P-D integral      561.637178257
#   Solution status   feasible
#                     621218.675799 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            614.40
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     75616
#                     0 (strong br.)
#                     5395 (separation)
#                     29862 (heuristics)
# [P90] Stopping fleet expansion: scenario +1 meets SLA and has no shortfall.
#     ✓ P90 fleet expansion search complete   [1199.78s]
#     ✓ Excel outputs written to outputs\prm_v2\monthly_summary\2026_06.xlsx   [14.18s]
# Completed 2026-06
#
# ================================================================================
# Running 2026-07
#     ✓ S25 ingest complete (7,782 passengers)   [78.49s]
#
# [V2] Building assumptions using historical data through 2026-07-13
# FAILED 2026-07
# Missing tau columns: ['tau_amb_mins', 'tau_mini_mins', 'tau_push_mins']
#
# ================================================================================
# Running 2026-08
#
# [V2] Building assumptions using historical data through 2026-07-13
# FAILED 2026-08
# Cannot set a DataFrame with multiple columns to the single column flight_key
#
# ================================================================================
# Running 2026-09
#
# [V2] Building assumptions using historical data through 2026-07-13
# FAILED 2026-09
# Cannot set a DataFrame with multiple columns to the single column flight_key
#
# ================================================================================
# Running 2026-10
#
# [V2] Building assumptions using historical data through 2026-07-13
# FAILED 2026-10
# Cannot set a DataFrame with multiple columns to the single column flight_key
#      month  mode  arrival_sla_pct  peak_amb  peak_mini  peak_staff  \
# 0  2025-09  P100       100.000000        11          3        43.0
# 1  2025-09   P90       100.000000        12          3        41.0
# 2  2025-10  P100       100.000000        11          3        55.0
# 3  2025-10   P90       100.000000        12          3        41.0
# 4  2026-04  P100        99.849815         9          3        37.0
# 5  2026-04   P90       100.000000         8          3        34.0
# 6  2026-05  P100       100.000000        10          3        54.0
# 7  2026-05   P90       100.000000         9          3        42.0
# 8  2026-06  P100       100.000000        11          3        59.0
# 9  2026-06   P90       100.000000         9          3        45.0
#
#    fleet_expansion_required  current_fleet_sufficient recommended_scenario
# 0                         0                         1     CURRENT_FLEET_OK
# 1                         0                         1     CURRENT_FLEET_OK
# 2                         0                         1     CURRENT_FLEET_OK
# 3                         1                         0    p90_future_plus_1
# 4                         1                         0   p100_future_plus_1
# 5                         1                         0    p90_future_plus_1
# 6                         0                         1     CURRENT_FLEET_OK
# 7                         0                         1     CURRENT_FLEET_OK
# 8                         1                         0   p100_future_plus_1
# 9                         1                         0    p90_future_plus_1
