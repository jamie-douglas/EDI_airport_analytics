# %% [markdown]
# ### Imports and Config

# %%
# ==========================================================
# 1. Imports and repo setup
# ==========================================================

import sys
from pathlib import Path
from datetime import date, timedelta
from calendar import monthrange

import pandas as pd

HERE = Path().resolve()
PROJECT_ROOT = HERE.parents[0]
sys.path.insert(0, str(PROJECT_ROOT))

from prm_opt.config import PlanningToggles, VEHICLE_MODELS

from prm_opt.optimise_prm_fleet_v2 import OptimiserConfig
from prm_opt.run_s25_s26_v2 import run_s25_s26_v2

from prm_opt.build_assumptions_v2 import build_assumptions_v2
from prm_opt.build_s26_assumptions import build_s26_assumptions

from prm_opt.ingest_s25 import ingest_s25
from prm_opt.ingest_s26 import ingest_s26
from prm_opt.build_jobs import build_jobs
from prm_opt.policy_s1 import apply_policy_s1
from prm_opt.outputs import baseline_s1_vehicle_curves_capacity, baseline_s1_summary

from prm_opt.ingest_s25_v2 import ingest_s25_v2
from prm_opt.ingest_s26_v2 import ingest_s26_v2
from prm_opt.build_flights_v2 import build_flights_v2

from prm_opt.policy_s2_flight_rules import run_s2_flight_rules

# %% [markdown]
# ### User Parameters

# %%
# ==========================================================
# 2. User parameters
# ==========================================================

OUTPUT_ROOT = Path("outputs/prm_combined")
MONTHLY_OUTPUT_DIR = OUTPUT_ROOT / "monthly"

OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)
MONTHLY_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

MONTHS_TO_RUN = [
    (2026, 4),
    (2026, 5),
    (2026, 6),
    (2026, 7),
    (2026, 8),
    (2026, 9),
    (2026, 10),
]

ASSUMPTION_S25_START = "2025-04-01"
ASSUMPTION_S25_END = "2025-10-31"

PENETRATION_UPLIFT = 1.08

RUN_P100 = True
RUN_P90 = True

S2_AMB_SEATCAP = 7
S2_AMB_WCCAP = 1

S2_MINI_SEATCAP = 6
S2_MINI_WCCAP = 2

S2_MINIBUS_THRESHOLD_PRMS = 3

TIME_FREQ = "5min"

# %% [markdown]
# ### Toggles and V2 config

# %%
# ==========================================================
# 3. Scenario configs
# ==========================================================

toggles_p100 = PlanningToggles(
    demand_mode="p100",
)

toggles_p90 = PlanningToggles(
    demand_mode="p90_stratified",
    p90_quantile=0.90,
    p90_strata=("SSR Code", "Has Own Chair", "A/D"),
)

v2_config = OptimiserConfig(
    tau_amb_solo_mins=31,
    tau_amb_comb_mins=26,
    tau_mini_mins=23,
    tau_push_mins=20,

    handover_buffer_mins=5,

    arrival_sla_target_pct=0.98,
    arrival_sla_target_mins=20,

    boarding_offset_mins=40,

    staff_amb=2,
    staff_mini=2,
    staff_per_prm_push=1,

    max_future_copies_per_model=5,

    solver_relative_gap=0.005,
)

# %% [markdown]
# ### date splitting

# %%
# ==========================================================
# 4. Date helpers
# ==========================================================

def get_month_run_flags(year, month, *, today=None):
    """
    Historical = before today, exclusive of today.
    Future = from today, inclusive of today.

    All end dates are exclusive because the SQL queries use:
        >= start
        < end
    """

    if today is None:
        today = date.today()

    month_start = date(year, month, 1)

    month_end_inclusive = date(
        year,
        month,
        monthrange(year, month)[1],
    )

    next_month_start = month_end_inclusive + timedelta(days=1)

    kwargs = {}

    run_s25 = False
    run_s26 = False

    if month_end_inclusive < today:

        run_s25 = True
        kwargs["s25_start"] = str(month_start)
        kwargs["s25_end"] = str(next_month_start)

    elif month_start >= today:

        run_s26 = True
        kwargs["s26_start"] = str(month_start)
        kwargs["s26_end"] = str(next_month_start)

    else:

        run_s25 = True
        run_s26 = True

        kwargs["s25_start"] = str(month_start)
        kwargs["s25_end"] = str(today)

        kwargs["s26_start"] = str(today)
        kwargs["s26_end"] = str(next_month_start)

    return {
        "month_start": month_start,
        "month_end_inclusive": month_end_inclusive,
        "next_month_start": next_month_start,
        "run_s25": run_s25,
        "run_s26": run_s26,
        "kwargs": kwargs,
    }

# %% [markdown]
# ### assumption caches

# %%
# ==========================================================
# 5. Assumption caches
# ==========================================================

_rule_assumptions_cache = None
_v2_assumptions_cache = None


def get_rule_assumptions():
    """
    Old S1/S1-style stack assumptions for future passenger-level ingest.
    """

    global _rule_assumptions_cache

    if _rule_assumptions_cache is None:
        _rule_assumptions_cache = build_s26_assumptions(
            s25_start=ASSUMPTION_S25_START,
            s25_end=ASSUMPTION_S25_END,
            bucket="15min",
        )

    return _rule_assumptions_cache


def get_v2_assumptions():
    """
    V2 assumptions for future flight-level ingest.
    """

    global _v2_assumptions_cache

    if _v2_assumptions_cache is None:
        _v2_assumptions_cache = build_assumptions_v2(
            s25_start=ASSUMPTION_S25_START,
            s25_end=ASSUMPTION_S25_END,
            config=v2_config,
        )

    return _v2_assumptions_cache


def apply_penetration_uplift_to_rule_assumptions(
    assumptions,
    uplift,
):
    """
    Apply uplift to old S1/S1-style future penetration assumptions.
    """

    out = {
        "inputs": assumptions["inputs"].copy(),
        "extras": assumptions.get("extras", {}).copy(),
    }

    pen = out["inputs"]["penetration_rates"].copy()

    pen["penetration_base"] = pen["penetration"]
    pen["penetration_uplift"] = float(uplift)
    pen["penetration"] = pen["penetration"] * float(uplift)

    out["inputs"]["penetration_rates"] = pen

    return out

# %% [markdown]
# ### S1 runner

# %%
# ==========================================================
# 7. S1 runner
# ==========================================================

def build_s1_jobs_for_period(
    *,
    month_info,
    toggles,
    rule_assumptions=None,
    seed=42,
):

    run_s25 = month_info["run_s25"]
    run_s26 = month_info["run_s26"]
    kwargs = month_info["kwargs"]

    parts = []

    if run_s25:

        df_hist = ingest_s25(
            start=kwargs["s25_start"],
            end=kwargs["s25_end"],
            seed=seed,
        )

        jobs_hist = build_jobs(
            df_hist,
            bucket="15min",
            toggles=toggles,
            use_90th_percentile_cap=False,
        )

        jobs_hist["source_period"] = "S25"
        parts.append(jobs_hist)

    if run_s26:

        if rule_assumptions is None:
            raise ValueError("Future S1 requires rule_assumptions.")

        df_future = ingest_s26(
            start=kwargs["s26_start"],
            end=kwargs["s26_end"],
            **rule_assumptions["inputs"],
            seed=seed,
        )

        jobs_future = build_jobs(
            df_future,
            bucket="15min",
            toggles=toggles,
            use_90th_percentile_cap=False,
        )

        jobs_future["source_period"] = "S26"
        parts.append(jobs_future)

    if len(parts) == 0:
        return pd.DataFrame()

    jobs = pd.concat(
        parts,
        ignore_index=True,
    )

    jobs.index.name = "j"

    return jobs


def _current_fleet_counts_from_vehicle_models():

    current_amb = sum(
        1
        for _, v in VEHICLE_MODELS.items()
        if v["type"] == "Amb"
        and not bool(v.get("is_future", False))
    )

    current_mini = sum(
        1
        for _, v in VEHICLE_MODELS.items()
        if v["type"] == "Mini"
        and not bool(v.get("is_future", False))
    )

    return current_amb, current_mini


def run_s1_for_period(
    *,
    month_info,
    toggles,
    rule_assumptions=None,
    seed=42,
):

    jobs = build_s1_jobs_for_period(
        month_info=month_info,
        toggles=toggles,
        rule_assumptions=rule_assumptions,
        seed=seed,
    )

    if jobs is None or len(jobs) == 0:

        empty_series = pd.Series(dtype=int)

        return {
            "jobs": pd.DataFrame(),
            "summary": {},
            "ambulift_curve": empty_series,
            "minibus_curve": empty_series,
            "driver_curve": empty_series,
            "veh_agent_curve": empty_series,
            "pusher_curve": empty_series,
            "fb_detail": pd.DataFrame(),
        }

    decisions = apply_policy_s1(jobs)

    jobs["s1_decision"] = jobs.index.map(decisions.get)

    curves = baseline_s1_vehicle_curves_capacity(
        jobs,
        decision_col="s1_decision",
        bucket_col="s",
        count_no_vehicle_as_push=True,
        amb_seatcap=3,
        amb_wccap=1,
        mini_seatcap=6,
        mini_wccap=2,
        duration_mins=20,
        time_freq=TIME_FREQ,
    )

    current_amb, current_mini = _current_fleet_counts_from_vehicle_models()

    summary = baseline_s1_summary(
        jobs,
        curves,
        current_amb=current_amb,
        current_mini=current_mini,
    )

    return {
        "jobs": jobs,
        "summary": summary,
        "ambulift_curve": curves["ambulift_curve"],
        "minibus_curve": curves["minibus_curve"],
        "driver_curve": curves["driver_curve"],
        "veh_agent_curve": curves["veh_agent_curve"],
        "pusher_curve": curves["pusher_curve"],
        "fb_detail": curves["fb_detail"],
    }

# %% [markdown]
# ### build V2 passengers and flights for S2

# %%
# ==========================================================
# 8. Build V2 passengers and flights for S2
# ==========================================================

def build_v2_passengers_for_period(
    *,
    month_info,
    v2_assumptions=None,
    seed=42,
):

    run_s25 = month_info["run_s25"]
    run_s26 = month_info["run_s26"]
    kwargs = month_info["kwargs"]

    parts = []

    if run_s25:

        df_hist = ingest_s25_v2(
            start=kwargs["s25_start"],
            end=kwargs["s25_end"],
            seed=seed,
        )

        df_hist["source_period"] = "S25"
        parts.append(df_hist)

    if run_s26:

        if v2_assumptions is None:
            raise ValueError("Future V2/S2 requires v2_assumptions.")

        df_future = ingest_s26_v2(
            start=kwargs["s26_start"],
            end=kwargs["s26_end"],
            penetration_rates=v2_assumptions["penetration_rates"],
            ssr_mix=v2_assumptions["ssr_mix"],
            stand_actuals=v2_assumptions["stand_actuals"],
            stand_dist=v2_assumptions["stand_dist"],
            penetration_uplift=PENETRATION_UPLIFT,
            seed=seed,
        )

        df_future["source_period"] = "S26"
        parts.append(df_future)

    if len(parts) == 0:
        return pd.DataFrame()

    passengers = pd.concat(
        parts,
        ignore_index=True,
    )

    return passengers


def build_v2_flights_for_period(
    *,
    month_info,
    demand_mode,
    v2_assumptions=None,
    seed=42,
):

    passengers = build_v2_passengers_for_period(
        month_info=month_info,
        v2_assumptions=v2_assumptions,
        seed=seed,
    )

    if passengers is None or len(passengers) == 0:
        return pd.DataFrame()

    flights = build_flights_v2(
        passengers,
        demand_mode=demand_mode,
        p90_quantile=0.90,
        boarding_offset_mins=v2_config.boarding_offset_mins,
        p90_strata=("demand_category", "A/D"),
    )

    return flights

# %% [markdown]
# ### S2 runner

# %%
# ==========================================================
# 9. S2 runner
# ==========================================================

def run_s2_for_period(
    *,
    month_info,
    demand_mode,
    v2_assumptions=None,
    seed=42,
):

    flights = build_v2_flights_for_period(
        month_info=month_info,
        demand_mode=demand_mode,
        v2_assumptions=v2_assumptions,
        seed=seed,
    )

    if flights is None or len(flights) == 0:

        empty_series = pd.Series(dtype=int)

        return {
            "flights": pd.DataFrame(),
            "flight_requirements": pd.DataFrame(),
            "summary": {},
            "ambulift_curve": empty_series,
            "minibus_curve": empty_series,
            "driver_curve": empty_series,
            "veh_agent_curve": empty_series,
            "event_detail": pd.DataFrame(),
            "curve_df": pd.DataFrame(),
        }

    out = run_s2_flight_rules(
        flights=flights,
        config=v2_config,
        amb_seatcap=S2_AMB_SEATCAP,
        amb_wccap=S2_AMB_WCCAP,
        mini_seatcap=S2_MINI_SEATCAP,
        mini_wccap=S2_MINI_WCCAP,
        minibus_threshold_prms=S2_MINIBUS_THRESHOLD_PRMS,
        time_freq=TIME_FREQ,
    )

    out["flights"] = flights

    return out

# %% [markdown]
# ### V2 optimiser runner

# %%
# ==========================================================
# 10. V2 optimiser runner
# ==========================================================

def run_v2_optimizer_for_period(
    *,
    month_info,
    v2_assumptions=None,
    output_dir,
    output_xlsx_name,
):

    run_s25 = month_info["run_s25"]
    run_s26 = month_info["run_s26"]
    kwargs = month_info["kwargs"]

    call_kwargs = {
        "run_s25": run_s25,
        "run_s26": run_s26,

        "vehicle_models": VEHICLE_MODELS,
        "config": v2_config,

        "output_dir": str(output_dir),
        "output_xlsx_name": output_xlsx_name,

        "run_p100": True,
        "run_p90": True,

        "run_fleet_report": True,
        "fleet_report_policy": "if_needed",
        "current_fleet_only_first": True,

        "max_ev10": 5,
        "max_ev18": 5,

        **kwargs,
    }

    if run_s26:

        if v2_assumptions is None:
            raise ValueError(
                "Future V2 optimiser requires v2_assumptions."
            )

        call_kwargs.update(
            {
                "penetration_rates": v2_assumptions["penetration_rates"],
                "ssr_mix": v2_assumptions["ssr_mix"],
                "stand_actuals": v2_assumptions["stand_actuals"],
                "stand_dist": v2_assumptions["stand_dist"],
                "penetration_uplift": PENETRATION_UPLIFT,
            }
        )

    result = run_s25_s26_v2(**call_kwargs)

    return result

# %% [markdown]
# # workbook write and V2 summary helper

# %%
# ==========================================================
# 11. Workbook writer and V2 summary helper
# ==========================================================

def _safe_sheet_name(name):

    invalid = ["\\", "/", "*", "?", ":", "[", "]"]

    out = str(name)

    for ch in invalid:
        out = out.replace(ch, "_")

    return out[:31]


def _write_df(
    writer,
    obj,
    sheet_name,
):

    if obj is None:
        return

    if isinstance(obj, dict):
        df = pd.DataFrame([obj])

    elif isinstance(obj, pd.Series):
        df = obj.rename("value").reset_index()

    elif isinstance(obj, pd.DataFrame):
        df = obj

    else:
        df = pd.DataFrame(obj)

    df.to_excel(
        writer,
        sheet_name=_safe_sheet_name(sheet_name),
        index=False,
    )


def write_monthly_combined_workbook(
    *,
    output_path,
    month_rows,
    s1_outputs,
    s2_outputs,
    v2_result,
):

    output_path = Path(output_path)

    output_path.parent.mkdir(
        parents=True,
        exist_ok=True,
    )

    with pd.ExcelWriter(
        output_path,
        engine="openpyxl",
    ) as writer:

        _write_df(
            writer,
            pd.DataFrame(month_rows),
            "Monthly_Summary",
        )

        # ----------------------------
        # S1 outputs
        # ----------------------------

        for mode_key, s1 in s1_outputs.items():

            _write_df(
                writer,
                s1.get("summary"),
                f"S1_{mode_key}_Summary",
            )

            _write_df(
                writer,
                s1.get("jobs"),
                f"S1_{mode_key}_Jobs",
            )

            _write_df(
                writer,
                s1.get("fb_detail"),
                f"S1_{mode_key}_FB_Detail",
            )

            _write_df(
                writer,
                s1.get("ambulift_curve"),
                f"S1_{mode_key}_Amb_Curve",
            )

            _write_df(
                writer,
                s1.get("minibus_curve"),
                f"S1_{mode_key}_Mini_Curve",
            )

        # ----------------------------
        # S2 outputs
        # ----------------------------

        for mode_key, s2 in s2_outputs.items():

            _write_df(
                writer,
                s2.get("summary"),
                f"S2_{mode_key}_Summary",
            )

            _write_df(
                writer,
                s2.get("flights"),
                f"S2_{mode_key}_Flights",
            )

            _write_df(
                writer,
                s2.get("flight_requirements"),
                f"S2_{mode_key}_Requirements",
            )

            _write_df(
                writer,
                s2.get("curve_df"),
                f"S2_{mode_key}_Curve",
            )

            _write_df(
                writer,
                s2.get("event_detail"),
                f"S2_{mode_key}_Events",
            )

        # ----------------------------
        # V2 outputs
        # ----------------------------

        if v2_result is not None:

            if "outputs_p100" in v2_result:

                for key, df in v2_result["outputs_p100"].items():

                    if isinstance(df, pd.DataFrame):

                        _write_df(
                            writer,
                            df,
                            f"V2_P100_{key}",
                        )

            if "outputs_p90" in v2_result:

                for key, df in v2_result["outputs_p90"].items():

                    if isinstance(df, pd.DataFrame):

                        _write_df(
                            writer,
                            df,
                            f"V2_P90_{key}",
                        )
            
            extra_v2_keys = [
                "p100_base_check",
                "p90_base_check",
                "fleet_requirements_p100",
                "fleet_requirements_p90",
                "recommended_p100",
                "recommended_p90",
            ]

            for key in extra_v2_keys:

                if (
                    key in v2_result
                    and isinstance(v2_result[key], pd.DataFrame)
                ):

                    _write_df(
                        writer,
                        v2_result[key],
                        f"V2_{key}",
                    )

    return output_path


def extract_v2_month_summary(
    v2_result,
    mode_key,
):

    if v2_result is None:
        return {}

    if mode_key == "P100":
        outputs = v2_result.get("outputs_p100", {})
    else:
        outputs = v2_result.get("outputs_p90", {})

    sla = outputs.get(
        "sla_summary",
        pd.DataFrame(),
    )

    fleet = outputs.get(
        "fleet_utilisation",
        pd.DataFrame(),
    )

    arrival_sla_pct = None

    if isinstance(sla, pd.DataFrame) and len(sla) > 0:

        row = sla.iloc[0]

        arrival_sla_pct = row.get(
            "arrival_sla_pct"
        )

    peak_amb = None
    peak_mini = None

    if (
        isinstance(fleet, pd.DataFrame)
        and len(fleet) > 0
        and "vehicle_type" in fleet.columns
        and "required_for_schedule" in fleet.columns
    ):

        peak_amb = int(
            pd.to_numeric(
                fleet.loc[
                    fleet["vehicle_type"] == "Amb",
                    "required_for_schedule",
                ],
                errors="coerce",
            ).fillna(0).sum()
        )

        peak_mini = int(
            pd.to_numeric(
                fleet.loc[
                    fleet["vehicle_type"] == "Mini",
                    "required_for_schedule",
                ],
                errors="coerce",
            ).fillna(0).sum()
        )

    return {
        "V2_arrival_sla_pct": arrival_sla_pct,
        "V2_PeakAmb": peak_amb,
        "V2_PeakMini": peak_mini,
    }

# %% [markdown]
# ### run one month

# %%
# ==========================================================
# 12. Run one month
# ==========================================================

def run_combined_month(
    year,
    month,
    *,
    seed=42,
):

    month_info = get_month_run_flags(
        year,
        month,
    )

    month_start = month_info["month_start"]

    month_tag = f"{year}_{month:02d}"

    print("")
    print("=" * 80)
    print(f"RUNNING COMBINED MONTH: {month_tag}")
    print("=" * 80)

    needs_future = bool(
        month_info["run_s26"]
    )

    rule_assumptions = None
    v2_assumptions = None

    if needs_future:

        rule_assumptions = (
            apply_penetration_uplift_to_rule_assumptions(
                get_rule_assumptions(),
                PENETRATION_UPLIFT,
            )
        )

        v2_assumptions = (
            get_v2_assumptions()
        )

    s1_outputs = {}
    s2_outputs = {}

    modes_to_run = []

    if RUN_P100:
        modes_to_run.append(
            (
                "P100",
                "p100",
                toggles_p100,
            )
        )

    if RUN_P90:
        modes_to_run.append(
            (
                "P90",
                "p90",
                toggles_p90,
            )
        )

    for mode_key, demand_mode, toggles in modes_to_run:

        print("")
        print(f"Running S1 {mode_key}")

        s1_outputs[mode_key] = (
            run_s1_for_period(
                month_info=month_info,
                toggles=toggles,
                rule_assumptions=rule_assumptions,
                seed=seed,
            )
        )

        print(f"Running S2 {mode_key}")

        s2_outputs[mode_key] = (
            run_s2_for_period(
                month_info=month_info,
                demand_mode=demand_mode,
                v2_assumptions=v2_assumptions,
                seed=seed,
            )
        )

    print("")
    print("Running V2 optimiser")

    v2_result = run_v2_optimizer_for_period(
        month_info=month_info,
        v2_assumptions=v2_assumptions,
        output_dir=MONTHLY_OUTPUT_DIR,
        output_xlsx_name=f"{month_tag}_v2.xlsx",
    )

    month_rows = []

    for mode_key, _, _ in modes_to_run:

        s1_summary = (
            s1_outputs[mode_key]
            .get("summary", {})
        )

        s2_summary = (
            s2_outputs[mode_key]
            .get("summary", {})
        )

        v2_summary = (
            extract_v2_month_summary(
                v2_result,
                mode_key,
            )
        )

        row = {

            "S1_PeakAmb":
                s1_summary.get("PeakAmb"),

            "S1_PeakMini":
                s1_summary.get("PeakMini"),

            "S1_PeakDrivers":
                s1_summary.get("PeakDrivers"),

            "S1_PeakVehAgents":
                s1_summary.get("PeakVehAgents"),

            "S2_PeakAmb":
                s2_summary.get("PeakAmb"),

            "S2_PeakMini":
                s2_summary.get("PeakMini"),

            "S2_PeakDrivers":
                s2_summary.get("PeakDrivers"),

            "S2_PeakVehAgents":
                s2_summary.get("PeakVehAgents"),

            **v2_summary,
        }

        month_rows.append(row)

    combined_path = (
        MONTHLY_OUTPUT_DIR
        / f"{month_tag}_combined.xlsx"
    )

    write_monthly_combined_workbook(
        output_path=combined_path,
        month_rows=month_rows,
        s1_outputs=s1_outputs,
        s2_outputs=s2_outputs,
        v2_result=v2_result,
    )

    print("")
    print(f"Completed month: {month_tag}")
    print(f"Workbook: {combined_path}")

    return {

        "month_rows":
            month_rows,

        "s1_outputs":
            s1_outputs,

        "s2_outputs":
            s2_outputs,

        "v2_result":
            v2_result,

        "combined_workbook_path":
            combined_path,
    }

# %% [markdown]
# ### Test Call

# %%
test_result = run_combined_month(
    2026,
    4,
)

pd.DataFrame(test_result["month_rows"])
# Out:
# ================================================================================
# RUNNING COMBINED MONTH: 2026_04
# ================================================================================
#
# Running S1 P100
#
# Unmatched passenger rows after merge (missing Chocks DT): 749
# Unique unmatched flight keys: 437
#
# Unmatched key reasons:
# reason
# no_flight_candidate               427
# exact_match_should_have_joined     10
# Name: count, dtype: int64
#
# Dropped 727 passenger rows due to reasons {'scheduled_dt_mismatch', 'no_flight_candidate'}
# [BUILD_JOBS] Dropping 4 jobs already impossible at release (beyond SLA + max late)
# Running S2 P100
#
# Running S1 P90
#
# Unmatched passenger rows after merge (missing Chocks DT): 749
# Unique unmatched flight keys: 437
#
# Unmatched key reasons:
# reason
# no_flight_candidate               427
# exact_match_should_have_joined     10
# Name: count, dtype: int64
#
# Dropped 727 passenger rows due to reasons {'scheduled_dt_mismatch', 'no_flight_candidate'}
# [BUILD_JOBS] Dropping 4 jobs already impossible at release (beyond SLA + max late)
# [BUILD_JOBS] Applying stratified percentile cap: q=0.90 | strata=['SSR Code', 'Has Own Chair', 'A/D']
# [BUILD_JOBS] Dropped 551 PRM jobs via stratified percentile cap
# Running S2 P90
#
# Running V2 optimiser
#     ✓ S25 ingest complete (14,953 passengers)   [40.18s]
#     ✓ Passenger dataset combined (14,953 passenger rows)   [0.00s]
#     ✓ P100 built (6,066 flights)   [0.13s]
#     P100 demand summary: 14,953 PRMs across 6,066 flights
#     ✓ prepare_model_data started | flights=6,066   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.02s]
#     ✓ ambulift intervals built | flights=6,066 ambulifts=14   [0.77s]
#     ✓ minibus intervals built | minibuses=3   [0.05s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=3,574,419   [0.69s]
#     ✓ minibus overlaps built | overlaps=318,654   [0.06s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.01s]
#     ✓ prepare_model_data complete | total=1.62s   [0.00s]
#     ✓ sets built | F=6,066 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=30,330 amb=254,772 mini=36,396   [0.59s]
#     ✓ ambulift overlap constraints built | 3,574,419   [18.19s]
#     ✓ minibus overlap constraints built | 318,654   [1.14s]
#     ✓ build_pyomo_model complete | total=20.45s   [0.53s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,066 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 4293653 rows; 363977 cols; 8916844 nonzeros; 321515 integer variables (321515 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 4e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 552396 rows, 125882 cols, 1203107 nonzeros 4s
# 242775 rows, 110732 cols, 891953 nonzeros 25s
# 224577 rows, 110721 cols, 846921 nonzeros 46s
# Presolve reductions: rows 224577(-4069076); columns 110721(-253256); nonzeros 846921(-8069923)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    224577 rows
#    110721 cols (98328 binary, 0 integer, 12393 implied int., 0 continuous, 0 domain fixed)
#    846921 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2350382531.479     Large        0      0      0         0    53.8s
#  R       0       0         0   0.00%   9018114.231686  1006344720.804    99.10%        0      0      0     47417   216.6s
#          0       0         0   0.00%   10019613.92818  1006344720.804    99.00%     1317    407      0     48420   221.7s
#  C       0       0         0   0.00%   11355754.12482  814345244.2968    98.61%     1470    651      0     49093   226.4s
#          0       0         0   0.00%   11355879.84149  814345244.2968    98.61%     1578    671      0     49348   272.9s
#          0       0         0   0.00%   11355880.55163  814345244.2968    98.61%     1589    680      0     51466   279.3s
#          0       0         0   0.00%   11356805.0983   814345244.2968    98.61%     1690    722      0     51845   284.9s
#          0       0         0   0.00%   11356809.10779  814345244.2968    98.61%     1698    726      0     52607   289.9s
#          0       0         0   0.00%   11356929.87328  814345244.2968    98.61%     1845    744      0     56017   304.4s
#          0       0         0   0.00%   11356930.52803  814345244.2968    98.61%     2080    646      0     63031   317.1s
#          0       0         0   0.00%   11356933.54805  814345244.2968    98.61%     2191    655      0     64709   322.6s
#          0       0         0   0.00%   11356933.71133  814345244.2968    98.61%     2301    665      0     72566   345.8s
#          0       0         0   0.00%   11357096.4045   814345244.2968    98.61%     2951    669      0     76115   365.9s
#          0       0         0   0.00%   11357096.4045   814345244.2968    98.61%     3409    658      0     76251   375.1s
#          0       0         0   0.00%   11357096.4045   814345244.2968    98.61%     3478    660      0     76304   383.1s
#          0       0         0   0.00%   11357096.4045   814345244.2968    98.61%     3552    662      0     76494   395.7s
#          0       0         0   0.00%   11357096.4045   814345244.2968    98.61%     3679    664      0     76517   408.2s
#          0       0         0   0.00%   11357096.4045   814345244.2968    98.61%     3735    644      0     76537   418.1s
#          0       0         0   0.00%   11357096.4045   814345244.2968    98.61%     3827    645      0     76561   424.9s
#  L       0       0         0   0.00%   11357096.4045   11357450.2968      0.00%     3827    645      0     76561   615.0s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          1       0         1 100.00%   11357096.4045   11357450.2968      0.00%     3827    645      0    144132   615.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      11357450.2968
#   Dual bound        11357096.4064
#   Gap               0.00312% (tolerance: 0.5%)
#   P-D integral      555.32231188
#   Solution status   feasible
#                     11357450.2968 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            615.17
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     144132
#                     0 (strong br.)
#                     29144 (separation)
#                     67571 (heuristics)
#     ✓ P100 optimisation complete   [724.96s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     4
# 2                            0                   9                     5
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      4               0                   0              0
# 2                      5               0                   4              0
# 3                      3               0                   0              0
#
# [P100] Running fleet expansion scenario: +1 future copy per future model
#     ✓ prepare_model_data started | flights=6,066   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.03s]
#     ✓ ambulift intervals built | flights=6,066 ambulifts=14   [0.62s]
#     ✓ minibus intervals built | minibuses=5   [0.05s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=3,574,419   [0.66s]
#     ✓ minibus overlaps built | overlaps=531,090   [0.10s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.01s]
#     ✓ prepare_model_data complete | total=1.49s   [0.00s]
#     ✓ sets built | F=6,066 AMB=14 MINI=5   [0.00s]
#     ✓ variables built | x=30,330 amb=254,772 mini=60,660   [0.19s]
#     ✓ ambulift overlap constraints built | 3,574,419   [28.78s]
#     ✓ minibus overlap constraints built | 531,090   [2.93s]
#     ✓ build_pyomo_model complete | total=32.48s   [0.57s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,066 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 4578883 rows; 388245 cols; 9535832 nonzeros; 345783 integer variables (345783 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 4e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 691228 rows, 142162 cols, 1500667 nonzeros 10s
# 284157 rows, 122869 cols, 1016590 nonzeros 32s
# 284157 rows, 122869 cols, 1016590 nonzeros 64s
# Presolve reductions: rows 284157(-4294726); columns 122869(-265376); nonzeros 1016590(-8519242)
#
# Solving MIP model with:
#    284157 rows
#    122869 cols (110473 binary, 0 integer, 12396 implied int., 0 continuous, 0 domain fixed)
#    1016590 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2413747641.936     Large        0      0      0         0    74.6s
#  R       0       0         0   0.00%   527484.02604    833521446.4475    99.94%        0      0      0     91489   324.1s
#          0       0         0   0.00%   527808.412562   833521446.4475    99.94%     1499    178      0     92012   330.6s
#          0       0         0   0.00%   528203.200544   833521446.4475    99.94%     1562    251      0    101356   354.6s
#          0       0         0   0.00%   528598.444497   833521446.4475    99.94%     1920    340   1533    101740   364.6s
#          0       0         0   0.00%   528785.533386   833521446.4475    99.94%     1939    379   1533    102191   371.9s
#          0       0         0   0.00%   528785.860875   833521446.4475    99.94%     1940    381   1533    111837   398.0s
#          0       0         0   0.00%   528822.260875   833521446.4475    99.94%     2497    389   1533    111994   403.4s
#          0       0         0   0.00%   528822.260875   833521446.4475    99.94%     2602    391   1533    112035   431.0s
#          0       0         0   0.00%   528822.260875   833521446.4475    99.94%     2772    393   1533    112123   471.5s
#          0       0         0   0.00%   528822.260875   833521446.4475    99.94%     2866    395   1533    112204   504.9s
#          0       0         0   0.00%   528822.260875   833521446.4475    99.94%     2998    397   1533    112306   545.1s
#          0       0         0   0.00%   528822.260875   833521446.4475    99.94%     3096    343   1533    112339   576.2s
#          0       0         0   0.00%   528854.260875   833521446.4475    99.94%     3268    347   1533    112419   614.3s
#          0       0         0   0.00%   528917.242693   833521446.4475    99.94%     3411    358   1533    112787   647.2s
#          0       0         0   0.00%   528924.714265   833521446.4475    99.94%     3419    362   1533    115755   654.4s
#          0       0         0   0.00%   528947.466472   833521446.4475    99.94%     3639    368   1533    123611   678.7s
#          0       0         0   0.00%   528947.466472   833521446.4475    99.94%     4190    353   1533    123762   684.0s
#          0       0         0   0.00%   528952.466472   833521446.4475    99.94%     4292    357   1533    123900   712.7s
#          0       0         0   0.00%   528954.799805   833521446.4475    99.94%     4328    362   1533    124096   729.1s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   528956.716472   833521446.4475    99.94%     4385    371   1533    124502   754.2s
#          0       0         0   0.00%   528959.466472   833521446.4475    99.94%     4422    375   1533    124644   768.3s
#          0       0         0   0.00%   528959.466472   833521446.4475    99.94%     4464    377   1533    124746   784.0s
#          0       0         0   0.00%   528959.52944    833521446.4475    99.94%     4510    379   1533    130294   817.3s
#          0       0         0   0.00%   528959.626693   833521446.4475    99.94%     4931    382   1533    140230   847.3s
#          0       0         0   0.00%   528959.626693   833521446.4475    99.94%     5340    366   1533    140408   852.8s
#          0       0         0   0.00%   528963.785388   833521446.4475    99.94%     5212    370   1533    181338   993.5s
#          0       0         0   0.00%   528963.785388   833521446.4475    99.94%     6153    375   1533    181883   999.2s
#          0       0         0   0.00%   528963.785388   833521446.4475    99.94%     5740    384   1533    182162  1007.0s
#  L       0       0         0   0.00%   528963.785388   529085.447489      0.02%     5740    384   1533    182162  1172.0s
#          1       0         1 100.00%   528963.785388   529085.447489      0.02%     5632    384   1533    235080  1172.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      529085.447489
#   Dual bound        528963.785388
#   Gap               0.023% (tolerance: 0.5%)
#   P-D integral      1096.38881533
#   Solution status   feasible
#                     529085.447489 (objective)
#                     0 (bound viol.)
#                     2.22044604925e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            1172.24
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     235080
#                     0 (strong br.)
#                     90673 (separation)
#                     52918 (heuristics)
# [P100] Stopping fleet expansion: scenario +1 meets SLA and has no shortfall.
#     ✓ P100 fleet expansion search complete   [1300.46s]
#     ✓ P90 built (6,066 flights)   [0.39s]
#     P90 demand summary: 13,619 PRMs across 6,066 flights
#     ✓ prepare_model_data started | flights=6,066   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.03s]
#     ✓ ambulift intervals built | flights=6,066 ambulifts=14   [0.69s]
#     ✓ minibus intervals built | minibuses=3   [0.07s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=3,530,975   [0.73s]
#     ✓ minibus overlaps built | overlaps=318,639   [0.07s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.01s]
#     ✓ prepare_model_data complete | total=1.61s   [0.00s]
#     ✓ sets built | F=6,066 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=30,330 amb=254,772 mini=36,396   [0.20s]
#     ✓ ambulift overlap constraints built | 3,530,975   [32.35s]
#     ✓ minibus overlap constraints built | 318,639   [2.20s]
#     ✓ build_pyomo_model complete | total=35.29s   [0.54s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,066 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 4250095 rows; 363977 cols; 8829827 nonzeros; 321515 integer variables (321515 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 8e+00]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -1
# Presolving model
# 548448 rows, 126122 cols, 1197831 nonzeros 4s
# 242901 rows, 110980 cols, 889624 nonzeros 20s
# 242901 rows, 110980 cols, 889624 nonzeros 45s
# Presolve reductions: rows 242901(-4007194); columns 110980(-252997); nonzeros 889624(-7940203)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    242901 rows
#    110980 cols (98569 binary, 0 integer, 12411 implied int., 0 continuous, 0 domain fixed)
#    889624 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2240352983.479     Large        0      0      0         0    54.6s
#  R       0       0         0   0.00%   1338073.945286  823331303.2192    99.84%        0      0      0     50867   154.6s
#          0       0         0   0.00%   1338396.207191  823331303.2192    99.84%      413    140      0     51303   161.9s
#          0       0         0   0.00%   1338834.350048  823331303.2192    99.84%      470    198      0     51455   171.8s
#          0       0         0   0.00%   1339313.683381  823331303.2192    99.84%      472    253   1777     51540   183.3s
#          0       0         0   0.00%   1339408.350048  823331303.2192    99.84%      564    265   1777     52229   206.1s
#          0       0         0   0.00%   1339462.350048  823331303.2192    99.84%      678    271   1777     52453   227.0s
#          0       0         0   0.00%   1339480.501687  823331303.2192    99.84%      682    274   1777     58776   245.6s
#          0       0         0   0.00%   1339544.168353  823331303.2192    99.84%     1017    279   1777     59001   253.1s
#          0       0         0   0.00%   1339577.168353  823331303.2192    99.84%     1025    281   1777     59137   260.0s
#          0       0         0   0.00%   1339577.209917  823331303.2192    99.84%     1036    282   1777     62291   272.5s
#          0       0         0   0.00%   1339587.515685  823331303.2192    99.84%     1242    287   1777     74202   308.4s
#          0       0         0   0.00%   1339587.567706  823331303.2192    99.84%     2290    289   1777     80582   335.7s
#          0       0         0   0.00%   1339587.567706  823331303.2192    99.84%     2683    242   1777     80606   354.0s
#          0       0         0   0.00%   1339587.567706  823331303.2192    99.84%     2756    243   1777     80663   369.1s
#          0       0         0   0.00%   1339587.567706  823331303.2192    99.84%     2770    244   1777     80683   385.1s
#          0       0         0   0.00%   1339587.968853  823331303.2192    99.84%     2788    245   1777     94278   434.8s
#          0       0         0   0.00%   1339593.557078  823331303.2192    99.84%     3180    252   1777    112451   500.6s
#          0       0         0   0.00%   1339593.557078  823331303.2192    99.84%     4257    256   1777    113554   520.3s
#          0       0         0   0.00%   1339593.557078  823331303.2192    99.84%     4373    259   1777    113954   535.0s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   1339593.557078  823331303.2192    99.84%     4465    262   1777    113993   554.1s
#          0       0         0   0.00%   1339593.557078  823331303.2192    99.84%     4591    264   1777    114185   570.8s
#          0       0         0   0.00%   1339593.557078  823331303.2192    99.84%     4648    259   1777    114220   580.6s
#          0       0         0   0.00%   1339593.557078  823331303.2192    99.84%     4731    261   1777    114246   591.1s
#          0       0         0   0.00%   1339593.557078  823331303.2192    99.84%     4827    263   1777    114333   601.0s
#  L       0       0         0   0.00%   1339593.557078  1340258.050228     0.05%     4827    263   1777    114333   750.9s
#          1       0         1 100.00%   1339593.557078  1340258.050228     0.05%     4776    263   1777    172420   751.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      1340258.05023
#   Dual bound        1339593.55708
#   Gap               0.0496% (tolerance: 0.5%)
#   P-D integral      694.901045263
#   Solution status   feasible
#                     1340258.05023 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            751.09
#   Max sub-MIP depth 3
#   Nodes             1
#   Repair LPs        0
#   LP iterations     172420
#                     0 (strong br.)
#                     63466 (separation)
#                     58087 (heuristics)
#     ✓ P90 optimisation complete   [876.06s]
#
# [P90 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   3                     2
# 2                            0                   7                     6
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      2               0                   2              0
# 2                      6               0                   3              0
# 3                      3               0                   0              0
#
# [P90] Running fleet expansion scenario: +1 future copy per future model
#     ✓ prepare_model_data started | flights=6,066   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.03s]
#     ✓ ambulift intervals built | flights=6,066 ambulifts=14   [10.51s]
#     ✓ minibus intervals built | minibuses=5   [0.09s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=3,530,975   [0.92s]
#     ✓ minibus overlaps built | overlaps=531,065   [0.13s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=11.71s   [0.00s]
#     ✓ sets built | F=6,066 AMB=14 MINI=5   [0.00s]
#     ✓ variables built | x=30,330 amb=254,772 mini=60,660   [0.49s]
#     ✓ ambulift overlap constraints built | 3,530,975   [22.92s]
#     ✓ minibus overlap constraints built | 531,065   [2.98s]
#     ✓ build_pyomo_model complete | total=27.12s   [0.73s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,066 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 4535315 rows; 388245 cols; 9448795 nonzeros; 345783 integer variables (345783 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -1
# Presolving model
# 687254 rows, 142402 cols, 1495339 nonzeros 5s
# 284247 rows, 123116 cols, 1013845 nonzeros 23s
# 284247 rows, 123116 cols, 1013845 nonzeros 49s
# Presolve reductions: rows 284247(-4251068); columns 123116(-265129); nonzeros 1013845(-8434950)
#
# Solving MIP model with:
#    284247 rows
#    123116 cols (110705 binary, 0 integer, 12411 implied int., 0 continuous, 0 domain fixed)
#    1013845 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2324718093.936     Large        0      0      0         0    59.5s
#  R       0       0         0   0.00%   518844.221666   718512655.4475    99.93%        0      0      0     65513   206.8s
#          0       0         0   0.00%   518890.783007   718512655.4475    99.93%     1047     37      0     82255   268.0s
#          0       0         0   0.00%   519076.118721   718512655.4475    99.93%     1965     95      0     83043   274.0s
#          0       0         0   0.00%   519088.952055   718512655.4475    99.93%     2223    109      0     83156   298.3s
#  C       0       0         0   0.00%   519167.785388   554696501.9269    99.91%     2233    120      0     84061   304.3s
#          0       0         0   0.00%   519247.118721   554696501.9269    99.91%     2856    130      0     84350   329.6s
#          0       0         0   0.00%   519269.785388   554696501.9269    99.91%     2968    135      0     84583   337.4s
#          0       0         0   0.00%   519274.785388   554696501.9269    99.91%     3126    141      0     85287   345.4s
#          0       0         0   0.00%   519274.785388   554696501.9269    99.91%     3272    144      0     85317   355.4s
#  L       0       0         0   0.00%   519274.785388   519380.525114      0.02%     3348    146      0     85436   590.5s
#          1       0         1 100.00%   519274.785388   519380.525114      0.02%     3348    146      0    128198   590.6s
#
# Solving report
#   Status            Optimal
#   Primal bound      519380.525114
#   Dual bound        519274.785388
#   Gap               0.0204% (tolerance: 0.5%)
#   P-D integral      530.147773687
#   Solution status   feasible
#                     519380.525114 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            590.64
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     128198
#                     0 (strong br.)
#                     19923 (separation)
#                     42762 (heuristics)
# [P90] Stopping fleet expansion: scenario +1 meets SLA and has no shortfall.
#     ✓ P90 fleet expansion search complete   [739.30s]
#     ✓ Excel outputs written to outputs\prm_combined\monthly\2026_04_v2.xlsx   [14.57s]
#
# Completed month: 2026_04
# Workbook: outputs\prm_combined\monthly\2026_04_combined.xlsx
#    S1_PeakAmb  S1_PeakMini  S1_PeakDrivers  S1_PeakVehAgents  S2_PeakAmb  \
# 0          13            5              14                14           9
# 1          11            4              13                13           9
#
#    S2_PeakMini  S2_PeakDrivers  S2_PeakVehAgents  V2_arrival_sla_pct  \
# 0           13              18                18            99.42312
# 1           11              18                18           100.00000
#
#    V2_PeakAmb  V2_PeakMini
# 0          10            3
# 1           9            3

# %%
may_result = run_combined_month(
    2026,
    5,
)

pd.DataFrame(may_result["month_rows"])
# Out:
# ================================================================================
# RUNNING COMBINED MONTH: 2026_05
# ================================================================================
#
# Running S1 P100
#
# Unmatched passenger rows after merge (missing Chocks DT): 852
# Unique unmatched flight keys: 458
#
# Unmatched key reasons:
# reason
# no_flight_candidate               449
# exact_match_should_have_joined      5
# scheduled_dt_mismatch               4
# Name: count, dtype: int64
#
# Dropped 837 passenger rows due to reasons {'scheduled_dt_mismatch', 'no_flight_candidate'}
# [BUILD_JOBS] Dropping 1 jobs already impossible at release (beyond SLA + max late)
# Running S2 P100
#
# Running S1 P90
#
# Unmatched passenger rows after merge (missing Chocks DT): 852
# Unique unmatched flight keys: 458
#
# Unmatched key reasons:
# reason
# no_flight_candidate               449
# exact_match_should_have_joined      5
# scheduled_dt_mismatch               4
# Name: count, dtype: int64
#
# Dropped 837 passenger rows due to reasons {'scheduled_dt_mismatch', 'no_flight_candidate'}
# [BUILD_JOBS] Dropping 1 jobs already impossible at release (beyond SLA + max late)
# [BUILD_JOBS] Applying stratified percentile cap: q=0.90 | strata=['SSR Code', 'Has Own Chair', 'A/D']
# [BUILD_JOBS] Dropped 752 PRM jobs via stratified percentile cap
# Running S2 P90
#
# Running V2 optimiser
#     ✓ S25 ingest complete (19,832 passengers)   [42.75s]
#     ✓ Passenger dataset combined (19,832 passenger rows)   [0.00s]
#     ✓ P100 built (7,139 flights)   [0.17s]
#     P100 demand summary: 19,832 PRMs across 7,139 flights
#     ✓ prepare_model_data started | flights=7,139   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.03s]
#     ✓ ambulift intervals built | flights=7,139 ambulifts=14   [0.94s]
#     ✓ minibus intervals built | minibuses=3   [0.07s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=4,850,181   [0.85s]
#     ✓ minibus overlaps built | overlaps=426,888   [0.07s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.01s]
#     ✓ prepare_model_data complete | total=1.98s   [0.00s]
#     ✓ sets built | F=7,139 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=35,695 amb=299,838 mini=42,834   [0.68s]
#     ✓ ambulift overlap constraints built | 4,850,181   [24.93s]
#     ✓ minibus overlap constraints built | 426,888   [3.51s]
#     ✓ build_pyomo_model complete | total=29.61s   [0.49s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,139 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 5748621 rows; 428357 cols; 11885286 nonzeros; 378384 integer variables (378384 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 704826 rows, 146837 cols, 1517900 nonzeros 6s
# 286183 rows, 129249 cols, 1092080 nonzeros 27s
# 264761 rows, 129226 cols, 1038942 nonzeros 52s
# Presolve reductions: rows 264761(-5483860); columns 129226(-299131); nonzeros 1038942(-10846344)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    264761 rows
#    129226 cols (114558 binary, 0 integer, 14668 implied int., 0 continuous, 0 domain fixed)
#    1038942 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2927493366.479     Large        0      0      0         0    60.6s
#  R       0       0         0   0.00%   49443164.40163  1712431357.297    97.11%        0      0      0     59438   240.4s
#          0       0         0   0.00%   57278282.94364  1712431357.297    96.66%     1540    327      0     60290   249.3s
#          0       0         0   0.00%   58214163.66691  1712431357.297    96.60%     2193    827      0     61654   255.8s
#          0       0         0   0.00%   58450731.05104  1712431357.297    96.59%     2436    962   1493     62943   273.0s
#          0       0         0   0.00%   58451494.30737  1712431357.297    96.59%     2527    999   1493     63876   282.3s
#          0       0         0   0.00%   58452223.49583  1712431357.297    96.59%     2741   1046   1493     65733   293.0s
#          0       0         0   0.00%   58452336.95832  1712431357.297    96.59%     2896   1059   1493     66568   300.1s
#          0       0         0   0.00%   58452406.29165  1712431357.297    96.59%     3057   1068   1493     66647   305.2s
#          0       0         0   0.00%   58452406.29165  1712431357.297    96.59%     3209   1072   1493     66740   313.2s
#          0       0         0   0.00%   58452419.33927  1712431357.297    96.59%     3316   1080   1493     67512   320.7s
#          0       0         0   0.00%   58452419.33927  1712431357.297    96.59%     3515   1093   1493     68559   331.3s
#          0       0         0   0.00%   58452419.33927  1712431357.297    96.59%     3688    963   1493     69301   342.5s
#  L       0       0         0   0.00%   58452419.33927  58454085.2968      0.00%     3688    963   1493     69301   542.6s
#          1       0         1 100.00%   58452419.33927  58454085.2968      0.00%     3688    963   1493     95789   542.7s
#
# Solving report
#   Status            Optimal
#   Primal bound      58454085.2968
#   Dual bound        58452419.3425
#   Gap               0.00285% (tolerance: 0.5%)
#   P-D integral      471.04665543
#   Solution status   feasible
#                     58454085.2968 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            542.70
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     95789
#                     0 (strong br.)
#                     9863 (separation)
#                     26488 (heuristics)
#     ✓ P100 optimisation complete   [694.40s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     4
# 2                            0                   9                     6
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      4               0                   0              0
# 2                      6               0                   3              0
# 3                      3               0                   0              0
#
# [P100] Fleet expansion triggered because: Shortfall=58.00
#
# [P100] Running fleet expansion scenario: +1 future copy per future model
#     ✓ prepare_model_data started | flights=7,139   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.03s]
#     ✓ ambulift intervals built | flights=7,139 ambulifts=14   [0.72s]
#     ✓ minibus intervals built | minibuses=5   [0.07s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=4,850,181   [0.86s]
#     ✓ minibus overlaps built | overlaps=711,480   [0.13s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.83s   [0.00s]
#     ✓ sets built | F=7,139 AMB=14 MINI=5   [0.01s]
#     ✓ variables built | x=35,695 amb=299,838 mini=71,390   [18.75s]
#     ✓ ambulift overlap constraints built | 4,850,181   [32.09s]
#     ✓ minibus overlap constraints built | 711,480   [3.55s]
#     ✓ build_pyomo_model complete | total=55.41s   [1.01s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,139 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 6118883 rows; 456917 cols; 12682922 nonzeros; 406944 integer variables (406944 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 881126 rows, 165953 cols, 1894166 nonzeros 7s
# 334762 rows, 143532 cols, 1242567 nonzeros 33s
# 334762 rows, 143532 cols, 1242567 nonzeros 65s
# Presolve reductions: rows 334762(-5784121); columns 143532(-313385); nonzeros 1242567(-11440355)
#
# Solving MIP model with:
#    334762 rows
#    143532 cols (128858 binary, 0 integer, 14674 implied int., 0 continuous, 0 domain fixed)
#    1242567 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2945858486.936     Large        0      0      0         0    76.2s
#  R       0       0         0   0.00%   2787072.019703  1225778955.753    99.77%        0      0      0     74092   458.9s
#          0       0         0   0.00%   2787339.920812  1225778955.753    99.77%     1270    163      0     74409   473.0s
#          0       0         0   0.00%   2788218.111641  1225778955.753    99.77%     1619    431      0     75674   481.6s
#          0       0         0   0.00%   2788724.840126  1225778955.753    99.77%     1852    566   1192     75980   492.1s
#          0       0         0   0.00%   2789056.011275  1225778955.753    99.77%     1918    626   1192     76954   501.4s
#          0       0         0   0.00%   2789139.972813  1225778955.753    99.77%     2031    644   1192     77475   508.3s
#          0       0         0   0.00%   2789162.590762  1225778955.753    99.77%     2110    652   1192     77623   513.9s
#          0       0         0   0.00%   2789188.679224  1225778955.753    99.77%     2238    665   1192     78425   521.4s
#          0       0         0   0.00%   2789190.429224  1225778955.753    99.77%     2364    673   1192     79462   528.0s
#          0       0         0   0.00%   2789243.262557  1225778955.753    99.77%     2608    696   1192     79861   573.2s
#          0       0         0   0.00%   2789257.329224  1225778955.753    99.77%     2673    562   1192     79885   580.0s
#          0       0         0   0.00%   2789297.021531  1225778955.753    99.77%     2753    570   1192     79910   587.1s
#          0       0         0   0.00%   2789298.688198  1225778955.753    99.77%     2947    576   1192     79933   626.2s
#          0       0         0   0.00%   2789302.354865  1225778955.753    99.77%     3002    583   1192     79956   633.0s
#          0       0         0   0.00%   2789303.829224  1225778955.753    99.77%     3085    589   1192     80017   657.6s
#          0       0         0   0.00%   2789308.787557  1225778955.753    99.77%     3147    527   1192     80038   662.8s
#          0       0         0   0.00%   2789369.062557  1225778955.753    99.77%     3198    537   1192     80585   671.4s
#          0       0         0   0.00%   2789369.062557  1225778955.753    99.77%     3334    541   1192     80635   691.9s
#          0       0         0   0.00%   2789369.062557  1225778955.753    99.77%     3435    545   1192     80742   702.9s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   2789369.340335  1225778955.753    99.77%     3528    549   1192     80768   715.0s
#  L       0       0         0   0.00%   2789369.340335  2789648.753425     0.01%     3528    549   1192     80768  1019.8s
#          1       0         1 100.00%   2789369.340335  2789648.753425     0.01%     3528    549   1192    101326  1019.9s
#
# Solving report
#   Status            Optimal
#   Primal bound      2789648.75342
#   Dual bound        2789369.34033
#   Gap               0.01% (tolerance: 0.5%)
#   P-D integral      941.68421546
#   Solution status   feasible
#                     2789648.75342 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            1019.92
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     101326
#                     0 (strong br.)
#                     6676 (separation)
#                     20558 (heuristics)
#
# [P100] Running fleet expansion scenario: +2 future copy per future model
#     ✓ prepare_model_data started | flights=7,139   [0.00s]
#     ✓ vehicle expansion complete | vehicles=21   [0.03s]
#     ✓ ambulift intervals built | flights=7,139 ambulifts=14   [0.80s]
#     ✓ minibus intervals built | minibuses=7   [0.08s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=4,850,181   [0.91s]
#     ✓ minibus overlaps built | overlaps=996,072   [0.18s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=2.04s   [0.00s]
#     ✓ sets built | F=7,139 AMB=14 MINI=7   [0.01s]
#     ✓ variables built | x=35,695 amb=299,838 mini=99,946   [0.26s]
#     ✓ ambulift overlap constraints built | 4,850,181   [50.16s]
#     ✓ minibus overlap constraints built | 996,072   [5.59s]
#     ✓ build_pyomo_model complete | total=56.85s   [0.84s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,139 Vehicles=21
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 6489145 rows; 485477 cols; 13480558 nonzeros; 435504 integer variables (435504 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 1057426 rows, 185069 cols, 2270432 nonzeros 11s
# 383606 rows, 157814 cols, 1394733 nonzeros 42s
# 383606 rows, 157814 cols, 1394733 nonzeros 76s
# Presolve reductions: rows 383606(-6105539); columns 157814(-327663); nonzeros 1394733(-12085825)
#
# Solving MIP model with:
#    383606 rows
#    157814 cols (143140 binary, 0 integer, 14674 implied int., 0 continuous, 0 domain fixed)
#    1394733 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2831224007.393     Large        0      0      0         0    88.7s
#  R       0       0         0   0.00%   1150608.70043   1189142292.21     99.90%        0      0      0    104521   646.9s
#          0       0         0   0.00%   1150681.422652  1189142292.21     99.90%      652    113      0    105480   656.7s
#          0       0         0   0.00%   1151087.433464  1189142292.21     99.90%      874    286      0    105854   663.3s
#          0       0         0   0.00%   1151314.409654  1189142292.21     99.90%     1064    359   1006    106598   689.9s
#          0       0         0   0.00%   1151363.219178  1189142292.21     99.90%     1149    378   1006    106666   700.7s
#          0       0         0   0.00%   1151363.219178  1189142292.21     99.90%     1230    383   1006    106737   711.7s
#          0       0         0   0.00%   1151364.885845  1189142292.21     99.90%     1267    387   1006    106751   723.4s
#          0       0         0   0.00%   1151369.885845  1189142292.21     99.90%     1346    391   1006    106808   732.4s
#          0       0         0   0.00%   1151369.885845  1189142292.21     99.90%     1448    392   1006    106811   744.1s
#          0       0         0   0.00%   1151369.885845  1189142292.21     99.90%     1466    394   1006    106845   753.1s
#          0       0         0   0.00%   1151369.885845  1189142292.21     99.90%     1573    396   1006    106896   771.2s
#          0       0         0   0.00%   1151369.885845  1189142292.21     99.90%     1643    399   1006    106978   784.6s
#  L       0       0         0   0.00%   1151369.885845  1151495.210046     0.01%     1643    399   1006    106978   986.8s
#          1       0         1 100.00%   1151369.885845  1151495.210046     0.01%     1643    399   1006    120989   986.9s
#
# Solving report
#   Status            Optimal
#   Primal bound      1151495.21005
#   Dual bound        1151369.88584
#   Gap               0.0109% (tolerance: 0.5%)
#   P-D integral      896.903993617
#   Solution status   feasible
#                     1151495.21005 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            986.95
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     120989
#                     0 (strong br.)
#                     2457 (separation)
#                     14011 (heuristics)
# [P100] Stopping fleet expansion: scenario +2 meets SLA and has no shortfall.
#     ✓ P100 fleet expansion search complete   [2428.54s]
#     ✓ P90 built (7,139 flights)   [0.80s]
#     P90 demand summary: 18,402 PRMs across 7,139 flights
#     ✓ prepare_model_data started | flights=7,139   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.06s]
#     ✓ ambulift intervals built | flights=7,139 ambulifts=14   [0.97s]
#     ✓ minibus intervals built | minibuses=3   [0.09s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=4,778,620   [1.11s]
#     ✓ minibus overlaps built | overlaps=426,894   [0.13s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.03s]
#     ✓ prepare_model_data complete | total=2.40s   [0.00s]
#     ✓ sets built | F=7,139 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=35,695 amb=299,838 mini=42,834   [0.33s]
#     ✓ ambulift overlap constraints built | 4,778,620   [78.43s]
#     ✓ minibus overlap constraints built | 426,894   [1.40s]
#     ✓ build_pyomo_model complete | total=81.00s   [0.83s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,139 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 5676987 rows; 428357 cols; 11742097 nonzeros; 378384 integer variables (378384 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 1e+01]
#   Cost    [2e+00, 3e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -2
# Presolving model
# 696610 rows, 147109 cols, 1506051 nonzeros 6s
# 285975 rows, 129529 cols, 1084141 nonzeros 31s
# 285975 rows, 129529 cols, 1084143 nonzeros 62s
# Presolve reductions: rows 285975(-5391012); columns 129529(-298828); nonzeros 1084143(-10657954)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    285975 rows
#    129529 cols (114838 binary, 0 integer, 14691 implied int., 0 continuous, 0 domain fixed)
#    1084143 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2853457508.479     Large        0      0      0         0    73.0s
#  R       0       0         0   0.00%   20420291.55853  1295411255.297    98.42%        0      0      0     55923   335.2s
#          0       0         0   0.00%   30421329.60226  1295411255.297    97.65%     1435    271      0     56904   344.2s
#          0       0         0   0.00%   30424854.92975  1295411255.297    97.65%     1870    672      0     57999   350.9s
#          0       0         0   0.00%   30427016.78798  1295411255.297    97.65%     2057    807   1841     59132   368.1s
#          0       0         0   0.00%   30427118.69274  1295411255.297    97.65%     2230    817   1841     59164   400.8s
#          0       0         0   0.00%   30427144.23927  1295411255.297    97.65%     2303    824   1841     59199   424.3s
#          0       0         0   0.00%   30427160.2708   1295411255.297    97.65%     2468    828   1841     59216   456.0s
#          0       0         0   0.00%   30427160.2708   1295411255.297    97.65%     2541    830   1841     59224   472.2s
#          0       0         0   0.00%   30427161.33747  1295411255.297    97.65%     2702    832   1841     59230   498.8s
#          0       0         0   0.00%   30427175.6708   1295411255.297    97.65%     2741    836   1841     59272   518.1s
#          0       0         0   0.00%   30427178.74223  1295411255.297    97.65%     2935    839   1841     59304   539.2s
#  L       0       0         0   0.00%   30427178.74223  30427858.2968      0.00%     2935    839   1841     59304   753.3s
#          1       0         1 100.00%   30427178.74223  30427858.2968      0.00%     2935    839   1841     82860   753.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      30427858.2968
#   Dual bound        30427178.7443
#   Gap               0.00223% (tolerance: 0.5%)
#   P-D integral      670.171076376
#   Solution status   feasible
#                     30427858.2968 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            753.50
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     82860
#                     0 (strong br.)
#                     3381 (separation)
#                     23556 (heuristics)
#     ✓ P90 optimisation complete   [968.53s]
#
# [P90 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     3
# 2                            0                   9                     6
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      3               0                   1              0
# 2                      6               0                   3              0
# 3                      3               0                   0              0
#
# [P90] Fleet expansion triggered because: Shortfall=30.00
#
# [P90] Running fleet expansion scenario: +1 future copy per future model
#     ✓ prepare_model_data started | flights=7,139   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.06s]
#     ✓ ambulift intervals built | flights=7,139 ambulifts=14   [0.79s]
#     ✓ minibus intervals built | minibuses=5   [0.07s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=4,778,620   [0.92s]
#     ✓ minibus overlaps built | overlaps=711,490   [0.13s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=2.00s   [0.00s]
#     ✓ sets built | F=7,139 AMB=14 MINI=5   [0.01s]
#     ✓ variables built | x=35,695 amb=299,838 mini=71,390   [0.24s]
#     ✓ ambulift overlap constraints built | 4,778,620   [54.68s]
#     ✓ minibus overlap constraints built | 711,490   [3.87s]
#     ✓ build_pyomo_model complete | total=59.54s   [0.75s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,139 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 6047253 rows; 456917 cols; 12539741 nonzeros; 406944 integer variables (406944 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 3e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -2
# Presolving model
# 872962 rows, 166225 cols, 1882421 nonzeros 11s
# 335141 rows, 143811 cols, 1237762 nonzeros 46s
# 335141 rows, 143811 cols, 1237762 nonzeros 80s
# Presolve reductions: rows 335141(-5712112); columns 143811(-313106); nonzeros 1237762(-11301979)
#
# Solving MIP model with:
#    335141 rows
#    143811 cols (129120 binary, 0 integer, 14691 implied int., 0 continuous, 0 domain fixed)
#    1237762 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2757823038.936     Large        0      0      0         0    92.9s
#  R       0       0         0   0.00%   595793.919961   1259587111.525    99.95%        0      0      0     65022   381.3s
#          0       0         0   0.00%   596036.237926   1259587111.525    99.95%     1153    143      0     65357   391.9s
#          0       0         0   0.00%   641080.413114   1259587111.525    99.95%     1328    286      0     66664   399.0s
#          0       0         0   0.00%   686740.109513   1259587111.525    99.95%     1514    501      0     67701   407.6s
#          0       0         0   0.00%   776948.679224   1259587111.525    99.94%     1599    570   1741     68395   416.7s
#          0       0         0   0.00%   777125.798271   1259587111.525    99.94%     1876    597   1741     68463   526.1s
#          0       0         0   0.00%   777179.381605   1259587111.525    99.94%     1962    613   1741     68573   532.6s
#          0       0         0   0.00%   777224.618967   1259587111.525    99.94%     2073    621   1741     69274   540.7s
#          0       0         0   0.00%   777232.09589    1259587111.525    99.94%     2269    633   1741     69346   547.1s
#          0       0         0   0.00%   777251.09589    1259587111.525    99.94%     2383    638   1741     69784   553.9s
#          0       0         0   0.00%   777251.09589    1259587111.525    99.94%     2470    453   1741     70361   560.2s
#  L       0       0         0   0.00%   777251.09589    778308.260274      0.14%     2470    453   1741     70361   774.9s
#          1       0         1 100.00%   777251.09589    778308.260274      0.14%     2470    453   1741     89894   775.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      778308.260274
#   Dual bound        777251.09589
#   Gap               0.136% (tolerance: 0.5%)
#   P-D integral      681.141063959
#   Solution status   feasible
#                     778308.260274 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            775.03
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     89894
#                     0 (strong br.)
#                     5339 (separation)
#                     19533 (heuristics)
# [P90] Stopping fleet expansion: scenario +1 meets SLA and has no shortfall.
#     ✓ P90 fleet expansion search complete   [975.58s]
#     ✓ Excel outputs written to outputs\prm_combined\monthly\2026_05_v2.xlsx   [17.93s]
#
# Completed month: 2026_05
# Workbook: outputs\prm_combined\monthly\2026_05_combined.xlsx
#    S1_PeakAmb  S1_PeakMini  S1_PeakDrivers  S1_PeakVehAgents  S2_PeakAmb  \
# 0          20            7              21                21           8
# 1          18            5              19                19           8
#
#    S2_PeakMini  S2_PeakDrivers  S2_PeakVehAgents  V2_arrival_sla_pct  \
# 0           17              22                22           98.252248
# 1           15              19                19           99.165533
#
#    V2_PeakAmb  V2_PeakMini
# 0          11            3
# 1          10            3

# %%
june_result = run_combined_month(
    2026,
    6,
)

pd.DataFrame(june_result["month_rows"])
# Out:
# ================================================================================
# RUNNING COMBINED MONTH: 2026_06
# ================================================================================
#
# Running S1 P100
#
# Unmatched passenger rows after merge (missing Chocks DT): 858
# Unique unmatched flight keys: 454
#
# Unmatched key reasons:
# reason
# no_flight_candidate               383
# scheduled_dt_mismatch              48
# exact_match_should_have_joined     23
# Name: count, dtype: int64
#
# Dropped 811 passenger rows due to reasons {'scheduled_dt_mismatch', 'no_flight_candidate'}
# [BUILD_JOBS] Dropping 14 jobs already impossible at release (beyond SLA + max late)
# Running S2 P100
#
# Running S1 P90
#
# Unmatched passenger rows after merge (missing Chocks DT): 858
# Unique unmatched flight keys: 454
#
# Unmatched key reasons:
# reason
# no_flight_candidate               383
# scheduled_dt_mismatch              48
# exact_match_should_have_joined     23
# Name: count, dtype: int64
#
# Dropped 811 passenger rows due to reasons {'scheduled_dt_mismatch', 'no_flight_candidate'}
# [BUILD_JOBS] Dropping 14 jobs already impossible at release (beyond SLA + max late)
# [BUILD_JOBS] Applying stratified percentile cap: q=0.90 | strata=['SSR Code', 'Has Own Chair', 'A/D']
# [BUILD_JOBS] Dropped 715 PRM jobs via stratified percentile cap
# Running S2 P90
#
# Running V2 optimiser
#     ✓ S25 ingest complete (19,272 passengers)   [53.90s]
#     ✓ Passenger dataset combined (19,272 passenger rows)   [0.00s]
#     ✓ P100 built (7,133 flights)   [0.17s]
#     P100 demand summary: 19,272 PRMs across 7,133 flights
#     ✓ prepare_model_data started | flights=7,133   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.03s]
#     ✓ ambulift intervals built | flights=7,133 ambulifts=14   [0.72s]
#     ✓ minibus intervals built | minibuses=3   [0.07s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=4,914,689   [0.87s]
#     ✓ minibus overlaps built | overlaps=437,124   [0.08s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.80s   [0.00s]
#     ✓ sets built | F=7,133 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=35,665 amb=299,586 mini=42,798   [0.61s]
#     ✓ ambulift overlap constraints built | 4,914,689   [28.90s]
#     ✓ minibus overlap constraints built | 437,124   [1.30s]
#     ✓ build_pyomo_model complete | total=31.57s   [0.76s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,133 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 5822944 rows; 427997 cols; 12033635 nonzeros; 378066 integer variables (378066 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 756437 rows, 151773 cols, 1622282 nonzeros 6s
# 299962 rows, 133203 cols, 1154260 nonzeros 31s
# 278560 rows, 133195 cols, 1101319 nonzeros 63s
# Presolve reductions: rows 278560(-5544384); columns 133195(-294802); nonzeros 1101319(-10932316)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    278560 rows
#    133195 cols (118258 binary, 0 integer, 14937 implied int., 0 continuous, 0 domain fixed)
#    1101319 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3152496091.479     Large        0      0      0         0    73.5s
#  R       0       0         0   0.00%   28618699.9611   1257444031.388    97.72%        0      0      0     75159   217.0s
#          0       0         0   0.00%   35788153.35269  1257444031.388    97.15%     1762    518      0     77061   224.9s
#          0       0         0   0.00%   36458143.39369  1257444031.388    97.10%     1937    767      0     78911   232.6s
#  C       0       0         0   0.00%   36458271.14369  815447122.2968    95.53%     1968    785      0     79784   237.8s
#          0       0         0   0.00%   36458321.3112   815447122.2968    95.53%     2027    799      0     91517   273.6s
#          0       0         0   0.00%   36460150.75932  815447122.2968    95.53%     2487    843      0     97999   300.5s
#          0       0         0   0.00%   36460281.42599  815447122.2968    95.53%     2656    858      0     98706   311.4s
#          0       0         0   0.00%   36460304.62599  815447122.2968    95.53%     2661    864      0     98859   320.6s
#          0       0         0   0.00%   36460308.19742  815447122.2968    95.53%     2664    867      0     99167   331.7s
#          0       0         0   0.00%   36460308.19742  815447122.2968    95.53%     2664    869      0     99322   342.6s
#          0       0         0   0.00%   36460308.19742  815447122.2968    95.53%     2664    871      0     99678   353.7s
#          0       0         0   0.00%   36460308.19742  815447122.2968    95.53%     2666    873      0     99766   363.9s
#          0       0         0   0.00%   36460308.19742  815447122.2968    95.53%     2666    771      0    100428   376.8s
#          0       0         0   0.00%   36460365.31965  815447122.2968    95.53%     2700    774      0    112484   423.8s
#          0       0         0   0.00%   36461010.0724   815447122.2968    95.53%     3142    840      0    112819   432.3s
#          0       0         0   0.00%   36461198.94308  815447122.2968    95.53%     3201    906      0    113482   437.5s
#          0       0         0   0.00%   36461254.6336   815447122.2968    95.53%     3229    905      0    128092   476.0s
#          0       0         0   0.00%   36461372.06218  815447122.2968    95.53%     3452    922      0    128222   481.5s
#          0       0         0   0.00%   36461387.79551  815447122.2968    95.53%     3474    928      0    128281   486.7s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   36461422.90055  815447122.2968    95.53%     3483    935      0    138939   514.7s
#          0       0         0   0.00%   36461424.18309  815447122.2968    95.53%     3803    940      0    139153   534.0s
#          0       0         0   0.00%   36461427.49141  815447122.2968    95.53%     3835    942      0    142638   558.6s
#          0       0         0   0.00%   36461427.49141  815447122.2968    95.53%     3989    955      0    142981   566.2s
#          0       0         0   0.00%   36461427.49141  815447122.2968    95.53%     4018    958      0    143313   578.3s
#          0       0         0   0.00%   36461427.49141  815447122.2968    95.53%     4028    961      0    144058   583.4s
#  L       0       0         0   0.00%   36461427.49141  36462020.21918     0.00%     4028    961      0    144058   743.7s
#          1       0         1 100.00%   36461427.49141  36462020.21918     0.00%     3362    961      0    176797   743.9s
#
# Solving report
#   Status            Optimal
#   Primal bound      36462020.2192
#   Dual bound        36461427.4932
#   Gap               0.00163% (tolerance: 0.5%)
#   P-D integral      646.554126729
#   Solution status   feasible
#                     36462020.2192 (objective)
#                     0 (bound viol.)
#                     7.9936057773e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            743.88
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     176797
#                     0 (strong br.)
#                     68899 (separation)
#                     32739 (heuristics)
#     ✓ P100 optimisation complete   [901.63s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   3                     3
# 2                            0                   5                     5
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      3               0                   1              0
# 2                      5               0                   4              0
# 3                      3               0                   0              0
#
# [P100] Fleet expansion triggered because: Shortfall=36.00
#
# [P100] Running fleet expansion scenario: +1 future copy per future model
#     ✓ prepare_model_data started | flights=7,133   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.03s]
#     ✓ ambulift intervals built | flights=7,133 ambulifts=14   [0.71s]
#     ✓ minibus intervals built | minibuses=5   [0.06s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=4,914,689   [0.94s]
#     ✓ minibus overlaps built | overlaps=728,540   [0.14s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.92s   [0.00s]
#     ✓ sets built | F=7,133 AMB=14 MINI=5   [0.00s]
#     ✓ variables built | x=35,665 amb=299,586 mini=71,330   [0.24s]
#     ✓ ambulift overlap constraints built | 4,914,689   [42.96s]
#     ✓ minibus overlap constraints built | 728,540   [4.89s]
#     ✓ build_pyomo_model complete | total=48.83s   [0.73s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,133 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 6199958 rows; 456533 cols; 12844727 nonzeros; 406602 integer variables (406602 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 940299 rows, 171169 cols, 2014044 nonzeros 8s
# 348463 rows, 147474 cols, 1305243 nonzeros 37s
# 348463 rows, 147474 cols, 1305243 nonzeros 72s
# Presolve reductions: rows 348463(-5851495); columns 147474(-309059); nonzeros 1305243(-11539484)
#
# Solving MIP model with:
#    348463 rows
#    147474 cols (132535 binary, 0 integer, 14939 implied int., 0 continuous, 0 domain fixed)
#    1305243 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3017861645.936     Large        0      0      0         0    85.5s
#  R       0       0         0   0.00%   799094.739555   999792509.0913    99.92%        0      0      0     48883   226.7s
#          0       0         0   0.00%   799418.667315   999792509.0913    99.92%     1206    130      0     49625   233.2s
#          0       0         0   0.00%   799553.662946   999792509.0913    99.92%     1356    240      0     51089   239.3s
#          0       0         0   0.00%   799957.459156   999792509.0913    99.92%     1498    383      0     52946   248.3s
#  C       0       0         0   0.00%   800075.934846   999790978.7534    99.92%     1525    415      0     53437   252.6s
#          0       0         0   0.00%   800217.328785   999790978.7534    99.92%     1544    447      0     54093   258.3s
#          0       0         0   0.00%   800261.622903   999790978.7534    99.92%     1561    458      0     54338   265.8s
#          0       0         0   0.00%   800336.172941   999790978.7534    99.92%     1574    471      0     54719   280.7s
#          0       0         0   0.00%   800437.451513   999790978.7534    99.92%     1611    487      0     56359   296.4s
#          0       0         0   0.00%   800455.451513   999790978.7534    99.92%     1643    495      0     57086   304.5s
#          0       0         0   0.00%   800460.814836   999790978.7534    99.92%     1688    506      0     73452   356.9s
#          0       0         0   0.00%   801383.214836   999790978.7534    99.92%     2580    454      0     73735   362.4s
#          0       0         0   0.00%   801401.184765   999790978.7534    99.92%     2640    466      0     80827   389.0s
#          0       0         0   0.00%   801454.73158    999790978.7534    99.92%     2903    479      0     89948   427.0s
#          0       0         0   0.00%   801529.398247   999790978.7534    99.92%     3515    486      0     90379   433.8s
#          0       0         0   0.00%   801537.48158    999790978.7534    99.92%     3606    493      0     90498   450.1s
#          0       0         0   0.00%   801577.334963   999790978.7534    99.92%     3680    474      0    106600   513.1s
#          0       0         0   0.00%   801578.749573   999790978.7534    99.92%     3811    482      0    109870   545.9s
#          0       0         0   0.00%   801578.749573   999790978.7534    99.92%     3978    488      0    110008   563.1s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   801592.249573   999790978.7534    99.92%     3987    496      0    110873   578.7s
#          0       0         0   0.00%   801599.249573   999790978.7534    99.92%     4013    444      0    111040   589.6s
#          0       0         0   0.00%   801616.688169   999790978.7534    99.92%     4055    449      0    111560   603.7s
#          0       0         0   0.00%   801616.688169   999790978.7534    99.92%     4197    454      0    111853   630.3s
#          0       0         0   0.00%   801617.279247   999790978.7534    99.92%     4215    457      0    123679   681.6s
#  L       0       0         0   0.00%   801617.279247   802215.675799      0.07%     4215    457      0    123679   798.5s
#          1       0         1 100.00%   801617.279247   802215.675799      0.07%     3593    457      0    167714   798.6s
#
# Solving report
#   Status            Optimal
#   Primal bound      802215.675799
#   Dual bound        801617.279247
#   Gap               0.0746% (tolerance: 0.5%)
#   P-D integral      711.953445231
#   Solution status   feasible
#                     802215.675799 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            798.62
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     167714
#                     0 (strong br.)
#                     74796 (separation)
#                     44035 (heuristics)
# [P100] Stopping fleet expansion: scenario +1 meets SLA and has no shortfall.
#     ✓ P100 fleet expansion search complete   [982.55s]
#     ✓ P90 built (7,133 flights)   [0.57s]
#     P90 demand summary: 18,114 PRMs across 7,133 flights
#     ✓ prepare_model_data started | flights=7,133   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.03s]
#     ✓ ambulift intervals built | flights=7,133 ambulifts=14   [0.72s]
#     ✓ minibus intervals built | minibuses=3   [0.06s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=4,851,962   [0.86s]
#     ✓ minibus overlaps built | overlaps=436,995   [0.08s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.79s   [0.00s]
#     ✓ sets built | F=7,133 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=35,665 amb=299,586 mini=42,798   [0.27s]
#     ✓ ambulift overlap constraints built | 4,851,962   [45.60s]
#     ✓ minibus overlap constraints built | 436,995   [1.48s]
#     ✓ build_pyomo_model complete | total=48.09s   [0.75s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,133 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 5759987 rows; 427997 cols; 11907822 nonzeros; 378066 integer variables (378066 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 1e+01]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -2
# Presolving model
# 748320 rows, 152077 cols, 1611262 nonzeros 9s
# 301186 rows, 133505 cols, 1152178 nonzeros 34s
# 301186 rows, 133505 cols, 1152178 nonzeros 69s
# Presolve reductions: rows 301186(-5458801); columns 133505(-294492); nonzeros 1152178(-10755644)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    301186 rows
#    133505 cols (118547 binary, 0 integer, 14958 implied int., 0 continuous, 0 domain fixed)
#    1152178 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3105463985.479     Large        0      0      0         0    81.3s
#  R       0       0         0   0.00%   8265313.397895  1395421177.297    99.41%        0      0      0     51949   372.5s
#          0       0         0   0.00%   13432934.11153  1395421177.297    99.04%     1378    232      0     52754   383.6s
#          0       0         0   0.00%   13434007.07423  1395421177.297    99.04%     1656    415      0     53586   388.9s
#          0       0         0   0.00%   13435979.55749  1395421177.297    99.04%     1826    565      0     54499   395.3s
#          0       0         0   0.00%   13437403.73924  1395421177.297    99.04%     1914    667      0     55553   401.6s
#          0       0         0   0.00%   13438286.87019  1395421177.297    99.04%     1991    696   1388     56285   415.6s
#          0       0         0   0.00%   13438427.52892  1395421177.297    99.04%     2349    709   1388     56378   529.4s
#          0       0         0   0.00%   13438503.36225  1395421177.297    99.04%     2518    716   1388     56422   582.5s
#          0       0         0   0.00%   13438516.14797  1395421177.297    99.04%     2975    722   1388     56448   808.5s
#          0       0         0   0.00%   13438516.3067   1395421177.297    99.04%     3091    725   1388     56462   839.6s
#          0       0         0   0.00%   13438516.86225  1395421177.297    99.04%     3202    728   1388     56478   863.4s
#          0       0         0   0.00%   13438523.86225  1395421177.297    99.04%     3327    730   1388     56493   911.7s
#          0       0         0   0.00%   13438523.86225  1395421177.297    99.04%     3441    732   1388     56609   944.3s
#          0       0         0   0.00%   13438523.86225  1395421177.297    99.04%     3492    734   1388     56656   950.0s
#  L       0       0         0   0.00%   13438523.86225  13438998.2968      0.00%     3492    734   1388     56656  1306.8s
#          1       0         1 100.00%   13438523.86225  13438998.2968      0.00%     3492    734   1388     98983  1306.9s
#
# Solving report
#   Status            Optimal
#   Primal bound      13438998.2968
#   Dual bound        13438523.863
#   Gap               0.00353% (tolerance: 0.5%)
#   P-D integral      1216.17936763
#   Solution status   feasible
#                     13438998.2968 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            1306.95
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     98983
#                     0 (strong br.)
#                     4707 (separation)
#                     42327 (heuristics)
#     ✓ P90 optimisation complete   [1476.66s]
#
# [P90 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     4
# 2                            0                   9                     8
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      4               0                   0              0
# 2                      8               0                   1              0
# 3                      3               0                   0              0
#
# [P90] Fleet expansion triggered because: Shortfall=13.00
#
# [P90] Running fleet expansion scenario: +1 future copy per future model
#     ✓ prepare_model_data started | flights=7,133   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.05s]
#     ✓ ambulift intervals built | flights=7,133 ambulifts=14   [0.88s]
#     ✓ minibus intervals built | minibuses=5   [0.06s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=4,851,962   [0.96s]
#     ✓ minibus overlaps built | overlaps=728,325   [0.15s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=2.13s   [0.00s]
#     ✓ sets built | F=7,133 AMB=14 MINI=5   [0.00s]
#     ✓ variables built | x=35,665 amb=299,586 mini=71,330   [0.24s]
#     ✓ ambulift overlap constraints built | 4,851,962   [41.40s]
#     ✓ minibus overlap constraints built | 728,325   [2.23s]
#     ✓ build_pyomo_model complete | total=44.57s   [0.70s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,133 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 6136915 rows; 456533 cols; 12718742 nonzeros; 406602 integer variables (406602 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -2
# Presolving model
# 932116 rows, 171473 cols, 2002892 nonzeros 8s
# 349607 rows, 147775 cols, 1302853 nonzeros 36s
# 349607 rows, 147775 cols, 1302853 nonzeros 72s
# Presolve reductions: rows 349607(-5787308); columns 147775(-308758); nonzeros 1302853(-11415889)
#
# Solving MIP model with:
#    349607 rows
#    147775 cols (132817 binary, 0 integer, 14958 implied int., 0 continuous, 0 domain fixed)
#    1302853 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2900829875.936     Large        0      0      0         0    85.7s
#  R       0       0         0   0.00%   789405.875603   1287778468.753    99.94%        0      0      0     75003   345.9s
#          0       0         0   0.00%   789479.54227    1287778468.753    99.94%     1021     77      0     75149   368.5s
#          0       0         0   0.00%   789525.35477    1287778468.753    99.94%     1148    146      0     75300   379.1s
#          0       0         0   0.00%   789845.291476   1287778468.753    99.94%     1197    204      0     75809   384.1s
#          0       0         0   0.00%   789899.360921   1287778468.753    99.94%     1467    244      0     75894   425.0s
#          0       0         0   0.00%   789987.097032   1287778468.753    99.94%     1597    276    988     76041   478.3s
#          0       0         0   0.00%   790163.513699   1287778468.753    99.94%     2020    300    988     76145   571.1s
#          0       0         0   0.00%   790264.513699   1287778468.753    99.94%     2092    312    988     76190   578.1s
#          0       0         0   0.00%   790320.847032   1287778468.753    99.94%     2438    329    988     76333   651.9s
#          0       0         0   0.00%   790350.347032   1287778468.753    99.94%     2515    338    988     77371   663.1s
#          0       0         0   0.00%   790359.013699   1287778468.753    99.94%     2693    342    988     77465   702.2s
#          0       0         0   0.00%   790362.013699   1287778468.753    99.94%     2767    344    988     77472   710.3s
#          0       0         0   0.00%   790362.013699   1287778468.753    99.94%     2979    345    988     77477   770.4s
#          0       0         0   0.00%   790362.013699   1287778468.753    99.94%     3129    346    988     77511   801.8s
#          0       0         0   0.00%   790362.013699   1287778468.753    99.94%     3214    274    988     77520   827.8s
#  L       0       0         0   0.00%   790362.013699   791165.260274      0.10%     3214    274    988     77520  1516.2s
#          1       0         1 100.00%   790362.013699   791165.260274      0.10%     3214    274    988    113342  1516.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      791165.260274
#   Dual bound        790362.013699
#   Gap               0.102% (tolerance: 0.5%)
#   P-D integral      1429.21983471
#   Solution status   feasible
#                     791165.260274 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            1516.37
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     113342
#                     0 (strong br.)
#                     2517 (separation)
#                     35822 (heuristics)
# [P90] Stopping fleet expansion: scenario +1 meets SLA and has no shortfall.
#     ✓ P90 fleet expansion search complete   [1692.27s]
#     ✓ Excel outputs written to outputs\prm_combined\monthly\2026_06_v2.xlsx   [17.81s]
#
# Completed month: 2026_06
# Workbook: outputs\prm_combined\monthly\2026_06_combined.xlsx
#    S1_PeakAmb  S1_PeakMini  S1_PeakDrivers  S1_PeakVehAgents  S2_PeakAmb  \
# 0          15            5              16                16           8
# 1          12            4              14                14           8
#
#    S2_PeakMini  S2_PeakDrivers  S2_PeakVehAgents  V2_arrival_sla_pct  \
# 0           17              25                25           99.024514
# 1           15              22                22           99.679898
#
#    V2_PeakAmb  V2_PeakMini
# 0           9            3
# 1          13            3

# %%
july_result = run_combined_month(
    2026,
    7,
)

pd.DataFrame(july_result["month_rows"])
# Out:
# ================================================================================
# RUNNING COMBINED MONTH: 2026_07
# ================================================================================
#
# Unmatched passenger rows after merge (missing Chocks DT): 4523
# Unique unmatched flight keys: 2750
#
# Unmatched key reasons:
# reason
# no_flight_candidate               1973
# scheduled_dt_mismatch              714
# exact_match_should_have_joined      63
# Name: count, dtype: int64
#
# Dropped 4406 passenger rows due to reasons {'scheduled_dt_mismatch', 'no_flight_candidate'}
# [1/5] Penetration + SSR mix…
#     ✓ penetration + SSR mix built   [432.61s]
# [2/5] Service times…
# [BUILD_JOBS] Dropping 36 jobs already impossible at release (beyond SLA + max late)
#
# [BUILD_JOBS] Dropping 4 arrival jobs with expired SLA window (max_late_mins=180).
#        Passenger ID Flight Number Airline Code      sla_start_time  \
# 99965      13159410           748           LS 2025-09-30 01:35:15
# 99966      13159411           748           LS 2025-09-30 01:35:15
# 99969      13159414           748           LS 2025-09-30 01:35:15
# 99970      13159415           748           LS 2025-09-30 01:35:15
#
#            Job Start Time  sla_limit           Chocks DT
# 99965 2025-09-30 04:59:07         20 2025-09-30 01:35:15
# 99966 2025-09-30 05:00:53         20 2025-09-30 01:35:15
# 99969 2025-09-30 04:59:15         20 2025-09-30 01:35:15
# 99970 2025-09-30 04:59:18         20 2025-09-30 01:35:15
#     ✓ service times built   [1.61s]
# [2b/5] Tau mode params (S25 medians)…
#     ✓ tau mode params built   [0.02s]
# [3/5] Chocks offsets…
#     ✓ chocks offsets built   [0.05s]
# [4/5] Early/late timing…
#     ✓ early/late params built   [0.05s]
# [5/5] Stand inputs…
#     ✓ stand inputs built   [0.06s]
#
# Running S1 P100
#
# Unmatched passenger rows after merge (missing Chocks DT): 492
# Unique unmatched flight keys: 254
#
# Unmatched key reasons:
# reason
# no_flight_candidate               238
# scheduled_dt_mismatch               9
# exact_match_should_have_joined      7
# Name: count, dtype: int64
#
# Dropped 478 passenger rows due to reasons {'scheduled_dt_mismatch', 'no_flight_candidate'}
# [BUILD_JOBS] Dropping 1 jobs already impossible at release (beyond SLA + max late)
#
# ================================================================================
# [DEBUG A] Future flights loaded & Pax computed
# ================================================================================
# df_flights rows: 5785
# Airlines (sample): ['EW' 'LS' 'U2' 'FR' 'DS' 'LM' 'BA' 'AF' 'KL' 'LH']
# Countries (sample): ['GERMANY' 'SPAIN' 'FRANCE' 'ITALY' 'GREECE' 'SLOVENIA' 'DENMARK' 'CYPRUS'
#  'NETHERLANDS' 'SWITZERLAND']
#
# Pax describe:
# count    5785.000000
# mean      155.076404
# std        50.701050
# min         0.000000
# 25%       136.000000
# 50%       169.000000
# 75%       185.000000
# max       397.000000
# Name: Pax, dtype: float64
#
# Top 10 rows (Airline, CountryName, Sector, dir, Pax):
#    Airline  CountryName         Sector dir    Pax
# 0       EW      GERMANY  International   D   85.0
# 1       LS        SPAIN  International   D  177.0
# 2       U2       FRANCE  International   D  186.0
# 3       FR        ITALY  International   D  180.0
# 4       LS        SPAIN  International   D  232.0
# 5       U2        SPAIN  International   D  177.0
# 6       FR        SPAIN  International   D  186.0
# 7       LS        SPAIN  International   D  222.0
# 8       LS       GREECE  International   D  155.0
# 9       U2     SLOVENIA  International   D  157.0
# 10      U2      DENMARK  International   D  155.0
# 11      U2       CYPRUS  International   D  178.0
# 12      EW      GERMANY  International   D  130.0
# 13      FR        ITALY  International   D  179.0
# 14      U2  NETHERLANDS  International   D  169.0
#
# ================================================================================
# [DEBUG B] Penetration lookup match rate
# ================================================================================
# Penetration keys available: 117
# Flights with penetration match: 5,553 / 5,785 (96.0%)
#
# Top missing (Airline, CountryName) combos in future flights:
#    Airline            CountryName  flight_rows
# 6       EC                  ITALY           38
# 3       DS            SWITZERLAND           38
# 8       EC                  SPAIN           38
# 4       EC                 FRANCE           28
# 7       EC            NETHERLANDS           18
# 5       EC                GERMANY           16
# 9       IB                  SPAIN           12
# 11      LG             LUXEMBOURG           10
# 14      RK                  MALTA            9
# 16      U2               SLOVENIA            8
# 15      RK                ROMANIA            4
# 1       BA                  ITALY            4
# 10      KK                AUSTRIA            2
# 2      BRO  SERBIA AND MONTENEGRO            2
# 13    None                AUSTRIA            2
#
# Example missing keys:
#     Airline  CountryName    Pax
# 9        U2     SLOVENIA  157.0
# 18       DS  SWITZERLAND  171.0
# 73       U2     SLOVENIA  137.0
# 200      EC        ITALY  114.0
# 202      EC       FRANCE  140.0
# 235      RK        MALTA  179.0
# 256      IB        SPAIN  166.0
# 263      DS  SWITZERLAND  164.0
# 264      DS  SWITZERLAND  149.0
# 266      EC       FRANCE  143.0
# 273      EC        SPAIN   95.0
# 279      EC        SPAIN  106.0
# 323      EC       FRANCE  174.0
# 333      EC        SPAIN  156.0
# 397      EC        ITALY  132.0
#
# ================================================================================
# [DEBUG C] Expected PRMs vs rounding
# ================================================================================
# Total expected PRMs (raw sum, BEFORE rounding): 9750.836253477126
# Total PRMs after rounding: 9872
#
# Raw PRM demand distribution (prm_raw):
# count    5785.000000
# mean        1.685538
# std         1.305320
# min         0.000000
# 25%         0.914104
# 50%         1.331169
# 75%         1.841055
# max         8.657703
# Name: _prm_raw, dtype: float64
#
# Top flights by raw PRM demand:
#      Airline               CountryName    Pax  _pen_used  _prm_raw  _prm_round
# 5234      BY                     SPAIN  188.0   0.046052  8.657703           9
# 2059      BY                     SPAIN  187.0   0.046052  8.611651           9
# 3556      VS  UNITED STATES OF AMERICA  397.0   0.021294  8.453666           8
# 2088      VS  UNITED STATES OF AMERICA  386.0   0.021294  8.219433           8
# 3950      BY                    GREECE  183.0   0.044835  8.204887           8
# 1750      BY                    GREECE  182.0   0.044835  8.160052           8
# 3201      BY                    GREECE  181.0   0.044835  8.115216           8
# 1846      VS  UNITED STATES OF AMERICA  380.0   0.021294  8.091670           8
# 3788      BY                    GREECE  179.0   0.044835  8.025545           8
# 2082      BY                    GREECE  177.0   0.044835  7.935874           8
# 1457      LS                  BULGARIA  185.0   0.042406  7.845200           8
# 114       LS                  BULGARIA  181.0   0.042406  7.675574           8
# 596       VS  UNITED STATES OF AMERICA  357.0   0.021294  7.601911           8
# 520       QR                     QATAR  254.0   0.028896  7.339531           7
# 3502      QR                     QATAR  254.0   0.028896  7.339531           7
# [DEBUG flight] Airline=EW | Country=GERMANY | Pax=85.0 | Pen=0.00340 | Pax*Pen=0.289 | PRMs=0
# [DEBUG flight] Airline=LS | Country=SPAIN | Pax=177.0 | Pen=0.02780 | Pax*Pen=4.921 | PRMs=5
# [DEBUG flight] Airline=U2 | Country=FRANCE | Pax=186.0 | Pen=0.00907 | Pax*Pen=1.687 | PRMs=2
# [DEBUG flight] Airline=FR | Country=ITALY | Pax=180.0 | Pen=0.00591 | Pax*Pen=1.065 | PRMs=1
# [DEBUG flight] Airline=LS | Country=SPAIN | Pax=232.0 | Pen=0.02780 | Pax*Pen=6.451 | PRMs=6
# [DEBUG flight] Airline=U2 | Country=SPAIN | Pax=177.0 | Pen=0.01493 | Pax*Pen=2.642 | PRMs=3
# [DEBUG flight] Airline=FR | Country=SPAIN | Pax=186.0 | Pen=0.01043 | Pax*Pen=1.939 | PRMs=2
# [DEBUG flight] Airline=LS | Country=SPAIN | Pax=222.0 | Pen=0.02780 | Pax*Pen=6.173 | PRMs=6
# [DEBUG flight] Airline=LS | Country=GREECE | Pax=155.0 | Pen=0.01888 | Pax*Pen=2.926 | PRMs=3
# [DEBUG flight] Airline=U2 | Country=SLOVENIA | Pax=157.0 | Pen=0.01000 | Pax*Pen=1.570 | PRMs=2
# [DEBUG flight] Airline=U2 | Country=DENMARK | Pax=155.0 | Pen=0.00907 | Pax*Pen=1.406 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=CYPRUS | Pax=178.0 | Pen=0.02357 | Pax*Pen=4.196 | PRMs=4
# [DEBUG flight] Airline=EW | Country=GERMANY | Pax=130.0 | Pen=0.00340 | Pax*Pen=0.441 | PRMs=0
# [DEBUG flight] Airline=FR | Country=ITALY | Pax=179.0 | Pen=0.00591 | Pax*Pen=1.059 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=NETHERLANDS | Pax=169.0 | Pen=0.00676 | Pax*Pen=1.142 | PRMs=1
#
# [DEBUG ingest_s26]
# Total PRM jobs (rows): 9872
# Columns: ['Passenger ID', 'Airline Code', 'Flight Number', 'A/D', 'Sector', 'CountryName', 'Stand', 'Scheduled Flight DT', 'Chocks DT', 'Minutes on Chocks', 'ScheduledDateTime_Local', 'Chocks_Est', 'Departure Gate', 'SSR Code', 'Has Own Chair', 'IsEffectiveRemote', 'PRM Flight Count', 'Concurrent Stress', 'Turnaround PRM Count', 'Turnaround Vertical Count', 'IsArrival', 'Adhoc Or Planned', 'IsAdhoc', 'Job Start Time', 'Job End Time', 'tau_amb_mins', 'tau_mini_mins', 'tau_push_mins']
# SSR Code present: True
# SSR Code distribution:
# SSR Code
# WCHR     5268
# WCHS     3993
# WCHC      557
# OTHER      54
# Name: count, dtype: int64
# Running S2 P100
#
# Running S1 P90
#
# Unmatched passenger rows after merge (missing Chocks DT): 492
# Unique unmatched flight keys: 254
#
# Unmatched key reasons:
# reason
# no_flight_candidate               238
# scheduled_dt_mismatch               9
# exact_match_should_have_joined      7
# Name: count, dtype: int64
#
# Dropped 478 passenger rows due to reasons {'scheduled_dt_mismatch', 'no_flight_candidate'}
# [BUILD_JOBS] Dropping 1 jobs already impossible at release (beyond SLA + max late)
# [BUILD_JOBS] Applying stratified percentile cap: q=0.90 | strata=['SSR Code', 'Has Own Chair', 'A/D']
# [BUILD_JOBS] Dropped 558 PRM jobs via stratified percentile cap
#
# ================================================================================
# [DEBUG A] Future flights loaded & Pax computed
# ================================================================================
# df_flights rows: 5785
# Airlines (sample): ['AF' 'FR' 'KL' 'BA' 'U2' 'LS' 'LH' 'LM' 'RK' 'QR']
# Countries (sample): ['FRANCE' 'POLAND' 'LATVIA' 'NETHERLANDS' 'GREAT BRITAIN' 'ITALY'
#  'PORTUGAL' 'SPAIN' 'GREECE' 'GERMANY']
#
# Pax describe:
# count    5785.000000
# mean      155.076404
# std        50.701050
# min         0.000000
# 25%       136.000000
# 50%       169.000000
# 75%       185.000000
# max       397.000000
# Name: Pax, dtype: float64
#
# Top 10 rows (Airline, CountryName, Sector, dir, Pax):
#    Airline    CountryName         Sector dir    Pax
# 0       AF         FRANCE  International   D   94.0
# 1       FR         POLAND  International   D  196.0
# 2       FR         LATVIA  International   D  174.0
# 3       KL    NETHERLANDS  International   D  139.0
# 4       BA  GREAT BRITAIN       Domestic   D   99.0
# 5       U2          ITALY  International   D  199.0
# 6       U2       PORTUGAL  International   D  177.0
# 7       LS          SPAIN  International   D  189.0
# 8       U2          ITALY  International   D  137.0
# 9       FR          SPAIN  International   D  169.0
# 10      LS         GREECE  International   D  224.0
# 11      U2         FRANCE  International   D  213.0
# 12      LH        GERMANY  International   D  171.0
# 13      FR          ITALY  International   D  182.0
# 14      BA  GREAT BRITAIN       Domestic   D   23.0
#
# ================================================================================
# [DEBUG B] Penetration lookup match rate
# ================================================================================
# Penetration keys available: 117
# Flights with penetration match: 5,553 / 5,785 (96.0%)
#
# Top missing (Airline, CountryName) combos in future flights:
#    Airline            CountryName  flight_rows
# 6       EC                  ITALY           38
# 3       DS            SWITZERLAND           38
# 8       EC                  SPAIN           38
# 4       EC                 FRANCE           28
# 7       EC            NETHERLANDS           18
# 5       EC                GERMANY           16
# 9       IB                  SPAIN           12
# 11      LG             LUXEMBOURG           10
# 14      RK                  MALTA            9
# 16      U2               SLOVENIA            8
# 15      RK                ROMANIA            4
# 1       BA                  ITALY            4
# 10      KK                AUSTRIA            2
# 2      BRO  SERBIA AND MONTENEGRO            2
# 13    None                AUSTRIA            2
#
# Example missing keys:
#     Airline  CountryName    Pax
# 117      EC        ITALY  114.0
# 119      EC       FRANCE  140.0
# 152      RK        MALTA  179.0
# 173      IB        SPAIN  166.0
# 180      DS  SWITZERLAND  164.0
# 181      DS  SWITZERLAND  149.0
# 183      EC       FRANCE  143.0
# 190      EC        SPAIN   95.0
# 196      EC        SPAIN  106.0
# 240      EC       FRANCE  174.0
# 250      EC        SPAIN  156.0
# 314      EC        ITALY  132.0
# 324      LG   LUXEMBOURG  116.0
# 378      DS  SWITZERLAND  160.0
# 392      EC  NETHERLANDS  157.0
#
# ================================================================================
# [DEBUG C] Expected PRMs vs rounding
# ================================================================================
# Total expected PRMs (raw sum, BEFORE rounding): 9750.836253477126
# Total PRMs after rounding: 9872
#
# Raw PRM demand distribution (prm_raw):
# count    5785.000000
# mean        1.685538
# std         1.305320
# min         0.000000
# 25%         0.914104
# 50%         1.331169
# 75%         1.841055
# max         8.657703
# Name: _prm_raw, dtype: float64
#
# Top flights by raw PRM demand:
#      Airline               CountryName    Pax  _pen_used  _prm_raw  _prm_round
# 5234      BY                     SPAIN  188.0   0.046052  8.657703           9
# 2198      BY                     SPAIN  187.0   0.046052  8.611651           9
# 3556      VS  UNITED STATES OF AMERICA  397.0   0.021294  8.453666           8
# 2243      VS  UNITED STATES OF AMERICA  386.0   0.021294  8.219433           8
# 3950      BY                    GREECE  183.0   0.044835  8.204887           8
# 1667      BY                    GREECE  182.0   0.044835  8.160052           8
# 3201      BY                    GREECE  181.0   0.044835  8.115216           8
# 1847      VS  UNITED STATES OF AMERICA  380.0   0.021294  8.091670           8
# 3788      BY                    GREECE  179.0   0.044835  8.025545           8
# 2222      BY                    GREECE  177.0   0.044835  7.935874           8
# 1374      LS                  BULGARIA  185.0   0.042406  7.845200           8
# 31        LS                  BULGARIA  181.0   0.042406  7.675574           8
# 513       VS  UNITED STATES OF AMERICA  357.0   0.021294  7.601911           8
# 4297      QR                     QATAR  254.0   0.028896  7.339531           7
# 330       QR                     QATAR  254.0   0.028896  7.339531           7
# [DEBUG flight] Airline=AF | Country=FRANCE | Pax=94.0 | Pen=0.00815 | Pax*Pen=0.766 | PRMs=1
# [DEBUG flight] Airline=FR | Country=POLAND | Pax=196.0 | Pen=0.00339 | Pax*Pen=0.665 | PRMs=1
# [DEBUG flight] Airline=FR | Country=LATVIA | Pax=174.0 | Pen=0.00430 | Pax*Pen=0.749 | PRMs=1
# [DEBUG flight] Airline=KL | Country=NETHERLANDS | Pax=139.0 | Pen=0.00898 | Pax*Pen=1.248 | PRMs=1
# [DEBUG flight] Airline=BA | Country=GREAT BRITAIN | Pax=99.0 | Pen=0.01039 | Pax*Pen=1.028 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=ITALY | Pax=199.0 | Pen=0.00941 | Pax*Pen=1.873 | PRMs=2
# [DEBUG flight] Airline=U2 | Country=PORTUGAL | Pax=177.0 | Pen=0.00848 | Pax*Pen=1.500 | PRMs=2
# [DEBUG flight] Airline=LS | Country=SPAIN | Pax=189.0 | Pen=0.02780 | Pax*Pen=5.255 | PRMs=5
# [DEBUG flight] Airline=U2 | Country=ITALY | Pax=137.0 | Pen=0.00941 | Pax*Pen=1.290 | PRMs=1
# [DEBUG flight] Airline=FR | Country=SPAIN | Pax=169.0 | Pen=0.01043 | Pax*Pen=1.762 | PRMs=2
# [DEBUG flight] Airline=LS | Country=GREECE | Pax=224.0 | Pen=0.01888 | Pax*Pen=4.229 | PRMs=4
# [DEBUG flight] Airline=U2 | Country=FRANCE | Pax=213.0 | Pen=0.00907 | Pax*Pen=1.932 | PRMs=2
# [DEBUG flight] Airline=LH | Country=GERMANY | Pax=171.0 | Pen=0.00614 | Pax*Pen=1.050 | PRMs=1
# [DEBUG flight] Airline=FR | Country=ITALY | Pax=182.0 | Pen=0.00591 | Pax*Pen=1.076 | PRMs=1
# [DEBUG flight] Airline=BA | Country=GREAT BRITAIN | Pax=23.0 | Pen=0.01039 | Pax*Pen=0.239 | PRMs=0
#
# [DEBUG ingest_s26]
# Total PRM jobs (rows): 9872
# Columns: ['Passenger ID', 'Airline Code', 'Flight Number', 'A/D', 'Sector', 'CountryName', 'Stand', 'Scheduled Flight DT', 'Chocks DT', 'Minutes on Chocks', 'ScheduledDateTime_Local', 'Chocks_Est', 'Departure Gate', 'SSR Code', 'Has Own Chair', 'IsEffectiveRemote', 'PRM Flight Count', 'Concurrent Stress', 'Turnaround PRM Count', 'Turnaround Vertical Count', 'IsArrival', 'Adhoc Or Planned', 'IsAdhoc', 'Job Start Time', 'Job End Time', 'tau_amb_mins', 'tau_mini_mins', 'tau_push_mins']
# SSR Code present: True
# SSR Code distribution:
# SSR Code
# WCHR     5250
# WCHS     4002
# WCHC      563
# OTHER      57
# Name: count, dtype: int64
# [BUILD_JOBS] Dropping 3 jobs already impossible at release (beyond SLA + max late)
# [BUILD_JOBS] Applying stratified percentile cap: q=0.90 | strata=['SSR Code', 'Has Own Chair', 'A/D']
# [BUILD_JOBS] Dropped 875 PRM jobs via stratified percentile cap
# Running S2 P90
#
# Running V2 optimiser
#     ✓ S25 ingest complete (9,693 passengers)   [43.70s]
#     ✓ Passenger dataset combined (19,612 passenger rows)   [135.96s]
#     ✓ P100 built (9,376 flights)   [0.18s]
#     P100 demand summary: 19,612 PRMs across 9,376 flights
#     ✓ prepare_model_data started | flights=9,376   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.03s]
#     ✓ ambulift intervals built | flights=9,376 ambulifts=14   [1.10s]
#     ✓ minibus intervals built | minibuses=3   [0.09s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=8,537,608   [1.47s]
#     ✓ minibus overlaps built | overlaps=778,287   [0.13s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=2.87s   [0.00s]
#     ✓ sets built | F=9,376 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=46,880 amb=393,792 mini=56,256   [1.09s]
#     ✓ ambulift overlap constraints built | 8,537,608   [42.68s]
#     ✓ minibus overlap constraints built | 778,287   [5.11s]
#     ✓ build_pyomo_model complete | total=49.55s   [0.67s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=9,376 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 9934899 rows; 562577 cols; 20378362 nonzeros; 496945 integer variables (496945 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 4e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 1254218 rows, 199662 cols, 2673516 nonzeros 11s
# 416179 rows, 176021 cols, 1767532 nonzeros 69s
# 416179 rows, 176021 cols, 1767532 nonzeros 134s
# Presolve reductions: rows 416179(-9518720); columns 176021(-386556); nonzeros 1767532(-18610830)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    416179 rows
#    176021 cols (156993 binary, 0 integer, 19028 implied int., 0 continuous, 0 domain fixed)
#    1767532 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3617520406.479     Large        0      0      0         0   150.0s
#  R       0       0         0   0.00%   831447.578889   1314488117.635    99.94%        0      0      0     75870   409.0s
#          0       0         0   0.00%   1498527.345878  1314488117.635    99.89%     1058    188      0     76568   420.1s
#          0       0         0   0.00%   1500849.838246  1314488117.635    99.89%     1356    501      0     77280   427.5s
#  C       0       0         0   0.00%   1501941.997343  879490803.2968    99.83%     1379    608      0     77896   436.3s
#          0       0         0   0.00%   1502007.168595  879490803.2968    99.83%     1401    618      0     78321   446.4s
#          0       0         0   0.00%   1502007.168595  879490803.2968    99.83%     1407    620      0     78676   453.2s
#          0       0         0   0.00%   1502118.168595  879490803.2968    99.83%     1419    625      0     78930   467.7s
#          0       0         0   0.00%   1502618.228581  879490803.2968    99.83%     1825    664      0    109957   891.2s
#          0       0         0   0.00%   1503707.895247  879490803.2968    99.83%     2836    723      0    111084   910.0s
#          0       0         0   0.00%   1503776.823819  879490803.2968    99.83%     2865    745      0    112091   916.5s
#          0       0         0   0.00%   1503797.686563  879490803.2968    99.83%     2879    759      0    135368   998.0s
#          0       0         0   0.00%   1503866.258482  879490803.2968    99.83%     3883    801      0    136279  1006.2s
#          0       0         0   0.00%   1503876.125093  879490803.2968    99.83%     3900    685      0    153457  1069.7s
#          0       0         0   0.00%   1503914.791759  879490803.2968    99.83%     4568    728      0    154092  1078.4s
#          0       0         0   0.00%   1503920.458426  879490803.2968    99.83%     4600    754      0    154481  1085.0s
#          0       0         0   0.00%   1503970.130632  879490803.2968    99.83%     4607    765      0    159949  1117.6s
#          0       0         0   0.00%   1503970.139561  879490803.2968    99.83%     4759    767      0    164888  1150.8s
#          0       0         0   0.00%   1504007.154063  879490803.2968    99.83%     4953    781      0    178280  1202.3s
#          0       0         0   0.00%   1504014.154063  879490803.2968    99.83%     5455    808      0    179793  1213.0s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   1504014.157385  879490803.2968    99.83%     5474    824      0    183004  1231.6s
#          0       0         0   0.00%   1504014.157385  879490803.2968    99.83%     5556    836      0    184161  1247.0s
#  L       0       0         0   0.00%   1504014.157385  1504465.050228     0.03%     5567    789      0    184361  1682.8s
#          1       0         1 100.00%   1504014.157385  1504465.050228     0.03%     5567    789      0    273386  1683.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      1504465.05023
#   Dual bound        1504014.15982
#   Gap               0.03% (tolerance: 0.5%)
#   P-D integral      1529.71788496
#   Solution status   feasible
#                     1504465.05023 (objective)
#                     0 (bound viol.)
#                     1.67265773881e-13 (int. viol.)
#                     0 (row viol.)
#   Timing            1682.96
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     273386
#                     0 (strong br.)
#                     108491 (separation)
#                     89025 (heuristics)
#     ✓ P100 optimisation complete   [1952.35s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   2                     2
# 2                            0                   8                     8
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      2               0                   2              0
# 2                      8               0                   1              0
# 3                      3               0                   0              0
#
# [P100] Fleet expansion triggered because: Shortfall=1.00
#
# [P100] Running fleet expansion scenario: +1 future copy per future model
#     ✓ prepare_model_data started | flights=9,376   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.04s]
#     ✓ ambulift intervals built | flights=9,376 ambulifts=14   [1.03s]
#     ✓ minibus intervals built | minibuses=5   [0.08s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=8,537,608   [1.52s]
#     ✓ minibus overlaps built | overlaps=1,297,145   [0.24s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=2.96s   [0.00s]
#     ✓ sets built | F=9,376 AMB=14 MINI=5   [0.02s]
#     ✓ variables built | x=46,880 amb=393,792 mini=93,760   [0.34s]
#     ✓ ambulift overlap constraints built | 8,537,608   [149.01s]
#     ✓ minibus overlap constraints built | 1,297,145   [3.95s]
#     ✓ build_pyomo_model complete | total=154.23s   [0.90s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=9,376 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 10566271 rows; 600085 cols; 21716114 nonzeros; 534453 integer variables (534453 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 4e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 1556246 rows, 225020 cols, 3306754 nonzeros 14s
# 480123 rows, 194777 cols, 1979082 nonzeros 73s
# 480123 rows, 194777 cols, 1979082 nonzeros 135s
# Presolve reductions: rows 480123(-10086148); columns 194777(-405308); nonzeros 1979082(-19737032)
#
# Solving MIP model with:
#    480123 rows
#    194777 cols (175749 binary, 0 integer, 19028 implied int., 0 continuous, 0 domain fixed)
#    1979082 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3728702616.708     Large        0      0      0         0   153.9s
#  R       0       0         0   0.00%   540675.013094   2010665152.452    99.97%        0      0      0     61923   365.3s
#          0       0         0   0.00%   540675.013094   2010665152.452    99.97%      986      3      0     62141   379.4s
#          0       0         0   0.00%   540675.013094   2010665152.452    99.97%     1004      6      0     62717   398.7s
#          0       0         0   0.00%   541450.45476    2010665152.452    99.97%     1062    215      0     63557   416.1s
#          0       0         0   0.00%   541786.350648   2010665152.452    99.97%     1338    407      0     64186   421.3s
#  C       0       0         0   0.00%   586256.691066   1626847565.1      99.96%     1449    572      0     65195   429.7s
#          0       0         0   0.00%   586750.983923   1626847565.1      99.96%     1477    669      0     65845   436.6s
#          0       0         0   0.00%   586790.071224   1626847565.1      99.96%     1493    684      0     66521   443.8s
#          0       0         0   0.00%   673793.971094   1626847565.1      99.96%     1508    693      0     67898   456.7s
#          0       0         0   0.00%   673839.137761   1626847565.1      99.96%     1557    709      0     68123   467.9s
#          0       0         0   0.00%   673860.375856   1626847565.1      99.96%     1565    715      0     68793   487.7s
#          0       0         0   0.00%   673893.947284   1626847565.1      99.96%     1972    720      0     68938   691.8s
#          0       0         0   0.00%   673898.613951   1626847565.1      99.96%     2349    724      0     70181   891.7s
#          0       0         0   0.00%   673898.613951   1626847565.1      99.96%     2740    727      0     70985  1079.1s
#          0       0         0   0.00%   673898.613951   1626847565.1      99.96%     2998    734      0     71609  1235.8s
#          0       0         0   0.00%   673898.613951   1626847565.1      99.96%     3011    696      0     72037  1255.4s
#          0       0         0   0.00%   673923.613951   1626847565.1      99.96%     3365    702      0     72242  1408.3s
#          0       0         0   0.00%   673932.699029   1626847565.1      99.96%     3748    711      0     91876  1666.7s
#          0       0         0   0.00%   674014.032363   1626847565.1      99.96%     4660    732      0     92096  1672.9s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   674014.032363   1626847565.1      99.96%     4666    740      0     92721  1678.5s
#          0       0         0   0.00%   674021.032363   1626847565.1      99.96%     4700    643      0     93352  1700.3s
#          0       0         0   0.00%   674038.032363   1626847565.1      99.96%     4780    652      0     93621  1732.6s
#          0       0         0   0.00%   674071.682955   1626847565.1      99.96%     4801    661      0     98508  1757.1s
#          0       0         0   0.00%   674096.598607   1626847565.1      99.96%     5008    670      0    102500  1778.9s
#          0       0         0   0.00%   674102.670036   1626847565.1      99.96%     5299    675      0    103286  1789.2s
#          0       0         0   0.00%   674104.753369   1626847565.1      99.96%     5377    671      0    103941  1828.6s
#          0       0         0   0.00%   674104.753369   1626847565.1      99.96%     5503    678      0    104143  1837.1s
#          0       0         0   0.00%   674107.420036   1626847565.1      99.96%     5521    686      0    104756  1847.3s
#  L       0       0         0   0.00%   674107.420036   674346.278539      0.04%     5521    686      0    104756  2180.7s
#          1       0         1 100.00%   674107.420036   674346.278539      0.04%     5502    686      0    167193  2181.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      674346.278539
#   Dual bound        674107.420036
#   Gap               0.0354% (tolerance: 0.5%)
#   P-D integral      2025.15978541
#   Solution status   feasible
#                     674346.278539 (objective)
#                     0 (bound viol.)
#                     1.35204353756e-13 (int. viol.)
#                     0 (row viol.)
#   Timing            2181.05
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     167193
#                     0 (strong br.)
#                     42833 (separation)
#                     62437 (heuristics)
# [P100] Stopping fleet expansion: scenario +1 meets SLA and has no shortfall.
#     ✓ P100 fleet expansion search complete   [2544.62s]
#     ✓ P90 built (9,376 flights)   [0.54s]
#     P90 demand summary: 17,921 PRMs across 9,376 flights
#     ✓ prepare_model_data started | flights=9,376   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.04s]
#     ✓ ambulift intervals built | flights=9,376 ambulifts=14   [1.07s]
#     ✓ minibus intervals built | minibuses=3   [0.10s]
#     ✓ staff intervals built   [0.03s]
#     ✓ ambulift overlaps built | overlaps=8,423,410   [1.53s]
#     ✓ minibus overlaps built | overlaps=778,464   [0.14s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=2.93s   [0.00s]
#     ✓ sets built | F=9,376 AMB=14 MINI=3   [0.01s]
#     ✓ variables built | x=46,880 amb=393,792 mini=56,256   [0.28s]
#     ✓ ambulift overlap constraints built | 8,423,410   [158.25s]
#     ✓ minibus overlap constraints built | 778,464   [3.26s]
#     ✓ build_pyomo_model complete | total=162.79s   [0.99s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=9,376 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 9820743 rows; 562577 cols; 20150185 nonzeros; 496945 integer variables (496945 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 9e+00]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -1
# Presolving model
# 1236317 rows, 200126 cols, 2642988 nonzeros 17s
# 415865 rows, 176486 cols, 1752406 nonzeros 91s
# 415865 rows, 176486 cols, 1752406 nonzeros 167s
# Presolve reductions: rows 415865(-9404878); columns 176486(-386091); nonzeros 1752406(-18397779)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    415865 rows
#    176486 cols (157429 binary, 0 integer, 19057 implied int., 0 continuous, 0 domain fixed)
#    1752406 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3769473492.826     Large        0      0      0         0   189.2s
#  R       0       0         0   0.00%   643026.135146   976467549.2192    99.93%        0      0      0    191474   837.5s
#          0       0         0   0.00%   1476359.46848   976467549.2192    99.85%      293     52      0    191920   848.2s
#          0       0         0   0.00%   1476547.56848   976467549.2192    99.85%     1242    102      0    192546   853.8s
#          0       0         0   0.00%   1476893.341496  976467549.2192    99.85%     1279    142      0    193131   859.3s
#  C       0       0         0   0.00%   1477271.62721   754469208.2968    99.80%     1286    186      0    193389   867.8s
#          0       0         0   0.00%   1477385.12721   754469208.2968    99.80%     1289    199      0    194073   874.3s
#          0       0         0   0.00%   1477402.460543  754469208.2968    99.80%     1294    204      0    194156   881.4s
#          0       0         0   0.00%   1477407.460543  754469208.2968    99.80%     1296    208      0    194534   889.1s
#          0       0         0   0.00%   1477407.972603  754469208.2968    99.80%     1311    211      0    266347  1215.4s
#          0       0         0   0.00%   1477433.972603  754469208.2968    99.80%     2314    217      0    266454  1223.2s
#          0       0         0   0.00%   1477433.972603  754469208.2968    99.80%     2336    220      0    267209  1235.3s
#          0       0         0   0.00%   1477433.972603  754469208.2968    99.80%     2354    223      0    268235  1262.9s
#          0       0         0   0.00%   1477433.972603  754469208.2968    99.80%     2405    225      0    269420  1305.4s
#          0       0         0   0.00%   1477433.972603  754469208.2968    99.80%     2563    227      0    270040  1348.3s
#          0       0         0   0.00%   1477433.972603  754469208.2968    99.80%     2693    197      0    271256  1400.5s
#          0       0         0   0.00%   1477433.972603  754469208.2968    99.80%     2820    199      0    272686  1462.6s
#          0       0         0   0.00%   1477433.972603  754469208.2968    99.80%     2871    201      0    273853  1530.2s
#          0       0         0   0.00%   1477433.972603  754469208.2968    99.80%     2956    203      0    274893  1594.2s
#          0       0         0   0.00%   1477433.972603  754469208.2968    99.80%     3005    205      0    275468  1654.3s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  L       0       0         0   0.00%   1477433.972603  1478291.050228     0.06%     3005    205      0    275468  2336.6s
#          1       0         1 100.00%   1477433.972603  1478291.050228     0.06%     3005    205      0    355881  2336.8s
#
# Solving report
#   Status            Optimal
#   Primal bound      1478291.05023
#   Dual bound        1477433.9726
#   Gap               0.058% (tolerance: 0.5%)
#   P-D integral      2143.55272464
#   Solution status   feasible
#                     1478291.05023 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            2336.81
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     355881
#                     0 (strong br.)
#                     83994 (separation)
#                     80413 (heuristics)
#     ✓ P90 optimisation complete   [2763.46s]
#
# [P90 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   3                     3
# 2                            0                   7                     6
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      3               0                   1              0
# 2                      6               0                   3              0
# 3                      3               0                   0              0
#
# [P90] Fleet expansion triggered because: Shortfall=1.00
#
# [P90] Running fleet expansion scenario: +1 future copy per future model
#     ✓ prepare_model_data started | flights=9,376   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.07s]
#     ✓ ambulift intervals built | flights=9,376 ambulifts=14   [1.43s]
#     ✓ minibus intervals built | minibuses=5   [0.12s]
#     ✓ staff intervals built   [0.03s]
#     ✓ ambulift overlaps built | overlaps=8,423,410   [2.23s]
#     ✓ minibus overlaps built | overlaps=1,297,440   [0.35s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.03s]
#     ✓ prepare_model_data complete | total=4.26s   [0.00s]
#     ✓ sets built | F=9,376 AMB=14 MINI=5   [0.02s]
#     ✓ variables built | x=46,880 amb=393,792 mini=93,760   [0.41s]
#     ✓ ambulift overlap constraints built | 8,423,410   [197.23s]
#     ✓ minibus overlap constraints built | 1,297,440   [7.28s]
#     ✓ build_pyomo_model complete | total=206.23s   [1.29s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=9,376 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 10452233 rows; 600085 cols; 21488173 nonzeros; 534453 integer variables (534453 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -1
# Presolving model
# 1538457 rows, 225484 cols, 3276450 nonzeros 19s
# 479888 rows, 195242 cols, 1963977 nonzeros 99s
# 479888 rows, 195242 cols, 1963977 nonzeros 182s
# Presolve reductions: rows 479888(-9972345); columns 195242(-404843); nonzeros 1963977(-19524196)
#
# Solving MIP model with:
#    479888 rows
#    195242 cols (176185 binary, 0 integer, 19057 implied int., 0 continuous, 0 domain fixed)
#    1963977 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3577474574.653     Large        0      0      0         0   208.2s
#  R       0       0         0   0.00%   502054.800348   949650817.0365    99.95%        0      0      0    168470   738.7s
#          0       0         0   0.00%   502054.800348   949650817.0365    99.95%      720      5      0    168710   763.8s
#          0       0         0   0.00%   502054.800348   949650817.0365    99.95%     1080     10      0    168856   783.6s
#          0       0         0   0.00%   502054.800348   949650817.0365    99.95%     1082     15      0    169025   806.2s
#          0       0         0   0.00%   502054.800348   949650817.0365    99.95%     1083     20      0    169204   828.2s
#  C       0       0         0   0.00%   502054.800348   919832845.1005    99.95%     1087     25      0    169324   852.4s
#          0       0         0   0.00%   502059.086062   919832845.1005    99.95%     1088     87      0    169674   873.6s
#          0       0         0   0.00%   656721.906473   919832845.1005    99.93%     1167    143      0    170022   901.0s
#          0       0         0   0.00%   656768.684251   919832845.1005    99.93%     1180    157      0    170204   909.4s
#          0       0         0   0.00%   656820.308889   919832845.1005    99.93%     1187    169      0    178802   944.5s
#          0       0         0   0.00%   656858.873346   919832845.1005    99.93%     1388    184      0    192660  1013.6s
#          0       0         0   0.00%   656908.873346   919832845.1005    99.93%     1781    196      0    193188  1024.4s
#          0       0         0   0.00%   656908.873346   919832845.1005    99.93%     1793    205      0    193716  1031.8s
#          0       0         0   0.00%   656909.471106   919832845.1005    99.93%     1798    211      0    210367  1110.7s
#          0       0         0   0.00%   656909.471106   919832845.1005    99.93%     2800    225      0    211106  1122.8s
#          0       0         0   0.00%   656909.471106   919832845.1005    99.93%     2831    229      0    211439  1142.4s
#          0       0         0   0.00%   656909.471106   919832845.1005    99.93%     2863    233      0    212106  1168.7s
#          0       0         0   0.00%   656909.471106   919832845.1005    99.93%     2881    237      0    212203  1184.3s
#          0       0         0   0.00%   656909.471106   919832845.1005    99.93%     2905    241      0    212404  1203.7s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  L       0       0         0   0.00%   656909.471106   657085.863014      0.03%     2905    241      0    212404  1514.0s
#          1       0         1 100.00%   656909.471106   657085.863014      0.03%     2905    241      0    259913  1514.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      657085.863014
#   Dual bound        656909.471106
#   Gap               0.0268% (tolerance: 0.5%)
#   P-D integral      1304.1875768
#   Solution status   feasible
#                     657085.863014 (objective)
#                     0 (bound viol.)
#                     3.33066907388e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            1514.40
#   Max sub-MIP depth 3
#   Nodes             1
#   Repair LPs        0
#   LP iterations     259913
#                     0 (strong br.)
#                     43934 (separation)
#                     47509 (heuristics)
# [P90] Stopping fleet expansion: scenario +1 meets SLA and has no shortfall.
#     ✓ P90 fleet expansion search complete   [2030.36s]
#     ✓ Excel outputs written to outputs\prm_combined\monthly\2026_07_v2.xlsx   [26.39s]
#
# Completed month: 2026_07
# Workbook: outputs\prm_combined\monthly\2026_07_combined.xlsx
#    S1_PeakAmb  S1_PeakMini  S1_PeakDrivers  S1_PeakVehAgents  S2_PeakAmb  \
# 0          13            5              14                14          10
# 1          11            3              13                13          10
#
#    S2_PeakMini  S2_PeakDrivers  S2_PeakVehAgents  V2_arrival_sla_pct  \
# 0           15              23                23           99.991071
# 1           14              22                22           99.990207
#
#    V2_PeakAmb  V2_PeakMini
# 0          11            3
# 1          10            3

# %%
august_result = run_combined_month(
    2026,
    8,
)

pd.DataFrame(august_result["month_rows"])
# Out:
# ================================================================================
# RUNNING COMBINED MONTH: 2026_08
# ================================================================================
#
# Unmatched passenger rows after merge (missing Chocks DT): 4523
# Unique unmatched flight keys: 2750
#
# Unmatched key reasons:
# reason
# no_flight_candidate               1973
# scheduled_dt_mismatch              714
# exact_match_should_have_joined      63
# Name: count, dtype: int64
#
# Dropped 4406 passenger rows due to reasons {'no_flight_candidate', 'scheduled_dt_mismatch'}
# [1/5] Penetration + SSR mix…
#     ✓ penetration + SSR mix built   [206.13s]
# [2/5] Service times…
# [BUILD_JOBS] Dropping 36 jobs already impossible at release (beyond SLA + max late)
#
# [BUILD_JOBS] Dropping 4 arrival jobs with expired SLA window (max_late_mins=180).
#        Passenger ID Flight Number Airline Code      sla_start_time  \
# 99965      13159410           748           LS 2025-09-30 01:35:15
# 99966      13159411           748           LS 2025-09-30 01:35:15
# 99969      13159414           748           LS 2025-09-30 01:35:15
# 99970      13159415           748           LS 2025-09-30 01:35:15
#
#            Job Start Time  sla_limit           Chocks DT
# 99965 2025-09-30 04:59:07         20 2025-09-30 01:35:15
# 99966 2025-09-30 05:00:53         20 2025-09-30 01:35:15
# 99969 2025-09-30 04:59:15         20 2025-09-30 01:35:15
# 99970 2025-09-30 04:59:18         20 2025-09-30 01:35:15
#     ✓ service times built   [1.64s]
# [2b/5] Tau mode params (S25 medians)…
#     ✓ tau mode params built   [0.02s]
# [3/5] Chocks offsets…
#     ✓ chocks offsets built   [0.06s]
# [4/5] Early/late timing…
#     ✓ early/late params built   [0.05s]
# [5/5] Stand inputs…
#     ✓ stand inputs built   [0.07s]
#
# Running S1 P100
#
# ================================================================================
# [DEBUG A] Future flights loaded & Pax computed
# ================================================================================
# df_flights rows: 11885
# Airlines (sample): ['BA' 'FR' 'TK' 'LM' 'KL' 'U2' 'LH' 'WK' 'AF' 'LS']
# Countries (sample): ['GREAT BRITAIN' 'SPAIN' 'POLAND' 'TURKEY' 'NETHERLANDS' 'LATVIA'
#  'GERMANY' 'SWITZERLAND' 'FRANCE' 'IRISH REPUBLIC']
#
# Pax describe:
# count    11885.000000
# mean       154.013883
# std         50.032020
# min          0.000000
# 25%        134.000000
# 50%        166.000000
# 75%        183.000000
# max        397.000000
# Name: Pax, dtype: float64
#
# Top 10 rows (Airline, CountryName, Sector, dir, Pax):
#    Airline     CountryName         Sector dir    Pax
# 0       BA   GREAT BRITAIN       Domestic   D  184.0
# 1       BA           SPAIN  International   D  106.0
# 2       FR          POLAND  International   D  180.0
# 3       BA   GREAT BRITAIN       Domestic   D  136.0
# 4       TK          TURKEY  International   D  163.0
# 5       LM   GREAT BRITAIN       Domestic   D   56.0
# 6       KL     NETHERLANDS  International   D  217.0
# 7       BA   GREAT BRITAIN       Domestic   D  160.0
# 8       U2   GREAT BRITAIN       Domestic   D  152.0
# 9       FR          LATVIA  International   D  197.0
# 10      LH         GERMANY  International   D  187.0
# 11      WK     SWITZERLAND  International   D  180.0
# 12      AF          FRANCE  International   D  102.0
# 13      U2   GREAT BRITAIN       Domestic   D  174.0
# 14      FR  IRISH REPUBLIC            CTA   D  189.0
#
# ================================================================================
# [DEBUG B] Penetration lookup match rate
# ================================================================================
# Penetration keys available: 117
# Flights with penetration match: 11,370 / 11,885 (95.7%)
#
# Top missing (Airline, CountryName) combos in future flights:
#    Airline     CountryName  flight_rows
# 4       EC           ITALY          116
# 1       DS     SWITZERLAND           80
# 6       EC           SPAIN           80
# 2       EC          FRANCE           66
# 5       EC     NETHERLANDS           38
# 3       EC         GERMANY           36
# 7       IB           SPAIN           26
# 9       RK           MALTA           18
# 8       LG      LUXEMBOURG           18
# 11      U2        SLOVENIA           18
# 0       BA           ITALY           10
# 10      RK         ROMANIA            8
# 12      ZT  IRISH REPUBLIC            1
#
# Example missing keys:
#     Airline  CountryName    Pax
# 59       EC        ITALY  144.0
# 162      DS  SWITZERLAND  164.0
# 171      EC       FRANCE  110.0
# 174      EC        ITALY  123.0
# 220      EC       FRANCE  133.0
# 231      EC      GERMANY  152.0
# 233      EC  NETHERLANDS  170.0
# 252      EC        SPAIN  126.0
# 254      EC        ITALY  144.0
# 298      DS  SWITZERLAND  186.0
# 299      EC        ITALY  121.0
# 328      IB        SPAIN  166.0
# 390      EC        SPAIN  137.0
# 393      DS  SWITZERLAND  181.0
# 394      EC        SPAIN  147.0
#
# ================================================================================
# [DEBUG C] Expected PRMs vs rounding
# ================================================================================
# Total expected PRMs (raw sum, BEFORE rounding): 19901.334416231635
# Total PRMs after rounding: 20207
#
# Raw PRM demand distribution (prm_raw):
# count    11885.000000
# mean         1.674492
# std          1.284004
# min          0.000000
# 25%          0.898789
# 50%          1.333081
# 75%          1.831157
# max          8.473497
# Name: _prm_raw, dtype: float64
#
# Top flights by raw PRM demand:
#       Airline               CountryName    Pax  _pen_used  _prm_raw  \
# 11020      BY                     SPAIN  184.0   0.046052  8.473497
# 6776       VS  UNITED STATES OF AMERICA  397.0   0.021294  8.453666
# 8570       VS  UNITED STATES OF AMERICA  397.0   0.021294  8.453666
# 10046      VS  UNITED STATES OF AMERICA  390.0   0.021294  8.304609
# 3953       BY                    GREECE  184.0   0.044835  8.249723
# 4722       BY                     SPAIN  179.0   0.046052  8.243238
# 2607       BY                    GREECE  180.0   0.044835  8.070381
# 10401      BY                    GREECE  178.0   0.044835  7.980710
# 10827      VS  UNITED STATES OF AMERICA  374.0   0.021294  7.963907
# 7589       VS  UNITED STATES OF AMERICA  373.0   0.021294  7.942613
# 8613       BY                    GREECE  177.0   0.044835  7.935874
# 10114      BY                    GREECE  174.0   0.044835  7.801368
# 6584       BY                     SPAIN  169.0   0.046052  7.782722
# 5002       LS                  BULGARIA  183.0   0.042406  7.760387
# 5299       BY                    GREECE  173.0   0.044835  7.756533
#
#        _prm_round
# 11020           8
# 6776            8
# 8570            8
# 10046           8
# 3953            8
# 4722            8
# 2607            8
# 10401           8
# 10827           8
# 7589            8
# 8613            8
# 10114           8
# 6584            8
# 5002            8
# 5299            8
# [DEBUG flight] Airline=BA | Country=GREAT BRITAIN | Pax=184.0 | Pen=0.01039 | Pax*Pen=1.911 | PRMs=2
# [DEBUG flight] Airline=BA | Country=SPAIN | Pax=106.0 | Pen=0.01648 | Pax*Pen=1.747 | PRMs=2
# [DEBUG flight] Airline=FR | Country=POLAND | Pax=180.0 | Pen=0.00339 | Pax*Pen=0.611 | PRMs=1
# [DEBUG flight] Airline=BA | Country=GREAT BRITAIN | Pax=136.0 | Pen=0.01039 | Pax*Pen=1.413 | PRMs=1
# [DEBUG flight] Airline=TK | Country=TURKEY | Pax=163.0 | Pen=0.02205 | Pax*Pen=3.595 | PRMs=4
# [DEBUG flight] Airline=LM | Country=GREAT BRITAIN | Pax=56.0 | Pen=0.02140 | Pax*Pen=1.198 | PRMs=1
# [DEBUG flight] Airline=KL | Country=NETHERLANDS | Pax=217.0 | Pen=0.00898 | Pax*Pen=1.949 | PRMs=2
# [DEBUG flight] Airline=BA | Country=GREAT BRITAIN | Pax=160.0 | Pen=0.01039 | Pax*Pen=1.662 | PRMs=2
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=152.0 | Pen=0.00990 | Pax*Pen=1.505 | PRMs=2
# [DEBUG flight] Airline=FR | Country=LATVIA | Pax=197.0 | Pen=0.00430 | Pax*Pen=0.848 | PRMs=1
# [DEBUG flight] Airline=LH | Country=GERMANY | Pax=187.0 | Pen=0.00614 | Pax*Pen=1.148 | PRMs=1
# [DEBUG flight] Airline=WK | Country=SWITZERLAND | Pax=180.0 | Pen=0.00419 | Pax*Pen=0.755 | PRMs=1
# [DEBUG flight] Airline=AF | Country=FRANCE | Pax=102.0 | Pen=0.00815 | Pax*Pen=0.831 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=174.0 | Pen=0.00990 | Pax*Pen=1.722 | PRMs=2
# [DEBUG flight] Airline=FR | Country=IRISH REPUBLIC | Pax=189.0 | Pen=0.00705 | Pax*Pen=1.333 | PRMs=1
#
# [DEBUG ingest_s26]
# Total PRM jobs (rows): 20207
# Columns: ['Passenger ID', 'Airline Code', 'Flight Number', 'A/D', 'Sector', 'CountryName', 'Stand', 'Scheduled Flight DT', 'Chocks DT', 'Minutes on Chocks', 'ScheduledDateTime_Local', 'Chocks_Est', 'Departure Gate', 'SSR Code', 'Has Own Chair', 'IsEffectiveRemote', 'PRM Flight Count', 'Concurrent Stress', 'Turnaround PRM Count', 'Turnaround Vertical Count', 'IsArrival', 'Adhoc Or Planned', 'IsAdhoc', 'Job Start Time', 'Job End Time', 'tau_amb_mins', 'tau_mini_mins', 'tau_push_mins']
# SSR Code present: True
# SSR Code distribution:
# SSR Code
# WCHR     10667
# WCHS      8248
# WCHC      1182
# OTHER      110
# Name: count, dtype: int64
# [BUILD_JOBS] Dropping 3 jobs already impossible at release (beyond SLA + max late)
# Running S2 P100
#
# Running S1 P90
#
# ================================================================================
# [DEBUG A] Future flights loaded & Pax computed
# ================================================================================
# df_flights rows: 11885
# Airlines (sample): ['FR' 'KL' 'BA' 'LS' 'U2' 'LH' 'RK' 'LM' 'QR' 'EC']
# Countries (sample): ['SLOVAKIA' 'NETHERLANDS' 'SPAIN' 'GREAT BRITAIN' 'POLAND' 'SWITZERLAND'
#  'GERMANY' 'CROATIA' 'ITALY' 'FRANCE']
#
# Pax describe:
# count    11885.000000
# mean       154.013883
# std         50.032020
# min          0.000000
# 25%        134.000000
# 50%        166.000000
# 75%        183.000000
# max        397.000000
# Name: Pax, dtype: float64
#
# Top 10 rows (Airline, CountryName, Sector, dir, Pax):
#    Airline     CountryName         Sector dir    Pax
# 0       FR        SLOVAKIA  International   D  187.0
# 1       KL     NETHERLANDS  International   D  128.0
# 2       FR           SPAIN  International   D  185.0
# 3       BA   GREAT BRITAIN       Domestic   D  136.0
# 4       FR          POLAND  International   D  184.0
# 5       LS           SPAIN  International   D  219.0
# 6       U2     SWITZERLAND  International   D  184.0
# 7       LH         GERMANY  International   D  132.0
# 8       U2         CROATIA  International   D  174.0
# 9       FR           ITALY  International   D  185.0
# 10      U2          FRANCE  International   D  182.0
# 11      FR           SPAIN  International   D  166.0
# 12      RK           MALTA  International   D  166.0
# 13      FR          POLAND  International   D  197.0
# 14      FR  IRISH REPUBLIC            CTA   D  190.0
#
# ================================================================================
# [DEBUG B] Penetration lookup match rate
# ================================================================================
# Penetration keys available: 117
# Flights with penetration match: 11,370 / 11,885 (95.7%)
#
# Top missing (Airline, CountryName) combos in future flights:
#    Airline     CountryName  flight_rows
# 4       EC           ITALY          116
# 1       DS     SWITZERLAND           80
# 6       EC           SPAIN           80
# 2       EC          FRANCE           66
# 5       EC     NETHERLANDS           38
# 3       EC         GERMANY           36
# 7       IB           SPAIN           26
# 9       RK           MALTA           18
# 8       LG      LUXEMBOURG           18
# 11      U2        SLOVENIA           18
# 0       BA           ITALY           10
# 10      RK         ROMANIA            8
# 12      ZT  IRISH REPUBLIC            1
#
# Example missing keys:
#     Airline  CountryName    Pax
# 12       RK        MALTA  166.0
# 18       EC  NETHERLANDS  141.0
# 62       U2     SLOVENIA  157.0
# 72       EC        ITALY  145.0
# 137      IB        SPAIN  166.0
# 165      EC      GERMANY  152.0
# 176      EC       FRANCE  110.0
# 188      EC        ITALY  144.0
# 337      DS  SWITZERLAND  164.0
# 346      LG   LUXEMBOURG  109.0
# 349      EC        ITALY  123.0
# 367      EC       FRANCE  157.0
# 387      EC        SPAIN  125.0
# 389      DS  SWITZERLAND  170.0
# 430      EC        SPAIN  137.0
#
# ================================================================================
# [DEBUG C] Expected PRMs vs rounding
# ================================================================================
# Total expected PRMs (raw sum, BEFORE rounding): 19901.334416231635
# Total PRMs after rounding: 20207
#
# Raw PRM demand distribution (prm_raw):
# count    11885.000000
# mean         1.674492
# std          1.284004
# min          0.000000
# 25%          0.898789
# 50%          1.333081
# 75%          1.831157
# max          8.473497
# Name: _prm_raw, dtype: float64
#
# Top flights by raw PRM demand:
#       Airline               CountryName    Pax  _pen_used  _prm_raw  \
# 11020      BY                     SPAIN  184.0   0.046052  8.473497
# 8570       VS  UNITED STATES OF AMERICA  397.0   0.021294  8.453666
# 6176       VS  UNITED STATES OF AMERICA  397.0   0.021294  8.453666
# 10046      VS  UNITED STATES OF AMERICA  390.0   0.021294  8.304609
# 3953       BY                    GREECE  184.0   0.044835  8.249723
# 4722       BY                     SPAIN  179.0   0.046052  8.243238
# 2607       BY                    GREECE  180.0   0.044835  8.070381
# 10401      BY                    GREECE  178.0   0.044835  7.980710
# 10827      VS  UNITED STATES OF AMERICA  374.0   0.021294  7.963907
# 7589       VS  UNITED STATES OF AMERICA  373.0   0.021294  7.942613
# 8613       BY                    GREECE  177.0   0.044835  7.935874
# 10114      BY                    GREECE  174.0   0.044835  7.801368
# 6810       BY                     SPAIN  169.0   0.046052  7.782722
# 5002       LS                  BULGARIA  183.0   0.042406  7.760387
# 5299       BY                    GREECE  173.0   0.044835  7.756533
#
#        _prm_round
# 11020           8
# 8570            8
# 6176            8
# 10046           8
# 3953            8
# 4722            8
# 2607            8
# 10401           8
# 10827           8
# 7589            8
# 8613            8
# 10114           8
# 6810            8
# 5002            8
# 5299            8
# [DEBUG flight] Airline=FR | Country=SLOVAKIA | Pax=187.0 | Pen=0.00245 | Pax*Pen=0.457 | PRMs=0
# [DEBUG flight] Airline=KL | Country=NETHERLANDS | Pax=128.0 | Pen=0.00898 | Pax*Pen=1.149 | PRMs=1
# [DEBUG flight] Airline=FR | Country=SPAIN | Pax=185.0 | Pen=0.01043 | Pax*Pen=1.929 | PRMs=2
# [DEBUG flight] Airline=BA | Country=GREAT BRITAIN | Pax=136.0 | Pen=0.01039 | Pax*Pen=1.413 | PRMs=1
# [DEBUG flight] Airline=FR | Country=POLAND | Pax=184.0 | Pen=0.00339 | Pax*Pen=0.624 | PRMs=1
# [DEBUG flight] Airline=LS | Country=SPAIN | Pax=219.0 | Pen=0.02780 | Pax*Pen=6.089 | PRMs=6
# [DEBUG flight] Airline=U2 | Country=SWITZERLAND | Pax=184.0 | Pen=0.00752 | Pax*Pen=1.384 | PRMs=1
# [DEBUG flight] Airline=LH | Country=GERMANY | Pax=132.0 | Pen=0.00614 | Pax*Pen=0.811 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=CROATIA | Pax=174.0 | Pen=0.00455 | Pax*Pen=0.792 | PRMs=1
# [DEBUG flight] Airline=FR | Country=ITALY | Pax=185.0 | Pen=0.00591 | Pax*Pen=1.094 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=FRANCE | Pax=182.0 | Pen=0.00907 | Pax*Pen=1.651 | PRMs=2
# [DEBUG flight] Airline=FR | Country=SPAIN | Pax=166.0 | Pen=0.01043 | Pax*Pen=1.731 | PRMs=2
# [DEBUG flight] Airline=RK | Country=MALTA | Pax=166.0 | Pen=0.01000 | Pax*Pen=1.660 | PRMs=2
# [DEBUG flight] Airline=FR | Country=POLAND | Pax=197.0 | Pen=0.00339 | Pax*Pen=0.668 | PRMs=1
# [DEBUG flight] Airline=FR | Country=IRISH REPUBLIC | Pax=190.0 | Pen=0.00705 | Pax*Pen=1.340 | PRMs=1
#
# [DEBUG ingest_s26]
# Total PRM jobs (rows): 20207
# Columns: ['Passenger ID', 'Airline Code', 'Flight Number', 'A/D', 'Sector', 'CountryName', 'Stand', 'Scheduled Flight DT', 'Chocks DT', 'Minutes on Chocks', 'ScheduledDateTime_Local', 'Chocks_Est', 'Departure Gate', 'SSR Code', 'Has Own Chair', 'IsEffectiveRemote', 'PRM Flight Count', 'Concurrent Stress', 'Turnaround PRM Count', 'Turnaround Vertical Count', 'IsArrival', 'Adhoc Or Planned', 'IsAdhoc', 'Job Start Time', 'Job End Time', 'tau_amb_mins', 'tau_mini_mins', 'tau_push_mins']
# SSR Code present: True
# SSR Code distribution:
# SSR Code
# WCHR     10667
# WCHS      8316
# WCHC      1122
# OTHER      102
# Name: count, dtype: int64
# [BUILD_JOBS] Dropping 3 jobs already impossible at release (beyond SLA + max late)
# [BUILD_JOBS] Applying stratified percentile cap: q=0.90 | strata=['SSR Code', 'Has Own Chair', 'A/D']
# [BUILD_JOBS] Dropped 1706 PRM jobs via stratified percentile cap
# Running S2 P90
#
# Running V2 optimiser
#     ✓ Passenger dataset combined (20,287 passenger rows)   [302.54s]
#     ✓ P100 built (11,364 flights)   [0.17s]
#     P100 demand summary: 20,287 PRMs across 11,364 flights
#     ✓ prepare_model_data started | flights=11,364   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.04s]
#     ✓ ambulift intervals built | flights=11,364 ambulifts=14   [1.47s]
#     ✓ minibus intervals built | minibuses=3   [0.11s]
#     ✓ staff intervals built   [0.03s]
#     ✓ ambulift overlaps built | overlaps=11,748,285   [1.95s]
#     ✓ minibus overlaps built | overlaps=1,080,180   [0.20s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.03s]
#     ✓ prepare_model_data complete | total=3.81s   [0.00s]
#     ✓ sets built | F=11,364 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=56,820 amb=477,288 mini=68,184   [1.58s]
#     ✓ ambulift overlap constraints built | 11,748,285   [76.57s]
#     ✓ minibus overlap constraints built | 1,080,180   [3.49s]
#     ✓ build_pyomo_model complete | total=82.52s   [0.88s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=11,364 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 13578543 rows; 681857 cols; 27772910 nonzeros; 602309 integer variables (602309 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 8e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -1
# Presolving model
# 1808089 rows, 254606 cols, 3830480 nonzeros 27s
# 549206 rows, 224275 cols, 2468295 nonzeros 164s
# 549206 rows, 224275 cols, 2468295 nonzeros 296s
# Presolve reductions: rows 549206(-13029337); columns 224275(-457582); nonzeros 2468295(-25304615)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    549206 rows
#    224275 cols (200847 binary, 0 integer, 23428 implied int., 0 continuous, 0 domain fixed)
#    2468295 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            4493560394.653     Large        0      0      0         0   325.5s
#  R       0       0         0   0.00%   566572.613481   1225555590.05     99.95%        0      0      0    112481  1145.9s
#          0       0         0   0.00%   566572.613481   1225555590.05     99.95%      902     94      0    113524  1284.7s
#          0       0         0   0.00%   566572.613481   1225555590.05     99.95%     1022    171      0    114110  1291.3s
#          0       0         0   0.00%   566572.613481   1225555590.05     99.95%     1100    175      0    114865  1300.8s
#          0       0         0   0.00%   566572.613481   1225555590.05     99.95%     1271    179      0    115443  1479.3s
#  C       0       0         0   0.00%   567029.546814   1138555850.297    99.95%     1553    306      0    115957  1805.8s
#          0       0         0   0.00%   567873.232528   1138555850.297    99.95%     1591    423      0    117626  1820.0s
#          0       0         0   0.00%   568296.743271   1138555850.297    99.95%     1627    469      0    151747  2030.7s
#          0       0         0   0.00%   568681.859716   1138555850.297    99.95%     2629    519      0    164116  2105.7s
#          0       0         0   0.00%   568723.859716   1138555850.297    99.95%     3156    552      0    166232  2130.8s
#          0       0         0   0.00%   568734.288287   1138555850.297    99.95%     3181    559      0    167588  2147.0s
#          0       0         0   0.00%   568734.288287   1138555850.297    99.95%     3196    564      0    169003  2170.0s
#          0       0         0   0.00%   568734.469368   1138555850.297    99.95%     3247    571      0    191041  2332.4s
#          0       0         0   0.00%   568756.040796   1138555850.297    99.95%     4259    600      0    192020  2345.4s
#          0       0         0   0.00%   568756.040796   1138555850.297    99.95%     4270    611      0    193050  2359.7s
#          0       0         0   0.00%   568756.276923   1138555850.297    99.95%     4299    617      0    204325  2425.0s
#          0       0         0   0.00%   568773.51209    1138555850.297    99.95%     4543    635      0    234487  2672.1s
#          0       0         0   0.00%   568773.51209    1138555850.297    99.95%     5546    676      0    237591  2708.9s
#          0       0         0   0.00%   568773.558905   1138555850.297    99.95%     5572    700      0    245379  2772.0s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   568773.558905   1138555850.297    99.95%     5656    714      0    246461  2784.8s
#          0       0         0   0.00%   568773.558905   1138555850.297    99.95%     5663    578      0    247609  2806.3s
#          0       0         0   0.00%   568773.558905   1138555850.297    99.95%     5732    590      0    248677  2827.8s
#          0       0         0   0.00%   568773.558905   1138555850.297    99.95%     5743    598      0    251309  2849.0s
#          0       0         0   0.00%   568773.558905   1138555850.297    99.95%     5757    606      0    252283  2863.5s
#  L       0       0         0   0.00%   568773.558905   568831.465753      0.01%     5757    606      0    252283  3629.1s
#          1       0         1 100.00%   568773.558905   568831.465753      0.01%     5757    606      0    318955  3629.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      568831.465753
#   Dual bound        568773.561644
#   Gap               0.0102% (tolerance: 0.5%)
#   P-D integral      3301.21208566
#   Solution status   feasible
#                     568831.465753 (objective)
#                     0 (bound viol.)
#                     2.0872192863e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            3629.38
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     318955
#                     0 (strong br.)
#                     139802 (separation)
#                     66672 (heuristics)
#     ✓ P100 optimisation complete   [4115.19s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   2                     2
# 2                            0                   9                     8
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      2               0                   2              0
# 2                      8               0                   1              0
# 3                      3               0                   0              0
#
# [P100] Current fleet meets SLA and has no current-fleet gap. Skipping fleet expansion search.
#     ✓ P90 built (11,364 flights)   [0.53s]
#     P90 demand summary: 18,548 PRMs across 11,364 flights
#     ✓ prepare_model_data started | flights=11,364   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.04s]
#     ✓ ambulift intervals built | flights=11,364 ambulifts=14   [1.39s]
#     ✓ minibus intervals built | minibuses=3   [0.12s]
#     ✓ staff intervals built   [0.03s]
#     ✓ ambulift overlaps built | overlaps=11,673,768   [2.32s]
#     ✓ minibus overlaps built | overlaps=1,080,357   [0.19s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.03s]
#     ✓ prepare_model_data complete | total=4.12s   [0.00s]
#     ✓ sets built | F=11,364 AMB=14 MINI=3   [0.02s]
#     ✓ variables built | x=56,820 amb=477,288 mini=68,184   [0.36s]
#     ✓ ambulift overlap constraints built | 11,673,768   [341.82s]
#     ✓ minibus overlap constraints built | 1,080,357   [3.35s]
#     ✓ build_pyomo_model complete | total=346.69s   [1.13s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=11,364 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 13504176 rows; 681857 cols; 27624203 nonzeros; 602309 integer variables (602309 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 6e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 1798209 rows, 254718 cols, 3812605 nonzeros 21s
# 549654 rows, 224387 cols, 2461953 nonzeros 141s
# 549654 rows, 224387 cols, 2461953 nonzeros 271s
# Presolve reductions: rows 549654(-12954522); columns 224387(-457470); nonzeros 2461953(-25162250)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    549654 rows
#    224387 cols (200952 binary, 0 integer, 23435 implied int., 0 continuous, 0 domain fixed)
#    2461953 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            4813521610         Large        0      0      0         0   302.4s
#  R       0       0         0   0.00%   553329.680365   1371539751.297    99.96%        0      0      0    113532  1036.8s
#          0       0         0   0.00%   553329.680365   1371539751.297    99.96%     1002      2      0    116892  1100.0s
#          0       0         0   0.00%   553329.680365   1371539751.297    99.96%     1023      4      0    116956  1115.7s
#          0       0         0   0.00%   553329.680365   1371539751.297    99.96%     1157      6      0    117559  1146.7s
#          0       0         0   0.00%   553329.680365   1371539751.297    99.96%     1173      8      0    117754  1162.4s
#          0       0         0   0.00%   553335.388128   1371539751.297    99.96%     1248     22   4667    124401  1283.0s
#          0       0         0   0.00%   553335.388128   1371539751.297    99.96%     1387     28   4667    125326  1307.8s
#          0       0         0   0.00%   553335.388128   1371539751.297    99.96%     1424     32   4667    125868  1336.0s
#          0       0         0   0.00%   553335.388128   1371539751.297    99.96%     1438     38   4667    127031  1355.5s
#          0       0         0   0.00%   553335.388128   1371539751.297    99.96%     1459     43   4667    127506  1368.2s
#          0       0         0   0.00%   553335.388128   1371539751.297    99.96%     1482     47   4667    129945  1398.0s
#          0       0         0   0.00%   553335.388128   1371539751.297    99.96%     1520     53   4667    131815  1449.1s
#          0       0         0   0.00%   553335.388128   1371539751.297    99.96%     1622     58   4667    133180  1558.5s
#          0       0         0   0.00%   553335.388128   1371539751.297    99.96%     1773     62   4667    134380  1654.2s
#          0       0         0   0.00%   553335.388128   1371539751.297    99.96%     1905     66   4667    134967  1720.3s
#          0       0         0   0.00%   553335.388128   1371539751.297    99.96%     2051     65   4667    136034  1823.2s
#          0       0         0   0.00%   553335.388128   1371539751.297    99.96%     2172     70   4667    137449  1904.3s
#          0       0         0   0.00%   553335.388128   1371539751.297    99.96%     2237     74   4667    138161  1953.4s
#          0       0         0   0.00%   553335.388128   1371539751.297    99.96%     2342     79   4667    139146  1985.6s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   553335.388128   1371539751.297    99.96%     2504     84   4667    139743  2038.1s
#  L       0       0         0   0.00%   553335.388128   554099.296804      0.14%     2504     84   4667    139743  3176.9s
#          1       0         1 100.00%   553335.388128   554099.296804      0.14%     2504     84   4667    236623  3177.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      554099.296804
#   Dual bound        553335.388128
#   Gap               0.138% (tolerance: 0.5%)
#   P-D integral      2872.38076179
#   Solution status   feasible
#                     554099.296804 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            3177.49
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     236623
#                     0 (strong br.)
#                     26211 (separation)
#                     96880 (heuristics)
#     ✓ P90 optimisation complete   [3940.67s]
#
# [P90 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     4
# 2                            0                   9                     8
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      4               0                   0              0
# 2                      8               0                   1              0
# 3                      3               0                   0              0
#
# [P90] Current fleet meets SLA and has no current-fleet gap. Skipping fleet expansion search.
#     ✓ Excel outputs written to outputs\prm_combined\monthly\2026_08_v2.xlsx   [25.16s]
#
# Completed month: 2026_08
# Workbook: outputs\prm_combined\monthly\2026_08_combined.xlsx
#    S1_PeakAmb  S1_PeakMini  S1_PeakDrivers  S1_PeakVehAgents  S2_PeakAmb  \
# 0          13            2              13                13          11
# 1          12            2              12                12          11
#
#    S2_PeakMini  S2_PeakDrivers  S2_PeakVehAgents  V2_arrival_sla_pct  \
# 0           14              24                24               100.0
# 1           13              23                23               100.0
#
#    V2_PeakAmb  V2_PeakMini
# 0          11            3
# 1          13            3

# %%
sep_result = run_combined_month(
    2026,
    9,
)

pd.DataFrame(sep_result["month_rows"])
# Out:
# ================================================================================
# RUNNING COMBINED MONTH: 2026_09
# ================================================================================
#
# Running S1 P100
#
# ================================================================================
# [DEBUG A] Future flights loaded & Pax computed
# ================================================================================
# df_flights rows: 11427
# Airlines (sample): ['EC' 'FR' 'RK' 'LM' 'EI' 'B6' 'HU' 'UA' 'U2' 'PC']
# Countries (sample): ['NETHERLANDS' 'ITALY' 'SPAIN' 'GREAT BRITAIN' 'IRISH REPUBLIC'
#  'UNITED STATES OF AMERICA' 'CHINA' 'GERMANY' 'TURKEY' 'FRANCE']
#
# Pax describe:
# count    11427.000000
# mean       148.412007
# std         53.715263
# min          0.000000
# 25%        123.000000
# 50%        160.000000
# 75%        180.000000
# max        397.000000
# Name: Pax, dtype: float64
#
# Top 10 rows (Airline, CountryName, Sector, dir, Pax):
#    Airline               CountryName         Sector dir    Pax
# 0       EC               NETHERLANDS  International   D  163.0
# 1       FR                     ITALY  International   D  176.0
# 2       RK                     SPAIN  International   D  151.0
# 3       LM             GREAT BRITAIN       Domestic   D   30.0
# 4       EI            IRISH REPUBLIC            CTA   D   44.0
# 5       B6  UNITED STATES OF AMERICA  International   D   14.0
# 6       HU                     CHINA  International   D  237.0
# 7       EI            IRISH REPUBLIC            CTA   D   47.0
# 8       FR                   GERMANY  International   D  182.0
# 9       UA  UNITED STATES OF AMERICA  International   D  140.0
# 10      EI            IRISH REPUBLIC            CTA   D   57.0
# 11      U2             GREAT BRITAIN       Domestic   D  172.0
# 12      PC                    TURKEY  International   D  225.0
# 13      RK             GREAT BRITAIN       Domestic   D  177.0
# 14      DL  UNITED STATES OF AMERICA  International   D  170.0
#
# ================================================================================
# [DEBUG B] Penetration lookup match rate
# ================================================================================
# Penetration keys available: 117
# Flights with penetration match: 10,989 / 11,427 (96.2%)
#
# Top missing (Airline, CountryName) combos in future flights:
#    Airline  CountryName  flight_rows
# 3       EC        ITALY          108
# 5       EC        SPAIN           68
# 2       EC       FRANCE           62
# 1       DS  SWITZERLAND           58
# 4       EC  NETHERLANDS           52
# 6       IB        SPAIN           20
# 11      U2     SLOVENIA           18
# 7       LG   LUXEMBOURG           16
# 9       RK        MALTA           16
# 10      RK      ROMANIA           10
# 0       BA        ITALY            8
# 8       RC       FRANCE            2
#
# Example missing keys:
#     Airline  CountryName    Pax
# 0        EC  NETHERLANDS  163.0
# 16       EC        ITALY  132.0
# 115      EC        ITALY  124.0
# 154      EC  NETHERLANDS  168.0
# 261      EC        ITALY  128.0
# 302      IB        SPAIN  163.0
# 309      DS  SWITZERLAND   88.0
# 315      EC       FRANCE  214.0
# 319      EC        SPAIN  132.0
# 368      EC       FRANCE  165.0
# 381      EC        ITALY  166.0
# 390      EC        ITALY  217.0
# 427      EC        SPAIN  169.0
# 433      RK        MALTA  171.0
# 442      EC       FRANCE  170.0
#
# ================================================================================
# [DEBUG C] Expected PRMs vs rounding
# ================================================================================
# Total expected PRMs (raw sum, BEFORE rounding): 19315.724121255254
# Total PRMs after rounding: 19564
#
# Raw PRM demand distribution (prm_raw):
# count    11427.000000
# mean         1.690358
# std          1.409674
# min          0.000000
# 25%          0.841391
# 50%          1.289699
# 75%          1.843343
# max          8.986591
# Name: _prm_raw, dtype: float64
#
# Top flights by raw PRM demand:
#      Airline CountryName    Pax  _pen_used  _prm_raw  _prm_round
# 812       QR       QATAR  311.0   0.028896  8.986591           9
# 3567      QR       QATAR  311.0   0.028896  8.986591           9
# 3650      QR       QATAR  311.0   0.028896  8.986591           9
# 3484      QR       QATAR  311.0   0.028896  8.986591           9
# 705       QR       QATAR  311.0   0.028896  8.986591           9
# 6875      QR       QATAR  311.0   0.028896  8.986591           9
# 4818      QR       QATAR  311.0   0.028896  8.986591           9
# 6133      QR       QATAR  311.0   0.028896  8.986591           9
# 4713      QR       QATAR  311.0   0.028896  8.986591           9
# 4898      QR       QATAR  311.0   0.028896  8.986591           9
# 271       QR       QATAR  311.0   0.028896  8.986591           9
# 2316      QR       QATAR  311.0   0.028896  8.986591           9
# 2234      QR       QATAR  311.0   0.028896  8.986591           9
# 4618      QR       QATAR  311.0   0.028896  8.986591           9
# 4979      QR       QATAR  311.0   0.028896  8.986591           9
# [DEBUG flight] Airline=EC | Country=NETHERLANDS | Pax=163.0 | Pen=0.01000 | Pax*Pen=1.630 | PRMs=2
# [DEBUG flight] Airline=FR | Country=ITALY | Pax=176.0 | Pen=0.00591 | Pax*Pen=1.041 | PRMs=1
# [DEBUG flight] Airline=RK | Country=SPAIN | Pax=151.0 | Pen=0.00888 | Pax*Pen=1.341 | PRMs=1
# [DEBUG flight] Airline=LM | Country=GREAT BRITAIN | Pax=30.0 | Pen=0.02140 | Pax*Pen=0.642 | PRMs=1
# [DEBUG flight] Airline=EI | Country=IRISH REPUBLIC | Pax=44.0 | Pen=0.01119 | Pax*Pen=0.492 | PRMs=0
# [DEBUG flight] Airline=B6 | Country=UNITED STATES OF AMERICA | Pax=14.0 | Pen=0.01370 | Pax*Pen=0.192 | PRMs=0
# [DEBUG flight] Airline=HU | Country=CHINA | Pax=237.0 | Pen=0.00431 | Pax*Pen=1.021 | PRMs=1
# [DEBUG flight] Airline=EI | Country=IRISH REPUBLIC | Pax=47.0 | Pen=0.01119 | Pax*Pen=0.526 | PRMs=1
# [DEBUG flight] Airline=FR | Country=GERMANY | Pax=182.0 | Pen=0.00307 | Pax*Pen=0.558 | PRMs=1
# [DEBUG flight] Airline=UA | Country=UNITED STATES OF AMERICA | Pax=140.0 | Pen=0.01681 | Pax*Pen=2.353 | PRMs=2
# [DEBUG flight] Airline=EI | Country=IRISH REPUBLIC | Pax=57.0 | Pen=0.01119 | Pax*Pen=0.638 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=172.0 | Pen=0.00990 | Pax*Pen=1.702 | PRMs=2
# [DEBUG flight] Airline=PC | Country=TURKEY | Pax=225.0 | Pen=0.00921 | Pax*Pen=2.071 | PRMs=2
# [DEBUG flight] Airline=RK | Country=GREAT BRITAIN | Pax=177.0 | Pen=0.00690 | Pax*Pen=1.221 | PRMs=1
# [DEBUG flight] Airline=DL | Country=UNITED STATES OF AMERICA | Pax=170.0 | Pen=0.01522 | Pax*Pen=2.587 | PRMs=3
#
# [DEBUG ingest_s26]
# Total PRM jobs (rows): 19564
# Columns: ['Passenger ID', 'Airline Code', 'Flight Number', 'A/D', 'Sector', 'CountryName', 'Stand', 'Scheduled Flight DT', 'Chocks DT', 'Minutes on Chocks', 'ScheduledDateTime_Local', 'Chocks_Est', 'Departure Gate', 'SSR Code', 'Has Own Chair', 'IsEffectiveRemote', 'PRM Flight Count', 'Concurrent Stress', 'Turnaround PRM Count', 'Turnaround Vertical Count', 'IsArrival', 'Adhoc Or Planned', 'IsAdhoc', 'Job Start Time', 'Job End Time', 'tau_amb_mins', 'tau_mini_mins', 'tau_push_mins']
# SSR Code present: True
# SSR Code distribution:
# SSR Code
# WCHR     10295
# WCHS      8144
# WCHC      1030
# OTHER       95
# Name: count, dtype: int64
# [BUILD_JOBS] Dropping 4 jobs already impossible at release (beyond SLA + max late)
# Running S2 P100
#
# Running S1 P90
#
# ================================================================================
# [DEBUG A] Future flights loaded & Pax computed
# ================================================================================
# df_flights rows: 11427
# Airlines (sample): ['AF' 'U2' 'FR' 'KL' 'BA' 'RK' 'LH' 'LS' 'LM' 'QR']
# Countries (sample): ['FRANCE' 'ITALY' 'NETHERLANDS' 'GREAT BRITAIN' 'SPAIN' 'ROMANIA'
#  'CROATIA' 'GERMANY' 'TUNISIA' 'IRISH REPUBLIC']
#
# Pax describe:
# count    11427.000000
# mean       148.412007
# std         53.715263
# min          0.000000
# 25%        123.000000
# 50%        160.000000
# 75%        180.000000
# max        397.000000
# Name: Pax, dtype: float64
#
# Top 10 rows (Airline, CountryName, Sector, dir, Pax):
#    Airline    CountryName         Sector dir    Pax
# 0       AF         FRANCE  International   D   91.0
# 1       U2          ITALY  International   D  175.0
# 2       FR         FRANCE  International   D  143.0
# 3       FR          ITALY  International   D  188.0
# 4       KL    NETHERLANDS  International   D  109.0
# 5       BA  GREAT BRITAIN       Domestic   D   87.0
# 6       U2  GREAT BRITAIN       Domestic   D  149.0
# 7       U2  GREAT BRITAIN       Domestic   D  145.0
# 8       U2  GREAT BRITAIN       Domestic   D  158.0
# 9       FR          SPAIN  International   D  197.0
# 10      RK        ROMANIA  International   D  145.0
# 11      U2  GREAT BRITAIN       Domestic   D  150.0
# 12      U2        CROATIA  International   D  171.0
# 13      FR          SPAIN  International   D  187.0
# 14      LH        GERMANY  International   D   87.0
#
# ================================================================================
# [DEBUG B] Penetration lookup match rate
# ================================================================================
# Penetration keys available: 117
# Flights with penetration match: 10,989 / 11,427 (96.2%)
#
# Top missing (Airline, CountryName) combos in future flights:
#    Airline  CountryName  flight_rows
# 3       EC        ITALY          108
# 5       EC        SPAIN           68
# 2       EC       FRANCE           62
# 1       DS  SWITZERLAND           58
# 4       EC  NETHERLANDS           52
# 6       IB        SPAIN           20
# 11      U2     SLOVENIA           18
# 7       LG   LUXEMBOURG           16
# 9       RK        MALTA           16
# 10      RK      ROMANIA           10
# 0       BA        ITALY            8
# 8       RC       FRANCE            2
#
# Example missing keys:
#     Airline  CountryName    Pax
# 10       RK      ROMANIA  145.0
# 53       EC  NETHERLANDS  163.0
# 107      EC        ITALY  132.0
# 159      EC        SPAIN  125.0
# 204      U2     SLOVENIA  135.0
# 293      DS  SWITZERLAND  149.0
# 301      EC        ITALY  124.0
# 305      EC        SPAIN  141.0
# 356      IB        SPAIN  156.0
# 360      EC  NETHERLANDS  168.0
# 420      EC        ITALY  207.0
# 425      DS  SWITZERLAND   98.0
# 487      EC        ITALY  128.0
# 496      EC       FRANCE  170.0
# 522      RK        MALTA  171.0
#
# ================================================================================
# [DEBUG C] Expected PRMs vs rounding
# ================================================================================
# Total expected PRMs (raw sum, BEFORE rounding): 19315.724121255254
# Total PRMs after rounding: 19564
#
# Raw PRM demand distribution (prm_raw):
# count    11427.000000
# mean         1.690358
# std          1.409674
# min          0.000000
# 25%          0.841391
# 50%          1.289699
# 75%          1.843343
# max          8.986591
# Name: _prm_raw, dtype: float64
#
# Top flights by raw PRM demand:
#      Airline CountryName    Pax  _pen_used  _prm_raw  _prm_round
# 2152      QR       QATAR  311.0   0.028896  8.986591           9
# 501       QR       QATAR  311.0   0.028896  8.986591           9
# 4898      QR       QATAR  311.0   0.028896  8.986591           9
# 2234      QR       QATAR  311.0   0.028896  8.986591           9
# 4818      QR       QATAR  311.0   0.028896  8.986591           9
# 5739      QR       QATAR  311.0   0.028896  8.986591           9
# 6591      QR       QATAR  311.0   0.028896  8.986591           9
# 4979      QR       QATAR  311.0   0.028896  8.986591           9
# 4508      QR       QATAR  311.0   0.028896  8.986591           9
# 4618      QR       QATAR  311.0   0.028896  8.986591           9
# 705       QR       QATAR  311.0   0.028896  8.986591           9
# 6875      QR       QATAR  311.0   0.028896  8.986591           9
# 4713      QR       QATAR  311.0   0.028896  8.986591           9
# 2316      QR       QATAR  311.0   0.028896  8.986591           9
# 3650      QR       QATAR  311.0   0.028896  8.986591           9
# [DEBUG flight] Airline=AF | Country=FRANCE | Pax=91.0 | Pen=0.00815 | Pax*Pen=0.741 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=ITALY | Pax=175.0 | Pen=0.00941 | Pax*Pen=1.648 | PRMs=2
# [DEBUG flight] Airline=FR | Country=FRANCE | Pax=143.0 | Pen=0.00741 | Pax*Pen=1.060 | PRMs=1
# [DEBUG flight] Airline=FR | Country=ITALY | Pax=188.0 | Pen=0.00591 | Pax*Pen=1.112 | PRMs=1
# [DEBUG flight] Airline=KL | Country=NETHERLANDS | Pax=109.0 | Pen=0.00898 | Pax*Pen=0.979 | PRMs=1
# [DEBUG flight] Airline=BA | Country=GREAT BRITAIN | Pax=87.0 | Pen=0.01039 | Pax*Pen=0.904 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=149.0 | Pen=0.00990 | Pax*Pen=1.475 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=145.0 | Pen=0.00990 | Pax*Pen=1.435 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=158.0 | Pen=0.00990 | Pax*Pen=1.564 | PRMs=2
# [DEBUG flight] Airline=FR | Country=SPAIN | Pax=197.0 | Pen=0.01043 | Pax*Pen=2.054 | PRMs=2
# [DEBUG flight] Airline=RK | Country=ROMANIA | Pax=145.0 | Pen=0.01000 | Pax*Pen=1.450 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=150.0 | Pen=0.00990 | Pax*Pen=1.485 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=CROATIA | Pax=171.0 | Pen=0.00455 | Pax*Pen=0.778 | PRMs=1
# [DEBUG flight] Airline=FR | Country=SPAIN | Pax=187.0 | Pen=0.01043 | Pax*Pen=1.950 | PRMs=2
# [DEBUG flight] Airline=LH | Country=GERMANY | Pax=87.0 | Pen=0.00614 | Pax*Pen=0.534 | PRMs=1
#
# [DEBUG ingest_s26]
# Total PRM jobs (rows): 19564
# Columns: ['Passenger ID', 'Airline Code', 'Flight Number', 'A/D', 'Sector', 'CountryName', 'Stand', 'Scheduled Flight DT', 'Chocks DT', 'Minutes on Chocks', 'ScheduledDateTime_Local', 'Chocks_Est', 'Departure Gate', 'SSR Code', 'Has Own Chair', 'IsEffectiveRemote', 'PRM Flight Count', 'Concurrent Stress', 'Turnaround PRM Count', 'Turnaround Vertical Count', 'IsArrival', 'Adhoc Or Planned', 'IsAdhoc', 'Job Start Time', 'Job End Time', 'tau_amb_mins', 'tau_mini_mins', 'tau_push_mins']
# SSR Code present: True
# SSR Code distribution:
# SSR Code
# WCHR     10301
# WCHS      8128
# WCHC      1017
# OTHER      118
# Name: count, dtype: int64
# [BUILD_JOBS] Dropping 4 jobs already impossible at release (beyond SLA + max late)
# [BUILD_JOBS] Applying stratified percentile cap: q=0.90 | strata=['SSR Code', 'Has Own Chair', 'A/D']
# [BUILD_JOBS] Dropped 1625 PRM jobs via stratified percentile cap
# Running S2 P90
#
# Running V2 optimiser
#     ✓ Passenger dataset combined (19,631 passenger rows)   [85.35s]
#     ✓ P100 built (10,781 flights)   [0.19s]
#     P100 demand summary: 19,631 PRMs across 10,781 flights
#     ✓ prepare_model_data started | flights=10,781   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.04s]
#     ✓ ambulift intervals built | flights=10,781 ambulifts=14   [1.30s]
#     ✓ minibus intervals built | minibuses=3   [0.13s]
#     ✓ staff intervals built   [0.03s]
#     ✓ ambulift overlaps built | overlaps=10,973,841   [2.31s]
#     ✓ minibus overlaps built | overlaps=1,007,217   [0.56s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.22s]
#     ✓ prepare_model_data complete | total=4.59s   [0.00s]
#     ✓ sets built | F=10,781 AMB=14 MINI=3   [0.01s]
#     ✓ variables built | x=53,905 amb=452,802 mini=64,686   [2.70s]
#     ✓ ambulift overlap constraints built | 10,973,841   [119.58s]
#     ✓ minibus overlap constraints built | 1,007,217   [5.70s]
#     ✓ build_pyomo_model complete | total=129.75s   [1.75s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=10,781 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 12692704 rows; 646877 cols; 25969552 nonzeros; 571410 integer variables (571410 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 9e+00]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -1
# Presolving model
# 1682425 rows, 237465 cols, 3564506 nonzeros 32s
# 510297 rows, 209313 cols, 2302479 nonzeros 326s
# 510297 rows, 209313 cols, 2302479 nonzeros 633s
# Presolve reductions: rows 510297(-12182407); columns 209313(-437564); nonzeros 2302479(-23667073)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    510297 rows
#    209313 cols (187332 binary, 0 integer, 21981 implied int., 0 continuous, 0 domain fixed)
#    2302479 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            4385531739.826     Large        0      0      0         0   711.7s
#  R       0       0         0   0.00%   1533357.778351  1259523019.219    99.88%        0      0      0    240258  2592.9s
#          0       0         0   0.00%   1533357.778351  1259523019.219    99.88%     1082     38      0    240639  2619.3s
#          0       0         0   0.00%   1533623.397399  1259523019.219    99.88%     2123    171      0    242462  2641.4s
#          0       0         0   0.00%   1533978.825791  1259523019.219    99.88%     2239    296      0    259682  2770.4s
#          0       0         0   0.00%   1534762.103568  1259523019.219    99.88%     2783    422      0    260956  2786.9s
#  C       0       0         0   0.00%   1535164.770235  1008524762.297    99.85%     2792    474      0    261151  2795.7s
#          0       0         0   0.00%   1535335.103568  1008524762.297    99.85%     2796    496      0    261398  2807.3s
#          0       0         0   0.00%   1535385.270235  1008524762.297    99.85%     3008    502      0    262087  2993.6s
#          0       0         0   0.00%   1535388.436902  1008524762.297    99.85%     3010    506      0    262355  3011.9s
#          0       0         0   0.00%   1535393.436902  1008524762.297    99.85%     3014    509      0    262724  3030.2s
#          0       0         0   0.00%   1535393.436902  1008524762.297    99.85%     3031    511      0    262808  3040.2s
#          0       0         0   0.00%   1535393.436902  1008524762.297    99.85%     3044    513      0    262859  3053.9s
#          0       0         0   0.00%   1535393.436902  1008524762.297    99.85%     3050    515      0    263229  3066.1s
#          0       0         0   0.00%   1535393.436902  1008524762.297    99.85%     3064    517      0    264003  3087.5s
#          0       0         0   0.00%   1535393.436902  1008524762.297    99.85%     3081    519      0    264756  3104.2s
#  L       0       0         0   0.00%   1535393.436902  1535597.465753     0.01%     3081    519      0    264756  4117.0s
#          1       0         1 100.00%   1535393.436902  1535597.465753     0.01%     3081    519      0    366348  4117.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      1535597.46575
#   Dual bound        1535393.43836
#   Gap               0.0133% (tolerance: 0.5%)
#   P-D integral      3399.70722598
#   Solution status   feasible
#                     1535597.46575 (objective)
#                     0 (bound viol.)
#                     1.33226762955e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            4117.33
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     366348
#                     0 (strong br.)
#                     24498 (separation)
#                     101592 (heuristics)
#     ✓ P100 optimisation complete   [4758.89s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     4
# 2                            0                   7                     7
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      4               0                   0              0
# 2                      7               0                   2              0
# 3                      3               0                   0              0
#
# [P100] Fleet expansion triggered because: Shortfall=1.00
#
# [P100] Running fleet expansion scenario: +1 future copy per future model
#     ✓ prepare_model_data started | flights=10,781   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.05s]
#     ✓ ambulift intervals built | flights=10,781 ambulifts=14   [1.21s]
#     ✓ minibus intervals built | minibuses=5   [0.12s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=10,973,841   [3.36s]
#     ✓ minibus overlaps built | overlaps=1,678,695   [0.43s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.11s]
#     ✓ prepare_model_data complete | total=5.31s   [0.00s]
#     ✓ sets built | F=10,781 AMB=14 MINI=5   [0.09s]
#     ✓ variables built | x=53,905 amb=452,802 mini=107,810   [0.54s]
#     ✓ ambulift overlap constraints built | 10,973,841   [538.18s]
#     ✓ minibus overlap constraints built | 1,678,695   [10.47s]
#     ✓ build_pyomo_model complete | total=551.40s   [2.12s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=10,781 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 13493556 rows; 690005 cols; 27657504 nonzeros; 614538 integer variables (614538 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -1
# Presolving model
# 2072627 rows, 267015 cols, 4377580 nonzeros 22s
# 583781 rows, 230879 cols, 2552637 nonzeros 144s
# 583781 rows, 230879 cols, 2552637 nonzeros 282s
# Presolve reductions: rows 583781(-12909775); columns 230879(-459126); nonzeros 2552637(-25104867)
#
# Solving MIP model with:
#    583781 rows
#    230879 cols (208898 binary, 0 integer, 21981 implied int., 0 continuous, 0 domain fixed)
#    2552637 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            4176715873.708     Large        0      0      0         0   329.7s
#  R       0       0         0   0.00%   712509.579032   1283700141.11     99.94%        0      0      0    252442  2138.7s
#          0       0         0   0.00%   712509.579032   1283700141.11     99.94%      290      2      0    252685  2163.8s
#          0       0         0   0.00%   712512.495698   1283700141.11     99.94%      745     25      0    254782  2226.6s
#          0       0         0   0.00%   712529.495698   1283700141.11     99.94%      781     45      0    254831  2235.9s
#          0       0         0   0.00%   712606.995698   1283700141.11     99.94%      795     63      0    255218  2260.5s
#          0       0         0   0.00%   712658.995698   1283700141.11     99.94%      798     79   2459    255368  2279.4s
#          0       0         0   0.00%   712668.329032   1283700141.11     99.94%      805     84   2459    256393  2316.5s
#          0       0         0   0.00%   712668.329032   1283700141.11     99.94%      812     87   2459    256416  2392.6s
#          0       0         0   0.00%   712695.353899   1283700141.11     99.94%      813     93   2459    264598  2458.0s
#          0       0         0   0.00%   712713.353899   1283700141.11     99.94%      908     98   2459    265803  2492.3s
#          0       0         0   0.00%   712713.353899   1283700141.11     99.94%      949    100   2459    266390  2554.7s
#          0       0         0   0.00%   712713.353899   1283700141.11     99.94%     1004    102   2459    267744  2631.1s
#          0       0         0   0.00%   712713.353899   1283700141.11     99.94%     1030    104   2459    268590  2661.6s
#  L       0       0         0   0.00%   712713.353899   712817.694064      0.01%     1030    104   2459    268590  4097.4s
#          1       0         1 100.00%   712713.353899   712817.694064      0.01%     1030    104   2459    377985  4098.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      712817.694064
#   Dual bound        712713.353899
#   Gap               0.0146% (tolerance: 0.5%)
#   P-D integral      3764.59951451
#   Solution status   feasible
#                     712817.694064 (objective)
#                     0 (bound viol.)
#                     4.05453448593e-13 (int. viol.)
#                     0 (row viol.)
#   Timing            4098.20
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     377985
#                     0 (strong br.)
#                     16148 (separation)
#                     109395 (heuristics)
# [P100] Stopping fleet expansion: scenario +1 meets SLA and has no shortfall.
#     ✓ P100 fleet expansion search complete   [5239.62s]
#     ✓ P90 built (10,781 flights)   [0.63s]
#     P90 demand summary: 18,032 PRMs across 10,781 flights
#     ✓ prepare_model_data started | flights=10,781   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.06s]
#     ✓ ambulift intervals built | flights=10,781 ambulifts=14   [1.24s]
#     ✓ minibus intervals built | minibuses=3   [0.12s]
#     ✓ staff intervals built   [0.03s]
#     ✓ ambulift overlaps built | overlaps=10,877,432   [3.10s]
#     ✓ minibus overlaps built | overlaps=1,007,430   [0.29s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.05s]
#     ✓ prepare_model_data complete | total=4.88s   [0.00s]
#     ✓ sets built | F=10,781 AMB=14 MINI=3   [0.07s]
#     ✓ variables built | x=53,905 amb=452,802 mini=64,686   [0.49s]
#     ✓ ambulift overlap constraints built | 10,877,432   [379.16s]
#     ✓ minibus overlap constraints built | 1,007,430   [7.62s]
#     ✓ build_pyomo_model complete | total=388.45s   [1.11s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=10,781 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 12596428 rows; 646877 cols; 25777080 nonzeros; 571410 integer variables (571410 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 6e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 1672155 rows, 237609 cols, 3545757 nonzeros 23s
# 509457 rows, 209460 cols, 2285510 nonzeros 158s
# 509457 rows, 209460 cols, 2285510 nonzeros 273s
# Presolve reductions: rows 509457(-12086971); columns 209460(-437417); nonzeros 2285510(-23491570)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    509457 rows
#    209460 cols (187470 binary, 0 integer, 21990 implied int., 0 continuous, 0 domain fixed)
#    2285510 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            4336499332.826     Large        0      0      0         0   307.8s
#  R       0       0         0   0.00%   1521093.16754   1172509448.466    99.87%        0      0      0    334148  1712.4s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%      154      1      0    334172  1775.6s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%      550      6      0    335367  1823.5s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%      562      8      0    335498  1839.9s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%      598     10      0    336010  1883.7s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%      705     11   4709    336143  1982.3s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%      754     12   4709    336522  2038.3s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%      782     13   4709    337031  2104.6s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%      894     16   4709    339041  2204.4s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%      910     17   4709    339403  2246.5s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%      916     18   4709    341069  2291.2s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%      927     19   4709    341848  2335.6s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%      956     20   4709    343037  2385.0s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     1034     21   4709    343166  2456.1s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     1044     22   4709    343987  2490.4s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     1060     23   4709    345201  2510.5s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     1150     24   4709    345580  2585.0s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     1162     25   4709    346546  2623.7s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     1210     26   4709    347050  2667.6s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     1287     27   4709    347882  2736.2s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     1293     28   4709    348102  2749.0s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     1377     29   4709    348191  2822.4s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     1419     30   4709    349517  2867.3s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     1466     31   4709    351875  2919.4s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     1602     32   4709    352543  2994.4s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     1652     32   4709    353483  3062.5s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     1791     33   4709    353699  3081.8s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     1831     34   4709    354208  3144.1s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     1948     39   4709    354296  3209.4s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     1964     43   4709    356213  3255.4s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     2164     44   4709    357022  3347.4s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     2352     46   4709    357101  3403.1s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     2327     49   4709    357722  3440.1s
#          0       0         0   0.00%   1521093.16754   1172509448.466    99.87%     2425     51   4709    358100  3519.5s
#          0       0         0   0.00%   1521093.249451  1172509448.466    99.87%     2445     53   4709    369119  3626.8s
#          0       0         0   0.00%   1521093.249451  1172509448.466    99.87%     3148     57   4709    369810  3673.6s
#          0       0         0   0.00%   1521093.249451  1172509448.466    99.87%     3303     59   4709    370699  3763.8s
#          0       0         0   0.00%   1521093.249451  1172509448.466    99.87%     3307     62   4709    370819  3775.5s
#          0       0         0   0.00%   1521093.249451  1172509448.466    99.87%     3331     64   4709    370919  3841.7s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   1521093.249451  1172509448.466    99.87%     3400     66   4709    372460  3899.2s
#          0       0         0   0.00%   1521093.249451  1172509448.466    99.87%     3497     65   4709    372666  3984.1s
#          0       0         0   0.00%   1521093.518826  1172509448.466    99.87%     3657     67   4709    393590  4147.1s
#          0       0         0   0.00%   1521093.518826  1172509448.466    99.87%     4664     70   4709    393783  4178.6s
#          0       0         0   0.00%   1521093.518826  1172509448.466    99.87%     4681     72   4709    394507  4215.2s
#          0       0         0   0.00%   1521093.518826  1172509448.466    99.87%     4773     74   4709    394566  4300.7s
#          0       0         0   0.00%   1521093.518826  1172509448.466    99.87%     4790     68   4709    394692  4331.0s
#          0       0         0   0.00%   1521093.518826  1172509448.466    99.87%     4887     70   4709    394788  4407.0s
#          0       0         0   0.00%   1521093.518826  1172509448.466    99.87%     4866     73   4709    395160  4438.2s
#          0       0         0   0.00%   1521093.518826  1172509448.466    99.87%     4908     75   4709    395186  4487.0s
#          0       0         0   0.00%   1521093.518826  1172509448.466    99.87%     4956     78   4709    395277  4530.1s
#          0       0         0   0.00%   1521093.518826  1172509448.466    99.87%     4966     78   4709    395811  4561.5s
#  L       0       0         0   0.00%   1521093.518826  1522287.050228     0.08%     4966     78   4709    395811  6485.4s
#          1       0         1 100.00%   1521093.518826  1522287.050228     0.08%     4935     78   4709    511411  6485.6s
#
# Solving report
#   Status            Optimal
#   Primal bound      1522287.05023
#   Dual bound        1521093.52055
#   Gap               0.0784% (tolerance: 0.5%)
#   P-D integral      6170.09999564
#   Solution status   feasible
#                     1522287.05023 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            6485.63
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     511411
#                     0 (strong br.)
#                     61663 (separation)
#                     115600 (heuristics)
#     ✓ P90 optimisation complete   [7235.28s]
#
# [P90 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   3                     3
# 2                            0                   7                     7
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      3               0                   1              0
# 2                      7               0                   2              0
# 3                      3               0                   0              0
#
# [P90] Fleet expansion triggered because: Shortfall=1.00
#
# [P90] Running fleet expansion scenario: +1 future copy per future model
#     ✓ prepare_model_data started | flights=10,781   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.06s]
#     ✓ ambulift intervals built | flights=10,781 ambulifts=14   [1.12s]
#     ✓ minibus intervals built | minibuses=5   [0.11s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=10,877,432   [1.93s]
#     ✓ minibus overlaps built | overlaps=1,679,050   [0.29s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.03s]
#     ✓ prepare_model_data complete | total=3.56s   [0.00s]
#     ✓ sets built | F=10,781 AMB=14 MINI=5   [0.02s]
#     ✓ variables built | x=53,905 amb=452,802 mini=107,810   [0.39s]
#     ✓ ambulift overlap constraints built | 10,877,432   [232.10s]
#     ✓ minibus overlap constraints built | 1,679,050   [9.15s]
#     ✓ build_pyomo_model complete | total=242.73s   [1.07s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=10,781 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 13397422 rows; 690005 cols; 27465316 nonzeros; 614538 integer variables (614538 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 2062467 rows, 267159 cols, 4359051 nonzeros 17s
# 583588 rows, 231026 cols, 2539499 nonzeros 111s
# 583588 rows, 231026 cols, 2539499 nonzeros 204s
# Presolve reductions: rows 583588(-12813834); columns 231026(-458979); nonzeros 2539499(-24925817)
#
# Solving MIP model with:
#    583588 rows
#    231026 cols (209036 binary, 0 integer, 21990 implied int., 0 continuous, 0 domain fixed)
#    2539499 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            4337499342.826     Large        0      0      0         0   239.7s
#  R       0       0         0   0.00%   702426.249081   923693326.4475    99.92%        0      0      0    179255   849.1s
#          0       0         0   0.00%   702426.249081   923693326.4475    99.92%     1020      4      0    179630   870.4s
#          0       0         0   0.00%   702426.249081   923693326.4475    99.92%     1027      8      0    180978   883.5s
#          0       0         0   0.00%   702426.249081   923693326.4475    99.92%     1049     12      0    181563   895.1s
#          0       0         0   0.00%   702426.249081   923693326.4475    99.92%     1057     16      0    181936   900.7s
#  C       0       0         0   0.00%   702426.249081   747877821.9269    99.91%     1060     20      0    182009   907.0s
#          0       0         0   0.00%   702426.249081   747877821.9269    99.91%     1159     24      0    182149   969.3s
#          0       0         0   0.00%   702426.249081   747877821.9269    99.91%     1161     56      0    182788   977.3s
#          0       0         0   0.00%   702427.135459   747877821.9269    99.91%     1190     68      0    212834  1118.5s
#          0       0         0   0.00%   702427.135459   747877821.9269    99.91%     2192    104      0    213997  1130.8s
#          0       0         0   0.00%   702427.135459   747877821.9269    99.91%     2209    113      0    214260  1138.5s
#          0       0         0   0.00%   702427.577057   747877821.9269    99.91%     2227    123      0    230348  1205.8s
#          0       0         0   0.00%   702427.577057   747877821.9269    99.91%     2638    140      0    230770  1213.2s
#          0       0         0   0.00%   702427.577057   747877821.9269    99.91%     2644    150      0    230907  1219.4s
#          0       0         0   0.00%   702427.577057   747877821.9269    99.91%     2650    161      0    231073  1226.8s
#          0       0         0   0.00%   702427.577057   747877821.9269    99.91%     2702    171      0    231311  1238.8s
#          0       0         0   0.00%   702427.577057   747877821.9269    99.91%     2717    143      0    231659  1246.3s
#  L       0       0         0   0.00%   702427.577057   702479.278539      0.01%     2717    143      0    231659  1904.3s
#          1       0         1 100.00%   702427.577057   702479.278539      0.01%     2717    143      0    354836  1904.6s
#
# Solving report
#   Status            Optimal
#   Primal bound      702479.278539
#   Dual bound        702427.577057
#   Gap               0.00736% (tolerance: 0.5%)
#   P-D integral      1662.51806143
#   Solution status   feasible
#                     702479.278539 (objective)
#                     0 (bound viol.)
#                     7.12985226414e-13 (int. viol.)
#                     0 (row viol.)
#   Timing            1904.61
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     354836
#                     0 (strong br.)
#                     52404 (separation)
#                     123177 (heuristics)
# [P90] Stopping fleet expansion: scenario +1 meets SLA and has no shortfall.
#     ✓ P90 fleet expansion search complete   [2446.20s]
#     ✓ Excel outputs written to outputs\prm_combined\monthly\2026_09_v2.xlsx   [29.68s]
#
# Completed month: 2026_09
# Workbook: outputs\prm_combined\monthly\2026_09_combined.xlsx
#    S1_PeakAmb  S1_PeakMini  S1_PeakDrivers  S1_PeakVehAgents  S2_PeakAmb  \
# 0          13            2              13                13          13
# 1          13            2              15                15          11
#
#    S2_PeakMini  S2_PeakDrivers  S2_PeakVehAgents  V2_arrival_sla_pct  \
# 0           15              26                26           99.989887
# 1           14              23                23           99.989199
#
#    V2_PeakAmb  V2_PeakMini
# 0          12            3
# 1          11            3

# %%
oct_result = run_combined_month(
    2026,
    10,
)

pd.DataFrame(oct_result["month_rows"])
# Out:
# ================================================================================
# RUNNING COMBINED MONTH: 2026_10
# ================================================================================
#
# Running S1 P100
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:3317, in Engine.raw_connection(self)
#    3296 """Return a "raw" DBAPI connection from the connection pool.
#    3297
#    3298 The returned object is a proxied version of the DBAPI
#    (...)   3315
#    3316 """
# -> 3317 return self.pool.connect()
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
#     443 The connection is instrumented such that when its
#    (...)    446
#     447 """
# --> 448 return _ConnectionFairy._checkout(self)
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1271 if not fairy:
# -> 1272     fairy = _ConnectionRecord.checkout(pool)
#    1274     if threadconns is not None:
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\impl.py:175, in QueuePool._do_get(self)
#     174 try:
# --> 175     return self._create_connection()
#     176 except:
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py:389, in Pool._create_connection(self)
#     387 """Called by subclasses to create a new ConnectionRecord."""
# --> 389 return _ConnectionRecord(self)
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\create.py:667, in create_engine.<locals>.connect(connection_record)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# OperationalError: ('08001', '[08001] [Microsoft][ODBC Driver 18 for SQL Server]TCP Provider: The wait operation timed out.\r\n (258) (SQLDriverConnect); [08001] [Microsoft][ODBC Driver 18 for SQL Server]Login timeout expired (0); [08001] [Microsoft][ODBC Driver 18 for SQL Server]A network-related or instance-specific error has occurred while establishing a connection to sqlmi-eal-dwh-prod-01.df05c9427633.database.windows.net,1433. Server is not found or not accessible. Check if instance name is correct and if SQL Server is configured to allow remote connections. For more information see SQL Server Books Online. (258)')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 oct_result = run_combined_month(
#       2     2026,
#       3     10,
#       4 )
#       6 pd.DataFrame(oct_result["month_rows"])
#
# Cell In[11], line 75, in run_combined_month(year, month, seed)
#      71 print("")
#      72 print(f"Running S1 {mode_key}")
#      74 s1_outputs[mode_key] = (
# ---> 75     run_s1_for_period(
#      76         month_info=month_info,
#      77         toggles=toggles,
#      78         rule_assumptions=rule_assumptions,
#      79         seed=seed,
#      80     )
#      81 )
#      83 print(f"Running S2 {mode_key}")
#      85 s2_outputs[mode_key] = (
#      86     run_s2_for_period(
#      87         month_info=month_info,
#    (...)     91     )
#      92 )
#
# Cell In[6], line 99, in run_s1_for_period(month_info, toggles, rule_assumptions, seed)
#      91 def run_s1_for_period(
#      92     *,
#      93     month_info,
#    (...)     96     seed=42,
#      97 ):
# ---> 99     jobs = build_s1_jobs_for_period(
#     100         month_info=month_info,
#     101         toggles=toggles,
#     102         rule_assumptions=rule_assumptions,
#     103         seed=seed,
#     104     )
#     106     if jobs is None or len(jobs) == 0:
#     108         empty_series = pd.Series(dtype=int)
#
# Cell In[6], line 42, in build_s1_jobs_for_period(month_info, toggles, rule_assumptions, seed)
#      39 if rule_assumptions is None:
#      40     raise ValueError("Future S1 requires rule_assumptions.")
# ---> 42 df_future = ingest_s26(
#      43     start=kwargs["s26_start"],
#      44     end=kwargs["s26_end"],
#      45     **rule_assumptions["inputs"],
#      46     seed=seed,
#      47 )
#      49 jobs_future = build_jobs(
#      50     df_future,
#      51     bucket="15min",
#      52     toggles=toggles,
#      53     use_90th_percentile_cap=False,
#      54 )
#      56 jobs_future["source_period"] = "S26"
#
# File ~\OneDrive - Edinburgh Airport Limited\Documents\GitHub\EDI_airport_analytics\prm_opt\ingest_s26.py:288, in ingest_s26(start, end, penetration_rates, ssr_mix, stand_actuals, stand_dist, service_time_params, tau_mode_params, chocks_offset_params, early_late_std_mins, seed, turnaround_max_gap_mins, spin_window_mins)
#     283 DEBUG_MAX_SHOW = 15   # limit prints
#     286 rng = np.random.default_rng(seed)
# --> 288 df_flights = load_future_flights(start, end).copy()
#     290 # Standardise fields and create sector/dir
#     291 df_flights["ScheduledDateTime_Local"] = pd.to_datetime(df_flights["ScheduledDateTime_Local"])
#
# File ~\OneDrive - Edinburgh Airport Limited\Documents\GitHub\EDI_airport_analytics\prm_opt\ingest_s26.py:54, in load_future_flights(start, end)
#      50 def load_future_flights(start: str, end: str) -> pd.DataFrame:
#      51     """
#      52     Load future flight schedule from EAL.FlightPerformance_FutureFlights.
#      53     """
# ---> 54     df = query(
#      55         table="EAL.FlightPerformance_FutureFlights",
#      56         columns=[
#      57             "FlightID",
#      58             "ScheduledDateTime_Local",
#      59             "ArrDeptureCode",
#      60             "FlightNumber",
#      61             "AirlineCode_IATA",
#      62             "CountryName",
#      63             "Sector",
#      64             "Pax_MostConfident",
#      65             "PublishedForecast_Pax",
#      66         ],
#      67         where=[
#      68             "ScheduledDateTime_Local >= :start",
#      69             "ScheduledDateTime_Local < :end",
#      70             "IsPassengerFlight = 1",
#      71         ],
#      72         params={"start": start, "end": end},
#      73         query_option="OPTION (RECOMPILE)",
#      74     )
#      75     return df
#
# File ~\OneDrive - Edinburgh Airport Limited\Documents\GitHub\EDI_airport_analytics\modules\utils\query.py:155, in query(table, columns, where, params, date_column, end_column, start, end, distinct, order_by, overlap, or_events, engine, query_option)
#     151     sql += f"{opt}"
#     154 #Execute
# --> 155 return read_sql(engine, sql, params=final_params)
#
# File ~\OneDrive - Edinburgh Airport Limited\Documents\GitHub\EDI_airport_analytics\modules\utils\sql.py:27, in read_sql(engine, sql, params, parse_dates)
#      25 if parse_dates:
#      26     return pd.read_sql(text(sql), con=engine, params=params, parse_dates=parse_dates)
# ---> 27 return pd.read_sql(text(sql), con=engine, params=params)
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:704, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     701     dtype_backend = "numpy"  # type: ignore[assignment]
#     702 assert dtype_backend is not lib.no_default
# --> 704 with pandasSQL_builder(con) as pandas_sql:
#     705     if isinstance(pandas_sql, SQLiteDatabase):
#     706         return pandas_sql.read_query(
#     707             sql,
#     708             index_col=index_col,
#    (...)    714             dtype=dtype,
#     715         )
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:906, in pandasSQL_builder(con, schema, need_transaction)
#     903     raise ImportError("Using URI string without sqlalchemy installed.")
#     905 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 906     return SQLDatabase(con, schema, need_transaction)
#     908 adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#     909 if adbc and isinstance(con, adbc.Connection):
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:1636, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1634     self.exit_stack.callback(con.dispose)
#    1635 if isinstance(con, Engine):
# -> 1636     con = self.exit_stack.enter_context(con.connect())
#    1637 if need_transaction and not con.in_transaction():
#    1638     self.exit_stack.enter_context(con.begin())
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:3293, in Engine.connect(self)
#    3270 def connect(self) -> Connection:
#    3271     """Return a new :class:`_engine.Connection` object.
#    3272
#    3273     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)   3290
#    3291     """
# -> 3293     return self._connection_cls(self)
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
# --> 145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#     148         raise
#     149 else:
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:2448, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2446 elif should_wrap:
#    2447     assert sqlalchemy_exception is not None
# -> 2448     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2449 else:
#    2450     assert exc_info[1] is not None
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     141 if connection is None:
#     142     try:
# --> 143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
#     145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\base.py:3317, in Engine.raw_connection(self)
#    3295 def raw_connection(self) -> PoolProxiedConnection:
#    3296     """Return a "raw" DBAPI connection from the connection pool.
#    3297
#    3298     The returned object is a proxied version of the DBAPI
#    (...)   3315
#    3316     """
# -> 3317     return self.pool.connect()
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     440 def connect(self) -> PoolProxiedConnection:
#     441     """Return a DBAPI connection from the pool.
#     442
#     443     The connection is instrumented such that when its
#    (...)    446
#     447     """
# --> 448     return _ConnectionFairy._checkout(self)
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1264 @classmethod
#    1265 def _checkout(
#    1266     cls,
#    (...)   1269     fairy: Optional[_ConnectionFairy] = None,
#    1270 ) -> _ConnectionFairy:
#    1271     if not fairy:
# -> 1272         fairy = _ConnectionRecord.checkout(pool)
#    1274         if threadconns is not None:
#    1275             threadconns.current = weakref.ref(fairy)
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175     return self._create_connection()
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#     179     raise
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     119     assert exc_value is not None
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#     123     self._exc_info = None  # remove potential circular references
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\impl.py:175, in QueuePool._do_get(self)
#     173 if self._inc_overflow():
#     174     try:
# --> 175         return self._create_connection()
#     176     except:
#     177         with util.safe_reraise():
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py:389, in Pool._create_connection(self)
#     386 def _create_connection(self) -> ConnectionPoolEntry:
#     387     """Called by subclasses to create a new ConnectionRecord."""
# --> 389     return _ConnectionRecord(self)
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     119     assert exc_value is not None
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#     123     self._exc_info = None  # remove potential circular references
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\create.py:667, in create_engine.<locals>.connect(connection_record)
#     665     return dialect.connect(*mutable_cargs, **mutable_cparams)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File c:\Users\jamie_douglas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sqlalchemy\engine\default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# OperationalError: (pyodbc.OperationalError) ('08001', '[08001] [Microsoft][ODBC Driver 18 for SQL Server]TCP Provider: The wait operation timed out.\r\n (258) (SQLDriverConnect); [08001] [Microsoft][ODBC Driver 18 for SQL Server]Login timeout expired (0); [08001] [Microsoft][ODBC Driver 18 for SQL Server]A network-related or instance-specific error has occurred while establishing a connection to sqlmi-eal-dwh-prod-01.df05c9427633.database.windows.net,1433. Server is not found or not accessible. Check if instance name is correct and if SQL Server is configured to allow remote connections. For more information see SQL Server Books Online. (258)')
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
