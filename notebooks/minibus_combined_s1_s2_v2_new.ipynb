# %% [markdown]
# ### Imports and Config

# %%
# ==========================================================
# 1. Imports and repo setup
# ==========================================================

import sys
from pathlib import Path
from datetime import date, timedelta
from calendar import monthrange

import pandas as pd

HERE = Path().resolve()
PROJECT_ROOT = HERE.parents[0]
sys.path.insert(0, str(PROJECT_ROOT))

from prm_opt.config import PlanningToggles, VEHICLE_MODELS

from prm_opt.optimise_prm_fleet_v2 import OptimiserConfig
from prm_opt.run_s25_s26_v2 import run_s25_s26_v2

from prm_opt.build_assumptions_v2 import build_assumptions_v2
from prm_opt.build_s26_assumptions import build_s26_assumptions

from prm_opt.ingest_s25 import ingest_s25
from prm_opt.ingest_s26 import ingest_s26
from prm_opt.build_jobs import build_jobs
from prm_opt.policy_s1 import apply_policy_s1
from prm_opt.outputs import baseline_s1_vehicle_curves_capacity, baseline_s1_summary

from prm_opt.ingest_s25_v2 import ingest_s25_v2
from prm_opt.ingest_s26_v2 import ingest_s26_v2
from prm_opt.build_flights_v2 import build_flights_v2

from prm_opt.policy_s2_flight_rules import run_s2_flight_rules

# %% [markdown]
# ### User Parameters

# %%
# ==========================================================
# 2. User parameters
# ==========================================================

OUTPUT_ROOT = Path("outputs/prm_combined_new")
MONTHLY_OUTPUT_DIR = OUTPUT_ROOT / "monthly"

OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)
MONTHLY_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

MONTHS_TO_RUN = [
    (2026, 5),
    (2026, 6),
    (2026, 7),
    (2026, 8),
    (2026, 9),
    (2026, 10),
]

ASSUMPTION_S25_START = "2025-04-01"
ASSUMPTION_S25_END = "2025-10-31"

PENETRATION_UPLIFT = 1.08

RUN_P100 = True
RUN_P90 = True

S2_AMB_SEATCAP = 7
S2_AMB_WCCAP = 1

S2_MINI_SEATCAP = 6
S2_MINI_WCCAP = 2

S2_MINIBUS_THRESHOLD_PRMS = 3

TIME_FREQ = "5min"

# %% [markdown]
# ### Toggles and V2 config

# %%
# ==========================================================
# 3. Scenario configs
# ==========================================================

toggles_p100 = PlanningToggles(
    demand_mode="p100",
)

toggles_p90 = PlanningToggles(
    demand_mode="p90_stratified",
    p90_quantile=0.90,
    p90_strata=("SSR Code", "Has Own Chair", "A/D"),
)

v2_config = OptimiserConfig(
    tau_amb_solo_mins=31,
    tau_amb_comb_mins=26,
    tau_mini_mins=23,
    tau_push_mins=20,

    handover_buffer_mins=5,

    arrival_sla_target_pct=0.98,
    arrival_sla_target_mins=20,

    boarding_offset_mins=40,

    staff_amb=2,
    staff_mini=2,
    staff_per_prm_push=1,

    max_future_copies_per_model=5,

    solver_relative_gap=0.005,
)

# %% [markdown]
# ### date splitting

# %%
# ==========================================================
# 4. Date helpers
# ==========================================================

def get_month_run_flags(year, month, *, today=None):
    """
    Historical = before today, exclusive of today.
    Future = from today, inclusive of today.

    All end dates are exclusive because the SQL queries use:
        >= start
        < end
    """

    if today is None:
        today = date.today()

    month_start = date(year, month, 1)

    month_end_inclusive = date(
        year,
        month,
        monthrange(year, month)[1],
    )

    next_month_start = month_end_inclusive + timedelta(days=1)

    kwargs = {}

    run_s25 = False
    run_s26 = False

    if month_end_inclusive < today:

        run_s25 = True
        kwargs["s25_start"] = str(month_start)
        kwargs["s25_end"] = str(next_month_start)

    elif month_start >= today:

        run_s26 = True
        kwargs["s26_start"] = str(month_start)
        kwargs["s26_end"] = str(next_month_start)

    else:

        run_s25 = True
        run_s26 = True

        kwargs["s25_start"] = str(month_start)
        kwargs["s25_end"] = str(today)

        kwargs["s26_start"] = str(today)
        kwargs["s26_end"] = str(next_month_start)

    return {
        "month_start": month_start,
        "month_end_inclusive": month_end_inclusive,
        "next_month_start": next_month_start,
        "run_s25": run_s25,
        "run_s26": run_s26,
        "kwargs": kwargs,
    }

# %% [markdown]
# ### assumption caches

# %%
# ==========================================================
# 5. Assumption caches
# ==========================================================

_rule_assumptions_cache = None
_v2_assumptions_cache = None


def get_rule_assumptions():
    """
    Old S1/S1-style stack assumptions for future passenger-level ingest.
    """

    global _rule_assumptions_cache

    if _rule_assumptions_cache is None:
        _rule_assumptions_cache = build_s26_assumptions(
            s25_start=ASSUMPTION_S25_START,
            s25_end=ASSUMPTION_S25_END,
            bucket="15min",
        )

    return _rule_assumptions_cache


def get_v2_assumptions():
    """
    V2 assumptions for future flight-level ingest.
    """

    global _v2_assumptions_cache

    if _v2_assumptions_cache is None:
        _v2_assumptions_cache = build_assumptions_v2(
            s25_start=ASSUMPTION_S25_START,
            s25_end=ASSUMPTION_S25_END,
            config=v2_config,
        )

    return _v2_assumptions_cache


def apply_penetration_uplift_to_rule_assumptions(
    assumptions,
    uplift,
):
    """
    Apply uplift to old S1/S1-style future penetration assumptions.
    """

    out = {
        "inputs": assumptions["inputs"].copy(),
        "extras": assumptions.get("extras", {}).copy(),
    }

    pen = out["inputs"]["penetration_rates"].copy()

    pen["penetration_base"] = pen["penetration"]
    pen["penetration_uplift"] = float(uplift)
    pen["penetration"] = pen["penetration"] * float(uplift)

    out["inputs"]["penetration_rates"] = pen

    return out

# %% [markdown]
# ### S1 runner

# %%
# ==========================================================
# 7. S1 runner
# ==========================================================

def build_s1_jobs_for_period(
    *,
    month_info,
    toggles,
    rule_assumptions=None,
    seed=42,
):

    run_s25 = month_info["run_s25"]
    run_s26 = month_info["run_s26"]
    kwargs = month_info["kwargs"]

    parts = []

    if run_s25:

        df_hist = ingest_s25(
            start=kwargs["s25_start"],
            end=kwargs["s25_end"],
            seed=seed,
        )

        jobs_hist = build_jobs(
            df_hist,
            bucket="15min",
            toggles=toggles,
            use_90th_percentile_cap=False,
        )

        jobs_hist["source_period"] = "S25"
        parts.append(jobs_hist)

    if run_s26:

        if rule_assumptions is None:
            raise ValueError("Future S1 requires rule_assumptions.")

        df_future = ingest_s26(
            start=kwargs["s26_start"],
            end=kwargs["s26_end"],
            **rule_assumptions["inputs"],
            seed=seed,
        )

        jobs_future = build_jobs(
            df_future,
            bucket="15min",
            toggles=toggles,
            use_90th_percentile_cap=False,
        )

        jobs_future["source_period"] = "S26"
        parts.append(jobs_future)

    if len(parts) == 0:
        return pd.DataFrame()

    jobs = pd.concat(
        parts,
        ignore_index=True,
    )

    jobs.index.name = "j"

    return jobs


def _current_fleet_counts_from_vehicle_models():

    current_amb = sum(
        1
        for _, v in VEHICLE_MODELS.items()
        if v["type"] == "Amb"
        and not bool(v.get("is_future", False))
    )

    current_mini = sum(
        1
        for _, v in VEHICLE_MODELS.items()
        if v["type"] == "Mini"
        and not bool(v.get("is_future", False))
    )

    return current_amb, current_mini


def run_s1_for_period(
    *,
    month_info,
    toggles,
    rule_assumptions=None,
    seed=42,
):

    jobs = build_s1_jobs_for_period(
        month_info=month_info,
        toggles=toggles,
        rule_assumptions=rule_assumptions,
        seed=seed,
    )

    if jobs is None or len(jobs) == 0:

        empty_series = pd.Series(dtype=int)

        return {
            "jobs": pd.DataFrame(),
            "summary": {},
            "ambulift_curve": empty_series,
            "minibus_curve": empty_series,
            "driver_curve": empty_series,
            "veh_agent_curve": empty_series,
            "pusher_curve": empty_series,
            "fb_detail": pd.DataFrame(),
        }

    decisions = apply_policy_s1(jobs)

    jobs["s1_decision"] = jobs.index.map(decisions.get)

    curves = baseline_s1_vehicle_curves_capacity(
        jobs,
        decision_col="s1_decision",
        bucket_col="s",
        count_no_vehicle_as_push=True,
        amb_seatcap=3,
        amb_wccap=1,
        mini_seatcap=6,
        mini_wccap=2,
        duration_mins=20,
        time_freq=TIME_FREQ,
    )

    current_amb, current_mini = _current_fleet_counts_from_vehicle_models()

    summary = baseline_s1_summary(
        jobs,
        curves,
        current_amb=current_amb,
        current_mini=current_mini,
    )

    return {
        "jobs": jobs,
        "summary": summary,
        "ambulift_curve": curves["ambulift_curve"],
        "minibus_curve": curves["minibus_curve"],
        "driver_curve": curves["driver_curve"],
        "veh_agent_curve": curves["veh_agent_curve"],
        "pusher_curve": curves["pusher_curve"],
        "fb_detail": curves["fb_detail"],
    }

# %% [markdown]
# ### build V2 passengers and flights for S2

# %%
# ==========================================================
# 8. Build V2 passengers and flights for S2
# ==========================================================

def build_v2_passengers_for_period(
    *,
    month_info,
    v2_assumptions=None,
    seed=42,
):

    run_s25 = month_info["run_s25"]
    run_s26 = month_info["run_s26"]
    kwargs = month_info["kwargs"]

    parts = []

    if run_s25:

        df_hist = ingest_s25_v2(
            start=kwargs["s25_start"],
            end=kwargs["s25_end"],
            seed=seed,
        )

        df_hist["source_period"] = "S25"
        parts.append(df_hist)

    if run_s26:

        if v2_assumptions is None:
            raise ValueError("Future V2/S2 requires v2_assumptions.")

        df_future = ingest_s26_v2(
            start=kwargs["s26_start"],
            end=kwargs["s26_end"],
            penetration_rates=v2_assumptions["penetration_rates"],
            ssr_mix=v2_assumptions["ssr_mix"],
            stand_actuals=v2_assumptions["stand_actuals"],
            stand_dist=v2_assumptions["stand_dist"],
            penetration_uplift=PENETRATION_UPLIFT,
            seed=seed,
        )

        df_future["source_period"] = "S26"
        parts.append(df_future)

    if len(parts) == 0:
        return pd.DataFrame()

    passengers = pd.concat(
        parts,
        ignore_index=True,
    )

    return passengers


def build_v2_flights_for_period(
    *,
    month_info,
    demand_mode,
    v2_assumptions=None,
    seed=42,
):

    passengers = build_v2_passengers_for_period(
        month_info=month_info,
        v2_assumptions=v2_assumptions,
        seed=seed,
    )

    if passengers is None or len(passengers) == 0:
        return pd.DataFrame()

    flights = build_flights_v2(
        passengers,
        demand_mode=demand_mode,
        p90_quantile=0.90,
        boarding_offset_mins=v2_config.boarding_offset_mins,
        p90_strata=("demand_category", "A/D"),
    )

    return flights

# %% [markdown]
# ### S2 runner

# %%
# ==========================================================
# 9. S2 runner
# ==========================================================

def run_s2_for_period(
    *,
    month_info,
    demand_mode,
    v2_assumptions=None,
    seed=42,
):

    flights = build_v2_flights_for_period(
        month_info=month_info,
        demand_mode=demand_mode,
        v2_assumptions=v2_assumptions,
        seed=seed,
    )

    if flights is None or len(flights) == 0:

        empty_series = pd.Series(dtype=int)

        return {
            "flights": pd.DataFrame(),
            "flight_requirements": pd.DataFrame(),
            "summary": {},
            "ambulift_curve": empty_series,
            "minibus_curve": empty_series,
            "driver_curve": empty_series,
            "veh_agent_curve": empty_series,
            "event_detail": pd.DataFrame(),
            "curve_df": pd.DataFrame(),
        }

    out = run_s2_flight_rules(
        flights=flights,
        config=v2_config,
        amb_seatcap=S2_AMB_SEATCAP,
        amb_wccap=S2_AMB_WCCAP,
        mini_seatcap=S2_MINI_SEATCAP,
        mini_wccap=S2_MINI_WCCAP,
        minibus_threshold_prms=S2_MINIBUS_THRESHOLD_PRMS,
        time_freq=TIME_FREQ,
    )

    out["flights"] = flights

    return out

# %% [markdown]
# ### V2 optimiser runner

# %%
# ==========================================================
# 10. V2 optimiser runner
# ==========================================================

def run_v2_optimizer_for_period(
    *,
    month_info,
    v2_assumptions=None,
    output_dir,
    output_xlsx_name,
):

    run_s25 = month_info["run_s25"]
    run_s26 = month_info["run_s26"]
    kwargs = month_info["kwargs"]

    call_kwargs = {
        "run_s25": run_s25,
        "run_s26": run_s26,

        "vehicle_models": VEHICLE_MODELS,
        "config": v2_config,

        "output_dir": str(output_dir),
        "output_xlsx_name": output_xlsx_name,

        "run_p100": True,
        "run_p90": True,

        "run_fleet_report": True,
        "fleet_report_policy": "if_needed",
        "current_fleet_only_first": True,

        "max_ev10": 5,
        "max_ev18": 5,

        **kwargs,
    }

    if run_s26:

        if v2_assumptions is None:
            raise ValueError(
                "Future V2 optimiser requires v2_assumptions."
            )

        call_kwargs.update(
            {
                "penetration_rates": v2_assumptions["penetration_rates"],
                "ssr_mix": v2_assumptions["ssr_mix"],
                "stand_actuals": v2_assumptions["stand_actuals"],
                "stand_dist": v2_assumptions["stand_dist"],
                "penetration_uplift": PENETRATION_UPLIFT,
            }
        )

    result = run_s25_s26_v2(**call_kwargs)

    return result

# %% [markdown]
# # workbook write and V2 summary helper

# %%
# ==========================================================
# 11. Workbook writer and V2 summary helper
# ==========================================================

def _safe_sheet_name(name):

    invalid = ["\\", "/", "*", "?", ":", "[", "]"]

    out = str(name)

    for ch in invalid:
        out = out.replace(ch, "_")

    return out[:31]


def _write_df(
    writer,
    obj,
    sheet_name,
):

    if obj is None:
        return

    if isinstance(obj, dict):
        df = pd.DataFrame([obj])

    elif isinstance(obj, pd.Series):
        df = obj.rename("value").reset_index()

    elif isinstance(obj, pd.DataFrame):
        df = obj

    else:
        df = pd.DataFrame(obj)

    df.to_excel(
        writer,
        sheet_name=_safe_sheet_name(sheet_name),
        index=False,
    )


def write_monthly_combined_workbook(
    *,
    output_path,
    month_rows,
    s1_outputs,
    s2_outputs,
    v2_result,
):

    output_path = Path(output_path)

    output_path.parent.mkdir(
        parents=True,
        exist_ok=True,
    )

    with pd.ExcelWriter(
        output_path,
        engine="openpyxl",
    ) as writer:

        _write_df(
            writer,
            pd.DataFrame(month_rows),
            "Monthly_Summary",
        )

        # ----------------------------
        # S1 outputs
        # ----------------------------

        for mode_key, s1 in s1_outputs.items():

            _write_df(
                writer,
                s1.get("summary"),
                f"S1_{mode_key}_Summary",
            )

            _write_df(
                writer,
                s1.get("jobs"),
                f"S1_{mode_key}_Jobs",
            )

            _write_df(
                writer,
                s1.get("fb_detail"),
                f"S1_{mode_key}_FB_Detail",
            )

            _write_df(
                writer,
                s1.get("ambulift_curve"),
                f"S1_{mode_key}_Amb_Curve",
            )

            _write_df(
                writer,
                s1.get("minibus_curve"),
                f"S1_{mode_key}_Mini_Curve",
            )

        # ----------------------------
        # S2 outputs
        # ----------------------------

        for mode_key, s2 in s2_outputs.items():

            _write_df(
                writer,
                s2.get("summary"),
                f"S2_{mode_key}_Summary",
            )

            _write_df(
                writer,
                s2.get("flights"),
                f"S2_{mode_key}_Flights",
            )

            _write_df(
                writer,
                s2.get("flight_requirements"),
                f"S2_{mode_key}_Requirements",
            )

            _write_df(
                writer,
                s2.get("curve_df"),
                f"S2_{mode_key}_Curve",
            )

            _write_df(
                writer,
                s2.get("event_detail"),
                f"S2_{mode_key}_Events",
            )

        # ----------------------------
        # V2 outputs
        # ----------------------------

        if v2_result is not None:

            if "outputs_p100" in v2_result:

                for key, df in v2_result["outputs_p100"].items():

                    if isinstance(df, pd.DataFrame):

                        _write_df(
                            writer,
                            df,
                            f"V2_P100_{key}",
                        )

            if "outputs_p90" in v2_result:

                for key, df in v2_result["outputs_p90"].items():

                    if isinstance(df, pd.DataFrame):

                        _write_df(
                            writer,
                            df,
                            f"V2_P90_{key}",
                        )
            
            extra_v2_keys = [
                "p100_base_check",
                "p90_base_check",
                "fleet_requirements_p100",
                "fleet_requirements_p90",
                "recommended_p100",
                "recommended_p90",
            ]

            for key in extra_v2_keys:

                if (
                    key in v2_result
                    and isinstance(v2_result[key], pd.DataFrame)
                ):

                    _write_df(
                        writer,
                        v2_result[key],
                        f"V2_{key}",
                    )

            recommended_output_sets = [
                ("P100", "recommended_outputs_p100"),
                ("P90", "recommended_outputs_p90"),
            ]

            for mode_label, key in recommended_output_sets:

                rec_outputs = v2_result.get(
                    key,
                    {},
                )

                if not isinstance(rec_outputs, dict):
                    continue

                for output_name, df in rec_outputs.items():

                    if isinstance(df, pd.DataFrame):

                        _write_df(
                            writer,
                            df,
                            f"V2_{mode_label}_REC_{output_name}",
                        )


    return output_path


def _safe_first_value(
    df,
    column,
    default=None,
):
    if (
        isinstance(df, pd.DataFrame)
        and len(df) > 0
        and column in df.columns
    ):
        return df.iloc[0].get(column, default)

    return default


def extract_v2_month_summary(
    v2_result,
    mode_key,
):
    if v2_result is None:
        return {}

    if mode_key == "P100":
        outputs = v2_result.get("outputs_p100", {})
        base_check = v2_result.get("p100_base_check", pd.DataFrame())
        recommended = v2_result.get("recommended_p100", pd.DataFrame())
    else:
        outputs = v2_result.get("outputs_p90", {})
        base_check = v2_result.get("p90_base_check", pd.DataFrame())
        recommended = v2_result.get("recommended_p90", pd.DataFrame())

    sla = outputs.get(
        "sla_summary",
        pd.DataFrame(),
    )

    fleet = outputs.get(
        "fleet_utilisation",
        pd.DataFrame(),
    )

    arrival_sla_pct = _safe_first_value(
        sla,
        "arrival_sla_pct",
        default=None,
    )

    arrival_target_pct = _safe_first_value(
        sla,
        "arrival_target_pct",
        default=None,
    )

    arrival_prms = _safe_first_value(
        sla,
        "arrival_prms",
        default=None,
    )

    late_arrival_prms = _safe_first_value(
        sla,
        "arrival_prm_breaches",
        default=None,
    )

    arrival_breached_flights = _safe_first_value(
        sla,
        "arrival_breached_flights",
        default=None,
    )

    base_shortfall_total = _safe_first_value(
        base_check,
        "shortfall_total",
        default=None,
    )

    base_gap_vs_current_total = _safe_first_value(
        base_check,
        "gap_vs_current_total",
        default=None,
    )

    base_current_fleet_sufficient = _safe_first_value(
        base_check,
        "current_fleet_sufficient",
        default=None,
    )

    needs_fleet_expansion = _safe_first_value(
        base_check,
        "needs_fleet_expansion",
        default=None,
    )

    fleet_trigger_reason = _safe_first_value(
        base_check,
        "fleet_trigger_reason",
        default="",
    )

    recommended_scenario = _safe_first_value(
        recommended,
        "scenario",
        default="current_fleet_only",
    )

    recommended_vehicles_bought = _safe_first_value(
        recommended,
        "recommended_vehicles_bought",
        default=None,
    )

    if recommended_vehicles_bought is None:
        recommended_vehicles_bought = _safe_first_value(
            recommended,
            "future_bought",
            default=0,
        )

    recommended_future_bought = _safe_first_value(
        recommended,
        "future_bought",
        default=0,
    )

    recommended_future_total_candidates = _safe_first_value(
        recommended,
        "future_total_candidates",
        default=0,
    )

    recommended_future_allocation = _safe_first_value(
        recommended,
        "future_allocation",
        default="",
    )

    recommended_shortfall_total = _safe_first_value(
        recommended,
        "shortfall_total",
        default=None,
    )

    recommended_arrival_sla_pct = _safe_first_value(
        recommended,
        "arrival_sla_pct",
        default=None,
    )

    recommended_scenario_passes = _safe_first_value(
        recommended,
        "scenario_passes",
        default=None,
    )

    peak_amb = None
    peak_mini = None
    current_amb = None
    current_mini = None
    gap_amb = None
    gap_mini = None

    if (
        isinstance(fleet, pd.DataFrame)
        and len(fleet) > 0
        and "vehicle_type" in fleet.columns
        and "required_for_schedule" in fleet.columns
    ):

        amb_rows = fleet[fleet["vehicle_type"] == "Amb"]
        mini_rows = fleet[fleet["vehicle_type"] == "Mini"]

        peak_amb = int(
            pd.to_numeric(
                amb_rows["required_for_schedule"],
                errors="coerce",
            )
            .fillna(0)
            .sum()
            or 0
        )

        peak_mini = int(
            pd.to_numeric(
                mini_rows["required_for_schedule"],
                errors="coerce",
            )
            .fillna(0)
            .sum()
            or 0
        )

        if "current_available" in fleet.columns:
            current_amb = int(
                pd.to_numeric(
                    amb_rows["current_available"],
                    errors="coerce",
                )
                .fillna(0)
                .sum()
                or 0
            )

            current_mini = int(
                pd.to_numeric(
                    mini_rows["current_available"],
                    errors="coerce",
                )
                .fillna(0)
                .sum()
                or 0
            )

        if "gap_vs_current" in fleet.columns:
            gap_amb = int(
                pd.to_numeric(
                    amb_rows["gap_vs_current"],
                    errors="coerce",
                )
                .fillna(0)
                .sum()
                or 0
            )

            gap_mini = int(
                pd.to_numeric(
                    mini_rows["gap_vs_current"],
                    errors="coerce",
                )
                .fillna(0)
                .sum()
                or 0
            )

    return {
        "V2_arrival_sla_pct": arrival_sla_pct,
        "V2_arrival_target_pct": arrival_target_pct,
        "V2_arrival_prms": arrival_prms,
        "V2_late_arrival_prms": late_arrival_prms,
        "V2_arrival_breached_flights": arrival_breached_flights,

        "V2_BasePeakAmb": peak_amb,
        "V2_BasePeakMini": peak_mini,
        "V2_CurrentAmb": current_amb,
        "V2_CurrentMini": current_mini,
        "V2_GapAmb": gap_amb,
        "V2_GapMini": gap_mini,

        "V2_base_shortfall_total": base_shortfall_total,
        "V2_base_gap_vs_current_total": base_gap_vs_current_total,
        "V2_base_current_fleet_sufficient": base_current_fleet_sufficient,
        "V2_needs_fleet_expansion": needs_fleet_expansion,
        "V2_fleet_trigger_reason": fleet_trigger_reason,

        "V2_recommended_scenario": recommended_scenario,
        "V2_recommended_vehicles_bought": recommended_vehicles_bought,
        "V2_recommended_future_bought": recommended_future_bought,
        "V2_recommended_future_total_candidates": recommended_future_total_candidates,
        "V2_recommended_future_allocation": recommended_future_allocation,
        "V2_recommended_shortfall_total": recommended_shortfall_total,
        "V2_recommended_arrival_sla_pct": recommended_arrival_sla_pct,
        "V2_recommended_scenario_passes": recommended_scenario_passes,
    }

# %%
def print_v2_recommendation_summary(
    v2_result,
):
    if v2_result is None:
        return

    for mode_key, rec_key, base_key in [
        ("P100", "recommended_p100", "p100_base_check"),
        ("P90", "recommended_p90", "p90_base_check"),
    ]:

        recommended = v2_result.get(
            rec_key,
            pd.DataFrame(),
        )

        base_check = v2_result.get(
            base_key,
            pd.DataFrame(),
        )

        print("")
        print("-" * 80)
        print(f"V2 {mode_key} recommendation summary")
        print("-" * 80)

        if isinstance(base_check, pd.DataFrame) and len(base_check) > 0:
            base_row = base_check.iloc[0]

            print("Base current-fleet check:")
            print(f"  Arrival SLA: {base_row.get('arrival_sla_pct')}")
            print(f"  Shortfall total: {base_row.get('shortfall_total')}")
            print(f"  Gap vs current: {base_row.get('gap_vs_current_total')}")
            print(f"  Needs expansion: {base_row.get('needs_fleet_expansion')}")
            print(f"  Trigger reason: {base_row.get('fleet_trigger_reason')}")

        if isinstance(recommended, pd.DataFrame) and len(recommended) > 0:
            rec_row = recommended.iloc[0]

            vehicles_bought = rec_row.get(
                "recommended_vehicles_bought",
                rec_row.get("future_bought", 0),
            )

            print("")
            print("Recommended fleet outcome:")
            print(f"  Scenario: {rec_row.get('scenario', 'current_fleet_only')}")
            print(f"  Future vehicles actually bought: {vehicles_bought}")
            print(f"  Future allocation tested: {rec_row.get('future_allocation', '')}")
            print(f"  Future candidates allowed: {rec_row.get('future_total_candidates', 0)}")
            print(f"  Shortfall after recommendation: {rec_row.get('shortfall_total', '')}")
            print(f"  Arrival SLA after recommendation: {rec_row.get('arrival_sla_pct', '')}")

        else:
            print("No recommendation table was generated.")

# %% [markdown]
# ### run one month

# %%
# ==========================================================
# 12. Run one month
# ==========================================================

def run_combined_month(
    year,
    month,
    *,
    seed=42,
):

    month_info = get_month_run_flags(
        year,
        month,
    )

    month_start = month_info["month_start"]

    month_tag = f"{year}_{month:02d}"

    print("")
    print("=" * 80)
    print(f"RUNNING COMBINED MONTH: {month_tag}")
    print("=" * 80)

    needs_future = bool(
        month_info["run_s26"]
    )

    rule_assumptions = None
    v2_assumptions = None

    if needs_future:

        rule_assumptions = (
            apply_penetration_uplift_to_rule_assumptions(
                get_rule_assumptions(),
                PENETRATION_UPLIFT,
            )
        )

        v2_assumptions = (
            get_v2_assumptions()
        )

    s1_outputs = {}
    s2_outputs = {}

    modes_to_run = []

    if RUN_P100:
        modes_to_run.append(
            (
                "P100",
                "p100",
                toggles_p100,
            )
        )

    if RUN_P90:
        modes_to_run.append(
            (
                "P90",
                "p90",
                toggles_p90,
            )
        )

    for mode_key, demand_mode, toggles in modes_to_run:

        print("")
        print(f"Running S1 {mode_key}")

        s1_outputs[mode_key] = (
            run_s1_for_period(
                month_info=month_info,
                toggles=toggles,
                rule_assumptions=rule_assumptions,
                seed=seed,
            )
        )

        print(f"Running S2 {mode_key}")

        s2_outputs[mode_key] = (
            run_s2_for_period(
                month_info=month_info,
                demand_mode=demand_mode,
                v2_assumptions=v2_assumptions,
                seed=seed,
            )
        )

    print("")
    print("Running V2 optimiser")

    v2_result = run_v2_optimizer_for_period(
        month_info=month_info,
        v2_assumptions=v2_assumptions,
        output_dir=MONTHLY_OUTPUT_DIR,
        output_xlsx_name=f"{month_tag}_v2.xlsx",
    )

    print_v2_recommendation_summary(
    v2_result
    )

    month_rows = []

    for mode_key, _, _ in modes_to_run:

        s1_summary = (
            s1_outputs[mode_key]
            .get("summary", {})
        )

        s2_summary = (
            s2_outputs[mode_key]
            .get("summary", {})
        )

        v2_summary = (
            extract_v2_month_summary(
                v2_result,
                mode_key,
            )
        )

        row = {

            "Mode":
                mode_key,

            "S1_PeakAmb":
                s1_summary.get("PeakAmb"),

            "S1_PeakMini":
                s1_summary.get("PeakMini"),

            "S1_PeakDrivers":
                s1_summary.get("PeakDrivers"),

            "S1_PeakVehAgents":
                s1_summary.get("PeakVehAgents"),

            "S2_PeakAmb":
                s2_summary.get("PeakAmb"),

            "S2_PeakMini":
                s2_summary.get("PeakMini"),

            "S2_PeakDrivers":
                s2_summary.get("PeakDrivers"),

            "S2_PeakVehAgents":
                s2_summary.get("PeakVehAgents"),

            **v2_summary,
        }

        month_rows.append(row)

    combined_path = (
        MONTHLY_OUTPUT_DIR
        / f"{month_tag}_combined.xlsx"
    )

    write_monthly_combined_workbook(
        output_path=combined_path,
        month_rows=month_rows,
        s1_outputs=s1_outputs,
        s2_outputs=s2_outputs,
        v2_result=v2_result,
    )

    print("")
    print(f"Completed month: {month_tag}")
    print(f"Workbook: {combined_path}")

    return {

        "month_rows":
            month_rows,

        "s1_outputs":
            s1_outputs,

        "s2_outputs":
            s2_outputs,

        "v2_result":
            v2_result,

        "combined_workbook_path":
            combined_path,
    }

# %% [markdown]
# ### Test Call

# %%
test_result = run_combined_month(
    2026,
    4,
)

pd.DataFrame(test_result["month_rows"])
# Out:
# ================================================================================
# RUNNING COMBINED MONTH: 2026_04
# ================================================================================
#
# Running S1 P100
#
# Unmatched passenger rows after merge (missing Chocks DT): 749
# Unique unmatched flight keys: 437
#
# Unmatched key reasons:
# reason
# no_flight_candidate               427
# exact_match_should_have_joined     10
# Name: count, dtype: int64
#
# Dropped 727 passenger rows due to reasons {'scheduled_dt_mismatch', 'no_flight_candidate'}
# [BUILD_JOBS] Dropping 4 jobs already impossible at release (beyond SLA + max late)
# Running S2 P100
#
# Running S1 P90
#
# Unmatched passenger rows after merge (missing Chocks DT): 749
# Unique unmatched flight keys: 437
#
# Unmatched key reasons:
# reason
# no_flight_candidate               427
# exact_match_should_have_joined     10
# Name: count, dtype: int64
#
# Dropped 727 passenger rows due to reasons {'scheduled_dt_mismatch', 'no_flight_candidate'}
# [BUILD_JOBS] Dropping 4 jobs already impossible at release (beyond SLA + max late)
# [BUILD_JOBS] Applying stratified percentile cap: q=0.90 | strata=['SSR Code', 'Has Own Chair', 'A/D']
# [BUILD_JOBS] Dropped 551 PRM jobs via stratified percentile cap
# Running S2 P90
#
# Running V2 optimiser
#     ✓ S25 ingest complete (14,953 passengers)   [37.76s]
#     ✓ Passenger dataset combined (14,953 passenger rows)   [0.00s]
#     ✓ P100 built (6,066 flights)   [0.14s]
#     P100 demand summary: 14,953 PRMs across 6,066 flights
#     ✓ prepare_model_data started | flights=6,066   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.03s]
#     ✓ ambulift intervals built | flights=6,066 ambulifts=14   [0.69s]
#     ✓ minibus intervals built | minibuses=3   [0.05s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=3,574,419   [0.68s]
#     ✓ minibus overlaps built | overlaps=318,654   [0.06s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.53s   [0.00s]
#     ✓ sets built | F=6,066 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=30,330 amb=254,772 mini=36,396   [0.60s]
#     ✓ ambulift overlap constraints built | 3,574,419   [21.00s]
#     ✓ minibus overlap constraints built | 318,654   [0.90s]
#     ✓ build_pyomo_model complete | total=23.16s   [0.67s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,066 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 4293610 rows; 363977 cols; 8916801 nonzeros; 321515 integer variables (321515 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 4e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 552396 rows, 124378 cols, 1185959 nonzeros 5s
# 236117 rows, 109225 cols, 863658 nonzeros 20s
# 217916 rows, 109213 cols, 818618 nonzeros 37s
# Presolve reductions: rows 217916(-4075694); columns 109213(-254764); nonzeros 818618(-8098183)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    217916 rows
#    109213 cols (96915 binary, 0 integer, 12298 implied int., 0 continuous, 0 domain fixed)
#    818618 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2427408845.479     Large        0      0      0         0    43.5s
#  R       0       0         0   0.00%   36287834.74874  1242612455.219    97.08%        0      0      0     41376   170.8s
#          0       0         0   0.00%   38621618.17877  1242612455.219    96.89%     1079    227      0     46882   195.8s
#          0       0         0   0.00%   38623801.15335  1242612455.219    96.89%     1483    417      0     55042   218.6s
#          0       0         0   0.00%   38626112.01407  1242612455.219    96.89%     1880    573      0     67271   248.2s
#          0       0         0   0.00%   38627131.46446  1242612455.219    96.89%     2246    658      0     69461   260.3s
#  C       0       0         0   0.00%   38627423.63113  941364018.2968    95.90%     2315    684      0     80455   305.4s
#          0       0         0   0.00%   38627505.65038  941364018.2968    95.90%     3203    708      0    102489   379.7s
#          0       0         0   0.00%   38627588.84279  941364018.2968    95.90%     3442    732      0    120057   432.3s
#          0       0         0   0.00%   38627633.66819  941364018.2968    95.90%     4231    745      0    121132   440.2s
#          0       0         0   0.00%   38627648.54041  941364018.2968    95.90%     4354    755      0    121420   447.8s
#          0       0         0   0.00%   38627654.20708  941364018.2968    95.90%     4501    763      0    122892   466.7s
#          0       0         0   0.00%   38627654.20708  941364018.2968    95.90%     4591    773      0    124193   477.3s
#          0       0         0   0.00%   38627654.20708  941364018.2968    95.90%     4753    785      0    125641   485.8s
#          0       0         0   0.00%   38627654.20708  941364018.2968    95.90%     4819    686      0    128137   495.3s
#          0       0         0   0.00%   38627675.95708  941364018.2968    95.90%     5190    693      0    131901   508.9s
#          0       0         0   0.00%   38627682.95708  941364018.2968    95.90%     5401    700      0    136247   521.1s
#          0       0         0   0.00%   38627682.95708  941364018.2968    95.90%     5588    705      0    138017   540.4s
#          0       0         0   0.00%   38627682.95708  941364018.2968    95.90%     5696    709      0    138799   555.6s
#  L       0       0         0   0.00%   38627682.95708  38628002.2968      0.00%     5696    709      0    138799   764.4s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          1       0         1 100.00%   38627682.95708  38628002.2968      0.00%     5696    709      0    197556   764.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      38628002.2968
#   Dual bound        38627682.9589
#   Gap               0.000827% (tolerance: 0.5%)
#   P-D integral      697.034265985
#   Solution status   feasible
#                     38628002.2968 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            764.50
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     197556
#                     0 (strong br.)
#                     97423 (separation)
#                     58757 (heuristics)
#     ✓ P100 optimisation complete   [883.21s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     4
# 2                            0                   9                     6
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      4               0                   0              0
# 2                      6               0                   3              0
# 3                      3               0                   0              0
#
# [P100] Fleet expansion triggered because: Vehicle shortfall exists
#
# [P100] Testing 1 total future minibus candidate(s)
#
# [P100] Running scenario p100_future_total_1_MB_EV_18_1 with allocation {'MB_EV_10': 0, 'MB_EV_18': 1}
#     ✓ prepare_model_data started | flights=6,066   [0.00s]
#     ✓ vehicle expansion complete | vehicles=18   [0.05s]
#     ✓ ambulift intervals built | flights=6,066 ambulifts=14   [0.74s]
#     ✓ minibus intervals built | minibuses=4   [0.08s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=3,574,419   [0.95s]
#     ✓ minibus overlaps built | overlaps=424,872   [0.10s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.95s   [0.00s]
#     ✓ sets built | F=6,066 AMB=14 MINI=4   [0.01s]
#     ✓ variables built | x=30,330 amb=254,772 mini=48,528   [0.29s]
#     ✓ ambulift overlap constraints built | 3,574,419   [37.74s]
#     ✓ minibus overlap constraints built | 424,872   [2.63s]
#     ✓ build_pyomo_model complete | total=41.52s   [0.85s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,066 Vehicles=18
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 4436225 rows; 376111 cols; 9226295 nonzeros; 333649 integer variables (333649 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 4e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 621812 rows, 132518 cols, 1334739 nonzeros 5s
# 257082 rows, 115295 cols, 927263 nonzeros 18s
# 257082 rows, 115295 cols, 927263 nonzeros 41s
# Presolve reductions: rows 257082(-4179143); columns 115295(-260816); nonzeros 927263(-8299032)
#
# Solving MIP model with:
#    257082 rows
#    115295 cols (102993 binary, 0 integer, 12302 implied int., 0 continuous, 0 domain fixed)
#    927263 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2465591709.708     Large        0      0      0         0    50.3s
#  R       0       0         0   0.00%   18795994.00109  889789328.4475    97.89%        0      0      0     38897   176.6s
#          0       0         0   0.00%   18796154.83355  889789328.4475    97.89%     1171    106      0     43018   196.8s
#          0       0         0   0.00%   18796380.05617  889789328.4475    97.89%     1451    199      0     53098   236.2s
#          0       0         0   0.00%   18796830.79237  889789328.4475    97.89%     1914    283      0     56635   253.7s
#          0       0         0   0.00%   18797208.42363  889789328.4475    97.89%     2060    342      0     58631   264.0s
#          0       0         0   0.00%   18797432.35809  889789328.4475    97.89%     2180    379   1225     65683   300.5s
#          0       0         0   0.00%   18797694.48645  889789328.4475    97.89%     2624    415   1225     74585   330.1s
#          0       0         0   0.00%   18797696.09097  889789328.4475    97.89%     3126    419   1225     94193   403.6s
#          0       0         0   0.00%   18797721.91442  889789328.4475    97.89%     3416    431   1225    128269   514.3s
#          0       0         0   0.00%   18797756.78539  889789328.4475    97.89%     4453    440   1225    128610   519.6s
#          0       0         0   0.00%   18797771.03539  889789328.4475    97.89%     4504    377   1225    129262   527.1s
#          0       0         0   0.00%   18797772.18539  889789328.4475    97.89%     4752    394   1225    129782   533.4s
#          0       0         0   0.00%   18797773.78539  889789328.4475    97.89%     4857    376   1225    130369   539.4s
#  L       0       0         0   0.00%   18797773.78539  18798283.86301     0.00%     4857    376   1225    130369   773.2s
#          1       0         1 100.00%   18797773.78539  18798283.86301     0.00%     4857    376   1225    204177   773.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      18798283.863
#   Dual bound        18797773.7854
#   Gap               0.00271% (tolerance: 0.5%)
#   P-D integral      709.823813496
#   Solution status   feasible
#                     18798283.863 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            773.32
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     204177
#                     0 (strong br.)
#                     91472 (separation)
#                     73808 (heuristics)
# [P100] Scenario passes: SLA 99.19%, shortfall 0.00, future vehicles bought 1
# [P100] Recommended scenario: p100_future_total_1_MB_EV_18_1
#     ✓ P100 fleet expansion search complete   [924.02s]
#     ✓ P90 built (6,066 flights)   [0.40s]
#     P90 demand summary: 13,619 PRMs across 6,066 flights
#     ✓ prepare_model_data started | flights=6,066   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.03s]
#     ✓ ambulift intervals built | flights=6,066 ambulifts=14   [0.65s]
#     ✓ minibus intervals built | minibuses=3   [0.06s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=3,530,975   [0.73s]
#     ✓ minibus overlaps built | overlaps=318,639   [0.08s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.57s   [0.00s]
#     ✓ sets built | F=6,066 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=30,330 amb=254,772 mini=36,396   [0.19s]
#     ✓ ambulift overlap constraints built | 3,530,975   [26.71s]
#     ✓ minibus overlap constraints built | 318,639   [2.28s]
#     ✓ build_pyomo_model complete | total=30.05s   [0.87s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,066 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 4250134 rows; 363977 cols; 8829866 nonzeros; 321515 integer variables (321515 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 8e+00]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -1
# Presolving model
# 548448 rows, 124650 cols, 1181997 nonzeros 8s
# 236989 rows, 109508 cols, 865384 nonzeros 33s
# 236989 rows, 109508 cols, 865384 nonzeros 63s
# Presolve reductions: rows 236989(-4013145); columns 109508(-254469); nonzeros 865384(-7964482)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    236989 rows
#    109508 cols (97189 binary, 0 integer, 12319 implied int., 0 continuous, 0 domain fixed)
#    865384 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2388375706.479     Large        0      0      0         0    73.5s
#  R       0       0         0   0.00%   16856620.7343   801849769.2192    97.90%        0      0      0     42985   230.5s
#          0       0         0   0.00%   16856835.16287  801849769.2192    97.90%      696     95      0     49450   307.4s
#          0       0         0   0.00%   16857049.60368  801849769.2192    97.90%     1004    172      0     68677   390.7s
#          0       0         0   0.00%   16857571.62749  801849769.2192    97.90%     1934    238      0     70699   407.2s
#          0       0         0   0.00%   16857999.29416  801849769.2192    97.90%     2073    289      0     72388   458.0s
#  C       0       0         0   0.00%   16858104.62749  801849449.2968    97.90%     2161    302      0     77458   494.3s
#          0       0         0   0.00%   16858109.62749  801849449.2968    97.90%     2399    307      0     80081   524.1s
#          0       0         0   0.00%   16858114.55708  801849449.2968    97.90%     2583    312      0     94747   569.8s
#          0       0         0   0.00%   16858114.55708  801849449.2968    97.90%     3337    326      0     96629   580.2s
#          0       0         0   0.00%   16858114.55708  801849449.2968    97.90%     3570    339      0     98472   591.4s
#          0       0         0   0.00%   16858114.55708  801849449.2968    97.90%     3638    344      0     98789   596.7s
#          0       0         0   0.00%   16858114.55708  801849449.2968    97.90%     3696    357      0     99905   605.9s
#          0       0         0   0.00%   16858114.55708  801849449.2968    97.90%     3795    308      0    101602   615.6s
#          0       0         0   0.00%   16858114.55708  801849449.2968    97.90%     3946    313      0    102124   622.0s
#          0       0         0   0.00%   16858114.55708  801849449.2968    97.90%     4037    318      0    102744   630.7s
#  L       0       0         0   0.00%   16858114.55708  16858241.2968      0.00%     4037    318      0    102744   881.1s
#          1       0         1 100.00%   16858114.55708  16858241.2968      0.00%     4037    318      0    155184   881.8s
#
# Solving report
#   Status            Optimal
#   Primal bound      16858241.2968
#   Dual bound        16858114.5616
#   Gap               0.000752% (tolerance: 0.5%)
#   P-D integral      793.342918164
#   Solution status   feasible
#                     16858241.2968 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            881.76
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     155184
#                     0 (strong br.)
#                     59759 (separation)
#                     52440 (heuristics)
#     ✓ P90 optimisation complete   [1011.50s]
#
# [P90 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     4
# 2                            0                   9                     6
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      4               0                   0              0
# 2                      6               0                   3              0
# 3                      3               0                   0              0
#
# [P90] Fleet expansion triggered because: Vehicle shortfall exists
#
# [P90] Testing 1 total future minibus candidate(s)
#
# [P90] Running scenario p90_future_total_1_MB_EV_18_1 with allocation {'MB_EV_10': 0, 'MB_EV_18': 1}
#     ✓ prepare_model_data started | flights=6,066   [0.00s]
#     ✓ vehicle expansion complete | vehicles=18   [0.09s]
#     ✓ ambulift intervals built | flights=6,066 ambulifts=14   [2.04s]
#     ✓ minibus intervals built | minibuses=4   [0.16s]
#     ✓ staff intervals built   [0.04s]
#     ✓ ambulift overlaps built | overlaps=3,530,975   [1.94s]
#     ✓ minibus overlaps built | overlaps=424,852   [0.21s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.04s]
#     ✓ prepare_model_data complete | total=4.53s   [0.00s]
#     ✓ sets built | F=6,066 AMB=14 MINI=4   [0.01s]
#     ✓ variables built | x=30,330 amb=254,772 mini=48,528   [0.65s]
#     ✓ ambulift overlap constraints built | 3,530,975   [587.49s]
#     ✓ minibus overlap constraints built | 424,852   [3.67s]
#     ✓ build_pyomo_model complete | total=593.08s   [1.26s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,066 Vehicles=18
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 4392744 rows; 376111 cols; 9139350 nonzeros; 333649 integer variables (333649 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -1
# Presolving model
# 617851 rows, 132790 cols, 1330751 nonzeros 6s
# 257691 rows, 115576 cols, 927922 nonzeros 26s
# 257691 rows, 115576 cols, 927922 nonzeros 60s
# Presolve reductions: rows 257691(-4135053); columns 115576(-260535); nonzeros 927922(-8211428)
#
# Solving MIP model with:
#    257691 rows
#    115576 cols (103257 binary, 0 integer, 12319 implied int., 0 continuous, 0 domain fixed)
#    927922 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2381558386.708     Large        0      0      0         0    71.7s
#  R       0       0         0   0.00%   16036676.82045  586031758.032     97.26%        0      0      0     44875   255.1s
#          0       0         0   0.00%   16036737.84967  586031758.032     97.26%     1052     37      0     50117   277.7s
#          0       0         0   0.00%   16036744.18301  586031758.032     97.26%     1170     71      0     50736   283.6s
#  C       0       0         0   0.00%   16036934.95205  466282702.5251    96.56%     1328    130      0     51551   291.1s
#          0       0         0   0.00%   16037096.78539  466282702.5251    96.56%     1509    159      0     52070   297.5s
#          0       0         0   0.00%   16037096.78539  466282702.5251    96.56%     1576    172      0     53437   306.1s
#  L       0       0         0   0.00%   16037096.78539  16037544.69406     0.00%     1644    176      0     53732   707.8s
#          1       0         1 100.00%   16037096.78539  16037544.69406     0.00%     1644    176      0    124888   708.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      16037544.6941
#   Dual bound        16037096.7854
#   Gap               0.00279% (tolerance: 0.5%)
#   P-D integral      620.216121662
#   Solution status   feasible
#                     16037544.6941 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            708.22
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     124888
#                     0 (strong br.)
#                     8857 (separation)
#                     71156 (heuristics)
# [P90] Scenario passes: SLA 99.24%, shortfall 0.00, future vehicles bought 1
# [P90] Recommended scenario: p90_future_total_1_MB_EV_18_1
#     ✓ P90 fleet expansion search complete   [1443.12s]
#     ✓ Excel outputs written to outputs\prm_combined_new\monthly\2026_04_v2.xlsx   [20.28s]
#
# Completed month: 2026_04
# Workbook: outputs\prm_combined_new\monthly\2026_04_combined.xlsx
#    S1_PeakAmb  S1_PeakMini  S1_PeakDrivers  S1_PeakVehAgents  S2_PeakAmb  \
# 0          13            5              14                14           9
# 1          11            4              13                13           9
#
#    S2_PeakMini  S2_PeakDrivers  S2_PeakVehAgents  V2_arrival_sla_pct  \
# 0           13              18                18           99.190149
# 1           11              18                18           99.235323
#
#    V2_PeakAmb  V2_PeakMini
# 0          11            3
# 1          11            3

# %%
may_result = run_combined_month(
    2026,
    5,
)

pd.DataFrame(may_result["month_rows"])
# Out:
# ================================================================================
# RUNNING COMBINED MONTH: 2026_05
# ================================================================================
#
# Running S1 P100
#
# Unmatched passenger rows after merge (missing Chocks DT): 852
# Unique unmatched flight keys: 458
#
# Unmatched key reasons:
# reason
# no_flight_candidate               449
# exact_match_should_have_joined      5
# scheduled_dt_mismatch               4
# Name: count, dtype: int64
#
# Dropped 837 passenger rows due to reasons {'scheduled_dt_mismatch', 'no_flight_candidate'}
# [BUILD_JOBS] Dropping 1 jobs already impossible at release (beyond SLA + max late)
# Running S2 P100
#
# Running S1 P90
#
# Unmatched passenger rows after merge (missing Chocks DT): 852
# Unique unmatched flight keys: 458
#
# Unmatched key reasons:
# reason
# no_flight_candidate               449
# exact_match_should_have_joined      5
# scheduled_dt_mismatch               4
# Name: count, dtype: int64
#
# Dropped 837 passenger rows due to reasons {'scheduled_dt_mismatch', 'no_flight_candidate'}
# [BUILD_JOBS] Dropping 1 jobs already impossible at release (beyond SLA + max late)
# [BUILD_JOBS] Applying stratified percentile cap: q=0.90 | strata=['SSR Code', 'Has Own Chair', 'A/D']
# [BUILD_JOBS] Dropped 752 PRM jobs via stratified percentile cap
# Running S2 P90
#
# Running V2 optimiser
#     ✓ S25 ingest complete (19,832 passengers)   [56.37s]
#     ✓ Passenger dataset combined (19,832 passenger rows)   [0.00s]
#     ✓ P100 built (7,139 flights)   [0.34s]
#     P100 demand summary: 19,832 PRMs across 7,139 flights
#     ✓ prepare_model_data started | flights=7,139   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.04s]
#     ✓ ambulift intervals built | flights=7,139 ambulifts=14   [1.41s]
#     ✓ minibus intervals built | minibuses=3   [0.11s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=4,850,181   [1.37s]
#     ✓ minibus overlaps built | overlaps=426,888   [0.13s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.03s]
#     ✓ prepare_model_data complete | total=3.11s   [0.00s]
#     ✓ sets built | F=7,139 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=35,695 amb=299,838 mini=42,834   [0.84s]
#     ✓ ambulift overlap constraints built | 4,850,181   [39.63s]
#     ✓ minibus overlap constraints built | 426,888   [1.93s]
#     ✓ build_pyomo_model complete | total=43.93s   [1.52s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,139 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 5748498 rows; 428357 cols; 11885163 nonzeros; 378384 integer variables (378384 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 704826 rows, 144773 cols, 1488633 nonzeros 8s
# 277022 rows, 127186 cols, 1047659 nonzeros 38s
# 255596 rows, 127158 cols, 994510 nonzeros 80s
# Presolve reductions: rows 255596(-5492902); columns 127158(-301199); nonzeros 994510(-10890653)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    255596 rows
#    127158 cols (112620 binary, 0 integer, 14538 implied int., 0 continuous, 0 domain fixed)
#    994510 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3019535176.479     Large        0      0      0         0    93.8s
#  R       0       0         0   0.00%   78721699.91129  1725960636.881    95.44%        0      0      0     22637   155.9s
#          0       0         0   0.00%   85890535.35779  1725960636.881    95.02%     1570    344      0     28310   183.1s
#          0       0         0   0.00%   87394130.57537  1725960636.881    94.94%     2130    614      0     46651   243.7s
#          0       0         0   0.00%   87731521.97354  1725960636.881    94.92%     3070    821      0     50662   261.7s
#          0       0         0   0.00%   87732883.60955  1725960636.881    94.92%     3293    934      0     56323   286.7s
#  C       0       0         0   0.00%   87733271.81384  1427960961.297    93.86%     3466    978      0     56412   291.9s
#          0       0         0   0.00%   87733453.68483  1427960961.297    93.86%     3519   1001      0     56457   297.1s
#          0       0         0   0.00%   87733714.6975   1427960961.297    93.86%     3533   1042      0     57046   303.1s
#          0       0         0   0.00%   87733865.19482  1427960961.297    93.86%     3603   1054      0     57166   318.8s
#          0       0         0   0.00%   87733868.81387  1427960961.297    93.86%     3777   1059      0     57197   378.5s
#          0       0         0   0.00%   87733881.81387  1427960961.297    93.86%     3817   1062      0     57212   387.9s
#          0       0         0   0.00%   87733881.81387  1427960961.297    93.86%     3934   1064      0     57217   434.1s
#          0       0         0   0.00%   87733894.86149  1427960961.297    93.86%     4003   1066      0     57251   481.3s
#          0       0         0   0.00%   87733894.86149  1427960961.297    93.86%     4071   1067      0     57275   529.1s
#  L       0       0         0   0.00%   87733894.86149  87734654.2968      0.00%     4071   1067      0     57275   812.4s
#          1       0         1 100.00%   87733894.86149  87734654.2968      0.00%     4071   1067      0     91285   812.6s
#
# Solving report
#   Status            Optimal
#   Primal bound      87734654.2968
#   Dual bound        87733894.863
#   Gap               0.000866% (tolerance: 0.5%)
#   P-D integral      679.104722312
#   Solution status   feasible
#                     87734654.2968 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            812.62
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     91285
#                     0 (strong br.)
#                     34638 (separation)
#                     34010 (heuristics)
#     ✓ P100 optimisation complete   [1045.15s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     4
# 2                            0                   9                     6
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      4               0                   0              0
# 2                      6               0                   3              0
# 3                      3               0                   0              0
#
# [P100] Fleet expansion triggered because: Vehicle shortfall exists
#
# [P100] Testing 1 total future minibus candidate(s)
#
# [P100] Running scenario p100_future_total_1_MB_EV_18_1 with allocation {'MB_EV_10': 0, 'MB_EV_18': 1}
#     ✓ prepare_model_data started | flights=7,139   [0.00s]
#     ✓ vehicle expansion complete | vehicles=18   [0.08s]
#     ✓ ambulift intervals built | flights=7,139 ambulifts=14   [2.13s]
#     ✓ minibus intervals built | minibuses=4   [0.17s]
#     ✓ staff intervals built   [0.05s]
#     ✓ ambulift overlaps built | overlaps=4,850,181   [2.11s]
#     ✓ minibus overlaps built | overlaps=569,184   [0.20s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.04s]
#     ✓ prepare_model_data complete | total=4.78s   [0.00s]
#     ✓ sets built | F=7,139 AMB=14 MINI=4   [0.01s]
#     ✓ variables built | x=35,695 amb=299,838 mini=57,112   [0.54s]
#     ✓ ambulift overlap constraints built | 4,850,181   [83.30s]
#     ✓ minibus overlap constraints built | 569,184   [5.01s]
#     ✓ build_pyomo_model complete | total=90.39s   [1.53s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,139 Vehicles=18
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 5933629 rows; 442637 cols; 12283981 nonzeros; 392664 integer variables (392664 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 792976 rows, 154331 cols, 1676766 nonzeros 7s
# 301426 rows, 134328 cols, 1123651 nonzeros 36s
# 301426 rows, 134328 cols, 1123651 nonzeros 75s
# Presolve reductions: rows 301426(-5632203); columns 134328(-308309); nonzeros 1123651(-11160330)
#
# Solving MIP model with:
#    301426 rows
#    134328 cols (119783 binary, 0 integer, 14545 implied int., 0 continuous, 0 domain fixed)
#    1123651 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2971717950.708     Large        0      0      0         0    93.0s
#  R       0       0         0   0.00%   33550682.53112  1343876667.279    97.50%        0      0      0     25132   163.0s
#          0       0         0   0.00%   33718017.6591   1343876667.279    97.49%     1256    228      0     27605   183.6s
#          0       0         0   0.00%   33718723.94536  1343876667.279    97.49%     1610    428      0     32878   202.7s
#          0       0         0   0.00%   34086811.32567  1343876667.279    97.46%     1895    607      0     33548   210.1s
#          0       0         0   0.00%   34221089.53766  1343876667.279    97.45%     2017    720      0     34216   216.6s
#  C       0       0         0   0.00%   34554951.09658  546131301.5251    93.67%     2141    781      0     34815   223.4s
#          0       0         0   0.00%   34888759.21996  546131301.5251    93.61%     2317    841      0     34943   230.0s
#          0       0         0   0.00%   34888835.80091  546131301.5251    93.61%     2322    855      0     35263   235.0s
#          0       0         0   0.00%   34888869.75091  546131301.5251    93.61%     2345    868      0     35721   243.1s
#          0       0         0   0.00%   34888879.75091  546131301.5251    93.61%     2364    874      0     38056   261.0s
#          0       0         0   0.00%   34889350.2215   546131301.5251    93.61%     2451    902      0     40386   296.1s
#          0       0         0   0.00%   34889899.25079  546131301.5251    93.61%     2575    925      0     41078   309.5s
#          0       0         0   0.00%   34890017.13449  546131301.5251    93.61%     2840    817      0     41735   416.0s
#          0       0         0   0.00%   34890231.57495  546131301.5251    93.61%     3312    843      0     41971   630.8s
#          0       0         0   0.00%   34890322.75165  546131301.5251    93.61%     3382    855      0     42234   639.2s
#          0       0         0   0.00%   34890450.06145  546131301.5251    93.61%     3454    863      0     42684   653.6s
#          0       0         0   0.00%   34890601.31786  546131301.5251    93.61%     3502    873      0     42796   664.2s
#  L       0       0         0   0.00%   34890601.31786  34891203.03196     0.00%     3502    873      0     42796  1187.3s
#          1       0         1 100.00%   34890601.31786  34891203.03196     0.00%     3502    873      0     85112  1187.6s
#
# Solving report
#   Status            Optimal
#   Primal bound      34891203.032
#   Dual bound        34890601.3179
#   Gap               0.00172% (tolerance: 0.5%)
#   P-D integral      1030.52003734
#   Solution status   feasible
#                     34891203.032 (objective)
#                     0 (bound viol.)
#                     1.33226762955e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            1187.62
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     85112
#                     0 (strong br.)
#                     17664 (separation)
#                     42316 (heuristics)
# [P100] Scenario does not pass: shortfall 5.00; current fleet gap 1
#
# [P100] Running scenario p100_future_total_1_MB_EV_10_1 with allocation {'MB_EV_10': 1, 'MB_EV_18': 0}
#     ✓ prepare_model_data started | flights=7,139   [0.00s]
#     ✓ vehicle expansion complete | vehicles=18   [0.05s]
#     ✓ ambulift intervals built | flights=7,139 ambulifts=14   [1.11s]
#     ✓ minibus intervals built | minibuses=4   [0.09s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=4,850,181   [1.79s]
#     ✓ minibus overlaps built | overlaps=569,184   [0.21s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=3.28s   [0.00s]
#     ✓ sets built | F=7,139 AMB=14 MINI=4   [0.04s]
#     ✓ variables built | x=35,695 amb=299,838 mini=57,112   [1.48s]
#     ✓ ambulift overlap constraints built | 4,850,181   [59.05s]
#     ✓ minibus overlap constraints built | 569,184   [4.87s]
#     ✓ build_pyomo_model complete | total=66.92s   [1.47s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,139 Vehicles=18
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 5933629 rows; 442637 cols; 12283981 nonzeros; 392664 integer variables (392664 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 792976 rows, 154331 cols, 1676766 nonzeros 7s
# 301426 rows, 134328 cols, 1123651 nonzeros 34s
# 301426 rows, 134328 cols, 1123651 nonzeros 71s
# Presolve reductions: rows 301426(-5632203); columns 134328(-308309); nonzeros 1123651(-11160330)
#
# Solving MIP model with:
#    301426 rows
#    134328 cols (119783 binary, 0 integer, 14545 implied int., 0 continuous, 0 domain fixed)
#    1123651 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2968718020.708     Large        0      0      0         0    87.6s
#  R       0       0         0   0.00%   34386536.33885  1483628289.279    97.68%        0      0      0     24769   150.5s
#          0       0         0   0.00%   34387591.27155  1483628289.279    97.68%     1521    293      0     28559   169.2s
#          0       0         0   0.00%   35189101.75514  1483628289.279    97.63%     2043    544      0     37334   195.1s
#          0       0         0   0.00%   35891049.29183  1483628289.279    97.58%     2556    760      0     41143   210.1s
#          0       0         0   0.00%   35891980.12405  1483628289.279    97.58%     2874    885      0     42491   219.5s
#  C       0       0         0   0.00%   35893046.96354  845880271.5251    95.76%     3072    966      0     42878   223.9s
#          0       0         0   0.00%   35893483.58754  845880271.5251    95.76%     3170   1007      0     44474   233.8s
#          0       0         0   0.00%   35893816.79237  845880271.5251    95.76%     3283   1052      0     46702   243.9s
#          0       0         0   0.00%   35893892.24078  845880271.5251    95.76%     3400   1068      0     47216   250.6s
#          0       0         0   0.00%   35893924.94153  845880271.5251    95.76%     3460   1084      0     47738   263.2s
#          0       0         0   0.00%   35893943.572    845880271.5251    95.76%     3570   1097      0     50727   278.8s
#          0       0         0   0.00%   35893996.66686  845880271.5251    95.76%     3760   1107      0     53947   294.9s
#          0       0         0   0.00%   35894051.72669  845880271.5251    95.76%     3931   1118      0     57156   313.0s
#          0       0         0   0.00%   35894086.17373  845880271.5251    95.76%     4204   1129      0     57235   321.1s
#  L       0       0         0   0.00%   35894086.17373  35895286.52511     0.00%     4204   1129      0     57235   474.8s
#          1       0         1 100.00%   35894086.17373  35895286.52511     0.00%     4204   1129      0     91876   475.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      35895286.5251
#   Dual bound        35894086.1737
#   Gap               0.00334% (tolerance: 0.5%)
#   P-D integral      374.215290742
#   Solution status   feasible
#                     35895286.5251 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            474.98
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     91876
#                     0 (strong br.)
#                     32466 (separation)
#                     34641 (heuristics)
# [P100] Scenario does not pass: shortfall 6.00; current fleet gap 1
#
# [P100] Testing 2 total future minibus candidate(s)
#
# [P100] Running scenario p100_future_total_2_MB_EV_18_2 with allocation {'MB_EV_10': 0, 'MB_EV_18': 2}
#     ✓ prepare_model_data started | flights=7,139   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.04s]
#     ✓ ambulift intervals built | flights=7,139 ambulifts=14   [1.00s]
#     ✓ minibus intervals built | minibuses=5   [0.08s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=4,850,181   [1.26s]
#     ✓ minibus overlaps built | overlaps=711,480   [0.20s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.03s]
#     ✓ prepare_model_data complete | total=2.63s   [0.00s]
#     ✓ sets built | F=7,139 AMB=14 MINI=5   [0.01s]
#     ✓ variables built | x=35,695 amb=299,838 mini=71,390   [23.95s]
#     ✓ ambulift overlap constraints built | 4,850,181   [43.31s]
#     ✓ minibus overlap constraints built | 711,480   [4.27s]
#     ✓ build_pyomo_model complete | total=73.58s   [2.03s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,139 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 6118760 rows; 456917 cols; 12682799 nonzeros; 406944 integer variables (406944 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 881126 rows, 163889 cols, 1864899 nonzeros 7s
# 325532 rows, 141469 cols, 1198194 nonzeros 27s
# 325532 rows, 141469 cols, 1198194 nonzeros 51s
# Presolve reductions: rows 325532(-5793228); columns 141469(-315448); nonzeros 1198194(-11484605)
#
# Solving MIP model with:
#    325532 rows
#    141469 cols (126924 binary, 0 integer, 14545 implied int., 0 continuous, 0 domain fixed)
#    1198194 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2921900640.936     Large        0      0      0         0    62.1s
#  R       0       0         0   0.00%   32061284.05728  1384053442.338    97.68%        0      0      0     27156   106.8s
#          0       0         0   0.00%   32061615.12844  1384053442.338    97.68%     1274    170      0     31592   127.7s
#          0       0         0   0.00%   32063099.7447   1384053442.338    97.68%     1719    524      0     34390   139.4s
#  C       0       0         0   0.00%   32063298.04482  1082803026.753    97.04%     1836    582      0     34694   142.8s
#          0       0         0   0.00%   32063629.81829  1082803026.753    97.04%     2045    641      0     35148   148.5s
#          0       0         0   0.00%   32063677.48756  1082803026.753    97.04%     2206    660      0     36980   159.0s
#          0       0         0   0.00%   32063704.48756  1082803026.753    97.04%     2318    672      0     37048   165.6s
#          0       0         0   0.00%   32063752.32803  1082803026.753    97.04%     2443    683      0     37265   170.6s
#          0       0         0   0.00%   32063759.47089  1082803026.753    97.04%     3252    689      0     37307   177.1s
#          0       0         0   0.00%   32063759.47089  1082803026.753    97.04%     3312    694      0     37803   183.3s
#          0       0         0   0.00%   32063759.47089  1082803026.753    97.04%     3526    568      0     37843   189.1s
#  L       0       0         0   0.00%   32063759.47089  32064400.75342     0.00%     3526    568      0     37843   347.8s
#          1       0         1 100.00%   32063759.47089  32064400.75342     0.00%     3526    568      0     64204   348.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      32064400.7534
#   Dual bound        32063759.4709
#   Gap               0.002% (tolerance: 0.5%)
#   P-D integral      278.284249281
#   Solution status   feasible
#                     32064400.7534 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            347.96
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     64204
#                     0 (strong br.)
#                     10687 (separation)
#                     26361 (heuristics)
# [P100] Scenario does not pass: shortfall 2.00; current fleet gap 2
#
# [P100] Running scenario p100_future_total_2_MB_EV_10_1_MB_EV_18_1 with allocation {'MB_EV_10': 1, 'MB_EV_18': 1}
#     ✓ prepare_model_data started | flights=7,139   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.04s]
#     ✓ ambulift intervals built | flights=7,139 ambulifts=14   [0.76s]
#     ✓ minibus intervals built | minibuses=5   [0.07s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=4,850,181   [1.03s]
#     ✓ minibus overlaps built | overlaps=711,480   [0.18s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=2.11s   [0.00s]
#     ✓ sets built | F=7,139 AMB=14 MINI=5   [0.00s]
#     ✓ variables built | x=35,695 amb=299,838 mini=71,390   [0.22s]
#     ✓ ambulift overlap constraints built | 4,850,181   [45.71s]
#     ✓ minibus overlap constraints built | 711,480   [3.85s]
#     ✓ build_pyomo_model complete | total=50.77s   [0.98s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,139 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 6118760 rows; 456917 cols; 12682799 nonzeros; 406944 integer variables (406944 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 881126 rows, 163889 cols, 1864899 nonzeros 6s
# 325532 rows, 141469 cols, 1198194 nonzeros 30s
# 325532 rows, 141469 cols, 1198194 nonzeros 57s
# Presolve reductions: rows 325532(-5793228); columns 141469(-315448); nonzeros 1198194(-11484605)
#
# Solving MIP model with:
#    325532 rows
#    141469 cols (126924 binary, 0 integer, 14545 implied int., 0 continuous, 0 domain fixed)
#    1198194 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3025900570.936     Large        0      0      0         0    69.1s
#  R       0       0         0   0.00%   32061372.45562  1376303557.338    97.67%        0      0      0     25118   118.0s
#          0       0         0   0.00%   32061797.3619   1376303557.338    97.67%     1295    176      0     29471   135.0s
#          0       0         0   0.00%   32062845.90435  1376303557.338    97.67%     1831    477      0     31201   144.5s
#          0       0         0   0.00%   32063169.20281  1376303557.338    97.67%     1966    564      0     37262   163.4s
#  C       0       0         0   0.00%   32063604.99392  1118803076.753    97.13%     2224    631      0     37841   168.1s
#          0       0         0   0.00%   32063764.89016  1118803076.753    97.13%     2323    665      0     39647   175.6s
#          0       0         0   0.00%   32063955.09741  1118803076.753    97.13%     2547    708      0     40251   183.1s
#          0       0         0   0.00%   32064005.77922  1118803076.753    97.13%     2621    720      0     40677   191.6s
#          0       0         0   0.00%   32064054.67922  1118803076.753    97.13%     2771    731      0     40893   198.4s
#          0       0         0   0.00%   32064054.67922  1118803076.753    97.13%     2996    741      0     41126   206.3s
#          0       0         0   0.00%   32064054.67922  1118803076.753    97.13%     3140    748      0     43279   216.8s
#  L       0       0         0   0.00%   32064054.67922  32064501.75342     0.00%     3140    748      0     43279   359.1s
#          1       0         1 100.00%   32064054.67922  32064501.75342     0.00%     3140    748      0     68640   359.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      32064501.7534
#   Dual bound        32064054.6792
#   Gap               0.00139% (tolerance: 0.5%)
#   P-D integral      282.844585336
#   Solution status   feasible
#                     32064501.7534 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            359.24
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     68640
#                     0 (strong br.)
#                     18161 (separation)
#                     25361 (heuristics)
# [P100] Scenario does not pass: shortfall 2.00; current fleet gap 2
#
# [P100] Running scenario p100_future_total_2_MB_EV_10_2 with allocation {'MB_EV_10': 2, 'MB_EV_18': 0}
#     ✓ prepare_model_data started | flights=7,139   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.03s]
#     ✓ ambulift intervals built | flights=7,139 ambulifts=14   [0.72s]
#     ✓ minibus intervals built | minibuses=5   [0.06s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=4,850,181   [0.91s]
#     ✓ minibus overlaps built | overlaps=711,480   [0.13s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.90s   [0.00s]
#     ✓ sets built | F=7,139 AMB=14 MINI=5   [0.00s]
#     ✓ variables built | x=35,695 amb=299,838 mini=71,390   [0.22s]
#     ✓ ambulift overlap constraints built | 4,850,181   [40.27s]
#     ✓ minibus overlap constraints built | 711,480   [4.06s]
#     ✓ build_pyomo_model complete | total=45.54s   [0.98s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,139 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 6118760 rows; 456917 cols; 12682799 nonzeros; 406944 integer variables (406944 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 881126 rows, 163889 cols, 1864899 nonzeros 7s
# 325532 rows, 141469 cols, 1198194 nonzeros 29s
# 325532 rows, 141469 cols, 1198194 nonzeros 56s
# Presolve reductions: rows 325532(-5793228); columns 141469(-315448); nonzeros 1198194(-11484605)
#
# Solving MIP model with:
#    325532 rows
#    141469 cols (126924 binary, 0 integer, 14545 implied int., 0 continuous, 0 domain fixed)
#    1198194 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3025900560.936     Large        0      0      0         0    70.2s
#  R       0       0         0   0.00%   32062435.73112  1484304207.338    97.84%        0      0      0     25994   126.1s
#          0       0         0   0.00%   32420041.68384  1484304207.338    97.82%     1476    270      0     26495   135.8s
#          0       0         0   0.00%   33064832.72896  1484304207.338    97.77%     2062    664      0     28121   143.2s
#          0       0         0   0.00%   33065160.95753  1484304207.338    97.77%     2225    740      0     31523   152.9s
#  C       0       0         0   0.00%   33065504.79506  1220803948.753    97.29%     2378    789      0     31637   157.4s
#          0       0         0   0.00%   33065857.62788  1220803948.753    97.29%     2477    870      0     32878   167.3s
#          0       0         0   0.00%   33066361.08344  1220803948.753    97.29%     2646    944      0     37519   185.3s
#          0       0         0   0.00%   33066559.25523  1220803948.753    97.29%     2847    966      0     42179   202.0s
#          0       0         0   0.00%   33066617.8947   1220803948.753    97.29%     3014    983      0     44164   212.2s
#          0       0         0   0.00%   33066673.52446  1220803948.753    97.29%     3183   1003      0     44343   220.9s
#          0       0         0   0.00%   33066718.41533  1220803948.753    97.29%     3328   1008      0     46202   255.6s
#          0       0         0   0.00%   33066729.607    1220803948.753    97.29%     3347    792      0     46251   261.7s
#          0       0         0   0.00%   33066868.45851  1220803948.753    97.29%     3523    805      0     46309   273.6s
#          0       0         0   0.00%   33066876.06591  1220803948.753    97.29%     3603    815      0     46460   280.4s
#  L       0       0         0   0.00%   33066876.06591  33067443.50685     0.00%     3603    815      0     46460   422.0s
#          1       0         1 100.00%   33066876.06591  33067443.50685     0.00%     3603    815      0     71244   422.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      33067443.5068
#   Dual bound        33066876.0659
#   Gap               0.00172% (tolerance: 0.5%)
#   P-D integral      342.872403032
#   Solution status   feasible
#                     33067443.5068 (objective)
#                     0 (bound viol.)
#                     1.66533453694e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            422.14
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     71244
#                     0 (strong br.)
#                     20466 (separation)
#                     24784 (heuristics)
# [P100] Scenario does not pass: shortfall 3.00; current fleet gap 2
#
# [P100] Testing 3 total future minibus candidate(s)
#
# [P100] Running scenario p100_future_total_3_MB_EV_18_3 with allocation {'MB_EV_10': 0, 'MB_EV_18': 3}
#     ✓ prepare_model_data started | flights=7,139   [0.00s]
#     ✓ vehicle expansion complete | vehicles=20   [0.03s]
#     ✓ ambulift intervals built | flights=7,139 ambulifts=14   [0.74s]
#     ✓ minibus intervals built | minibuses=6   [0.07s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=4,850,181   [0.95s]
#     ✓ minibus overlaps built | overlaps=853,776   [0.18s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=2.01s   [0.00s]
#     ✓ sets built | F=7,139 AMB=14 MINI=6   [0.00s]
#     ✓ variables built | x=35,695 amb=299,838 mini=85,668   [0.27s]
#     ✓ ambulift overlap constraints built | 4,850,181   [44.71s]
#     ✓ minibus overlap constraints built | 853,776   [2.64s]
#     ✓ build_pyomo_model complete | total=50.80s   [3.18s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,139 Vehicles=20
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 6303891 rows; 471197 cols; 13081617 nonzeros; 421224 integer variables (421224 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 969276 rows, 173447 cols, 2053032 nonzeros 7s
# 350026 rows, 148610 cols, 1274962 nonzeros 30s
# 350026 rows, 148610 cols, 1274962 nonzeros 60s
# Presolve reductions: rows 350026(-5953865); columns 148610(-322587); nonzeros 1274962(-11806655)
#
# Solving MIP model with:
#    350026 rows
#    148610 cols (134065 binary, 0 integer, 14545 implied int., 0 continuous, 0 domain fixed)
#    1274962 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2800083561.164     Large        0      0      0         0    74.0s
#  R       0       0         0   0.00%   31242158.03494  1196734988.151    97.39%        0      0      0     29408   137.7s
#          0       0         0   0.00%   31242325.87225  1196734988.151    97.39%      851    134      0     29644   145.3s
#          0       0         0   0.00%   31242769.13502  1196734988.151    97.39%     1108    335      0     30546   152.9s
#  C       0       0         0   0.00%   31243218.36966  602488360.9817    94.81%     1231    414      0     30749   161.9s
#          0       0         0   0.00%   31243245.99087  602488360.9817    94.81%     1293    427      0     34964   178.1s
#          0       0         0   0.00%   31243374.15753  602488360.9817    94.81%     1507    447      0     35307   188.1s
#          0       0         0   0.00%   31243394.99087  602488360.9817    94.81%     1588    455      0     35808   195.9s
#          0       0         0   0.00%   31243409.65753  602488360.9817    94.81%     1686    463      0     35873   205.5s
#          0       0         0   0.00%   31243411.3242   602488360.9817    94.81%     1766    468      0     36280   219.6s
#          0       0         0   0.00%   31243436.3242   602488360.9817    94.81%     1861    474      0     38775   238.7s
#          0       0         0   0.00%   31243436.3242   602488360.9817    94.81%     2055    476      0     38784   255.2s
#          0       0         0   0.00%   31243436.3242   602488360.9817    94.81%     2063    480      0     42938   273.0s
#          0       0         0   0.00%   31243436.3242   602488360.9817    94.81%     2497    372      0     46274   295.6s
#          0       0         0   0.00%   31243447.7242   602488360.9817    94.81%     2884    378      0     47412   307.4s
#          0       0         0   0.00%   31243447.7242   602488360.9817    94.81%     3217    387      0     47552   318.2s
#          0       0         0   0.00%   31243447.7242   602488360.9817    94.81%     3339    391      0     49245   330.2s
#          0       0         0   0.00%   31243455.3242   602488360.9817    94.81%     3575    359      0     49814   343.1s
#          0       0         0   0.00%   31243459.3242   602488360.9817    94.81%     3742    366      0     50405   348.6s
#          0       0         0   0.00%   31243490.65753  602488360.9817    94.81%     3867    371      0     50462   354.4s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   31243510.65753  602488360.9817    94.81%     4026    376      0     50606   361.4s
#          0       0         0   0.00%   31243510.65753  602488360.9817    94.81%     4202    381      0     50628   366.9s
#          0       0         0   0.00%   31243510.65753  602488360.9817    94.81%     4276    375      0     50751   373.7s
#          0       0         0   0.00%   31243533.3242   602488360.9817    94.81%     4450    380      0     50797   382.6s
#          0       0         0   0.00%   31243533.3242   602488360.9817    94.81%     4666    384      0     50842   393.6s
#          0       0         0   0.00%   31243533.3242   602488360.9817    94.81%     4768    388      0     50857   400.2s
#          0       0         0   0.00%   31243533.3242   602488360.9817    94.81%     4907    392      0     51088   407.5s
#  L       0       0         0   0.00%   31243533.3242   31243657.98174     0.00%     4907    392      0     51088   578.3s
#          1       0         1 100.00%   31243533.3242   31243657.98174     0.00%     4581    392      0     81513   578.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      31243657.9817
#   Dual bound        31243533.3242
#   Gap               0.000399% (tolerance: 0.5%)
#   P-D integral      481.461941294
#   Solution status   feasible
#                     31243657.9817 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            578.52
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     81513
#                     0 (strong br.)
#                     21680 (separation)
#                     30425 (heuristics)
# [P100] Scenario does not pass: shortfall 1.00; current fleet gap 3
#
# [P100] Running scenario p100_future_total_3_MB_EV_10_1_MB_EV_18_2 with allocation {'MB_EV_10': 1, 'MB_EV_18': 2}
#     ✓ prepare_model_data started | flights=7,139   [0.00s]
#     ✓ vehicle expansion complete | vehicles=20   [0.04s]
#     ✓ ambulift intervals built | flights=7,139 ambulifts=14   [0.74s]
#     ✓ minibus intervals built | minibuses=6   [0.06s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=4,850,181   [0.91s]
#     ✓ minibus overlaps built | overlaps=853,776   [0.16s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.94s   [0.00s]
#     ✓ sets built | F=7,139 AMB=14 MINI=6   [0.00s]
#     ✓ variables built | x=35,695 amb=299,838 mini=85,668   [0.24s]
#     ✓ ambulift overlap constraints built | 4,850,181   [46.16s]
#     ✓ minibus overlap constraints built | 853,776   [4.47s]
#     ✓ build_pyomo_model complete | total=51.90s   [1.04s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,139 Vehicles=20
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 6303891 rows; 471197 cols; 13081617 nonzeros; 421224 integer variables (421224 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 969276 rows, 173447 cols, 2053032 nonzeros 8s
# 350026 rows, 148610 cols, 1274962 nonzeros 31s
# 350026 rows, 148610 cols, 1274962 nonzeros 58s
# Presolve reductions: rows 350026(-5953865); columns 148610(-322587); nonzeros 1274962(-11806655)
#
# Solving MIP model with:
#    350026 rows
#    148610 cols (134065 binary, 0 integer, 14545 implied int., 0 continuous, 0 domain fixed)
#    1274962 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2927083191.164     Large        0      0      0         0    72.3s
#  R       0       0         0   0.00%   31242158.03494  1188735038.151    97.37%        0      0      0     28845   131.2s
#          0       0         0   0.00%   31242326.4278   1188735038.151    97.37%     1059    136      0     35706   153.5s
#          0       0         0   0.00%   31242567.19327  1188735038.151    97.37%     1343    249      0     43776   171.9s
#          0       0         0   0.00%   31242941.82375  1188735038.151    97.37%     1541    347      0     45773   179.3s
#          0       0         0   0.00%   31243157.07182  1188735038.151    97.37%     1633    403      0     51500   197.7s
#  C       0       0         0   0.00%   31243389.99087  406490090.9817    92.31%     1784    448      0     54210   211.4s
#          0       0         0   0.00%   31243402.65753  406490090.9817    92.31%     2053    465      0     58089   224.6s
#          0       0         0   0.00%   31243456.03989  406490090.9817    92.31%     2219    479      0     58810   232.1s
#          0       0         0   0.00%   31243483.04087  406490090.9817    92.31%     2477    488      0     58979   258.9s
#          0       0         0   0.00%   31243501.25753  406490090.9817    92.31%     2577    495      0     59039   274.7s
#          0       0         0   0.00%   31243501.65753  406490090.9817    92.31%     2601    501      0     59953   282.9s
#          0       0         0   0.00%   31243519.65753  406490090.9817    92.31%     2696    505      0     60006   296.0s
#          0       0         0   0.00%   31243519.65753  406490090.9817    92.31%     2874    509      0     60069   311.2s
#          0       0         0   0.00%   31243519.65753  406490090.9817    92.31%     3020    511      0     60208   323.4s
#          0       0         0   0.00%   31243519.65753  406490090.9817    92.31%     3140    512      0     60210   334.0s
#          0       0         0   0.00%   31243519.65753  406490090.9817    92.31%     3206    373      0     60214   345.0s
#  L       0       0         0   0.00%   31243519.65753  31243671.98174     0.00%     3206    373      0     60214   508.9s
#          1       0         1 100.00%   31243519.65753  31243671.98174     0.00%     3206    373      0     87918   509.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      31243671.9817
#   Dual bound        31243519.6575
#   Gap               0.000488% (tolerance: 0.5%)
#   P-D integral      411.041185625
#   Solution status   feasible
#                     31243671.9817 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            509.06
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     87918
#                     0 (strong br.)
#                     31369 (separation)
# ...
# 2                            0                   9                     5
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      4               0                   0              0
# 2                      5               0                   4              0
# 3                      3               0                   0              0
#
# [P90] Fleet expansion triggered because: Vehicle shortfall exists
#
# [P90] Testing 1 total future minibus candidate(s)
#
# [P90] Running scenario p90_future_total_1_MB_EV_18_1 with allocation {'MB_EV_10': 0, 'MB_EV_18': 1}
#     ✓ prepare_model_data started | flights=7,139   [0.00s]
#     ✓ vehicle expansion complete | vehicles=18   [0.03s]
#     ✓ ambulift intervals built | flights=7,139 ambulifts=14   [0.69s]
#     ✓ minibus intervals built | minibuses=4   [0.06s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=4,778,620   [0.99s]
#     ✓ minibus overlaps built | overlaps=569,192   [0.11s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.93s   [0.00s]
#     ✓ sets built | F=7,139 AMB=14 MINI=4   [0.00s]
#     ✓ variables built | x=35,695 amb=299,838 mini=57,112   [0.23s]
#     ✓ ambulift overlap constraints built | 4,778,620   [33.25s]
#     ✓ minibus overlap constraints built | 569,192   [3.24s]
#     ✓ build_pyomo_model complete | total=37.66s   [0.94s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,139 Vehicles=18
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 5862049 rows; 442637 cols; 12140848 nonzeros; 392664 integer variables (392664 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 3e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -2
# Presolving model
# 784786 rows, 154763 cols, 1669765 nonzeros 5s
# 302542 rows, 134767 cols, 1125450 nonzeros 24s
# 302542 rows, 134767 cols, 1125450 nonzeros 48s
# Presolve reductions: rows 302542(-5559507); columns 134767(-307870); nonzeros 1125450(-11015398)
#
# Solving MIP model with:
#    302542 rows
#    134767 cols (120195 binary, 0 integer, 14572 implied int., 0 continuous, 0 domain fixed)
#    1125450 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2905674189.708     Large        0      0      0         0    59.2s
#  R       0       0         0   0.00%   22368307.80488  1104361203.279    97.97%        0      0      0     25809    98.7s
#          0       0         0   0.00%   22368590.11386  1104361203.279    97.97%     1253    157      0     26212   104.9s
#          0       0         0   0.00%   23369083.87689  1104361203.279    97.88%     1449    297      0     27293   110.8s
#          0       0         0   0.00%   24370423.44812  1104361203.279    97.79%     1747    526      0     30201   121.1s
#  C       0       0         0   0.00%   24370684.09848  735112906.5251    96.68%     1884    585      0     30576   124.2s
#          0       0         0   0.00%   24370966.96758  735112906.5251    96.68%     2055    643      0     31512   130.8s
#          0       0         0   0.00%   24371058.73425  735112906.5251    96.68%     2288    658      0     31919   142.1s
#          0       0         0   0.00%   24371401.03425  735112906.5251    96.68%     3280    683      0     32191   154.6s
#          0       0         0   0.00%   24371401.03425  735112906.5251    96.68%     3414    692      0     32418   162.1s
#          0       0         0   0.00%   24371401.03425  735112906.5251    96.68%     3587    702      0     33303   169.6s
#          0       0         0   0.00%   24371410.40925  735112906.5251    96.68%     3773    608      0     33567   180.7s
#          0       0         0   0.00%   24371410.40925  735112906.5251    96.68%     3894    619      0     33766   186.2s
#  L       0       0         0   0.00%   24371410.40925  24371930.52511     0.00%     3980    623      0     33811   279.0s
#          1       0         1 100.00%   24371410.40925  24371930.52511     0.00%     3980    623      0     60674   279.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      24371930.5251
#   Dual bound        24371410.4092
#   Gap               0.00213% (tolerance: 0.5%)
#   P-D integral      213.797772059
#   Solution status   feasible
#                     24371930.5251 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            279.18
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     60674
#                     0 (strong br.)
#                     8002 (separation)
#                     26863 (heuristics)
# [P90] Scenario does not pass: shortfall 2.00; current fleet gap 1
#
# [P90] Running scenario p90_future_total_1_MB_EV_10_1 with allocation {'MB_EV_10': 1, 'MB_EV_18': 0}
#     ✓ prepare_model_data started | flights=7,139   [0.00s]
#     ✓ vehicle expansion complete | vehicles=18   [0.03s]
#     ✓ ambulift intervals built | flights=7,139 ambulifts=14   [0.70s]
#     ✓ minibus intervals built | minibuses=4   [0.06s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=4,778,620   [0.90s]
#     ✓ minibus overlaps built | overlaps=569,192   [0.10s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.83s   [0.00s]
#     ✓ sets built | F=7,139 AMB=14 MINI=4   [0.00s]
#     ✓ variables built | x=35,695 amb=299,838 mini=57,112   [0.21s]
#     ✓ ambulift overlap constraints built | 4,778,620   [32.44s]
#     ✓ minibus overlap constraints built | 569,192   [1.55s]
#     ✓ build_pyomo_model complete | total=35.14s   [0.93s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,139 Vehicles=18
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 5862049 rows; 442637 cols; 12140848 nonzeros; 392664 integer variables (392664 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 1e+01]
#   Cost    [2e+00, 3e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -2
# Presolving model
# 784786 rows, 154763 cols, 1669765 nonzeros 6s
# 302542 rows, 134767 cols, 1125450 nonzeros 25s
# 302542 rows, 134767 cols, 1125450 nonzeros 50s
# Presolve reductions: rows 302542(-5559507); columns 134767(-307870); nonzeros 1125450(-11015398)
#
# Solving MIP model with:
#    302542 rows
#    134767 cols (120195 binary, 0 integer, 14572 implied int., 0 continuous, 0 domain fixed)
#    1125450 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2951674189.708     Large        0      0      0         0    61.1s
#  R       0       0         0   0.00%   22368373.01917  1104361307.279    97.97%        0      0      0     27069   108.5s
#          0       0         0   0.00%   22368878.36227  1104361307.279    97.97%      895    169      0     32826   127.4s
#          0       0         0   0.00%   23370117.94599  1104361307.279    97.88%     1399    442      0     33989   136.1s
#  C       0       0         0   0.00%   24371068.78425  595614550.5251    95.91%     1646    593      0     34735   144.1s
#          0       0         0   0.00%   24371339.26758  595614550.5251    95.91%     1743    644      0     34865   150.5s
#          0       0         0   0.00%   24371355.26758  595614550.5251    95.91%     1834    651      0     35244   156.1s
#          0       0         0   0.00%   24371619.73425  595614550.5251    95.91%     1939    673      0     35420   169.5s
#          0       0         0   0.00%   24371633.86758  595614550.5251    95.91%     2117    682      0     35984   177.6s
#  L       0       0         0   0.00%   24371633.86758  24372118.52511     0.00%     2217    685      0     36022   344.1s
#          1       0         1 100.00%   24371633.86758  24372118.52511     0.00%     2217    685      0     70717   344.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      24372118.5251
#   Dual bound        24371633.8676
#   Gap               0.00199% (tolerance: 0.5%)
#   P-D integral      273.63404165
#   Solution status   feasible
#                     24372118.5251 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            344.20
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     70717
#                     0 (strong br.)
#                     8953 (separation)
#                     34695 (heuristics)
# [P90] Scenario does not pass: shortfall 2.00; current fleet gap 1
#
# [P90] Testing 2 total future minibus candidate(s)
#
# [P90] Running scenario p90_future_total_2_MB_EV_18_2 with allocation {'MB_EV_10': 0, 'MB_EV_18': 2}
#     ✓ prepare_model_data started | flights=7,139   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.03s]
#     ✓ ambulift intervals built | flights=7,139 ambulifts=14   [0.68s]
#     ✓ minibus intervals built | minibuses=5   [0.06s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=4,778,620   [0.87s]
#     ✓ minibus overlaps built | overlaps=711,490   [0.13s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.81s   [0.00s]
#     ✓ sets built | F=7,139 AMB=14 MINI=5   [0.00s]
#     ✓ variables built | x=35,695 amb=299,838 mini=71,390   [0.21s]
#     ✓ ambulift overlap constraints built | 4,778,620   [39.22s]
#     ✓ minibus overlap constraints built | 711,490   [2.03s]
#     ✓ build_pyomo_model complete | total=42.40s   [0.94s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,139 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 6047182 rows; 456917 cols; 12539670 nonzeros; 406944 integer variables (406944 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 3e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -2
# Presolving model
# 872962 rows, 164321 cols, 1857950 nonzeros 5s
# 327003 rows, 141908 cols, 1201860 nonzeros 25s
# 327003 rows, 141908 cols, 1201860 nonzeros 50s
# Presolve reductions: rows 327003(-5720179); columns 141908(-315009); nonzeros 1201860(-11337810)
#
# Solving MIP model with:
#    327003 rows
#    141908 cols (127336 binary, 0 integer, 14572 implied int., 0 continuous, 0 domain fixed)
#    1201860 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2873856939.936     Large        0      0      0         0    62.2s
#  R       0       0         0   0.00%   22368307.80488  1180860977.279    98.11%        0      0      0     25053    95.8s
#          0       0         0   0.00%   22368487.13821  1180860977.279    98.11%     1278    157      0     29273   112.6s
#          0       0         0   0.00%   22458970.06308  1180860977.279    98.10%     1862    443      0     30938   117.8s
#  C       0       0         0   0.00%   22459931.06507  369299568.9269    93.92%     2066    607      0     31841   124.5s
#          0       0         0   0.00%   22549557.02922  369299568.9269    93.89%     2209    675      0     32425   130.8s
#          0       0         0   0.00%   22549567.52446  369299568.9269    93.89%     2340    696      0     32880   136.4s
#  L       0       0         0   0.00%   22549567.52446  22549835.75342     0.00%     2340    696      0     32880   207.1s
#          1       0         1 100.00%   22549567.52446  22549835.75342     0.00%     2340    696      0     57044   207.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      22549835.7534
#   Dual bound        22549567.5245
#   Gap               0.00119% (tolerance: 0.5%)
#   P-D integral      138.756077505
#   Solution status   feasible
#                     22549835.7534 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            207.26
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     57044
#                     0 (strong br.)
#                     7827 (separation)
#                     24164 (heuristics)
# [P90] Scenario passes: SLA 99.21%, shortfall 0.00, future vehicles bought 2
# [P90] Recommended scenario: p90_future_total_2_MB_EV_18_2
#     ✓ P90 fleet expansion search complete   [1292.79s]
#     ✓ Excel outputs written to outputs\prm_combined_new\monthly\2026_05_v2.xlsx   [14.77s]
#
# Completed month: 2026_05
# Workbook: outputs\prm_combined_new\monthly\2026_05_combined.xlsx
#    S1_PeakAmb  S1_PeakMini  S1_PeakDrivers  S1_PeakVehAgents  S2_PeakAmb  \
# 0          20            7              21                21           8
# 1          18            5              19                19           8
#
#    S2_PeakMini  S2_PeakDrivers  S2_PeakVehAgents  V2_arrival_sla_pct  \
# 0           17              22                22           99.016889
# 1           15              19                19           99.210884
#
#    V2_PeakAmb  V2_PeakMini
# 0          11            3
# 1          10            3

# %%
june_result = run_combined_month(
    2026,
    6,
)

pd.DataFrame(june_result["month_rows"])
# Out:
# ================================================================================
# RUNNING COMBINED MONTH: 2026_06
# ================================================================================
#
# Running S1 P100
#
# Unmatched passenger rows after merge (missing Chocks DT): 858
# Unique unmatched flight keys: 454
#
# Unmatched key reasons:
# reason
# no_flight_candidate               383
# scheduled_dt_mismatch              48
# exact_match_should_have_joined     23
# Name: count, dtype: int64
#
# Dropped 811 passenger rows due to reasons {'scheduled_dt_mismatch', 'no_flight_candidate'}
# [BUILD_JOBS] Dropping 14 jobs already impossible at release (beyond SLA + max late)
# Running S2 P100
#
# Running S1 P90
#
# Unmatched passenger rows after merge (missing Chocks DT): 858
# Unique unmatched flight keys: 454
#
# Unmatched key reasons:
# reason
# no_flight_candidate               383
# scheduled_dt_mismatch              48
# exact_match_should_have_joined     23
# Name: count, dtype: int64
#
# Dropped 811 passenger rows due to reasons {'scheduled_dt_mismatch', 'no_flight_candidate'}
# [BUILD_JOBS] Dropping 14 jobs already impossible at release (beyond SLA + max late)
# [BUILD_JOBS] Applying stratified percentile cap: q=0.90 | strata=['SSR Code', 'Has Own Chair', 'A/D']
# [BUILD_JOBS] Dropped 715 PRM jobs via stratified percentile cap
# Running S2 P90
#
# Running V2 optimiser
#     ✓ S25 ingest complete (19,272 passengers)   [30.82s]
#     ✓ Passenger dataset combined (19,272 passenger rows)   [0.00s]
#     ✓ P100 built (7,133 flights)   [0.16s]
#     P100 demand summary: 19,272 PRMs across 7,133 flights
#     ✓ prepare_model_data started | flights=7,133   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.02s]
#     ✓ ambulift intervals built | flights=7,133 ambulifts=14   [0.68s]
#     ✓ minibus intervals built | minibuses=3   [0.07s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=4,914,689   [0.87s]
#     ✓ minibus overlaps built | overlaps=437,124   [0.07s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.75s   [0.00s]
#     ✓ sets built | F=7,133 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=35,665 amb=299,586 mini=42,798   [0.51s]
#     ✓ ambulift overlap constraints built | 4,914,689   [26.49s]
#     ✓ minibus overlap constraints built | 437,124   [1.22s]
#     ✓ build_pyomo_model complete | total=29.14s   [0.92s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,133 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 5822883 rows; 427997 cols; 12033574 nonzeros; 378066 integer variables (378066 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 756437 rows, 149581 cols, 1591156 nonzeros 5s
# 289894 rows, 130917 cols, 1106157 nonzeros 25s
# 268495 rows, 130910 cols, 1053224 nonzeros 51s
# Presolve reductions: rows 268495(-5554388); columns 130910(-297087); nonzeros 1053224(-10980350)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    268495 rows
#    130910 cols (116116 binary, 0 integer, 14794 implied int., 0 continuous, 0 domain fixed)
#    1053224 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3208536871.479     Large        0      0      0         0    61.1s
#  R       0       0         0   0.00%   67898667.60382  1666221369.635    95.92%        0      0      0     41482   176.0s
#          0       0         0   0.00%   76401050.68864  1666221369.635    95.41%     1333    308      0     44620   192.9s
#          0       0         0   0.00%   77069340.63342  1666221369.635    95.37%     1653    538      0     84690   338.5s
#          0       0         0   0.00%   77270107.36568  1666221369.635    95.36%     2778    734      0     94092   379.7s
#          0       0         0   0.00%   77742401.70978  1666221369.635    95.33%     3094    827      0    101341   406.9s
#  C       0       0         0   0.00%   77742762.74311  1320973030.297    94.11%     3341    854      0    112455   447.0s
#          0       0         0   0.00%   77743152.01308  1320973030.297    94.11%     3957    908      0    126595   483.2s
#          0       0         0   0.00%   77743307.71743  1320973030.297    94.11%     4691    980      0    128218   491.6s
#          0       0         0   0.00%   77743373.77816  1320973030.297    94.11%     4745   1003      0    130725   501.8s
#          0       0         0   0.00%   77743376.17498  1320973030.297    94.11%     4830   1011      0    131417   516.0s
#          0       0         0   0.00%   77743387.91325  1320973030.297    94.11%     4992   1023      0    132129   524.4s
#          0       0         0   0.00%   77743390.89165  1320973030.297    94.11%     5142    925      0    133415   535.7s
#  L       0       0         0   0.00%   77743390.89165  77743687.80365     0.00%     5142    925      0    133415   823.4s
#          1       0         1 100.00%   77743390.89165  77743687.80365     0.00%     5142    925      0    190462   823.6s
#
# Solving report
#   Status            Optimal
#   Primal bound      77743687.8037
#   Dual bound        77743390.895
#   Gap               0.000382% (tolerance: 0.5%)
#   P-D integral      727.156300857
#   Solution status   feasible
#                     77743687.8037 (objective)
#                     0 (bound viol.)
#                     2.22044604925e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            823.56
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     190462
#                     0 (strong br.)
#                     91933 (separation)
#                     57047 (heuristics)
#     ✓ P100 optimisation complete   [965.32s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   0                     0
# 1                            0                   2                     2
# 2                            0                   6                     6
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      0               0                   1              0
# 1                      2               0                   2              0
# 2                      6               0                   3              0
# 3                      3               0                   0              0
#
# [P100] Fleet expansion triggered because: Vehicle shortfall exists
#
# [P100] Testing 1 total future minibus candidate(s)
#
# [P100] Running scenario p100_future_total_1_MB_EV_18_1 with allocation {'MB_EV_10': 0, 'MB_EV_18': 1}
#     ✓ prepare_model_data started | flights=7,133   [0.00s]
#     ✓ vehicle expansion complete | vehicles=18   [0.03s]
#     ✓ ambulift intervals built | flights=7,133 ambulifts=14   [0.70s]
#     ✓ minibus intervals built | minibuses=4   [0.06s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=4,914,689   [0.90s]
#     ✓ minibus overlaps built | overlaps=582,832   [0.12s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.85s   [0.00s]
#     ✓ sets built | F=7,133 AMB=14 MINI=4   [0.00s]
#     ✓ variables built | x=35,665 amb=299,586 mini=57,064   [0.25s]
#     ✓ ambulift overlap constraints built | 4,914,689   [38.96s]
#     ✓ minibus overlap constraints built | 582,832   [3.48s]
#     ✓ build_pyomo_model complete | total=43.64s   [0.94s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,133 Vehicles=18
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 6011390 rows; 442265 cols; 12439120 nonzeros; 392334 integer variables (392334 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 848368 rows, 159279 cols, 1787037 nonzeros 5s
# 313994 rows, 138053 cols, 1180981 nonzeros 26s
# 313994 rows, 138053 cols, 1180981 nonzeros 54s
# Presolve reductions: rows 313994(-5697396); columns 138053(-304212); nonzeros 1180981(-11258139)
#
# Solving MIP model with:
#    313994 rows
#    138053 cols (123257 binary, 0 integer, 14796 implied int., 0 continuous, 0 domain fixed)
#    1180981 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3247719361.708     Large        0      0      0         0    66.0s
#  R       0       0         0   0.00%   35897074.78479  1282139508.863    97.20%        0      0      0     46581   230.4s
#          0       0         0   0.00%   35898297.45125  1282139508.863    97.20%     1311    192      0     53973   260.8s
#          0       0         0   0.00%   35899019.53564  1282139508.863    97.20%     1648    355      0     61511   286.0s
#          0       0         0   0.00%   35899774.25487  1282139508.863    97.20%     1874    496      0     72977   326.6s
#          0       0         0   0.00%   35900518.60405  1282139508.863    97.20%     2302    585      0     74655   339.7s
#  C       0       0         0   0.00%   35900740.15543  987889532.5251    96.37%     2366    640      0     76760   352.9s
#          0       0         0   0.00%   35901135.98018  987889532.5251    96.37%     2415    675      0     85575   394.5s
#          0       0         0   0.00%   35901302.35637  987889532.5251    96.37%     3081    695      0     88509   412.9s
#          0       0         0   0.00%   35901361.45812  987889532.5251    96.37%     3533    711      0    108664   602.5s
#          0       0         0   0.00%   35901403.84057  987889532.5251    96.37%     4539    719      0    115459   645.1s
#          0       0         0   0.00%   35901423.80679  987889532.5251    96.37%     5475    727      0    183420   853.0s
#          0       0         0   0.00%   35901443.19458  987889532.5251    96.37%     6095    734      0    226139  1004.3s
#          0       0         0   0.00%   35901468.52791  987889532.5251    96.37%     7116    740      0    230980  1031.4s
#          0       0         0   0.00%   35901506.12399  987889532.5251    96.37%     7505    747      0    231418  1043.1s
#          0       0         0   0.00%   35901506.97511  987889532.5251    96.37%     7589    628      0    232286  1064.4s
#          0       0         0   0.00%   35901506.97511  987889532.5251    96.37%     7772    633      0    232792  1091.0s
#          0       0         0   0.00%   35901507.13425  987889532.5251    96.37%     7885    637      0    234915  1112.8s
#          0       0         0   0.00%   35901518.20091  987889532.5251    96.37%     8084    643      0    237631  1128.1s
#          0       0         0   0.00%   35901522.20091  987889532.5251    96.37%     8308    647      0    238240  1145.8s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   35901522.20091  987889532.5251    96.37%     8476    604      0    238840  1167.9s
#          0       0         0   0.00%   35901522.20091  987889532.5251    96.37%     8677    606      0    240307  1190.6s
#  L       0       0         0   0.00%   35901522.20091  35901890.44749     0.00%     8677    606      0    240307  1437.3s
#          1       0         1 100.00%   35901522.20091  35901890.44749     0.00%     8677    606      0    298188  1437.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      35901890.4475
#   Dual bound        35901522.2009
#   Gap               0.00103% (tolerance: 0.5%)
#   P-D integral      1327.80211105
#   Solution status   feasible
#                     35901890.4475 (objective)
#                     0 (bound viol.)
#                     6.66133814775e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            1437.46
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     298188
#                     0 (strong br.)
#                     193726 (separation)
#                     57881 (heuristics)
# [P100] Scenario does not pass: shortfall 9.00; current fleet gap 1
#
# [P100] Running scenario p100_future_total_1_MB_EV_10_1 with allocation {'MB_EV_10': 1, 'MB_EV_18': 0}
#     ✓ prepare_model_data started | flights=7,133   [0.00s]
#     ✓ vehicle expansion complete | vehicles=18   [0.03s]
#     ✓ ambulift intervals built | flights=7,133 ambulifts=14   [0.68s]
#     ✓ minibus intervals built | minibuses=4   [0.07s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=4,914,689   [0.92s]
#     ✓ minibus overlaps built | overlaps=582,832   [0.11s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.84s   [0.00s]
#     ✓ sets built | F=7,133 AMB=14 MINI=4   [0.00s]
#     ✓ variables built | x=35,665 amb=299,586 mini=57,064   [12.00s]
#     ✓ ambulift overlap constraints built | 4,914,689   [25.45s]
#     ✓ minibus overlap constraints built | 582,832   [3.48s]
#     ✓ build_pyomo_model complete | total=41.88s   [0.94s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,133 Vehicles=18
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 6011390 rows; 442265 cols; 12439120 nonzeros; 392334 integer variables (392334 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 848368 rows, 159279 cols, 1787037 nonzeros 5s
# 313994 rows, 138053 cols, 1180981 nonzeros 26s
# 313994 rows, 138053 cols, 1180981 nonzeros 54s
# Presolve reductions: rows 313994(-5697396); columns 138053(-304212); nonzeros 1180981(-11258139)
#
# Solving MIP model with:
#    313994 rows
#    138053 cols (123257 binary, 0 integer, 14796 implied int., 0 continuous, 0 domain fixed)
#    1180981 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3200719821.708     Large        0      0      0         0    65.6s
#  R       0       0         0   0.00%   35899319.30093  1411140935.863    97.46%        0      0      0     48123   229.5s
#          0       0         0   0.00%   35901181.3777   1411140935.863    97.46%     1420    232      0     81875   366.9s
#          0       0         0   0.00%   35902481.99471  1411140935.863    97.46%     2648    413      0     87830   387.7s
#          0       0         0   0.00%   35903492.0166   1411140935.863    97.46%     2874    564      0     95823   414.2s
#          0       0         0   0.00%   35904095.93984  1411140935.863    97.46%     3136    640      0     99585   427.1s
#  C       0       0         0   0.00%   35904497.81451  1053391263.525    96.59%     3245    693      0    104401   445.5s
#          0       0         0   0.00%   35904707.68746  1053391263.525    96.59%     3395    726      0    116718   511.4s
#          0       0         0   0.00%   35904790.10726  1053391263.525    96.59%     3876    743      0    128585   561.0s
#          0       0         0   0.00%   35904871.39298  1053391263.525    96.59%     4292    752      0    131817   588.6s
#          0       0         0   0.00%   35904875.50123  1053391263.525    96.59%     4470    757      0    147903   676.5s
#          0       0         0   0.00%   35904893.50123  1053391263.525    96.59%     5375    763      0    148283   726.0s
#          0       0         0   0.00%   35904916.64561  1053391263.525    96.59%     5602    768      0    151170   809.3s
#          0       0         0   0.00%   35904919.54233  1053391263.525    96.59%     6034    775      0    154077   859.3s
#          0       0         0   0.00%   35904919.54233  1053391263.525    96.59%     6359    779      0    154835   898.7s
#          0       0         0   0.00%   35904919.54233  1053391263.525    96.59%     6738    783      0    157103   944.7s
#          0       0         0   0.00%   35904919.54233  1053391263.525    96.59%     7071    651      0    157466   964.5s
#          0       0         0   0.00%   35905135.2088   1053391263.525    96.59%     7360    694      0    159270   979.2s
#          0       0         0   0.00%   35905169.50865  1053391263.525    96.59%     7504    713      0    160762   988.2s
#          0       0         0   0.00%   35905234.32393  1053391263.525    96.59%     7626    730      0    163258   997.1s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   35905246.40925  1053391263.525    96.59%     7694    745      0    164212  1004.1s
#          0       0         0   0.00%   35905246.40925  1053391263.525    96.59%     7750    719      0    167978  1020.3s
#          0       0         0   0.00%   35905335.06056  1053391263.525    96.59%     8012    728      0    168907  1026.8s
#          0       0         0   0.00%   35905345.22723  1053391263.525    96.59%     8202    737      0    170364  1041.9s
#          0       0         0   0.00%   35905353.44334  1053391263.525    96.59%     8351    749      0    171175  1050.1s
#          0       0         0   0.00%   35905357.11     1053391263.525    96.59%     8417    760      0    174203  1063.7s
#          0       0         0   0.00%   35905373.64536  1053391263.525    96.59%     8703    761      0    175959  1077.3s
#          0       0         0   0.00%   35905376.64536  1053391263.525    96.59%     9062    768      0    178700  1088.5s
#          0       0         0   0.00%   35905389.20091  1053391263.525    96.59%     9271    775      0    180423  1095.8s
#          0       0         0   0.00%   35905389.20091  1053391263.525    96.59%     9359    781      0    183817  1108.1s
#          0       0         0   0.00%   35905391.20091  1053391263.525    96.59%     9561    788      0    185516  1115.4s
#          0       0         0   0.00%   35905391.20091  1053391263.525    96.59%     9641    753      0    188825  1126.4s
#  L       0       0         0   0.00%   35905391.20091  35905545.03196     0.00%     9641    753      0    188825  1349.1s
#          1       0         1 100.00%   35905391.20091  35905545.03196     0.00%     7900    753      0    244116  1349.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      35905545.032
#   Dual bound        35905391.2009
#   Gap               0.000428% (tolerance: 0.5%)
#   P-D integral      1246.44661394
#   Solution status   feasible
#                     35905545.032 (objective)
#                     0 (bound viol.)
#                     4.56301663121e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            1349.20
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     244116
#                     0 (strong br.)
#                     140702 (separation)
#                     55291 (heuristics)
# [P100] Scenario does not pass: shortfall 9.00; current fleet gap 1
#
# [P100] Testing 2 total future minibus candidate(s)
#
# [P100] Running scenario p100_future_total_2_MB_EV_18_2 with allocation {'MB_EV_10': 0, 'MB_EV_18': 2}
#     ✓ prepare_model_data started | flights=7,133   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.03s]
#     ✓ ambulift intervals built | flights=7,133 ambulifts=14   [0.71s]
#     ✓ minibus intervals built | minibuses=5   [0.07s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=4,914,689   [0.90s]
#     ✓ minibus overlaps built | overlaps=728,540   [0.13s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.87s   [0.00s]
#     ✓ sets built | F=7,133 AMB=14 MINI=5   [0.00s]
#     ✓ variables built | x=35,665 amb=299,586 mini=71,330   [0.25s]
#     ✓ ambulift overlap constraints built | 4,914,689   [49.87s]
#     ✓ minibus overlap constraints built | 728,540   [3.95s]
#     ✓ build_pyomo_model complete | total=55.05s   [0.97s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,133 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 6199897 rows; 456533 cols; 12844666 nonzeros; 406602 integer variables (406602 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 940299 rows, 168977 cols, 1982918 nonzeros 6s
# 338337 rows, 145188 cols, 1257070 nonzeros 29s
# 338337 rows, 145188 cols, 1257070 nonzeros 57s
# Presolve reductions: rows 338337(-5861560); columns 145188(-311345); nonzeros 1257070(-11587596)
#
# Solving MIP model with:
#    338337 rows
#    145188 cols (130392 binary, 0 integer, 14796 implied int., 0 continuous, 0 domain fixed)
#    1257070 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3240901961.936     Large        0      0      0         0    68.9s
#  R       0       0         0   0.00%   32075579.67398  1224817420.091    97.38%        0      0      0     47482   234.9s
#          0       0         0   0.00%   32075790.5085   1224817420.091    97.38%      648    131      0     49616   251.5s
#          0       0         0   0.00%   32075985.38436  1224817420.091    97.38%      825    244      0     50355   256.9s
#          0       0         0   0.00%   32076526.35504  1224817420.091    97.38%      899    341      0     54647   275.8s
#          0       0         0   0.00%   32077731.37625  1224817420.091    97.38%     1044    391      0     56511   287.5s
#  C       0       0         0   0.00%   32077926.66911  1183815984.753    97.29%     1083    422      0     58601   302.9s
#          0       0         0   0.00%   32078065.60742  1183815984.753    97.29%     1119    442      0     60262   313.9s
#          0       0         0   0.00%   32078113.16802  1183815984.753    97.29%     1134    454      0     62322   323.7s
#          0       0         0   0.00%   32078137.33469  1183815984.753    97.29%     1192    463      0     63642   333.2s
#          0       0         0   0.00%   32078156.33976  1183815984.753    97.29%     1221    469      0    109487   483.4s
#          0       0         0   0.00%   32078296.68987  1183815984.753    97.29%     2222    485      0    121673   531.3s
#          0       0         0   0.00%   32078298.35653  1183815984.753    97.29%     2965    491      0    138007   603.0s
#          0       0         0   0.00%   32078313.7851   1183815984.753    97.29%     4172    496      0    148050   721.9s
#          0       0         0   0.00%   32078322.26256  1183815984.753    97.29%     4789    501      0    168847   783.1s
#          0       0         0   0.00%   32078350.76256  1183815984.753    97.29%     5801    520      0    171777   799.7s
#          0       0         0   0.00%   32078403.42922  1183815984.753    97.29%     6101    441      0    173632   810.7s
#          0       0         0   0.00%   32078404.82922  1183815984.753    97.29%     6212    448      0    175915   819.5s
#          0       0         0   0.00%   32078425.42922  1183815984.753    97.29%     6420    463      0    177005   828.7s
#          0       0         0   0.00%   32078425.42922  1183815984.753    97.29%     6519    426      0    177797   837.0s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   32078425.42922  1183815984.753    97.29%     6582    433      0    178702   842.8s
#          0       0         0   0.00%   32078425.42922  1183815984.753    97.29%     6656    437      0    179810   850.2s
#          0       0         0   0.00%   32078425.42922  1183815984.753    97.29%     6791    443      0    180292   856.6s
#  L       0       0         0   0.00%   32078425.42922  32079259.09132     0.00%     6791    443      0    180292  1207.0s
#          1       0         1 100.00%   32078425.42922  32079259.09132     0.00%     6791    443      0    271500  1207.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      32079259.0913
#   Dual bound        32078425.4292
#   Gap               0.0026% (tolerance: 0.5%)
#   P-D integral      1111.01046729
#   Solution status   feasible
#                     32079259.0913 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            1207.11
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     271500
#                     0 (strong br.)
#                     132810 (separation)
#                     91208 (heuristics)
# [P100] Scenario does not pass: shortfall 5.00; current fleet gap 2
#
# [P100] Running scenario p100_future_total_2_MB_EV_10_1_MB_EV_18_1 with allocation {'MB_EV_10': 1, 'MB_EV_18': 1}
#     ✓ prepare_model_data started | flights=7,133   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.04s]
#     ✓ ambulift intervals built | flights=7,133 ambulifts=14   [0.72s]
#     ✓ minibus intervals built | minibuses=5   [0.06s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=4,914,689   [0.98s]
#     ✓ minibus overlaps built | overlaps=728,540   [0.14s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.97s   [0.00s]
#     ✓ sets built | F=7,133 AMB=14 MINI=5   [0.01s]
#     ✓ variables built | x=35,665 amb=299,586 mini=71,330   [0.22s]
#     ✓ ambulift overlap constraints built | 4,914,689   [39.94s]
#     ✓ minibus overlap constraints built | 728,540   [2.16s]
#     ✓ build_pyomo_model complete | total=43.30s   [0.98s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,133 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 6199897 rows; 456533 cols; 12844666 nonzeros; 406602 integer variables (406602 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 940299 rows, 168977 cols, 1982918 nonzeros 6s
# 338337 rows, 145188 cols, 1257070 nonzeros 28s
# 338337 rows, 145188 cols, 1257070 nonzeros 56s
# Presolve reductions: rows 338337(-5861560); columns 145188(-311345); nonzeros 1257070(-11587596)
#
# Solving MIP model with:
#    338337 rows
#    145188 cols (130392 binary, 0 integer, 14796 implied int., 0 continuous, 0 domain fixed)
#    1257070 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3111902291.936     Large        0      0      0         0    67.7s
#  R       0       0         0   0.00%   32075674.30325  1259817313.091    97.45%        0      0      0     45322   222.8s
#          0       0         0   0.00%   32075915.23155  1259817313.091    97.45%      764    141      0     47677   239.6s
#          0       0         0   0.00%   32076426.62285  1259817313.091    97.45%      953    264      0     49929   252.7s
#          0       0         0   0.00%   32076949.79512  1259817313.091    97.45%     1061    364      0     55160   276.5s
#          0       0         0   0.00%   32077916.74676  1259817313.091    97.45%     1261    420      0     57292   291.1s
#  C       0       0         0   0.00%   32078095.61858  1185316248.753    97.29%     1300    454      0     59135   303.8s
#          0       0         0   0.00%   32078260.95747  1185316248.753    97.29%     1336    473      0     74909   357.8s
#          0       0         0   0.00%   32078329.27315  1185316248.753    97.29%     2331    485      0    103843   466.0s
#          0       0         0   0.00%   32078396.28747  1185316248.753    97.29%     3339    503      0    108383   487.5s
#          0       0         0   0.00%   32078436.65494  1185316248.753    97.29%     3565    519      0    134834   587.3s
#          0       0         0   0.00%   32078473.12094  1185316248.753    97.29%     4570    529      0    187469   729.6s
#          0       0         0   0.00%   32078503.93373  1185316248.753    97.29%     5586    547      0    190547   742.2s
#          0       0         0   0.00%   32078517.75424  1185316248.753    97.29%     5813    554      0    190674   749.9s
#          0       0         0   0.00%   32078527.17182  1185316248.753    97.29%     5843    563      0    191451   758.9s
#          0       0         0   0.00%   32078527.17182  1185316248.753    97.29%     5871    568      0    191840   767.0s
#          0       0         0   0.00%   32078576.40482  1185316248.753    97.29%     5954    463      0    192002   780.4s
#          0       0         0   0.00%   32078576.40482  1185316248.753    97.29%     6082    469      0    194469   795.0s
#          0       0         0   0.00%   32078576.40482  1185316248.753    97.29%     6181    476      0    195070   808.4s
#          0       0         0   0.00%   32078576.40482  1185316248.753    97.29%     6204    481      0    195650   818.9s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   32078576.76256  1185316248.753    97.29%     6282    487      0    196304   835.3s
#  L       0       0         0   0.00%   32078576.76256  32079323.6758      0.00%     6282    487      0    196304  1085.0s
#          1       0         1 100.00%   32078576.76256  32079323.6758      0.00%     6282    487      0    254815  1085.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      32079323.6758
#   Dual bound        32078576.7626
#   Gap               0.00233% (tolerance: 0.5%)
#   P-D integral      993.224928387
#   Solution status   feasible
#                     32079323.6758 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            1085.15
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     254815
#                     0 (strong br.)
#                     150982 (separation)
#                     58511 (heuristics)
# [P100] Scenario does not pass: shortfall 5.00; current fleet gap 2
#
# [P100] Running scenario p100_future_total_2_MB_EV_10_2 with allocation {'MB_EV_10': 2, 'MB_EV_18': 0}
#     ✓ prepare_model_data started | flights=7,133   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.03s]
#     ✓ ambulift intervals built | flights=7,133 ambulifts=14   [0.69s]
#     ✓ minibus intervals built | minibuses=5   [0.06s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=4,914,689   [0.91s]
#     ✓ minibus overlaps built | overlaps=728,540   [0.14s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.87s   [0.00s]
#     ✓ sets built | F=7,133 AMB=14 MINI=5   [0.00s]
#     ✓ variables built | x=35,665 amb=299,586 mini=71,330   [0.23s]
#     ✓ ambulift overlap constraints built | 4,914,689   [39.79s]
#     ✓ minibus overlap constraints built | 728,540   [3.90s]
#     ✓ build_pyomo_model complete | total=44.86s   [0.94s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,133 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 6199897 rows; 456533 cols; 12844666 nonzeros; 406602 integer variables (406602 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 940299 rows, 168977 cols, 1982918 nonzeros 6s
# 338337 rows, 145188 cols, 1257070 nonzeros 30s
# 338337 rows, 145188 cols, 1257070 nonzeros 58s
# Presolve reductions: rows 338337(-5861560); columns 145188(-311345); nonzeros 1257070(-11587596)
#
# Solving MIP model with:
#    338337 rows
#    145188 cols (130392 binary, 0 integer, 14796 implied int., 0 continuous, 0 domain fixed)
#    1257070 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3054902681.936     Large        0      0      0         0    69.8s
#  R       0       0         0   0.00%   32076525.51421  1368568059.091    97.66%        0      0      0     44115   224.3s
#          0       0         0   0.00%   32077000.17532  1368568059.091    97.66%      867    197      0     54031   266.9s
#          0       0         0   0.00%   32078610.41511  1368568059.091    97.66%     1380    362      0     68606   317.1s
#          0       0         0   0.00%   32079473.917    1368568059.091    97.66%     1773    486      0     84737   369.3s
#          0       0         0   0.00%   32079688.30788  1368568059.091    97.66%     2283    529      0     86852   382.5s
#  C       0       0         0   0.00%   32079879.70345  1224317588.753    97.38%     2327    556      0     95956   417.1s
#          0       0         0   0.00%   32079933.0845   1224317588.753    97.38%     2518    571      0    117122   493.4s
#          0       0         0   0.00%   32080068.98508  1224317588.753    97.38%     3322    592      0    119601   506.9s
#          0       0         0   0.00%   32080089.25935  1224317588.753    97.38%     3346    601      0    150897   636.0s
#          0       0         0   0.00%   32080120.20935  1224317588.753    97.38%     4050    615      0    162411   695.5s
#          0       0         0   0.00%   32080147.62819  1224317588.753    97.38%     4254    628      0    212770   886.9s
#          0       0         0   0.00%   32080154.12819  1224317588.753    97.38%     5259    648      0    226107   946.2s
#          0       0         0   0.00%   32080159.14005  1224317588.753    97.38%     5549    655      0    240875  1013.1s
#          0       0         0   0.00%   32080187.64005  1224317588.753    97.38%     5957    661      0    242994  1037.1s
#          0       0         0   0.00%   32080187.75989  1224317588.753    97.38%     5960    664      0    271614  1167.7s
#          0       0         0   0.00%   32080187.81662  1224317588.753    97.38%     6473    510      0    302439  1298.2s
#          0       0         0   0.00%   32080187.81662  1224317588.753    97.38%     6601    519      0    308841  1335.1s
#          0       0         0   0.00%   32080188.07029  1224317588.753    97.38%     6676    522      0    350444  1517.0s
#          0       0         0   0.00%   32080188.07029  1224317588.753    97.38%     7677    526      0    355682  1550.8s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   32080188.07029  1224317588.753    97.38%     7734    530      0    356863  1568.4s
#  L       0       0         0   0.00%   32080188.07029  32081527.09132     0.00%     7734    530      0    356863  1814.9s
#          1       0         1 100.00%   32080188.07029  32081527.09132     0.00%     7734    530      0    442298  1815.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      32081527.0913
#   Dual bound        32080188.0703
#   Gap               0.00417% (tolerance: 0.5%)
#   P-D integral      1703.18553017
#   Solution status   feasible
#                     32081527.0913 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            1815.11
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     442298
#                     0 (strong br.)
#                     312748 (separation)
#                     85435 (heuristics)
# [P100] Scenario does not pass: shortfall 5.00; current fleet gap 2
#
# [P100] Testing 3 total future minibus candidate(s)
#
# [P100] Running scenario p100_future_total_3_MB_EV_18_3 with allocation {'MB_EV_10': 0, 'MB_EV_18': 3}
#     ✓ prepare_model_data started | flights=7,133   [0.00s]
#     ✓ vehicle expansion complete | vehicles=20   [0.03s]
#     ✓ ambulift intervals built | flights=7,133 ambulifts=14   [0.69s]
#     ✓ minibus intervals built | minibuses=6   [0.06s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=4,914,689   [0.99s]
#     ✓ minibus overlaps built | overlaps=874,248   [0.18s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.98s   [0.00s]
#     ✓ sets built | F=7,133 AMB=14 MINI=6   [0.00s]
#     ✓ variables built | x=35,665 amb=299,586 mini=85,596   [0.24s]
#     ✓ ambulift overlap constraints built | 4,914,689   [47.69s]
#     ✓ minibus overlap constraints built | 874,248   [2.62s]
#     ✓ build_pyomo_model complete | total=51.56s   [1.00s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,133 Vehicles=20
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 6388404 rows; 470801 cols; 13250212 nonzeros; 420870 integer variables (420870 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 6e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 1032230 rows, 178675 cols, 2178799 nonzeros 6s
# 362640 rows, 152323 cols, 1333064 nonzeros 29s
# 362640 rows, 152323 cols, 1333064 nonzeros 57s
# Presolve reductions: rows 362640(-6025764); columns 152323(-318478); nonzeros 1333064(-11917148)
#
# Solving MIP model with:
#    362640 rows
#    152323 cols (137527 binary, 0 integer, 14796 implied int., 0 continuous, 0 domain fixed)
#    1333064 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3122085192.164     Large        0      0      0         0    69.7s
#  R       0       0         0   0.00%   32075579.94442  1384815569.753    97.68%        0      0      0     41499   180.6s
#          0       0         0   0.00%   32075694.95395  1384815569.753    97.68%      899    141      0     48953   213.0s
#          0       0         0   0.00%   32077082.53153  1384815569.753    97.68%     1213    255      0     50499   220.0s
#          0       0         0   0.00%   32077590.28089  1384815569.753    97.68%     1306    352      0     53013   232.3s
#          0       0         0   0.00%   32077787.8547   1384815569.753    97.68%     1375    410      0     55579   244.1s
#          0       0         0   0.00%   32077851.97667  1384815569.753    97.68%     1488    448   2203     60417   269.5s
#          0       0         0   0.00%   32078137.96715  1384815569.753    97.68%     1681    477   2203     62354   282.0s
#          0       0         0   0.00%   32078183.96715  1384815569.753    97.68%     2032    485   2203     62393   428.3s
#          0       0         0   0.00%   32078225.02775  1384815569.753    97.68%     2036    492   2203     62499   434.3s
#          0       0         0   0.00%   32078236.36109  1384815569.753    97.68%     2039    500   2203     65172   448.3s
#          0       0         0   0.00%   32078236.36109  1384815569.753    97.68%     2183    505   2203     66079   455.2s
#          0       0         0   0.00%   32078248.36109  1384815569.753    97.68%     2435    509   2203     66148   474.4s
#          0       0         0   0.00%   32078248.36109  1384815569.753    97.68%     2437    511   2203     70130   492.9s
#          0       0         0   0.00%   32078252.30048  1384815569.753    97.68%     2588    513   2203     75971   526.7s
#          0       0         0   0.00%   32078262.38382  1384815569.753    97.68%     2813    516   2203     78357   539.2s
#          0       0         0   0.00%   32078268.88382  1384815569.753    97.68%     2925    378   2203     80268   554.4s
#          0       0         0   0.00%   32078268.88382  1384815569.753    97.68%     3164    381   2203     81855   565.9s
#          0       0         0   0.00%   32078277.88382  1384815569.753    97.68%     3251    383   2203     81980   577.3s
#          0       0         0   0.00%   32078277.88382  1384815569.753    97.68%     3365    385   2203     82984   681.4s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   32078277.88382  1384815569.753    97.68%     3419    387   2203     86355   703.2s
#          0       0         0   0.00%   32078277.88382  1384815569.753    97.68%     3613    327   2203     86546   714.5s
#          0       0         0   0.00%   32078277.88382  1384815569.753    97.68%     3828    328   2203     88434   811.0s
#          0       0         0   0.00%   32078304.07826  1384815569.753    97.68%     4000    336   2203     92143   875.8s
#          0       0         0   0.00%   32078313.07826  1384815569.753    97.68%     4342    345   2203     93454   886.3s
# ...
#          0       0         0   0.00%   24635866.59056  1282873774.11     98.08%     3757    439   1388     84521   687.4s
#          0       0         0   0.00%   24635866.59056  1282873774.11     98.08%     3940    441   1388     84624   729.0s
#          0       0         0   0.00%   24635866.59056  1282873774.11     98.08%     4012    444   1388     84838   740.3s
#          0       0         0   0.00%   24635866.59056  1282873774.11     98.08%     4099    446   1388     84878   758.4s
#  L       0       0         0   0.00%   24635866.59056  24636076.10959     0.00%     4099    446   1388     84878  1129.7s
#          1       0         1 100.00%   24635866.59056  24636076.10959     0.00%     3656    446   1388    137509  1129.9s
#
# Solving report
#   Status            Optimal
#   Primal bound      24636076.1096
#   Dual bound        24635866.5906
#   Gap               0.00085% (tolerance: 0.5%)
#   P-D integral      1036.13465891
#   Solution status   feasible
#                     24636076.1096 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            1129.90
#   Max sub-MIP depth 4
#   Nodes             1
#   Repair LPs        0
#   LP iterations     137509
#                     0 (strong br.)
#                     49582 (separation)
#                     52631 (heuristics)
# [P90] Scenario does not pass: shortfall 1.00; current fleet gap 1
#
# [P90] Running scenario p90_future_total_1_MB_EV_10_1 with allocation {'MB_EV_10': 1, 'MB_EV_18': 0}
#     ✓ prepare_model_data started | flights=7,133   [0.00s]
#     ✓ vehicle expansion complete | vehicles=18   [0.04s]
#     ✓ ambulift intervals built | flights=7,133 ambulifts=14   [0.75s]
#     ✓ minibus intervals built | minibuses=4   [0.06s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=4,851,962   [0.93s]
#     ✓ minibus overlaps built | overlaps=582,660   [0.11s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.92s   [0.00s]
#     ✓ sets built | F=7,133 AMB=14 MINI=4   [0.00s]
#     ✓ variables built | x=35,665 amb=299,586 mini=57,064   [0.25s]
#     ✓ ambulift overlap constraints built | 4,851,962   [42.84s]
#     ✓ minibus overlap constraints built | 582,660   [3.63s]
#     ✓ build_pyomo_model complete | total=47.71s   [0.98s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,133 Vehicles=18
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 5948463 rows; 442265 cols; 12313294 nonzeros; 392334 integer variables (392334 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 1e+01]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -2
# Presolving model
# 840218 rows, 159695 cols, 1779436 nonzeros 6s
# 315619 rows, 138562 cols, 1185128 nonzeros 28s
# 315619 rows, 138562 cols, 1185128 nonzeros 60s
# Presolve reductions: rows 315619(-5632844); columns 138562(-303703); nonzeros 1185128(-11128166)
#
# Solving MIP model with:
#    315619 rows
#    138562 cols (123734 binary, 0 integer, 14828 implied int., 0 continuous, 0 domain fixed)
#    1185128 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3018682876.708     Large        0      0      0         0    74.2s
#  R       0       0         0   0.00%   24633479.45828  1292873905.525    98.09%        0      0      0     36054   173.5s
#          0       0         0   0.00%   24633762.43646  1292873905.525    98.09%      710    127      0     42779   205.6s
#          0       0         0   0.00%   24634048.20789  1292873905.525    98.09%     1014    245      0     56193   249.5s
#          0       0         0   0.00%   24634830.69082  1292873905.525    98.09%     1572    353      0     65853   283.3s
#          0       0         0   0.00%   24635082.25706  1292873905.525    98.09%     1959    426      0     66231   288.5s
#          0       0         0   0.00%   24635381.11979  1292873905.525    98.09%     1986    480   1672     66379   297.8s
#          0       0         0   0.00%   24635572.07975  1292873905.525    98.09%     2008    507   1672     67985   306.9s
#          0       0         0   0.00%   24635656.30702  1292873905.525    98.09%     2082    519   1672     68992   314.4s
#          0       0         0   0.00%   24635752.89035  1292873905.525    98.09%     2116    531   1672     70874   327.1s
#          0       0         0   0.00%   24635762.89035  1292873905.525    98.09%     2198    535   1672     71534   337.3s
#          0       0         0   0.00%   24635767.89035  1292873905.525    98.09%     2205    537   1672     74228   350.6s
#          0       0         0   0.00%   24635862.4239   1292873905.525    98.09%     2260    555   1672     84608   390.8s
#          0       0         0   0.00%   24635920.25723  1292873905.525    98.09%     2746    559   1672     84968   399.1s
#          0       0         0   0.00%   24635955.59056  1292873905.525    98.09%     2815    483   1672     85455   405.2s
#          0       0         0   0.00%   24635955.59056  1292873905.525    98.09%     2924    484   1672     85711   431.5s
#          0       0         0   0.00%   24635972.59056  1292873905.525    98.09%     2974    491   1672     85981   451.4s
#          0       0         0   0.00%   24635979.59056  1292873905.525    98.09%     3082    496   1672     91810   506.1s
#          0       0         0   0.00%   24635987.20091  1292873905.525    98.09%     3361    500   1672    108882   604.0s
#          0       0         0   0.00%   24635987.20091  1292873905.525    98.09%     4107    474   1672    109278   622.5s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   24635987.20091  1292873905.525    98.09%     4124    477   1672    109939   630.9s
#          0       0         0   0.00%   24635987.20091  1292873905.525    98.09%     4232    481   1672    110227   643.6s
#          0       0         0   0.00%   24635987.20091  1292873905.525    98.09%     4340    484   1672    110894   679.8s
#          0       0         0   0.00%   24635987.20091  1292873905.525    98.09%     4569    488   1672    117035   738.5s
#          0       0         0   0.00%   24635987.20091  1292873905.525    98.09%     4917    455   1672    117115   760.7s
#          0       0         0   0.00%   24635987.20091  1292873905.525    98.09%     5016    459   1672    120556   781.6s
#          0       0         0   0.00%   24635987.20091  1292873905.525    98.09%     5281    463   1672    121273   798.2s
#          0       0         0   0.00%   24635987.20091  1292873905.525    98.09%     5382    466   1672    122295   811.2s
#          0       0         0   0.00%   24635987.20091  1292873905.525    98.09%     5562    468   1672    122327   831.9s
#  L       0       0         0   0.00%   24635987.20091  24636780.52511     0.00%     5562    468   1672    122327  1053.2s
#          1       0         1 100.00%   24635987.20091  24636780.52511     0.00%     4835    468   1672    160257  1053.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      24636780.5251
#   Dual bound        24635987.2009
#   Gap               0.00322% (tolerance: 0.5%)
#   P-D integral      961.695414021
#   Solution status   feasible
#                     24636780.5251 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            1053.37
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     160257
#                     0 (strong br.)
#                     86273 (separation)
#                     37930 (heuristics)
# [P90] Scenario does not pass: shortfall 1.00; current fleet gap 1
#
# [P90] Testing 2 total future minibus candidate(s)
#
# [P90] Running scenario p90_future_total_2_MB_EV_18_2 with allocation {'MB_EV_10': 0, 'MB_EV_18': 2}
#     ✓ prepare_model_data started | flights=7,133   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.04s]
#     ✓ ambulift intervals built | flights=7,133 ambulifts=14   [0.73s]
#     ✓ minibus intervals built | minibuses=5   [0.07s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=4,851,962   [0.93s]
#     ✓ minibus overlaps built | overlaps=728,325   [0.15s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=1.93s   [0.00s]
#     ✓ sets built | F=7,133 AMB=14 MINI=5   [0.00s]
#     ✓ variables built | x=35,665 amb=299,586 mini=71,330   [0.25s]
#     ✓ ambulift overlap constraints built | 4,851,962   [41.03s]
#     ✓ minibus overlap constraints built | 728,325   [2.64s]
#     ✓ build_pyomo_model complete | total=45.10s   [1.17s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=7,133 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 6136927 rows; 456533 cols; 12718754 nonzeros; 406602 integer variables (406602 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -2
# Presolving model
# 932116 rows, 169393 cols, 1975251 nonzeros 7s
# 340020 rows, 145697 cols, 1261457 nonzeros 31s
# 340020 rows, 145697 cols, 1261457 nonzeros 61s
# Presolve reductions: rows 340020(-5796907); columns 145697(-310836); nonzeros 1261457(-11457297)
#
# Solving MIP model with:
#    340020 rows
#    145697 cols (130869 binary, 0 integer, 14828 implied int., 0 continuous, 0 domain fixed)
#    1261457 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2960865866.936     Large        0      0      0         0    75.5s
#  R       0       0         0   0.00%   23814031.74742  1064055771.091    97.76%        0      0      0     45451   249.4s
#          0       0         0   0.00%   23814112.58076  1064055771.091    97.76%      976     89      0     45626   257.2s
#          0       0         0   0.00%   23814323.4502   1064055771.091    97.76%     1107    168      0     47905   275.5s
#          0       0         0   0.00%   23814630.47163  1064055771.091    97.76%     1240    279      0     52210   303.4s
#  C       0       0         0   0.00%   23814968.81052  879806456.7534    97.29%     1362    320      0     56271   327.1s
#          0       0         0   0.00%   23815072.62718  879806456.7534    97.29%     1579    334      0     64302   365.9s
#          0       0         0   0.00%   23815133.36052  879806456.7534    97.29%     2090    346      0     64331   373.6s
#          0       0         0   0.00%   23815153.50486  879806456.7534    97.29%     2091    350      0     93431   519.8s
#          0       0         0   0.00%   23815170.50486  879806456.7534    97.29%     3099    354      0     93557   548.8s
#          0       0         0   0.00%   23815186.42922  879806456.7534    97.29%     3159    357      0    136055   727.3s
#          0       0         0   0.00%   23815186.42922  879806456.7534    97.29%     4173    367      0    136200   746.1s
#          0       0         0   0.00%   23815186.42922  879806456.7534    97.29%     4230    370      0    138167   775.3s
#          0       0         0   0.00%   23815186.42922  879806456.7534    97.29%     4354    373      0    139648   783.3s
#          0       0         0   0.00%   23815186.42922  879806456.7534    97.29%     4562    256      0    143973   814.1s
#          0       0         0   0.00%   23815186.42922  879806456.7534    97.29%     4810    261      0    146214   831.8s
#          0       0         0   0.00%   23815186.42922  879806456.7534    97.29%     4922    265      0    146879   846.7s
#          0       0         0   0.00%   23815186.42922  879806456.7534    97.29%     5050    268      0    148857   865.9s
#          0       0         0   0.00%   23815186.42922  879806456.7534    97.29%     5207    272      0    149484   875.0s
#          0       0         0   0.00%   23815186.42922  879806456.7534    97.29%     5307    261      0    150172   884.2s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  L       0       0         0   0.00%   23815186.42922  23815449.75342     0.00%     5307    261      0    150172  1278.6s
#          1       0         1 100.00%   23815186.42922  23815449.75342     0.00%     5307    261      0    194104  1278.7s
#
# Solving report
#   Status            Optimal
#   Primal bound      23815449.7534
#   Dual bound        23815186.4292
#   Gap               0.00111% (tolerance: 0.5%)
#   P-D integral      1174.97414619
#   Solution status   feasible
#                     23815449.7534 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            1278.74
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     194104
#                     0 (strong br.)
#                     104721 (separation)
#                     43932 (heuristics)
# [P90] Scenario passes: SLA 99.16%, shortfall 0.00, future vehicles bought 2
# [P90] Recommended scenario: p90_future_total_2_MB_EV_18_2
#     ✓ P90 fleet expansion search complete   [3991.18s]
#     ✓ Excel outputs written to outputs\prm_combined_new\monthly\2026_06_v2.xlsx   [16.07s]
#
# Completed month: 2026_06
# Workbook: outputs\prm_combined_new\monthly\2026_06_combined.xlsx
#    S1_PeakAmb  S1_PeakMini  S1_PeakDrivers  S1_PeakVehAgents  S2_PeakAmb  \
# 0          15            5              16                16           8
# 1          12            4              14                14           8
#
#    S2_PeakMini  S2_PeakDrivers  S2_PeakVehAgents  V2_arrival_sla_pct  \
# 0           17              25                25           99.109339
# 1           15              22                22           99.158588
#
#    V2_PeakAmb  V2_PeakMini
# 0           8            3
# 1           9            3

# %%
july_result = run_combined_month(
    2026,
    7,
)

pd.DataFrame(july_result["month_rows"])
# Out:
# ================================================================================
# RUNNING COMBINED MONTH: 2026_07
# ================================================================================
#
# Unmatched passenger rows after merge (missing Chocks DT): 4523
# Unique unmatched flight keys: 2750
#
# Unmatched key reasons:
# reason
# no_flight_candidate               1973
# scheduled_dt_mismatch              714
# exact_match_should_have_joined      63
# Name: count, dtype: int64
#
# Dropped 4406 passenger rows due to reasons {'scheduled_dt_mismatch', 'no_flight_candidate'}
# [1/5] Penetration + SSR mix…
#     ✓ penetration + SSR mix built   [212.02s]
# [2/5] Service times…
# [BUILD_JOBS] Dropping 36 jobs already impossible at release (beyond SLA + max late)
#
# [BUILD_JOBS] Dropping 4 arrival jobs with expired SLA window (max_late_mins=180).
#        Passenger ID Flight Number Airline Code      sla_start_time  \
# 99965      13159410           748           LS 2025-09-30 01:35:15
# 99966      13159411           748           LS 2025-09-30 01:35:15
# 99969      13159414           748           LS 2025-09-30 01:35:15
# 99970      13159415           748           LS 2025-09-30 01:35:15
#
#            Job Start Time  sla_limit           Chocks DT
# 99965 2025-09-30 04:59:07         20 2025-09-30 01:35:15
# 99966 2025-09-30 05:00:53         20 2025-09-30 01:35:15
# 99969 2025-09-30 04:59:15         20 2025-09-30 01:35:15
# 99970 2025-09-30 04:59:18         20 2025-09-30 01:35:15
#     ✓ service times built   [2.02s]
# [2b/5] Tau mode params (S25 medians)…
#     ✓ tau mode params built   [0.02s]
# [3/5] Chocks offsets…
#     ✓ chocks offsets built   [0.07s]
# [4/5] Early/late timing…
#     ✓ early/late params built   [0.06s]
# [5/5] Stand inputs…
#     ✓ stand inputs built   [0.09s]
#
# Running S1 P100
#
# Unmatched passenger rows after merge (missing Chocks DT): 767
# Unique unmatched flight keys: 399
#
# Unmatched key reasons:
# reason
# no_flight_candidate               364
# scheduled_dt_mismatch              26
# exact_match_should_have_joined      9
# Name: count, dtype: int64
#
# Dropped 750 passenger rows due to reasons {'scheduled_dt_mismatch', 'no_flight_candidate'}
# [BUILD_JOBS] Dropping 4 jobs already impossible at release (beyond SLA + max late)
#
# ================================================================================
# [DEBUG A] Future flights loaded & Pax computed
# ================================================================================
# df_flights rows: 2333
# Airlines (sample): ['FR' 'LS' 'U2' 'BA' 'RK' 'LM' 'EW' 'EC' 'AF' 'LH']
# Countries (sample): ['ITALY' 'SPAIN' 'GREAT BRITAIN' 'FRANCE' 'SWITZERLAND' 'NETHERLANDS'
#  'GERMANY' 'PORTUGAL' 'TURKEY' 'GREECE']
#
# Pax describe:
# count    2333.000000
# mean      155.550793
# std        51.086435
# min         0.000000
# 25%       138.000000
# 50%       168.000000
# 75%       185.000000
# max       397.000000
# Name: Pax, dtype: float64
#
# Top 10 rows (Airline, CountryName, Sector, dir, Pax):
#    Airline    CountryName         Sector dir    Pax
# 0       FR          ITALY  International   D  189.0
# 1       LS          SPAIN  International   D  227.0
# 2       U2  GREAT BRITAIN       Domestic   D  158.0
# 3       FR          SPAIN  International   D  178.0
# 4       LS          SPAIN  International   D  232.0
# 5       U2         FRANCE  International   D  182.0
# 6       U2    SWITZERLAND  International   D  180.0
# 7       U2         FRANCE  International   D  174.0
# 8       BA  GREAT BRITAIN       Domestic   D  168.0
# 9       RK  GREAT BRITAIN       Domestic   D  169.0
# 10      LM  GREAT BRITAIN       Domestic   D   32.0
# 11      LM  GREAT BRITAIN       Domestic   D   28.0
# 12      LM  GREAT BRITAIN       Domestic   D   22.0
# 13      FR          ITALY  International   D  189.0
# 14      U2    NETHERLANDS  International   D  182.0
#
# ================================================================================
# [DEBUG B] Penetration lookup match rate
# ================================================================================
# Penetration keys available: 117
# Flights with penetration match: 2,242 / 2,333 (96.1%)
#
# Top missing (Airline, CountryName) combos in future flights:
#    Airline     CountryName  flight_rows
# 0       DS     SWITZERLAND           16
# 3       EC           ITALY           16
# 1       EC          FRANCE           14
# 5       EC           SPAIN           14
# 2       EC         GERMANY            6
# 4       EC     NETHERLANDS            6
# 6       IB           SPAIN            6
# 8       LG      LUXEMBOURG            4
# 7       KK         AUSTRIA            2
# 10      RK           MALTA            2
# 11      RK         ROMANIA            2
# 12      U2        SLOVENIA            2
# 9       LM  IRISH REPUBLIC            1
#
# Example missing keys:
#     Airline     CountryName    Pax
# 27       EC          FRANCE  159.0
# 37       EC           ITALY  137.0
# 47       LM  IRISH REPUBLIC   70.0
# 113      EC          FRANCE  178.0
# 188      EC           ITALY  169.0
# 244      IB           SPAIN  156.0
# 272      EC         GERMANY  147.0
# 282      EC          FRANCE  186.0
# 296      EC           ITALY  140.0
# 321      EC          FRANCE  186.0
# 341      DS     SWITZERLAND  185.0
# 342      EC           SPAIN  124.0
# 389      IB           SPAIN  186.0
# 418      EC         GERMANY  147.0
# 427      EC          FRANCE  180.0
#
# ================================================================================
# [DEBUG C] Expected PRMs vs rounding
# ================================================================================
# Total expected PRMs (raw sum, BEFORE rounding): 3926.410041758661
# Total PRMs after rounding: 3988
#
# Raw PRM demand distribution (prm_raw):
# count    2333.000000
# mean        1.682988
# std         1.312938
# min         0.000000
# 25%         0.908861
# 50%         1.329605
# 75%         1.835093
# max         8.611651
# Name: _prm_raw, dtype: float64
#
# Top flights by raw PRM demand:
#      Airline               CountryName    Pax  _pen_used  _prm_raw  _prm_round
# 1015      BY                     SPAIN  187.0   0.046052  8.611651           9
# 257       VS  UNITED STATES OF AMERICA  397.0   0.021294  8.453666           8
# 1682      VS  UNITED STATES OF AMERICA  390.0   0.021294  8.304609           8
# 2259      BY                    GREECE  180.0   0.044835  8.070381           8
# 82        LS                  BULGARIA  188.0   0.042406  7.972419           8
# 2096      BY                    GREECE  176.0   0.044835  7.891039           8
# 2005      LS                  BULGARIA  175.0   0.042406  7.421135           7
# 2010      QR                     QATAR  254.0   0.028896  7.339531           7
# 1718      QR                     QATAR  254.0   0.028896  7.339531           7
# 1155      QR                     QATAR  254.0   0.028896  7.339531           7
# 1503      QR                     QATAR  254.0   0.028896  7.339531           7
# 2099      QR                     QATAR  254.0   0.028896  7.339531           7
# 2175      QR                     QATAR  254.0   0.028896  7.339531           7
# 1873      QR                     QATAR  254.0   0.028896  7.339531           7
# 1081      QR                     QATAR  254.0   0.028896  7.339531           7
# [DEBUG flight] Airline=FR | Country=ITALY | Pax=189.0 | Pen=0.00591 | Pax*Pen=1.118 | PRMs=1
# [DEBUG flight] Airline=LS | Country=SPAIN | Pax=227.0 | Pen=0.02780 | Pax*Pen=6.312 | PRMs=6
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=158.0 | Pen=0.00990 | Pax*Pen=1.564 | PRMs=2
# [DEBUG flight] Airline=FR | Country=SPAIN | Pax=178.0 | Pen=0.01043 | Pax*Pen=1.856 | PRMs=2
# [DEBUG flight] Airline=LS | Country=SPAIN | Pax=232.0 | Pen=0.02780 | Pax*Pen=6.451 | PRMs=6
# [DEBUG flight] Airline=U2 | Country=FRANCE | Pax=182.0 | Pen=0.00907 | Pax*Pen=1.651 | PRMs=2
# [DEBUG flight] Airline=U2 | Country=SWITZERLAND | Pax=180.0 | Pen=0.00752 | Pax*Pen=1.354 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=FRANCE | Pax=174.0 | Pen=0.00907 | Pax*Pen=1.578 | PRMs=2
# [DEBUG flight] Airline=BA | Country=GREAT BRITAIN | Pax=168.0 | Pen=0.01039 | Pax*Pen=1.745 | PRMs=2
# [DEBUG flight] Airline=RK | Country=GREAT BRITAIN | Pax=169.0 | Pen=0.00690 | Pax*Pen=1.166 | PRMs=1
# [DEBUG flight] Airline=LM | Country=GREAT BRITAIN | Pax=32.0 | Pen=0.02140 | Pax*Pen=0.685 | PRMs=1
# [DEBUG flight] Airline=LM | Country=GREAT BRITAIN | Pax=28.0 | Pen=0.02140 | Pax*Pen=0.599 | PRMs=1
# [DEBUG flight] Airline=LM | Country=GREAT BRITAIN | Pax=22.0 | Pen=0.02140 | Pax*Pen=0.471 | PRMs=0
# [DEBUG flight] Airline=FR | Country=ITALY | Pax=189.0 | Pen=0.00591 | Pax*Pen=1.118 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=NETHERLANDS | Pax=182.0 | Pen=0.00676 | Pax*Pen=1.230 | PRMs=1
#
# [DEBUG ingest_s26]
# Total PRM jobs (rows): 3988
# Columns: ['Passenger ID', 'Airline Code', 'Flight Number', 'A/D', 'Sector', 'CountryName', 'Stand', 'Scheduled Flight DT', 'Chocks DT', 'Minutes on Chocks', 'ScheduledDateTime_Local', 'Chocks_Est', 'Departure Gate', 'SSR Code', 'Has Own Chair', 'IsEffectiveRemote', 'PRM Flight Count', 'Concurrent Stress', 'Turnaround PRM Count', 'Turnaround Vertical Count', 'IsArrival', 'Adhoc Or Planned', 'IsAdhoc', 'Job Start Time', 'Job End Time', 'tau_amb_mins', 'tau_mini_mins', 'tau_push_mins']
# SSR Code present: True
# SSR Code distribution:
# SSR Code
# WCHR     2113
# WCHS     1623
# WCHC      232
# OTHER      20
# Name: count, dtype: int64
# [BUILD_JOBS] Dropping 1 jobs already impossible at release (beyond SLA + max late)
# Running S2 P100
#
# Running S1 P90
#
# Unmatched passenger rows after merge (missing Chocks DT): 767
# Unique unmatched flight keys: 399
#
# Unmatched key reasons:
# reason
# no_flight_candidate               364
# scheduled_dt_mismatch              26
# exact_match_should_have_joined      9
# Name: count, dtype: int64
#
# Dropped 750 passenger rows due to reasons {'scheduled_dt_mismatch', 'no_flight_candidate'}
# [BUILD_JOBS] Dropping 4 jobs already impossible at release (beyond SLA + max late)
# [BUILD_JOBS] Applying stratified percentile cap: q=0.90 | strata=['SSR Code', 'Has Own Chair', 'A/D']
# [BUILD_JOBS] Dropped 847 PRM jobs via stratified percentile cap
#
# ================================================================================
# [DEBUG A] Future flights loaded & Pax computed
# ================================================================================
# df_flights rows: 2333
# Airlines (sample): ['U2' 'FR' 'LS' 'BA' 'RK' 'LM' 'EW' 'EC' 'AF' 'LH']
# Countries (sample): ['FRANCE' 'ITALY' 'SPAIN' 'GREAT BRITAIN' 'GREECE' 'POLAND' 'SWITZERLAND'
#  'DENMARK' 'CROATIA' 'IRISH REPUBLIC']
#
# Pax describe:
# count    2333.000000
# mean      155.550793
# std        51.086435
# min         0.000000
# 25%       138.000000
# 50%       168.000000
# 75%       185.000000
# max       397.000000
# Name: Pax, dtype: float64
#
# Top 10 rows (Airline, CountryName, Sector, dir, Pax):
#    Airline    CountryName         Sector dir    Pax
# 0       U2         FRANCE  International   D  182.0
# 1       FR          ITALY  International   D  189.0
# 2       LS          SPAIN  International   D  227.0
# 3       U2          SPAIN  International   D  186.0
# 4       U2          ITALY  International   D  220.0
# 5       U2  GREAT BRITAIN       Domestic   D  158.0
# 6       FR          SPAIN  International   D  178.0
# 7       LS          SPAIN  International   D  232.0
# 8       LS         GREECE  International   D  162.0
# 9       U2         POLAND  International   D  227.0
# 10      LS          SPAIN  International   D  183.0
# 11      U2    SWITZERLAND  International   D  180.0
# 12      U2          ITALY  International   D  152.0
# 13      U2        DENMARK  International   D  169.0
# 14      LS          SPAIN  International   D  185.0
#
# ================================================================================
# [DEBUG B] Penetration lookup match rate
# ================================================================================
# Penetration keys available: 117
# Flights with penetration match: 2,242 / 2,333 (96.1%)
#
# Top missing (Airline, CountryName) combos in future flights:
#    Airline     CountryName  flight_rows
# 0       DS     SWITZERLAND           16
# 3       EC           ITALY           16
# 1       EC          FRANCE           14
# 5       EC           SPAIN           14
# 2       EC         GERMANY            6
# 4       EC     NETHERLANDS            6
# 6       IB           SPAIN            6
# 8       LG      LUXEMBOURG            4
# 7       KK         AUSTRIA            2
# 10      RK           MALTA            2
# 11      RK         ROMANIA            2
# 12      U2        SLOVENIA            2
# 9       LM  IRISH REPUBLIC            1
#
# Example missing keys:
#     Airline     CountryName    Pax
# 20       LM  IRISH REPUBLIC   70.0
# 47       EC          FRANCE  159.0
# 49       EC           ITALY  137.0
# 117      EC          FRANCE  178.0
# 188      EC           ITALY  169.0
# 244      IB           SPAIN  156.0
# 272      EC         GERMANY  147.0
# 282      EC          FRANCE  186.0
# 296      EC           ITALY  140.0
# 321      EC          FRANCE  186.0
# 341      DS     SWITZERLAND  185.0
# 342      EC           SPAIN  124.0
# 389      IB           SPAIN  186.0
# 418      EC         GERMANY  147.0
# 427      EC          FRANCE  180.0
#
# ================================================================================
# [DEBUG C] Expected PRMs vs rounding
# ================================================================================
# Total expected PRMs (raw sum, BEFORE rounding): 3926.410041758661
# Total PRMs after rounding: 3988
#
# Raw PRM demand distribution (prm_raw):
# count    2333.000000
# mean        1.682988
# std         1.312938
# min         0.000000
# 25%         0.908861
# 50%         1.329605
# 75%         1.835093
# max         8.611651
# Name: _prm_raw, dtype: float64
#
# Top flights by raw PRM demand:
#      Airline               CountryName    Pax  _pen_used  _prm_raw  _prm_round
# 1015      BY                     SPAIN  187.0   0.046052  8.611651           9
# 257       VS  UNITED STATES OF AMERICA  397.0   0.021294  8.453666           8
# 1682      VS  UNITED STATES OF AMERICA  390.0   0.021294  8.304609           8
# 2259      BY                    GREECE  180.0   0.044835  8.070381           8
# 83        LS                  BULGARIA  188.0   0.042406  7.972419           8
# 2096      BY                    GREECE  176.0   0.044835  7.891039           8
# 2005      LS                  BULGARIA  175.0   0.042406  7.421135           7
# 366       QR                     QATAR  254.0   0.028896  7.339531           7
# 1718      QR                     QATAR  254.0   0.028896  7.339531           7
# 1503      QR                     QATAR  254.0   0.028896  7.339531           7
# 2099      QR                     QATAR  254.0   0.028896  7.339531           7
# 1791      QR                     QATAR  254.0   0.028896  7.339531           7
# 2010      QR                     QATAR  254.0   0.028896  7.339531           7
# 2175      QR                     QATAR  254.0   0.028896  7.339531           7
# 1873      QR                     QATAR  254.0   0.028896  7.339531           7
# [DEBUG flight] Airline=U2 | Country=FRANCE | Pax=182.0 | Pen=0.00907 | Pax*Pen=1.651 | PRMs=2
# [DEBUG flight] Airline=FR | Country=ITALY | Pax=189.0 | Pen=0.00591 | Pax*Pen=1.118 | PRMs=1
# [DEBUG flight] Airline=LS | Country=SPAIN | Pax=227.0 | Pen=0.02780 | Pax*Pen=6.312 | PRMs=6
# [DEBUG flight] Airline=U2 | Country=SPAIN | Pax=186.0 | Pen=0.01493 | Pax*Pen=2.776 | PRMs=3
# [DEBUG flight] Airline=U2 | Country=ITALY | Pax=220.0 | Pen=0.00941 | Pax*Pen=2.071 | PRMs=2
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=158.0 | Pen=0.00990 | Pax*Pen=1.564 | PRMs=2
# [DEBUG flight] Airline=FR | Country=SPAIN | Pax=178.0 | Pen=0.01043 | Pax*Pen=1.856 | PRMs=2
# [DEBUG flight] Airline=LS | Country=SPAIN | Pax=232.0 | Pen=0.02780 | Pax*Pen=6.451 | PRMs=6
# [DEBUG flight] Airline=LS | Country=GREECE | Pax=162.0 | Pen=0.01888 | Pax*Pen=3.058 | PRMs=3
# [DEBUG flight] Airline=U2 | Country=POLAND | Pax=227.0 | Pen=0.00878 | Pax*Pen=1.993 | PRMs=2
# [DEBUG flight] Airline=LS | Country=SPAIN | Pax=183.0 | Pen=0.02780 | Pax*Pen=5.088 | PRMs=5
# [DEBUG flight] Airline=U2 | Country=SWITZERLAND | Pax=180.0 | Pen=0.00752 | Pax*Pen=1.354 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=ITALY | Pax=152.0 | Pen=0.00941 | Pax*Pen=1.431 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=DENMARK | Pax=169.0 | Pen=0.00907 | Pax*Pen=1.533 | PRMs=2
# [DEBUG flight] Airline=LS | Country=SPAIN | Pax=185.0 | Pen=0.02780 | Pax*Pen=5.144 | PRMs=5
#
# [DEBUG ingest_s26]
# Total PRM jobs (rows): 3988
# Columns: ['Passenger ID', 'Airline Code', 'Flight Number', 'A/D', 'Sector', 'CountryName', 'Stand', 'Scheduled Flight DT', 'Chocks DT', 'Minutes on Chocks', 'ScheduledDateTime_Local', 'Chocks_Est', 'Departure Gate', 'SSR Code', 'Has Own Chair', 'IsEffectiveRemote', 'PRM Flight Count', 'Concurrent Stress', 'Turnaround PRM Count', 'Turnaround Vertical Count', 'IsArrival', 'Adhoc Or Planned', 'IsAdhoc', 'Job Start Time', 'Job End Time', 'tau_amb_mins', 'tau_mini_mins', 'tau_push_mins']
# SSR Code present: True
# SSR Code distribution:
# SSR Code
# WCHR     2094
# WCHS     1633
# WCHC      240
# OTHER      21
# Name: count, dtype: int64
# [BUILD_JOBS] Dropping 1 jobs already impossible at release (beyond SLA + max late)
# [BUILD_JOBS] Applying stratified percentile cap: q=0.90 | strata=['SSR Code', 'Has Own Chair', 'A/D']
# [BUILD_JOBS] Dropped 213 PRM jobs via stratified percentile cap
# Running S2 P90
#
# Running V2 optimiser
#     ✓ S25 ingest complete (15,214 passengers)   [29.12s]
#     ✓ Passenger dataset combined (19,218 passenger rows)   [12.75s]
#     ✓ P100 built (8,303 flights)   [0.23s]
#     P100 demand summary: 19,218 PRMs across 8,303 flights
#     ✓ prepare_model_data started | flights=8,303   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.05s]
#     ✓ ambulift intervals built | flights=8,303 ambulifts=14   [1.06s]
#     ✓ minibus intervals built | minibuses=3   [0.10s]
#     ✓ staff intervals built   [0.03s]
#     ✓ ambulift overlaps built | overlaps=6,679,085   [1.35s]
#     ✓ minibus overlaps built | overlaps=606,459   [0.11s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=2.71s   [0.00s]
#     ✓ sets built | F=8,303 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=41,515 amb=348,726 mini=49,818   [1.15s]
#     ✓ ambulift overlap constraints built | 6,679,085   [39.32s]
#     ✓ minibus overlap constraints built | 606,459   [1.77s]
#     ✓ build_pyomo_model complete | total=43.40s   [1.16s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=8,303 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 7833727 rows; 498197 cols; 16118243 nonzeros; 440076 integer variables (440076 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 4e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 952084 rows, 169293 cols, 2020578 nonzeros 10s
# 342333 rows, 149267 cols, 1374900 nonzeros 45s
# 342333 rows, 149267 cols, 1374900 nonzeros 89s
# Presolve reductions: rows 342333(-7491394); columns 149267(-348930); nonzeros 1374900(-14743343)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    342333 rows
#    149267 cols (132640 binary, 0 integer, 16627 implied int., 0 continuous, 0 domain fixed)
#    1374900 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3066521737.479     Large        0      0      0         0   106.6s
#  R       0       0         0   0.00%   15309294.41711  1436215846.466    98.93%        0      0      0     48219   289.5s
#          0       0         0   0.00%   15976578.46676  1436215846.466    98.89%     1118    230      0     54754   329.8s
#          0       0         0   0.00%   15978747.74169  1436215846.466    98.89%     1502    434      0     58981   351.0s
#          0       0         0   0.00%   15980915.8308   1436215846.466    98.89%     1700    595      0     62403   367.2s
#          0       0         0   0.00%   15982092.49271  1436215846.466    98.89%     1761    682      0     63935   377.3s
#          0       0         0   0.00%   15982453.25137  1436215846.466    98.89%     1785    701   8696     71866   428.4s
#          0       0         0   0.00%   15982871.38471  1436215846.466    98.89%     2046    725   8696     75612   451.4s
#          0       0         0   0.00%   15982895.85777  1436215846.466    98.89%     2132    733   8696     86126   504.5s
#          0       0         0   0.00%   15983042.00626  1436215846.466    98.89%     2315    738   8696     86749   521.2s
#          0       0         0   0.00%   15983403.84199  1436215846.466    98.89%     2936    787   8696     97201   914.7s
#          0       0         0   0.00%   15983685.33309  1436215846.466    98.89%     3379    826   8696    108071   980.9s
#          0       0         0   0.00%   15983811.09207  1436215846.466    98.89%     3896    855   8696    109731   993.6s
#          0       0         0   0.00%   15983886.32381  1436215846.466    98.89%     3945    871   8696    112102  1014.5s
#          0       0         0   0.00%   15983886.61121  1436215846.466    98.89%     4070    877   8696    132229  1123.4s
#          0       0         0   0.00%   15983894.87125  1436215846.466    98.89%     4308    896   8696    150840  1251.9s
#          0       0         0   0.00%   15983898.53562  1436215846.466    98.89%     5191    780   8696    173777  1354.3s
#          0       0         0   0.00%   15984119.72468  1436215846.466    98.89%     5388    799   8696    204719  1471.7s
#          0       0         0   0.00%   15984130.94784  1436215846.466    98.89%     6025    814   8696    206611  1502.0s
#          0       0         0   0.00%   15984131.69648  1436215846.466    98.89%     6050    824   8696    226587  1605.5s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   15984132.01053  1436215846.466    98.89%     6474    845   8696    236387  1688.6s
#          0       0         0   0.00%   15984132.09766  1436215846.466    98.89%     6642    815   8696    261814  1806.9s
#          0       0         0   0.00%   15984132.09766  1436215846.466    98.89%     6771    831   8696    262748  1818.1s
#          0       0         0   0.00%   15984132.09766  1436215846.466    98.89%     6883    839   8696    264253  1850.2s
#          0       0         0   0.00%   15984132.09766  1436215846.466    98.89%     6937    846   8696    266558  1883.9s
#          0       0         0   0.00%   15984132.22048  1436215846.466    98.89%     7000    856   8696    275746  1945.3s
#  L       0       0         0   0.00%   15984132.22048  15984348.6347      0.00%     7000    856   8696    275746  2397.4s
#          1       0         1 100.00%   15984132.22048  15984348.6347      0.00%     7000    856   8696    346284  2397.6s
#
# Solving report
#   Status            Optimal
#   Primal bound      15984348.6347
#   Dual bound        15984132.2237
#   Gap               0.00135% (tolerance: 0.5%)
#   P-D integral      2266.67573107
#   Solution status   feasible
#                     15984348.6347 (objective)
#                     0 (bound viol.)
#                     4.4408920985e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            2397.60
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     346284
#                     0 (strong br.)
#                     227527 (separation)
#                     70538 (heuristics)
#     ✓ P100 optimisation complete   [2618.05s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   3                     3
# 2                            0                   6                     6
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      3               0                   1              0
# 2                      6               0                   3              0
# 3                      3               0                   0              0
#
# [P100] Fleet expansion triggered because: Vehicle shortfall exists
#
# [P100] Testing 1 total future minibus candidate(s)
#
# [P100] Running scenario p100_future_total_1_MB_EV_18_1 with allocation {'MB_EV_10': 0, 'MB_EV_18': 1}
#     ✓ prepare_model_data started | flights=8,303   [0.00s]
#     ✓ vehicle expansion complete | vehicles=18   [0.04s]
#     ✓ ambulift intervals built | flights=8,303 ambulifts=14   [1.11s]
#     ✓ minibus intervals built | minibuses=4   [0.09s]
#     ✓ staff intervals built   [0.03s]
#     ✓ ambulift overlaps built | overlaps=6,679,085   [1.38s]
#     ✓ minibus overlaps built | overlaps=808,612   [0.18s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=2.85s   [0.00s]
#     ✓ sets built | F=8,303 AMB=14 MINI=4   [0.01s]
#     ✓ variables built | x=41,515 amb=348,726 mini=66,424   [0.30s]
#     ✓ ambulift overlap constraints built | 6,679,085   [102.24s]
#     ✓ minibus overlap constraints built | 808,612   [3.06s]
#     ✓ build_pyomo_model complete | total=110.52s   [4.91s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=8,303 Vehicles=18
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 8085699 rows; 514805 cols; 16655399 nonzeros; 456684 integer variables (456684 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 4e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 1071539 rows, 180370 cols, 2272589 nonzeros 9s
# 370722 rows, 157572 cols, 1466088 nonzeros 46s
# 370722 rows, 157572 cols, 1466088 nonzeros 90s
# Presolve reductions: rows 370722(-7714977); columns 157572(-357233); nonzeros 1466088(-15189311)
#
# Solving MIP model with:
#    370722 rows
#    157572 cols (140945 binary, 0 integer, 16627 implied int., 0 continuous, 0 domain fixed)
#    1466088 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3095704427.708     Large        0      0      0         0   108.1s
#  R       0       0         0   0.00%   15017629.0301   2099393364.283    99.28%        0      0      0     53736   289.4s
#          0       0         0   0.00%   15018387.57177  2099393364.283    99.28%      852    258      0     55218   310.7s
#          0       0         0   0.00%   15148904.17274  2099393364.283    99.28%     1201    486      0     63737   346.2s
#          0       0         0   0.00%   15149319.79219  2099393364.283    99.28%     1656    563      0     64552   355.5s
#          0       0         0   0.00%   15149667.40186  2099393364.283    99.28%     1691    608      0     65862   366.4s
#  C       0       0         0   0.00%   15149927.57805  1468894764.699    98.97%     1749    641      0     67910   383.0s
#          0       0         0   0.00%   15149975.24471  1468894764.699    98.97%     1899    647      0     68120   445.7s
#          0       0         0   0.00%   15149975.24471  1468894764.699    98.97%     1968    648      0     69005   510.8s
#          0       0         0   0.00%   15150053.56217  1468894764.699    98.97%     2160    667      0     69556   564.3s
#          0       0         0   0.00%   15150100.61773  1468894764.699    98.97%     2183    676      0     71087   574.5s
#          0       0         0   0.00%   15150111.2844   1468894764.699    98.97%     2193    683      0     71962   583.1s
#          0       0         0   0.00%   15150124.57011  1468894764.699    98.97%     2313    688      0     72095   597.4s
#          0       0         0   0.00%   15150130.85582  1468894764.699    98.97%     2396    693      0     72177   612.6s
#  L       0       0         0   0.00%   15150130.85582  15151636.86301     0.01%     2396    693      0     72177   998.5s
#          1       0         1 100.00%   15150130.85582  15151636.86301     0.01%     2396    693      0    155815   998.7s
#
# Solving report
#   Status            Optimal
#   Primal bound      15151636.863
#   Dual bound        15150130.8558
#   Gap               0.00994% (tolerance: 0.5%)
#   P-D integral      882.496442572
#   Solution status   feasible
#                     15151636.863 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            998.69
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     155815
#                     0 (strong br.)
#                     18441 (separation)
#                     83638 (heuristics)
# [P100] Scenario passes: SLA 99.50%, shortfall 0.00, future vehicles bought 1
# [P100] Recommended scenario: p100_future_total_1_MB_EV_18_1
#     ✓ P100 fleet expansion search complete   [1284.81s]
#     ✓ P90 built (8,303 flights)   [0.63s]
#     P90 demand summary: 17,968 PRMs across 8,303 flights
#     ✓ prepare_model_data started | flights=8,303   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.04s]
#     ✓ ambulift intervals built | flights=8,303 ambulifts=14   [0.84s]
#     ✓ minibus intervals built | minibuses=3   [0.08s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=6,579,900   [1.26s]
#     ✓ minibus overlaps built | overlaps=606,549   [0.12s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=2.38s   [0.00s]
#     ✓ sets built | F=8,303 AMB=14 MINI=3   [0.01s]
#     ✓ variables built | x=41,515 amb=348,726 mini=49,818   [0.24s]
#     ✓ ambulift overlap constraints built | 6,579,900   [80.13s]
#     ✓ minibus overlap constraints built | 606,549   [5.28s]
#     ✓ build_pyomo_model complete | total=86.97s   [1.30s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=8,303 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 7734540 rows; 498197 cols; 15919961 nonzeros; 440076 integer variables (440076 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 1e+01]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -1
# Presolving model
# 935997 rows, 170573 cols, 2007805 nonzeros 9s
# 345705 rows, 150547 cols, 1379729 nonzeros 45s
# 345705 rows, 150547 cols, 1379729 nonzeros 88s
# Presolve reductions: rows 345705(-7388835); columns 150547(-347650); nonzeros 1379729(-14540232)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    345705 rows
#    150547 cols (133840 binary, 0 integer, 16707 implied int., 0 continuous, 0 domain fixed)
#    1379729 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3028468804.479     Large        0      0      0         0   104.2s
#  R       0       0         0   0.00%   8113745.856458  1127687745.466    99.28%        0      0      0     73394   361.7s
#          0       0         0   0.00%   8947102.618363  1127687745.466    99.21%      553    106      0     75989   384.7s
#          0       0         0   0.00%   8947236.748233  1127687745.466    99.21%      667    199      0     77149   395.9s
#          0       0         0   0.00%   8948134.832649  1127687745.466    99.21%      746    275      0     84419   437.6s
#          0       0         0   0.00%   8948237.999315  1127687745.466    99.21%      920    280      0     86874   457.4s
#          0       0         0   0.00%   8948237.999315  1127687745.466    99.21%      937    282   3713     88950   486.1s
#          0       0         0   0.00%   8948237.999315  1127687745.466    99.21%      947    284   3713     90437   509.3s
#          0       0         0   0.00%   8948237.999315  1127687745.466    99.21%     1163    286   3713     92496   716.8s
#          0       0         0   0.00%   8949213.593138  1127687745.466    99.21%     1494    375   3713    147009  1174.5s
#          0       0         0   0.00%   8949595.199478  1127687745.466    99.21%     2495    428   3713    213649  1460.9s
#          0       0         0   0.00%   8949634.866145  1127687745.466    99.21%     3526    455   3713    216737  1496.3s
#          0       0         0   0.00%   8949737.275236  1127687745.466    99.21%     3641    464   3713    219072  1518.2s
#          0       0         0   0.00%   8949742.652781  1127687745.466    99.21%     3706    470   3713    258075  1716.3s
#          0       0         0   0.00%   8949750.452781  1127687745.466    99.21%     4779    474   3713    258624  1751.9s
#          0       0         0   0.00%   8949766.452781  1127687745.466    99.21%     4857    479   3713    260246  1770.1s
#          0       0         0   0.00%   8949769.583043  1127687745.466    99.21%     5104    472   3713    313678  2029.0s
#          0       0         0   0.00%   8949769.583043  1127687745.466    99.21%     5509    484   3713    317859  2058.8s
#          0       0         0   0.00%   8949775.083043  1127687745.466    99.21%     5563    491   3713    319581  2079.4s
#          0       0         0   0.00%   8949780.1881    1127687745.466    99.21%     5681    496   3713    360329  2316.9s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   8949780.190156  1127687745.466    99.21%     6684    500   3713    363420  2341.4s
#          0       0         0   0.00%   8949780.190156  1127687745.466    99.21%     6902    394   3713    367068  2370.6s
#          0       0         0   0.00%   8949780.190156  1127687745.466    99.21%     7011    398   3713    369038  2389.7s
#          0       0         0   0.00%   8949780.190156  1127687745.466    99.21%     7233    401   3713    371101  2412.1s
#          0       0         0   0.00%   8949780.190156  1127687745.466    99.21%     7457    405   3713    373547  2436.5s
#  L       0       0         0   0.00%   8949780.190156  8949832.634703     0.00%     7457    405   3713    373547  2978.1s
#          1       0         1 100.00%   8949780.190156  8949832.634703     0.00%     7457    405   3713    453428  2978.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      8949832.6347
#   Dual bound        8949780.19178
#   Gap               0.000586% (tolerance: 0.5%)
#   P-D integral      2852.4711129
#   Solution status   feasible
#                     8949832.6347 (objective)
#                     0 (bound viol.)
#                     2.22044604925e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            2978.29
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     453428
#                     0 (strong br.)
#                     300153 (separation)
#                     79881 (heuristics)
#     ✓ P90 optimisation complete   [3237.88s]
#
# [P90 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   3                     3
# 2                            0                   6                     6
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      3               0                   1              0
# 2                      6               0                   3              0
# 3                      3               0                   0              0
#
# [P90] Fleet expansion triggered because: Vehicle shortfall exists
#
# [P90] Testing 1 total future minibus candidate(s)
#
# [P90] Running scenario p90_future_total_1_MB_EV_18_1 with allocation {'MB_EV_10': 0, 'MB_EV_18': 1}
#     ✓ prepare_model_data started | flights=8,303   [0.00s]
#     ✓ vehicle expansion complete | vehicles=18   [0.04s]
#     ✓ ambulift intervals built | flights=8,303 ambulifts=14   [0.85s]
#     ✓ minibus intervals built | minibuses=4   [0.08s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=6,579,900   [1.29s]
#     ✓ minibus overlaps built | overlaps=808,732   [0.17s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=2.46s   [0.00s]
#     ✓ sets built | F=8,303 AMB=14 MINI=4   [0.01s]
#     ✓ variables built | x=41,515 amb=348,726 mini=66,424   [0.30s]
#     ✓ ambulift overlap constraints built | 6,579,900   [85.55s]
#     ✓ minibus overlap constraints built | 808,732   [5.40s]
#     ✓ build_pyomo_model complete | total=92.62s   [1.37s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=8,303 Vehicles=18
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 7986542 rows; 514805 cols; 16457177 nonzeros; 456684 integer variables (456684 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -1
# Presolving model
# 1055499 rows, 181650 cols, 2259910 nonzeros 10s
# 374162 rows, 158852 cols, 1471658 nonzeros 48s
# 374162 rows, 158852 cols, 1471658 nonzeros 95s
# Presolve reductions: rows 374162(-7612380); columns 158852(-355953); nonzeros 1471658(-14985519)
#
# Solving MIP model with:
#    374162 rows
#    158852 cols (142145 binary, 0 integer, 16707 implied int., 0 continuous, 0 domain fixed)
#    1471658 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            3091468514.479     Large        0      0      0         0   112.4s
#  R       0       0         0   0.00%   7972454.457169  1230619894.621    99.35%        0      0      0     93258   444.7s
#          0       0         0   0.00%   7972517.887441  1230619894.621    99.35%      644    115      0     94932   464.2s
#          0       0         0   0.00%   7972730.378598  1230619894.621    99.35%      813    224      0     96603   476.2s
#          0       0         0   0.00%   8007281.144308  1230619894.621    99.35%      884    307      0    100469   503.3s
#          0       0         0   0.00%   8007379.775137  1230619894.621    99.35%      907    320      0    163827   768.4s
#          0       0         0   0.00%   8126235.271789  1230619894.621    99.34%     1908    338   2312    170914   807.2s
#          0       0         0   0.00%   8126270.771789  1230619894.621    99.34%     1969    357   2312    173646   822.1s
#          0       0         0   0.00%   8126270.771789  1230619894.621    99.34%     1990    362   2312    174344   829.8s
#          0       0         0   0.00%   8126270.771789  1230619894.621    99.34%     2006    368   2312    178936   869.7s
#          0       0         0   0.00%   8126270.771789  1230619894.621    99.34%     2084    372   2312    181297   908.5s
#          0       0         0   0.00%   8126270.771789  1230619894.621    99.34%     2226    376   2312    192230   994.0s
#          0       0         0   0.00%   8126270.771789  1230619894.621    99.34%     2599    382   2312    195249  1047.2s
#          0       0         0   0.00%   8126270.771789  1230619894.621    99.34%     2776    386   2312    195948  1099.0s
#          0       0         0   0.00%   8126270.771789  1230619894.621    99.34%     2873    389   2312    197587  1150.4s
#          0       0         0   0.00%   8126270.771789  1230619894.621    99.34%     2957    351   2312    198227  1190.5s
#          0       0         0   0.00%   8126270.771789  1230619894.621    99.34%     3059    355   2312    200537  1223.0s
#  L       0       0         0   0.00%   8126270.771789  8126566.863014     0.00%     3059    355   2312    200537  1642.9s
#          1       0         1 100.00%   8126270.771789  8126566.863014     0.00%     3059    355   2312    293063  1643.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      8126566.86301
#   Dual bound        8126270.77179
#   Gap               0.00364% (tolerance: 0.5%)
#   P-D integral      1521.99321408
#   Solution status   feasible
#                     8126566.86301 (objective)
#                     0 (bound viol.)
#                     3.77475828373e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            1643.10
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     293063
#                     0 (strong br.)
#                     107279 (separation)
#                     92526 (heuristics)
# [P90] Scenario passes: SLA 99.72%, shortfall 0.00, future vehicles bought 1
# [P90] Recommended scenario: p90_future_total_1_MB_EV_18_1
#     ✓ P90 fleet expansion search complete   [1911.11s]
#     ✓ Excel outputs written to outputs\prm_combined_new\monthly\2026_07_v2.xlsx   [20.41s]
#
# Completed month: 2026_07
# Workbook: outputs\prm_combined_new\monthly\2026_07_combined.xlsx
#    S1_PeakAmb  S1_PeakMini  S1_PeakDrivers  S1_PeakVehAgents  S2_PeakAmb  \
# 0          13            5              14                14          11
# 1          11            3              13                13          10
#
#    S2_PeakMini  S2_PeakDrivers  S2_PeakVehAgents  V2_arrival_sla_pct  \
# 0           15              21                21           99.502743
# 1           14              20                20           99.721448
#
#    V2_PeakAmb  V2_PeakMini
# 0          10            3
# 1          10            3

# %%
august_result = run_combined_month(
    2026,
    8,
)

pd.DataFrame(august_result["month_rows"])
# Out:
# ================================================================================
# RUNNING COMBINED MONTH: 2026_08
# ================================================================================
#
# Running S1 P100
#
# ================================================================================
# [DEBUG A] Future flights loaded & Pax computed
# ================================================================================
# df_flights rows: 11882
# Airlines (sample): ['AF' 'U2' 'FR' 'RK' 'LS' 'BA' 'LM' 'QR' 'EC' 'EI']
# Countries (sample): ['FRANCE' 'ITALY' 'MALTA' 'SPAIN' 'GREAT BRITAIN' 'IRISH REPUBLIC' 'QATAR'
#  'NETHERLANDS' 'CZECH REPUBLIC' 'SWITZERLAND']
#
# Pax describe:
# count    11882.000000
# mean       153.121444
# std         51.562349
# min          0.000000
# 25%        134.000000
# 50%        166.000000
# 75%        183.000000
# max        397.000000
# Name: Pax, dtype: float64
#
# Top 10 rows (Airline, CountryName, Sector, dir, Pax):
#    Airline     CountryName         Sector dir    Pax
# 0       AF          FRANCE  International   D   99.0
# 1       U2          FRANCE  International   D  212.0
# 2       FR           ITALY  International   D  184.0
# 3       RK           MALTA  International   D  165.0
# 4       LS           SPAIN  International   D  186.0
# 5       BA           SPAIN  International   D  106.0
# 6       FR           SPAIN  International   D  183.0
# 7       U2   GREAT BRITAIN       Domestic   D  209.0
# 8       U2   GREAT BRITAIN       Domestic   D  173.0
# 9       FR  IRISH REPUBLIC            CTA   D  194.0
# 10      LM   GREAT BRITAIN       Domestic   D   28.0
# 11      LS           ITALY  International   D  175.0
# 12      LS           ITALY  International   D  214.0
# 13      LM   GREAT BRITAIN       Domestic   D   17.0
# 14      QR           QATAR  International   D  254.0
#
# ================================================================================
# [DEBUG B] Penetration lookup match rate
# ================================================================================
# Penetration keys available: 117
# Flights with penetration match: 11,367 / 11,882 (95.7%)
#
# Top missing (Airline, CountryName) combos in future flights:
#    Airline     CountryName  flight_rows
# 4       EC           ITALY          116
# 1       DS     SWITZERLAND           80
# 6       EC           SPAIN           80
# 2       EC          FRANCE           66
# 5       EC     NETHERLANDS           38
# 3       EC         GERMANY           36
# 7       IB           SPAIN           26
# 9       RK           MALTA           18
# 8       LG      LUXEMBOURG           18
# 11      U2        SLOVENIA           18
# 0       BA           ITALY           10
# 10      RK         ROMANIA            8
# 12      ZT  IRISH REPUBLIC            1
#
# Example missing keys:
#     Airline  CountryName    Pax
# 3        RK        MALTA  165.0
# 15       EC  NETHERLANDS  143.0
# 74       EC      GERMANY  140.0
# 76       U2     SLOVENIA  154.0
# 89       EC        ITALY  139.0
# 93       BA        ITALY   68.0
# 127      EC        SPAIN  152.0
# 128      DS  SWITZERLAND  181.0
# 131      EC        SPAIN  143.0
# 205      EC      GERMANY  151.0
# 213      EC       FRANCE  111.0
# 224      EC        ITALY  140.0
# 362      EC        ITALY  125.0
# 394      EC       FRANCE  138.0
# 404      EC  NETHERLANDS  156.0
#
# ================================================================================
# [DEBUG C] Expected PRMs vs rounding
# ================================================================================
# Total expected PRMs (raw sum, BEFORE rounding): 19611.4586372338
# Total PRMs after rounding: 19917
#
# Raw PRM demand distribution (prm_raw):
# count    11882.000000
# mean         1.650518
# std          1.285401
# min          0.000000
# 25%          0.884971
# 50%          1.326352
# 75%          1.803813
# max          8.473497
# Name: _prm_raw, dtype: float64
#
# Top flights by raw PRM demand:
#       Airline               CountryName    Pax  _pen_used  _prm_raw  \
# 10548      BY                     SPAIN  184.0   0.046052  8.473497
# 8395       VS  UNITED STATES OF AMERICA  397.0   0.021294  8.453666
# 7016       VS  UNITED STATES OF AMERICA  397.0   0.021294  8.453666
# 9759       VS  UNITED STATES OF AMERICA  397.0   0.021294  8.453666
# 10564      VS  UNITED STATES OF AMERICA  386.0   0.021294  8.219433
# 7434       VS  UNITED STATES OF AMERICA  385.0   0.021294  8.198139
# 3944       BY                    GREECE  182.0   0.044835  8.160052
# 4705       BY                     SPAIN  177.0   0.046052  8.151135
# 2606       BY                    GREECE  178.0   0.044835  7.980710
# 10428      BY                    GREECE  177.0   0.044835  7.935874
# 8568       BY                    GREECE  176.0   0.044835  7.891039
# 1451       VS  UNITED STATES OF AMERICA  369.0   0.021294  7.857437
# 4983       LS                  BULGARIA  185.0   0.042406  7.845200
# 6883       BY                     SPAIN  169.0   0.046052  7.782722
# 10039      BY                    GREECE  173.0   0.044835  7.756533
#
#        _prm_round
# 10548           8
# 8395            8
# 7016            8
# 9759            8
# 10564           8
# 7434            8
# 3944            8
# 4705            8
# 2606            8
# 10428           8
# 8568            8
# 1451            8
# 4983            8
# 6883            8
# 10039           8
# [DEBUG flight] Airline=AF | Country=FRANCE | Pax=99.0 | Pen=0.00815 | Pax*Pen=0.807 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=FRANCE | Pax=212.0 | Pen=0.00907 | Pax*Pen=1.923 | PRMs=2
# [DEBUG flight] Airline=FR | Country=ITALY | Pax=184.0 | Pen=0.00591 | Pax*Pen=1.088 | PRMs=1
# [DEBUG flight] Airline=RK | Country=MALTA | Pax=165.0 | Pen=0.01000 | Pax*Pen=1.650 | PRMs=2
# [DEBUG flight] Airline=LS | Country=SPAIN | Pax=186.0 | Pen=0.02780 | Pax*Pen=5.172 | PRMs=5
# [DEBUG flight] Airline=BA | Country=SPAIN | Pax=106.0 | Pen=0.01648 | Pax*Pen=1.747 | PRMs=2
# [DEBUG flight] Airline=FR | Country=SPAIN | Pax=183.0 | Pen=0.01043 | Pax*Pen=1.908 | PRMs=2
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=209.0 | Pen=0.00990 | Pax*Pen=2.069 | PRMs=2
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=173.0 | Pen=0.00990 | Pax*Pen=1.712 | PRMs=2
# [DEBUG flight] Airline=FR | Country=IRISH REPUBLIC | Pax=194.0 | Pen=0.00705 | Pax*Pen=1.368 | PRMs=1
# [DEBUG flight] Airline=LM | Country=GREAT BRITAIN | Pax=28.0 | Pen=0.02140 | Pax*Pen=0.599 | PRMs=1
# [DEBUG flight] Airline=LS | Country=ITALY | Pax=175.0 | Pen=0.01540 | Pax*Pen=2.695 | PRMs=3
# [DEBUG flight] Airline=LS | Country=ITALY | Pax=214.0 | Pen=0.01540 | Pax*Pen=3.295 | PRMs=3
# [DEBUG flight] Airline=LM | Country=GREAT BRITAIN | Pax=17.0 | Pen=0.02140 | Pax*Pen=0.364 | PRMs=0
# [DEBUG flight] Airline=QR | Country=QATAR | Pax=254.0 | Pen=0.02890 | Pax*Pen=7.340 | PRMs=7
#
# [DEBUG ingest_s26]
# Total PRM jobs (rows): 19917
# Columns: ['Passenger ID', 'Airline Code', 'Flight Number', 'A/D', 'Sector', 'CountryName', 'Stand', 'Scheduled Flight DT', 'Chocks DT', 'Minutes on Chocks', 'ScheduledDateTime_Local', 'Chocks_Est', 'Departure Gate', 'SSR Code', 'Has Own Chair', 'IsEffectiveRemote', 'PRM Flight Count', 'Concurrent Stress', 'Turnaround PRM Count', 'Turnaround Vertical Count', 'IsArrival', 'Adhoc Or Planned', 'IsAdhoc', 'Job Start Time', 'Job End Time', 'tau_amb_mins', 'tau_mini_mins', 'tau_push_mins']
# SSR Code present: True
# SSR Code distribution:
# SSR Code
# WCHR     10502
# WCHS      8176
# WCHC      1128
# OTHER      111
# Name: count, dtype: int64
# [BUILD_JOBS] Dropping 5 jobs already impossible at release (beyond SLA + max late)
# Running S2 P100
#
# Running S1 P90
#
# ================================================================================
# [DEBUG A] Future flights loaded & Pax computed
# ================================================================================
# df_flights rows: 11882
# Airlines (sample): ['AF' 'U2' 'FR' 'KL' 'BA' 'LS' 'LH' 'RK' 'LM' 'QR']
# Countries (sample): ['FRANCE' 'SLOVAKIA' 'NETHERLANDS' 'SPAIN' 'GREAT BRITAIN' 'POLAND'
#  'SWITZERLAND' 'GERMANY' 'CROATIA' 'ITALY']
#
# Pax describe:
# count    11882.000000
# mean       153.121444
# std         51.562349
# min          0.000000
# 25%        134.000000
# 50%        166.000000
# 75%        183.000000
# max        397.000000
# Name: Pax, dtype: float64
#
# Top 10 rows (Airline, CountryName, Sector, dir, Pax):
#    Airline    CountryName         Sector dir    Pax
# 0       AF         FRANCE  International   D   99.0
# 1       U2         FRANCE  International   D  212.0
# 2       FR       SLOVAKIA  International   D  193.0
# 3       KL    NETHERLANDS  International   D  145.0
# 4       FR          SPAIN  International   D  188.0
# 5       BA  GREAT BRITAIN       Domestic   D  140.0
# 6       U2  GREAT BRITAIN       Domestic   D  125.0
# 7       U2          SPAIN  International   D  181.0
# 8       FR         POLAND  International   D  184.0
# 9       LS          SPAIN  International   D  221.0
# 10      U2    SWITZERLAND  International   D  176.0
# 11      LH        GERMANY  International   D  137.0
# 12      U2        CROATIA  International   D  174.0
# 13      FR          ITALY  International   D  184.0
# 14      FR        ROMANIA  International   D  196.0
#
# ================================================================================
# [DEBUG B] Penetration lookup match rate
# ================================================================================
# Penetration keys available: 117
# Flights with penetration match: 11,367 / 11,882 (95.7%)
#
# Top missing (Airline, CountryName) combos in future flights:
#    Airline     CountryName  flight_rows
# 4       EC           ITALY          116
# 1       DS     SWITZERLAND           80
# 6       EC           SPAIN           80
# 2       EC          FRANCE           66
# 5       EC     NETHERLANDS           38
# 3       EC         GERMANY           36
# 7       IB           SPAIN           26
# 9       RK           MALTA           18
# 8       LG      LUXEMBOURG           18
# 11      U2        SLOVENIA           18
# 0       BA           ITALY           10
# 10      RK         ROMANIA            8
# 12      ZT  IRISH REPUBLIC            1
#
# Example missing keys:
#     Airline  CountryName    Pax
# 20       RK        MALTA  165.0
# 36       EC  NETHERLANDS  143.0
# 101      EC      GERMANY  140.0
# 103      U2     SLOVENIA  154.0
# 116      EC        ITALY  139.0
# 121      BA        ITALY   68.0
# 156      EC        SPAIN  152.0
# 157      DS  SWITZERLAND  181.0
# 160      EC        SPAIN  143.0
# 228      EC        ITALY  170.0
# 231      IB        SPAIN  173.0
# 262      EC      GERMANY  151.0
# 275      EC       FRANCE  111.0
# 292      EC        ITALY  140.0
# 319      EC       FRANCE  155.0
#
# ================================================================================
# [DEBUG C] Expected PRMs vs rounding
# ================================================================================
# Total expected PRMs (raw sum, BEFORE rounding): 19611.4586372338
# Total PRMs after rounding: 19917
#
# Raw PRM demand distribution (prm_raw):
# count    11882.000000
# mean         1.650518
# std          1.285401
# min          0.000000
# 25%          0.884971
# 50%          1.326352
# 75%          1.803813
# max          8.473497
# Name: _prm_raw, dtype: float64
#
# Top flights by raw PRM demand:
#       Airline               CountryName    Pax  _pen_used  _prm_raw  \
# 10548      BY                     SPAIN  184.0   0.046052  8.473497
# 6370       VS  UNITED STATES OF AMERICA  397.0   0.021294  8.453666
# 9759       VS  UNITED STATES OF AMERICA  397.0   0.021294  8.453666
# 8395       VS  UNITED STATES OF AMERICA  397.0   0.021294  8.453666
# 10564      VS  UNITED STATES OF AMERICA  386.0   0.021294  8.219433
# 7434       VS  UNITED STATES OF AMERICA  385.0   0.021294  8.198139
# 3944       BY                    GREECE  182.0   0.044835  8.160052
# 4705       BY                     SPAIN  177.0   0.046052  8.151135
# 2606       BY                    GREECE  178.0   0.044835  7.980710
# 10428      BY                    GREECE  177.0   0.044835  7.935874
# 8568       BY                    GREECE  176.0   0.044835  7.891039
# 1451       VS  UNITED STATES OF AMERICA  369.0   0.021294  7.857437
# 4983       LS                  BULGARIA  185.0   0.042406  7.845200
# 7194       BY                     SPAIN  169.0   0.046052  7.782722
# 10039      BY                    GREECE  173.0   0.044835  7.756533
#
#        _prm_round
# 10548           8
# 6370            8
# 9759            8
# 8395            8
# 10564           8
# 7434            8
# 3944            8
# 4705            8
# 2606            8
# 10428           8
# 8568            8
# 1451            8
# 4983            8
# 7194            8
# 10039           8
# [DEBUG flight] Airline=AF | Country=FRANCE | Pax=99.0 | Pen=0.00815 | Pax*Pen=0.807 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=FRANCE | Pax=212.0 | Pen=0.00907 | Pax*Pen=1.923 | PRMs=2
# [DEBUG flight] Airline=FR | Country=SLOVAKIA | Pax=193.0 | Pen=0.00245 | Pax*Pen=0.472 | PRMs=0
# [DEBUG flight] Airline=KL | Country=NETHERLANDS | Pax=145.0 | Pen=0.00898 | Pax*Pen=1.302 | PRMs=1
# [DEBUG flight] Airline=FR | Country=SPAIN | Pax=188.0 | Pen=0.01043 | Pax*Pen=1.960 | PRMs=2
# [DEBUG flight] Airline=BA | Country=GREAT BRITAIN | Pax=140.0 | Pen=0.01039 | Pax*Pen=1.454 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=125.0 | Pen=0.00990 | Pax*Pen=1.237 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=SPAIN | Pax=181.0 | Pen=0.01493 | Pax*Pen=2.702 | PRMs=3
# [DEBUG flight] Airline=FR | Country=POLAND | Pax=184.0 | Pen=0.00339 | Pax*Pen=0.624 | PRMs=1
# [DEBUG flight] Airline=LS | Country=SPAIN | Pax=221.0 | Pen=0.02780 | Pax*Pen=6.145 | PRMs=6
# [DEBUG flight] Airline=U2 | Country=SWITZERLAND | Pax=176.0 | Pen=0.00752 | Pax*Pen=1.324 | PRMs=1
# [DEBUG flight] Airline=LH | Country=GERMANY | Pax=137.0 | Pen=0.00614 | Pax*Pen=0.841 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=CROATIA | Pax=174.0 | Pen=0.00455 | Pax*Pen=0.792 | PRMs=1
# [DEBUG flight] Airline=FR | Country=ITALY | Pax=184.0 | Pen=0.00591 | Pax*Pen=1.088 | PRMs=1
# [DEBUG flight] Airline=FR | Country=ROMANIA | Pax=196.0 | Pen=0.00456 | Pax*Pen=0.894 | PRMs=1
#
# [DEBUG ingest_s26]
# Total PRM jobs (rows): 19917
# Columns: ['Passenger ID', 'Airline Code', 'Flight Number', 'A/D', 'Sector', 'CountryName', 'Stand', 'Scheduled Flight DT', 'Chocks DT', 'Minutes on Chocks', 'ScheduledDateTime_Local', 'Chocks_Est', 'Departure Gate', 'SSR Code', 'Has Own Chair', 'IsEffectiveRemote', 'PRM Flight Count', 'Concurrent Stress', 'Turnaround PRM Count', 'Turnaround Vertical Count', 'IsArrival', 'Adhoc Or Planned', 'IsAdhoc', 'Job Start Time', 'Job End Time', 'tau_amb_mins', 'tau_mini_mins', 'tau_push_mins']
# SSR Code present: True
# SSR Code distribution:
# SSR Code
# WCHR     10502
# WCHS      8179
# WCHC      1135
# OTHER      101
# Name: count, dtype: int64
# [BUILD_JOBS] Dropping 5 jobs already impossible at release (beyond SLA + max late)
# [BUILD_JOBS] Applying stratified percentile cap: q=0.90 | strata=['SSR Code', 'Has Own Chair', 'A/D']
# [BUILD_JOBS] Dropped 1697 PRM jobs via stratified percentile cap
# Running S2 P90
#
# Running V2 optimiser
#     ✓ Passenger dataset combined (20,002 passenger rows)   [60.96s]
#     ✓ P100 built (11,285 flights)   [0.17s]
#     P100 demand summary: 20,002 PRMs across 11,285 flights
#     ✓ prepare_model_data started | flights=11,285   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.04s]
#     ✓ ambulift intervals built | flights=11,285 ambulifts=14   [1.27s]
#     ✓ minibus intervals built | minibuses=3   [0.13s]
#     ✓ staff intervals built   [0.03s]
#     ✓ ambulift overlaps built | overlaps=11,538,765   [2.04s]
#     ✓ minibus overlaps built | overlaps=1,064,328   [0.20s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.04s]
#     ✓ prepare_model_data complete | total=3.75s   [0.00s]
#     ✓ sets built | F=11,285 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=56,425 amb=473,970 mini=67,710   [3.43s]
#     ✓ ambulift overlap constraints built | 11,538,765   [68.30s]
#     ✓ minibus overlap constraints built | 1,064,328   [9.55s]
#     ✓ build_pyomo_model complete | total=83.11s   [1.83s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=11,285 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 13347961 rows; 677117 cols; 27307406 nonzeros; 598122 integer variables (598122 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 8e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -1
# Presolving model
# 1842066 rows, 256163 cols, 3885886 nonzeros 17s
# 551686 rows, 225384 cols, 2494484 nonzeros 127s
# 551686 rows, 225384 cols, 2494484 nonzeros 252s
# Presolve reductions: rows 551686(-12796275); columns 225384(-451733); nonzeros 2494484(-24812922)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    551686 rows
#    225384 cols (201966 binary, 0 integer, 23418 implied int., 0 continuous, 0 domain fixed)
#    2494484 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            4709563069.479     Large        0      0      0         0   285.8s
#  R       0       0         0   0.00%   6570021.635136  1568306322.635    99.58%        0      0      0    173351  1241.6s
#          0       0         0   0.00%   6570098.158946  1568306322.635    99.58%      823     84      0    175176  1276.0s
#          0       0         0   0.00%   6570200.349422  1568306322.635    99.58%      969    206      0    178934  1325.5s
#          0       0         0   0.00%   6570784.520851  1568306322.635    99.58%     1104    318      0    182983  1379.3s
#          0       0         0   0.00%   6571168.504978  1568306322.635    99.58%     1141    342      0    184632  1407.8s
#  C       0       0         0   0.00%   6571225.36212   1448306590.297    99.55%     1145    349      0    188259  1458.5s
#          0       0         0   0.00%   6571225.36212   1448306590.297    99.55%     1155    351      0    189808  1489.9s
#          0       0         0   0.00%   6571225.36212   1448306590.297    99.55%     1162    353      0    191824  1528.7s
#          0       0         0   0.00%   6571225.36212   1448306590.297    99.55%     1176    355      0    192821  1554.7s
#          0       0         0   0.00%   6571225.36212   1448306590.297    99.55%     1182    357      0    194987  1602.4s
#          0       0         0   0.00%   6571225.36212   1448306590.297    99.55%     1226    359      0    195909  1737.7s
#          0       0         0   0.00%   6571225.36212   1448306590.297    99.55%     1235    361      0    199099  1795.9s
#          0       0         0   0.00%   6571225.36212   1448306590.297    99.55%     1453    363      0    200217  2013.5s
#  L       0       0         0   0.00%   6571225.36212   6572544.050228     0.02%     1453    363      0    200217  3347.0s
#          1       0         1 100.00%   6571225.36212   6572544.050228     0.02%     1453    363      0    345960  3347.9s
#
# Solving report
#   Status            Optimal
#   Primal bound      6572544.05023
#   Dual bound        6571225.3653
#   Gap               0.0201% (tolerance: 0.5%)
#   P-D integral      3050.46367659
#   Solution status   feasible
#                     6572544.05023 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            3347.89
#   Max sub-MIP depth 4
#   Nodes             1
#   Repair LPs        0
#   LP iterations     345960
#                     0 (strong br.)
#                     26866 (separation)
#                     145743 (heuristics)
#     ✓ P100 optimisation complete   [3767.11s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   3                     3
# 2                            0                   7                     7
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      3               0                   1              0
# 2                      7               0                   2              0
# 3                      3               0                   0              0
#
# [P100] Fleet expansion triggered because: Vehicle shortfall exists
#
# [P100] Testing 1 total future minibus candidate(s)
#
# [P100] Running scenario p100_future_total_1_MB_EV_18_1 with allocation {'MB_EV_10': 0, 'MB_EV_18': 1}
#     ✓ prepare_model_data started | flights=11,285   [0.00s]
#     ✓ vehicle expansion complete | vehicles=18   [0.10s]
#     ✓ ambulift intervals built | flights=11,285 ambulifts=14   [1.48s]
#     ✓ minibus intervals built | minibuses=4   [0.13s]
#     ✓ staff intervals built   [0.03s]
#     ✓ ambulift overlaps built | overlaps=11,538,765   [2.39s]
#     ✓ minibus overlaps built | overlaps=1,419,104   [0.52s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.06s]
#     ✓ prepare_model_data complete | total=4.71s   [0.00s]
#     ✓ sets built | F=11,285 AMB=14 MINI=4   [0.03s]
#     ✓ variables built | x=56,425 amb=473,970 mini=90,280   [0.62s]
#     ✓ ambulift overlap constraints built | 11,538,765   [316.06s]
#     ✓ minibus overlap constraints built | 1,419,104   [4.85s]
#     ✓ build_pyomo_model complete | total=323.52s   [1.95s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=11,285 Vehicles=18
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 13770448 rows; 699689 cols; 28197520 nonzeros; 620694 integer variables (620694 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -1
# Presolving model
# 2049991 rows, 271795 cols, 4319048 nonzeros 22s
# 590134 rows, 236671 cols, 2624942 nonzeros 145s
# 590134 rows, 236671 cols, 2624942 nonzeros 281s
# Presolve reductions: rows 590134(-13180314); columns 236671(-463018); nonzeros 2624942(-25572578)
#
# Solving MIP model with:
#    590134 rows
#    236671 cols (213253 binary, 0 integer, 23418 implied int., 0 continuous, 0 domain fixed)
#    2624942 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            4645745997.881     Large        0      0      0         0   323.4s
#  R       0       0         0   0.00%   3750246.832787  1300988039.694    99.71%        0      0      0    137319  1199.4s
#          0       0         0   0.00%   3750246.832787  1300988039.694    99.71%      862      2      0    139178  1239.7s
#          0       0         0   0.00%   3750246.832787  1300988039.694    99.71%      902      4      0    142827  1311.3s
#          0       0         0   0.00%   3750246.832787  1300988039.694    99.71%     1092      6      0    143515  1554.8s
#          0       0         0   0.00%   3750285.904216  1300988039.694    99.71%     1099     47      0    152883  1669.2s
#  C       0       0         0   0.00%   3750368.904216  1161739150.525    99.68%     1411     71      0    154669  1908.5s
#          0       0         0   0.00%   3750428.089139  1161739150.525    99.68%     1559     92      0    206074  2567.3s
#          0       0         0   0.00%   3750445.089139  1161739150.525    99.68%     2576    146      0    214675  2651.8s
#          0       0         0   0.00%   3750458.660568  1161739150.525    99.68%     2657    166      0    244823  2875.1s
#          0       0         0   0.00%   3750532.493901  1161739150.525    99.68%     3580    197      0    247083  2904.6s
#          0       0         0   0.00%   3750594.827234  1161739150.525    99.68%     3593    214      0    248905  2968.3s
#          0       0         0   0.00%   3750602.827234  1161739150.525    99.68%     3624    224      0    251578  2999.2s
#          0       0         0   0.00%   3750602.827234  1161739150.525    99.68%     3636    233      0    253128  3023.8s
#          0       0         0   0.00%   3750602.827234  1161739150.525    99.68%     3664    240      0    255765  3061.9s
#          0       0         0   0.00%   3750602.827234  1161739150.525    99.68%     3701    247      0    257270  3084.4s
#          0       0         0   0.00%   3750602.827234  1161739150.525    99.68%     3724    247      0    258985  3121.5s
#          0       0         0   0.00%   3750607.739155  1161739150.525    99.68%     3801    262      0    282410  3328.3s
#          0       0         0   0.00%   3750612.805822  1161739150.525    99.68%     4855    276      0    284704  3412.2s
#          0       0         0   0.00%   3750613.805822  1161739150.525    99.68%     4890    282      0    287531  3464.3s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   3750615.805822  1161739150.525    99.68%     4950    287      0    289853  3514.2s
#          0       0         0   0.00%   3750615.805822  1161739150.525    99.68%     4997    250      0    291704  3555.0s
#          0       0         0   0.00%   3750615.882265  1161739150.525    99.68%     5131    256      0    310741  3760.3s
#          0       0         0   0.00%   3750619.762557  1161739150.525    99.68%     5771    266      0    357313  4160.3s
#          0       0         0   0.00%   3750622.616438  1161739150.525    99.68%     6776    284      0    422115  4508.5s
#          0       0         0   0.00%   3750622.616438  1161739150.525    99.68%     7777    289      0    424905  4546.2s
#          0       0         0   0.00%   3750622.616438  1161739150.525    99.68%     7968    279      0    436453  4615.8s
#          0       0         0   0.00%   3750622.616438  1161739150.525    99.68%     8989    284      0    436865  4640.3s
#          0       0         0   0.00%   3750622.616438  1161739150.525    99.68%     9093    289      0    438139  4663.9s
#          0       0         0   0.00%   3750622.616438  1161739150.525    99.68%     9242    293      0    438382  4696.5s
#          0       0         0   0.00%   3750622.616438  1161739150.525    99.68%     9288    297      0    439320  4734.1s
#          0       0         0   0.00%   3750622.616438  1161739150.525    99.68%     9369    264      0    440215  4755.4s
#  L       0       0         0   0.00%   3750622.616438  3751152.278539     0.01%     9369    264      0    440215  6275.8s
#          1       0         1 100.00%   3750622.616438  3751152.278539     0.01%     9161    264      0    580076  6276.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      3751152.27854
#   Dual bound        3750622.61644
#   Gap               0.0141% (tolerance: 0.5%)
#   P-D integral      5934.75407349
#   Solution status   feasible
#                     3751152.27854 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            6276.13
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     580076
#                     0 (strong br.)
#                     302896 (separation)
#                     139861 (heuristics)
# [P100] Scenario passes: SLA 99.88%, shortfall 0.00, future vehicles bought 1
# [P100] Recommended scenario: p100_future_total_1_MB_EV_18_1
#     ✓ P100 fleet expansion search complete   [7061.45s]
#     ✓ P90 built (11,285 flights)   [0.73s]
#     P90 demand summary: 18,279 PRMs across 11,285 flights
#     ✓ prepare_model_data started | flights=11,285   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.07s]
#     ✓ ambulift intervals built | flights=11,285 ambulifts=14   [1.38s]
#     ✓ minibus intervals built | minibuses=3   [0.15s]
#     ✓ staff intervals built   [0.03s]
#     ✓ ambulift overlaps built | overlaps=11,469,978   [2.81s]
#     ✓ minibus overlaps built | overlaps=1,064,469   [0.30s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.05s]
#     ✓ prepare_model_data complete | total=4.79s   [0.00s]
#     ✓ sets built | F=11,285 AMB=14 MINI=3   [0.02s]
#     ✓ variables built | x=56,425 amb=473,970 mini=67,710   [0.64s]
#     ✓ ambulift overlap constraints built | 11,469,978   [304.13s]
#     ✓ minibus overlap constraints built | 1,064,469   [3.62s]
#     ✓ build_pyomo_model complete | total=310.75s   [2.34s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=11,285 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 13279284 rows; 677117 cols; 27170083 nonzeros; 598122 integer variables (598122 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 6e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 1833554 rows, 256627 cols, 3880872 nonzeros 19s
# 553419 rows, 225849 cols, 2497065 nonzeros 129s
# 553419 rows, 225849 cols, 2497066 nonzeros 259s
# Presolve reductions: rows 553419(-12725865); columns 225849(-451268); nonzeros 2497066(-24673017)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    553419 rows
#    225849 cols (202402 binary, 0 integer, 23447 implied int., 0 continuous, 0 domain fixed)
#    2497066 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            4593522253.653     Large        0      0      0         0   298.8s
#  R       0       0         0   0.00%   5302589.48422   1455538143.466    99.64%        0      0      0    200603  1330.2s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%      364      3      0    204000  1398.4s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     1146      6      0    205983  1458.1s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     1156      9      0    208612  1498.0s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     1178     12      0    230529  1701.6s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     1577     15  20289    231163  1773.0s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     1579     29  20289    234263  1816.7s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     1589     35  20289    235878  1849.8s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     1817     40  20289    239374  2194.1s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     1833     43  20289    239855  2214.5s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     2079     46  20289    241024  2587.4s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     2081     49  20289    243367  2626.5s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     2087     53  20289    246020  2684.5s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     2121     56  20289    248917  2756.9s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     2136     59  20289    250634  2822.6s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     2153     60  20289    253407  2929.0s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     2217     63  20289    255368  2994.5s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     2234     67  20289    258125  3064.6s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     2257     71  20289    261736  3121.2s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     2303     74  20289    264125  3195.0s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     2309     77  20289    267925  3270.0s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     2536     80  20289    270703  3694.5s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     2574     83  20289    275074  3783.1s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     2658     86  20289    276426  3839.9s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     2701     89  20289    278215  3904.1s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     2729     90  20289    282574  3991.5s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     2809     93  20289    283533  4044.6s
#          0       0         0   0.00%   5302589.48422   1455538143.466    99.64%     2869     96  20289    286985  4121.0s
#          0       0         0   0.00%   5302589.586628  1455538143.466    99.64%     2965     99  20289    328318  4541.2s
#          0       0         0   0.00%   5302589.586628  1455538143.466    99.64%     3973    111  20289    331625  4597.4s
#          0       0         0   0.00%   5302589.586628  1455538143.466    99.64%     3983    114  20289    334755  4641.4s
#          0       0         0   0.00%   5302589.586628  1455538143.466    99.64%     4008    119  20289    338661  4708.6s
#          0       0         0   0.00%   5302589.586628  1455538143.466    99.64%     4011    124  20289    341423  4753.6s
#          0       0         0   0.00%   5302589.586628  1455538143.466    99.64%     4010    129  20289    343923  4799.0s
#          0       0         0   0.00%   5302589.586628  1455538143.466    99.64%     4027    133  20289    345793  4847.7s
#          0       0         0   0.00%   5302589.586628  1455538143.466    99.64%     4043    132  20289    348187  4922.2s
#          0       0         0   0.00%   5302589.586628  1455538143.466    99.64%     3931    137  20289    352039  5028.6s
#          0       0         0   0.00%   5302589.586628  1455538143.466    99.64%     3888    141  20289    354294  5121.9s
#          0       0         0   0.00%   5302589.586628  1455538143.466    99.64%     3866    144  20289    356382  5175.6s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  L       0       0         0   0.00%   5302589.586628  5302642.050228     0.00%     3866    144  20289    356382  7195.3s
#          1       0         1 100.00%   5302589.586628  5302642.050228     0.00%     3758    144  20289    518956  7195.7s
#
# Solving report
#   Status            Optimal
#   Primal bound      5302642.05023
#   Dual bound        5302589.58904
#   Gap               0.000989% (tolerance: 0.5%)
#   P-D integral      6873.41662497
#   Solution status   feasible
#                     5302642.05023 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            7195.66
#   Max sub-MIP depth 4
#   Nodes             1
#   Repair LPs        0
#   LP iterations     518956
#                     0 (strong br.)
#                     155779 (separation)
#                     162574 (heuristics)
#     ✓ P90 optimisation complete   [7825.36s]
#
# [P90 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   3                     3
# 2                            0                   7                     7
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      3               0                   1              0
# 2                      7               0                   2              0
# 3                      3               0                   0              0
#
# [P90] Fleet expansion triggered because: Vehicle shortfall exists
#
# [P90] Testing 1 total future minibus candidate(s)
#
# [P90] Running scenario p90_future_total_1_MB_EV_18_1 with allocation {'MB_EV_10': 0, 'MB_EV_18': 1}
#     ✓ prepare_model_data started | flights=11,285   [0.00s]
#     ✓ vehicle expansion complete | vehicles=18   [0.07s]
#     ✓ ambulift intervals built | flights=11,285 ambulifts=14   [1.56s]
#     ✓ minibus intervals built | minibuses=4   [0.12s]
#     ✓ staff intervals built   [0.04s]
#     ✓ ambulift overlaps built | overlaps=11,469,978   [2.98s]
#     ✓ minibus overlaps built | overlaps=1,419,292   [0.54s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.06s]
#     ✓ prepare_model_data complete | total=5.37s   [0.00s]
#     ✓ sets built | F=11,285 AMB=14 MINI=4   [0.11s]
#     ✓ variables built | x=56,425 amb=473,970 mini=90,280   [0.71s]
#     ✓ ambulift overlap constraints built | 11,469,978   [275.43s]
#     ✓ minibus overlap constraints built | 1,419,292   [4.79s]
#     ✓ build_pyomo_model complete | total=282.78s   [1.73s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=11,285 Vehicles=18
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 13701818 rows; 699689 cols; 28060291 nonzeros; 620694 integer variables (620694 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 2041538 rows, 272259 cols, 4314152 nonzeros 19s
# 591863 rows, 237136 cols, 2628486 nonzeros 131s
# 591863 rows, 237136 cols, 2628492 nonzeros 259s
# Presolve reductions: rows 591863(-13109955); columns 237136(-462553); nonzeros 2628492(-25431799)
#
# Solving MIP model with:
#    591863 rows
#    237136 cols (213689 binary, 0 integer, 23447 implied int., 0 continuous, 0 domain fixed)
#    2628492 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            4736521191.826     Large        0      0      0         0   305.1s
#  R       0       0         0   0.00%   2484613.681065  1022974422.032    99.76%        0      0      0    206822  1329.7s
#          0       0         0   0.00%   2484613.681065  1022974422.032    99.76%      628      2      0    211458  1407.5s
#          0       0         0   0.00%   2484613.681065  1022974422.032    99.76%     1630     20      0    215025  1447.0s
#          0       0         0   0.00%   2484613.681065  1022974422.032    99.76%     1661     29      0    219206  1504.5s
#          0       0         0   0.00%   2484613.681065  1022974422.032    99.76%     1775     36      0    221856  1546.3s
#  C       0       0         0   0.00%   2484613.681065  833476390.5251    99.70%     1933     40      0    224211  1673.4s
#          0       0         0   0.00%   2484613.681065  833476390.5251    99.70%     1962     44      0    226045  1713.6s
#          0       0         0   0.00%   2484614.008571  833476390.5251    99.70%     1995     48      0    290086  2219.2s
#          0       0         0   0.00%   2484614.435427  833476390.5251    99.70%     3016     69      0    363427  2992.5s
#          0       0         0   0.00%   2484614.464421  833476390.5251    99.70%     4022     99      0    373074  3119.9s
#          0       0         0   0.00%   2484614.491452  833476390.5251    99.70%     4121    106      0    391868  3324.4s
#          0       0         0   0.00%   2484614.637559  833476390.5251    99.70%     4432    117      0    448290  3774.0s
#          0       0         0   0.00%   2484615.93285   833476390.5251    99.70%     5436    144      0    504719  4243.3s
#          0       0         0   0.00%   2484615.93285   833476390.5251    99.70%     6445    165      0    510245  4315.1s
#          0       0         0   0.00%   2484615.93285   833476390.5251    99.70%     6474    173      0    515122  4378.6s
#          0       0         0   0.00%   2484615.93285   833476390.5251    99.70%     6496    174      0    520079  4444.4s
#          0       0         0   0.00%   2484616.785555  833476390.5251    99.70%     6582    191      0    607140  5198.9s
#          0       0         0   0.00%   2484617.360459  833476390.5251    99.70%     7598    214      0    665272  5758.3s
#          0       0         0   0.00%   2484617.360459  833476390.5251    99.70%     8609    242      0    669534  5814.2s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   2484617.38191   833476390.5251    99.70%     8648    259      0    685585  5980.4s
#          0       0         0   0.00%   2484617.38191   833476390.5251    99.70%     8818    240      0    686345  5991.6s
#          0       0         0   0.00%   2484617.544242  833476390.5251    99.70%     8963    257      0    719966  6308.7s
#          0       0         0   0.00%   2484617.544242  833476390.5251    99.70%     9969    281      0    731824  6397.6s
#          0       0         0   0.00%   2484617.749486  833476390.5251    99.70%    10083    296      0    764403  6679.6s
#          0       0         0   0.00%   2484617.826674  833476390.5251    99.70%    11043    329      0    787915  6933.1s
#          0       0         0   0.00%   2484617.993933  833476390.5251    99.70%     8818    309      0    825118  7295.7s
#          0       0         0   0.00%   2484618.656119  833476390.5251    99.70%     9498    337      0    857602  7680.5s
#          0       0         0   0.00%   2484618.656119  833476390.5251    99.70%    10181    365      0    861144  7725.9s
#          0       0         0   0.00%   2484618.656119  833476390.5251    99.70%    10208    378      0    863901  7779.2s
#          0       0         0   0.00%   2484619.259107  833476390.5251    99.70%    10228    390      0    915507  8276.2s
#          0       0         0   0.00%   2484619.455966  833476390.5251    99.70%    11233    373      0    976260  8771.0s
#          0       0         0   0.00%   2484619.455966  833476390.5251    99.70%     8792    390      0    980269  8828.2s
#          0       0         0   0.00%   2484619.455966  833476390.5251    99.70%     9798    423      0    984752  8889.1s
#          0       0         0   0.00%   2484619.659164  833476390.5251    99.70%     9820    434      0     1074k  9639.9s
#          0       0         0   0.00%   2484619.659164  833476390.5251    99.70%    10829    470      0     1081k  9726.0s
#          0       0         0   0.00%   2484619.659164  833476390.5251    99.70%     9408    391      0     1086k  9883.0s
#          0       0         0   0.00%   2484619.659164  833476390.5251    99.70%     9812    412      0     1093k  9979.2s
#  L       0       0         0   0.00%   2484619.659164  2484942.278539     0.01%     9812    412      0     1093k 10864.8s
#          1       0         1 100.00%   2484619.659164  2484942.278539     0.01%     9812    412      0     1191k 10865.7s
#
# Solving report
#   Status            Optimal
#   Primal bound      2484942.27854
#   Dual bound        2484619.65916
#   Gap               0.013% (tolerance: 0.5%)
#   P-D integral      10530.1268223
#   Solution status   feasible
#                     2484942.27854 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            10865.67
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1191483
#                     0 (strong br.)
#                     886495 (separation)
#                     98166 (heuristics)
# [P90] Scenario passes: SLA 99.92%, shortfall 0.00, future vehicles bought 1
# [P90] Recommended scenario: p90_future_total_1_MB_EV_18_1
#     ✓ P90 fleet expansion search complete   [11507.36s]
#     ✓ Excel outputs written to outputs\prm_combined_new\monthly\2026_08_v2.xlsx   [25.51s]
#
# Completed month: 2026_08
# Workbook: outputs\prm_combined_new\monthly\2026_08_combined.xlsx
#    S1_PeakAmb  S1_PeakMini  S1_PeakDrivers  S1_PeakVehAgents  S2_PeakAmb  \
# 0          13            2              13                13          10
# 1          12            2              12                12          10
#
#    S2_PeakMini  S2_PeakDrivers  S2_PeakVehAgents  V2_arrival_sla_pct  \
# 0           16              25                25           99.879239
# 1           15              24                24           99.923068
#
#    V2_PeakAmb  V2_PeakMini
# 0          11            3
# 1          11            3

# %%
sep_result = run_combined_month(
    2026,
    9,
)

pd.DataFrame(sep_result["month_rows"])
# Out:
# ================================================================================
# RUNNING COMBINED MONTH: 2026_09
# ================================================================================
#
# Running S1 P100
#
# ================================================================================
# [DEBUG A] Future flights loaded & Pax computed
# ================================================================================
# df_flights rows: 11423
# Airlines (sample): ['U2' 'FR' 'LS' 'LM' 'AC' 'EI' 'EC' 'QR' 'AF' 'AY']
# Countries (sample): ['TUNISIA' 'IRISH REPUBLIC' 'GREECE' 'GREAT BRITAIN' 'NETHERLANDS' 'SPAIN'
#  'CANADA' 'SWITZERLAND' 'GERMANY' 'ITALY']
#
# Pax describe:
# count    11423.000000
# mean       147.464501
# std         56.296451
# min          0.000000
# 25%        121.000000
# 50%        159.000000
# 75%        181.000000
# max        397.000000
# Name: Pax, dtype: float64
#
# Top 10 rows (Airline, CountryName, Sector, dir, Pax):
#    Airline     CountryName         Sector dir    Pax
# 0       U2         TUNISIA  International   D  188.0
# 1       FR  IRISH REPUBLIC            CTA   D  130.0
# 2       LS          GREECE  International   D  162.0
# 3       U2          GREECE  International   D  216.0
# 4       LM   GREAT BRITAIN       Domestic   D   53.0
# 5       U2     NETHERLANDS  International   D  180.0
# 6       LS           SPAIN  International   D  164.0
# 7       FR           SPAIN  International   D  176.0
# 8       AC          CANADA  International   D  265.0
# 9       FR           SPAIN  International   D  181.0
# 10      U2     SWITZERLAND  International   D  177.0
# 11      EI  IRISH REPUBLIC            CTA   D   45.0
# 12      FR         GERMANY  International   D  183.0
# 13      EI  IRISH REPUBLIC            CTA   D   59.0
# 14      FR           SPAIN  International   D  182.0
#
# ================================================================================
# [DEBUG B] Penetration lookup match rate
# ================================================================================
# Penetration keys available: 117
# Flights with penetration match: 10,985 / 11,423 (96.2%)
#
# Top missing (Airline, CountryName) combos in future flights:
#    Airline  CountryName  flight_rows
# 3       EC        ITALY          108
# 5       EC        SPAIN           68
# 2       EC       FRANCE           62
# 1       DS  SWITZERLAND           58
# 4       EC  NETHERLANDS           52
# 6       IB        SPAIN           20
# 11      U2     SLOVENIA           18
# 7       LG   LUXEMBOURG           16
# 9       RK        MALTA           16
# 10      RK      ROMANIA           10
# 0       BA        ITALY            8
# 8       RC       FRANCE            2
#
# Example missing keys:
#     Airline  CountryName    Pax
# 15       EC        ITALY  133.0
# 24       EC        SPAIN  125.0
# 47       U2     SLOVENIA  130.0
# 114      EC        ITALY  126.0
# 154      EC  NETHERLANDS  168.0
# 202      DS  SWITZERLAND   95.0
# 251      EC        ITALY  140.0
# 288      IB        SPAIN  155.0
# 293      DS  SWITZERLAND   90.0
# 302      EC        SPAIN  129.0
# 410      EC        ITALY  147.0
# 434      RC       FRANCE  126.0
# 460      DS  SWITZERLAND  146.0
# 495      RK        MALTA  155.0
# 515      EC  NETHERLANDS  127.0
#
# ================================================================================
# [DEBUG C] Expected PRMs vs rounding
# ================================================================================
# Total expected PRMs (raw sum, BEFORE rounding): 19011.061705038617
# Total PRMs after rounding: 19289
#
# Raw PRM demand distribution (prm_raw):
# count    11423.000000
# mean         1.664279
# std          1.424108
# min          0.000000
# 25%          0.822938
# 50%          1.274875
# 75%          1.824667
# max          8.986591
# Name: _prm_raw, dtype: float64
#
# Top flights by raw PRM demand:
#       Airline CountryName    Pax  _pen_used  _prm_raw  _prm_round
# 11419      QR       QATAR  311.0   0.028896  8.986591           9
# 4842       QR       QATAR  311.0   0.028896  8.986591           9
# 4565       QR       QATAR  311.0   0.028896  8.986591           9
# 8820       QR       QATAR  311.0   0.028896  8.986591           9
# 4659       QR       QATAR  311.0   0.028896  8.986591           9
# 3527       QR       QATAR  311.0   0.028896  8.986591           9
# 4006       QR       QATAR  311.0   0.028896  8.986591           9
# 6539       QR       QATAR  311.0   0.028896  8.986591           9
# 802        QR       QATAR  311.0   0.028896  8.986591           9
# 5318       QR       QATAR  311.0   0.028896  8.986591           9
# 4372       QR       QATAR  311.0   0.028896  8.986591           9
# 9431       QR       QATAR  311.0   0.028896  8.986591           9
# 7625       QR       QATAR  311.0   0.028896  8.986591           9
# 4922       QR       QATAR  311.0   0.028896  8.986591           9
# 3445       QR       QATAR  311.0   0.028896  8.986591           9
# [DEBUG flight] Airline=U2 | Country=TUNISIA | Pax=188.0 | Pen=0.02534 | Pax*Pen=4.763 | PRMs=5
# [DEBUG flight] Airline=FR | Country=IRISH REPUBLIC | Pax=130.0 | Pen=0.00705 | Pax*Pen=0.917 | PRMs=1
# [DEBUG flight] Airline=LS | Country=GREECE | Pax=162.0 | Pen=0.01888 | Pax*Pen=3.058 | PRMs=3
# [DEBUG flight] Airline=U2 | Country=GREECE | Pax=216.0 | Pen=0.01278 | Pax*Pen=2.760 | PRMs=3
# [DEBUG flight] Airline=LM | Country=GREAT BRITAIN | Pax=53.0 | Pen=0.02140 | Pax*Pen=1.134 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=NETHERLANDS | Pax=180.0 | Pen=0.00676 | Pax*Pen=1.216 | PRMs=1
# [DEBUG flight] Airline=LS | Country=SPAIN | Pax=164.0 | Pen=0.02780 | Pax*Pen=4.560 | PRMs=5
# [DEBUG flight] Airline=FR | Country=SPAIN | Pax=176.0 | Pen=0.01043 | Pax*Pen=1.835 | PRMs=2
# [DEBUG flight] Airline=AC | Country=CANADA | Pax=265.0 | Pen=0.01707 | Pax*Pen=4.523 | PRMs=5
# [DEBUG flight] Airline=FR | Country=SPAIN | Pax=181.0 | Pen=0.01043 | Pax*Pen=1.887 | PRMs=2
# [DEBUG flight] Airline=U2 | Country=SWITZERLAND | Pax=177.0 | Pen=0.00752 | Pax*Pen=1.331 | PRMs=1
# [DEBUG flight] Airline=EI | Country=IRISH REPUBLIC | Pax=45.0 | Pen=0.01119 | Pax*Pen=0.504 | PRMs=1
# [DEBUG flight] Airline=FR | Country=GERMANY | Pax=183.0 | Pen=0.00307 | Pax*Pen=0.562 | PRMs=1
# [DEBUG flight] Airline=EI | Country=IRISH REPUBLIC | Pax=59.0 | Pen=0.01119 | Pax*Pen=0.660 | PRMs=1
# [DEBUG flight] Airline=FR | Country=SPAIN | Pax=182.0 | Pen=0.01043 | Pax*Pen=1.898 | PRMs=2
#
# [DEBUG ingest_s26]
# Total PRM jobs (rows): 19289
# Columns: ['Passenger ID', 'Airline Code', 'Flight Number', 'A/D', 'Sector', 'CountryName', 'Stand', 'Scheduled Flight DT', 'Chocks DT', 'Minutes on Chocks', 'ScheduledDateTime_Local', 'Chocks_Est', 'Departure Gate', 'SSR Code', 'Has Own Chair', 'IsEffectiveRemote', 'PRM Flight Count', 'Concurrent Stress', 'Turnaround PRM Count', 'Turnaround Vertical Count', 'IsArrival', 'Adhoc Or Planned', 'IsAdhoc', 'Job Start Time', 'Job End Time', 'tau_amb_mins', 'tau_mini_mins', 'tau_push_mins']
# SSR Code present: True
# SSR Code distribution:
# SSR Code
# WCHR     10226
# WCHS      7956
# WCHC       998
# OTHER      109
# Name: count, dtype: int64
# Running S2 P100
#
# Running S1 P90
#
# ================================================================================
# [DEBUG A] Future flights loaded & Pax computed
# ================================================================================
# df_flights rows: 11423
# Airlines (sample): ['AF' 'U2' 'FR' 'KL' 'BA' 'RK' 'LH' 'LS' 'LM' 'QR']
# Countries (sample): ['FRANCE' 'ITALY' 'NETHERLANDS' 'GREAT BRITAIN' 'SPAIN' 'ROMANIA'
#  'CROATIA' 'GERMANY' 'TUNISIA' 'IRISH REPUBLIC']
#
# Pax describe:
# count    11423.000000
# mean       147.464501
# std         56.296451
# min          0.000000
# 25%        121.000000
# 50%        159.000000
# 75%        181.000000
# max        397.000000
# Name: Pax, dtype: float64
#
# Top 10 rows (Airline, CountryName, Sector, dir, Pax):
#    Airline    CountryName         Sector dir    Pax
# 0       AF         FRANCE  International   D   91.0
# 1       U2          ITALY  International   D  178.0
# 2       FR         FRANCE  International   D  138.0
# 3       FR          ITALY  International   D  185.0
# 4       KL    NETHERLANDS  International   D  107.0
# 5       BA  GREAT BRITAIN       Domestic   D   88.0
# 6       U2  GREAT BRITAIN       Domestic   D  148.0
# 7       U2  GREAT BRITAIN       Domestic   D  135.0
# 8       U2  GREAT BRITAIN       Domestic   D  150.0
# 9       FR          SPAIN  International   D  197.0
# 10      RK        ROMANIA  International   D  148.0
# 11      U2  GREAT BRITAIN       Domestic   D  148.0
# 12      U2        CROATIA  International   D  168.0
# 13      FR          SPAIN  International   D  187.0
# 14      LH        GERMANY  International   D   95.0
#
# ================================================================================
# [DEBUG B] Penetration lookup match rate
# ================================================================================
# Penetration keys available: 117
# Flights with penetration match: 10,985 / 11,423 (96.2%)
#
# Top missing (Airline, CountryName) combos in future flights:
#    Airline  CountryName  flight_rows
# 3       EC        ITALY          108
# 5       EC        SPAIN           68
# 2       EC       FRANCE           62
# 1       DS  SWITZERLAND           58
# 4       EC  NETHERLANDS           52
# 6       IB        SPAIN           20
# 11      U2     SLOVENIA           18
# 7       LG   LUXEMBOURG           16
# 9       RK        MALTA           16
# 10      RK      ROMANIA           10
# 0       BA        ITALY            8
# 8       RC       FRANCE            2
#
# Example missing keys:
#     Airline  CountryName    Pax
# 10       RK      ROMANIA  148.0
# 53       EC  NETHERLANDS  164.0
# 105      EC        ITALY  133.0
# 156      EC        SPAIN  125.0
# 201      U2     SLOVENIA  130.0
# 289      DS  SWITZERLAND  144.0
# 297      EC        ITALY  126.0
# 301      EC        SPAIN  140.0
# 352      IB        SPAIN  154.0
# 356      EC  NETHERLANDS  168.0
# 416      EC        ITALY  208.0
# 421      DS  SWITZERLAND   95.0
# 481      EC        ITALY  140.0
# 490      EC       FRANCE  186.0
# 515      RK        MALTA  179.0
#
# ================================================================================
# [DEBUG C] Expected PRMs vs rounding
# ================================================================================
# Total expected PRMs (raw sum, BEFORE rounding): 19011.061705038614
# Total PRMs after rounding: 19289
#
# Raw PRM demand distribution (prm_raw):
# count    11423.000000
# mean         1.664279
# std          1.424108
# min          0.000000
# 25%          0.822938
# 50%          1.274875
# 75%          1.824667
# max          8.986591
# Name: _prm_raw, dtype: float64
#
# Top flights by raw PRM demand:
#      Airline CountryName    Pax  _pen_used  _prm_raw  _prm_round
# 38        QR       QATAR  311.0   0.028896  8.986591           9
# 6539      QR       QATAR  311.0   0.028896  8.986591           9
# 5673      QR       QATAR  311.0   0.028896  8.986591           9
# 4842      QR       QATAR  311.0   0.028896  8.986591           9
# 4659      QR       QATAR  311.0   0.028896  8.986591           9
# 4763      QR       QATAR  311.0   0.028896  8.986591           9
# 4565      QR       QATAR  311.0   0.028896  8.986591           9
# 4372      QR       QATAR  311.0   0.028896  8.986591           9
# 4006      QR       QATAR  311.0   0.028896  8.986591           9
# 8048      QR       QATAR  311.0   0.028896  8.986591           9
# 7625      QR       QATAR  311.0   0.028896  8.986591           9
# 4922      QR       QATAR  311.0   0.028896  8.986591           9
# 7051      QR       QATAR  311.0   0.028896  8.986591           9
# 5318      QR       QATAR  311.0   0.028896  8.986591           9
# 9431      QR       QATAR  311.0   0.028896  8.986591           9
# [DEBUG flight] Airline=AF | Country=FRANCE | Pax=91.0 | Pen=0.00815 | Pax*Pen=0.741 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=ITALY | Pax=178.0 | Pen=0.00941 | Pax*Pen=1.676 | PRMs=2
# [DEBUG flight] Airline=FR | Country=FRANCE | Pax=138.0 | Pen=0.00741 | Pax*Pen=1.023 | PRMs=1
# [DEBUG flight] Airline=FR | Country=ITALY | Pax=185.0 | Pen=0.00591 | Pax*Pen=1.094 | PRMs=1
# [DEBUG flight] Airline=KL | Country=NETHERLANDS | Pax=107.0 | Pen=0.00898 | Pax*Pen=0.961 | PRMs=1
# [DEBUG flight] Airline=BA | Country=GREAT BRITAIN | Pax=88.0 | Pen=0.01039 | Pax*Pen=0.914 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=148.0 | Pen=0.00990 | Pax*Pen=1.465 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=135.0 | Pen=0.00990 | Pax*Pen=1.336 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=150.0 | Pen=0.00990 | Pax*Pen=1.485 | PRMs=1
# [DEBUG flight] Airline=FR | Country=SPAIN | Pax=197.0 | Pen=0.01043 | Pax*Pen=2.054 | PRMs=2
# [DEBUG flight] Airline=RK | Country=ROMANIA | Pax=148.0 | Pen=0.01000 | Pax*Pen=1.480 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=148.0 | Pen=0.00990 | Pax*Pen=1.465 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=CROATIA | Pax=168.0 | Pen=0.00455 | Pax*Pen=0.764 | PRMs=1
# [DEBUG flight] Airline=FR | Country=SPAIN | Pax=187.0 | Pen=0.01043 | Pax*Pen=1.950 | PRMs=2
# [DEBUG flight] Airline=LH | Country=GERMANY | Pax=95.0 | Pen=0.00614 | Pax*Pen=0.583 | PRMs=1
#
# [DEBUG ingest_s26]
# Total PRM jobs (rows): 19289
# Columns: ['Passenger ID', 'Airline Code', 'Flight Number', 'A/D', 'Sector', 'CountryName', 'Stand', 'Scheduled Flight DT', 'Chocks DT', 'Minutes on Chocks', 'ScheduledDateTime_Local', 'Chocks_Est', 'Departure Gate', 'SSR Code', 'Has Own Chair', 'IsEffectiveRemote', 'PRM Flight Count', 'Concurrent Stress', 'Turnaround PRM Count', 'Turnaround Vertical Count', 'IsArrival', 'Adhoc Or Planned', 'IsAdhoc', 'Job Start Time', 'Job End Time', 'tau_amb_mins', 'tau_mini_mins', 'tau_push_mins']
# SSR Code present: True
# SSR Code distribution:
# SSR Code
# WCHR     10163
# WCHS      7963
# WCHC      1052
# OTHER      111
# Name: count, dtype: int64
# [BUILD_JOBS] Applying stratified percentile cap: q=0.90 | strata=['SSR Code', 'Has Own Chair', 'A/D']
# [BUILD_JOBS] Dropped 1614 PRM jobs via stratified percentile cap
# Running S2 P90
#
# Running V2 optimiser
#     ✓ Passenger dataset combined (19,351 passenger rows)   [60.70s]
#     ✓ P100 built (10,692 flights)   [0.31s]
#     P100 demand summary: 19,351 PRMs across 10,692 flights
#     ✓ prepare_model_data started | flights=10,692   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.04s]
#     ✓ ambulift intervals built | flights=10,692 ambulifts=14   [1.14s]
#     ✓ minibus intervals built | minibuses=3   [0.13s]
#     ✓ staff intervals built   [0.03s]
#     ✓ ambulift overlaps built | overlaps=10,777,909   [1.91s]
#     ✓ minibus overlaps built | overlaps=986,061   [0.18s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.03s]
#     ✓ prepare_model_data complete | total=3.45s   [0.00s]
#     ✓ sets built | F=10,692 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=53,460 amb=449,064 mini=64,152   [1.09s]
#     ✓ ambulift overlap constraints built | 10,777,909   [60.70s]
#     ✓ minibus overlap constraints built | 986,061   [7.38s]
#     ✓ build_pyomo_model complete | total=70.92s   [1.75s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=10,692 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 12469708 rows; 641537 cols; 25518814 nonzeros; 566693 integer variables (566693 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 9e+00]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -1
# Presolving model
# 1668526 rows, 235522 cols, 3516741 nonzeros 17s
# 503557 rows, 207512 cols, 2262160 nonzeros 109s
# 503557 rows, 207512 cols, 2262160 nonzeros 217s
# Presolve reductions: rows 503557(-11966151); columns 207512(-434025); nonzeros 2262160(-23256654)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    503557 rows
#    207512 cols (185695 binary, 0 integer, 21817 implied int., 0 continuous, 0 domain fixed)
#    2262160 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            4424540217.826     Large        0      0      0         0   256.5s
#  R       0       0         0   0.00%   8288191.99399   1650025144.466    99.50%        0      0      0     73039   669.9s
#          0       0         0   0.00%   8288724.414625  1650025144.466    99.50%     1261    159      0     74612   693.9s
#          0       0         0   0.00%   8289253.897958  1650025144.466    99.50%     1431    296      0     76721   715.3s
#          0       0         0   0.00%   8290059.545578  1650025144.466    99.50%     1531    405      0     77225   724.8s
#          0       0         0   0.00%   8290160.391172  1650025144.466    99.50%     1537    424      0    104124   916.9s
#  C       0       0         0   0.00%   8291255.891172  1237277737.297    99.33%     2407    439      0    116509  1017.4s
#          0       0         0   0.00%   8291376.224505  1237277737.297    99.33%     2558    444      0    117853  1043.6s
#          0       0         0   0.00%   8291377.891172  1237277737.297    99.33%     2570    448      0    118965  1097.4s
#          0       0         0   0.00%   8291377.891172  1237277737.297    99.33%     2574    451      0    133239  1196.8s
#          0       0         0   0.00%   8291377.891172  1237277737.297    99.33%     3048    454      0    135183  1281.2s
#          0       0         0   0.00%   8291377.891172  1237277737.297    99.33%     3484    456      0    135673  1392.8s
#          0       0         0   0.00%   8291377.891172  1237277737.297    99.33%     3585    458      0    136545  1472.7s
#          0       0         0   0.00%   8291377.891172  1237277737.297    99.33%     3594    460      0    137240  1494.4s
#          0       0         0   0.00%   8291377.891172  1237277737.297    99.33%     3791    462      0    137473  1591.6s
#          0       0         0   0.00%   8291377.891172  1237277737.297    99.33%     3892    464      0    137557  1667.3s
#          0       0         0   0.00%   8291377.891172  1237277737.297    99.33%     4064    438      0    139166  1773.9s
#          0       0         0   0.00%   8291895.655414  1237277737.297    99.33%     4259    531      0    186318  2117.3s
#          0       0         0   0.00%   8291967.07947   1237277737.297    99.33%     5262    562      0    211647  2293.6s
#          0       0         0   0.00%   8291967.400848  1237277737.297    99.33%     6235    583      0    249429  2583.6s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   8291985.265206  1237277737.297    99.33%     7236    618      0    281406  2889.3s
#          0       0         0   0.00%   8291990.265206  1237277737.297    99.33%     8239    648      0    291898  2993.8s
#          0       0         0   0.00%   8291990.40986   1237277737.297    99.33%     8810    665      0    302461  3095.1s
#          0       0         0   0.00%   8291993.08058   1237277737.297    99.33%     9003    679      0    331640  3386.4s
#          0       0         0   0.00%   8291993.08058   1237277737.297    99.33%     9662    712      0    343802  3481.1s
#          0       0         0   0.00%   8291993.352706  1237277737.297    99.33%     9806    722      0    380516  3791.7s
#          0       0         0   0.00%   8291993.781333  1237277737.297    99.33%    10431    752      0    401251  3996.4s
#          0       0         0   0.00%   8291993.781333  1237277737.297    99.33%    10923    784      0    404936  4033.0s
#          0       0         0   0.00%   8291993.781333  1237277737.297    99.33%    10535    800      0    416452  4136.1s
#          0       0         0   0.00%   8291993.781333  1237277737.297    99.33%    10861    817      0    428362  4234.8s
#          0       0         0   0.00%   8291993.781333  1237277737.297    99.33%    10526    826      0    428883  4252.3s
#          0       0         0   0.00%   8291993.781333  1237277737.297    99.33%    10822    711      0    442667  4364.4s
#  L       0       0         0   0.00%   8291993.781333  8292125.050228     0.00%    10822    711      0    442667  5501.7s
#          1       0         1 100.00%   8291993.781333  8292125.050228     0.00%    10673    711      0    534400  5502.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      8292125.05023
#   Dual bound        8291993.78539
#   Gap               0.00158% (tolerance: 0.5%)
#   P-D integral      5211.90118454
#   Solution status   feasible
#                     8292125.05023 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            5502.08
#   Max sub-MIP depth 4
#   Nodes             1
#   Repair LPs        0
#   LP iterations     534400
#                     0 (strong br.)
#                     369628 (separation)
#                     91733 (heuristics)
#     ✓ P100 optimisation complete   [5900.08s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   3                     3
# 2                            0                   7                     7
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      3               0                   1              0
# 2                      7               0                   2              0
# 3                      3               0                   0              0
#
# [P100] Fleet expansion triggered because: Vehicle shortfall exists
#
# [P100] Testing 1 total future minibus candidate(s)
#
# [P100] Running scenario p100_future_total_1_MB_EV_18_1 with allocation {'MB_EV_10': 0, 'MB_EV_18': 1}
#     ✓ prepare_model_data started | flights=10,692   [0.00s]
#     ✓ vehicle expansion complete | vehicles=18   [0.06s]
#     ✓ ambulift intervals built | flights=10,692 ambulifts=14   [1.61s]
#     ✓ minibus intervals built | minibuses=4   [0.14s]
#     ✓ staff intervals built   [0.04s]
#     ✓ ambulift overlaps built | overlaps=10,777,909   [3.01s]
#     ✓ minibus overlaps built | overlaps=1,314,748   [0.37s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.07s]
#     ✓ prepare_model_data complete | total=5.31s   [0.00s]
#     ✓ sets built | F=10,692 AMB=14 MINI=4   [0.02s]
#     ✓ variables built | x=53,460 amb=449,064 mini=85,536   [0.67s]
#     ✓ ambulift overlap constraints built | 10,777,909   [332.05s]
#     ✓ minibus overlap constraints built | 1,314,748   [4.87s]
#     ✓ build_pyomo_model complete | total=339.44s   [1.82s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=10,692 Vehicles=18
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 12862548 rows; 662923 cols; 26347262 nonzeros; 588079 integer variables (588079 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -1
# Presolving model
# 1859448 rows, 250176 cols, 3914838 nonzeros 24s
# 540155 rows, 218206 cols, 2386606 nonzeros 141s
# 540155 rows, 218206 cols, 2386606 nonzeros 261s
# Presolve reductions: rows 540155(-12322393); columns 218206(-444717); nonzeros 2386606(-23960656)
#
# Solving MIP model with:
#    540155 rows
#    218206 cols (196389 binary, 0 integer, 21817 implied int., 0 continuous, 0 domain fixed)
#    2386606 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            4403540217.826     Large        0      0      0         0   308.7s
#  R       0       0         0   0.00%   4466990.47407   1145706063.863    99.61%        0      0      0     93088   835.2s
#          0       0         0   0.00%   4466990.47407   1145706063.863    99.61%      482      4      0     94124   865.3s
#          0       0         0   0.00%   4466990.47407   1145706063.863    99.61%      668      8      0     94721   981.8s
#          0       0         0   0.00%   4467035.807404  1145706063.863    99.61%      674     49      0     95326   997.7s
#          0       0         0   0.00%   4467088.557404  1145706063.863    99.61%      708     79      0     96947  1020.4s
#  C       0       0         0   0.00%   4467182.22407   918208199.5251    99.51%      772    106      0     98089  1049.2s
#          0       0         0   0.00%   4467297.557404  918208199.5251    99.51%      785    127      0     99211  1067.9s
#          0       0         0   0.00%   4467388.72407   918208199.5251    99.51%      791    141      0    100952  1093.1s
#          0       0         0   0.00%   4467388.72407   918208199.5251    99.51%      821    143      0    101732  1112.3s
#          0       0         0   0.00%   4467435.72407   918208199.5251    99.51%      830    146      0    102026  1123.9s
#          0       0         0   0.00%   4467440.72407   918208199.5251    99.51%      834    148      0    102566  1136.7s
#          0       0         0   0.00%   4467445.72407   918208199.5251    99.51%      843    150      0    103224  1153.1s
#          0       0         0   0.00%   4467450.72407   918208199.5251    99.51%      848    152      0    108145  1193.2s
#          0       0         0   0.00%   4467465.72407   918208199.5251    99.51%     1227    160      0    111897  1244.4s
#          0       0         0   0.00%   4467522.72407   918208199.5251    99.51%     1551    165      0    112995  1279.0s
#          0       0         0   0.00%   4467522.72407   918208199.5251    99.51%     1604    155      0    113783  1304.0s
#          0       0         0   0.00%   4467522.72407   918208199.5251    99.51%     1686    161      0    117404  1375.1s
#          0       0         0   0.00%   4467585.390737  918208199.5251    99.51%     1873    166      0    118168  1407.3s
#          0       0         0   0.00%   4467596.72407   918208199.5251    99.51%     1896    175      0    120416  1463.6s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   4467596.72407   918208199.5251    99.51%     1981    178      0    120927  1500.8s
#          0       0         0   0.00%   4467596.72407   918208199.5251    99.51%     2081    161      0    121831  1579.8s
#          0       0         0   0.00%   4467596.72407   918208199.5251    99.51%     2279    163      0    122713  1614.1s
#          0       0         0   0.00%   4467596.72407   918208199.5251    99.51%     2427    166      0    122773  1665.4s
#          0       0         0   0.00%   4467596.72407   918208199.5251    99.51%     2459    169      0    123274  1688.4s
#  L       0       0         0   0.00%   4467596.72407   4468051.278539     0.01%     2459    169      0    123274  2997.5s
#          1       0         1 100.00%   4467596.72407   4468051.278539     0.01%     2459    169      0    247265  2998.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      4468051.27854
#   Dual bound        4467596.72407
#   Gap               0.0102% (tolerance: 0.5%)
#   P-D integral      2677.13990164
#   Solution status   feasible
#                     4468051.27854 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            2998.11
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     247265
#                     0 (strong br.)
#                     30186 (separation)
#                     123991 (heuristics)
# [P100] Scenario passes: SLA 99.85%, shortfall 0.00, future vehicles bought 1
# [P100] Recommended scenario: p100_future_total_1_MB_EV_18_1
#     ✓ P100 fleet expansion search complete   [3689.42s]
#     ✓ P90 built (10,692 flights)   [0.78s]
#     P90 demand summary: 17,401 PRMs across 10,692 flights
#     ✓ prepare_model_data started | flights=10,692   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.08s]
#     ✓ ambulift intervals built | flights=10,692 ambulifts=14   [1.28s]
#     ✓ minibus intervals built | minibuses=3   [0.11s]
#     ✓ staff intervals built   [0.03s]
#     ✓ ambulift overlaps built | overlaps=10,683,954   [3.06s]
#     ✓ minibus overlaps built | overlaps=986,319   [0.32s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.01s]
#     ✓ staff requirements and staff-minutes calculated   [0.05s]
#     ✓ prepare_model_data complete | total=4.93s   [0.00s]
#     ✓ sets built | F=10,692 AMB=14 MINI=3   [0.14s]
#     ✓ variables built | x=53,460 amb=449,064 mini=64,152   [0.75s]
#     ✓ ambulift overlap constraints built | 10,683,954   [273.12s]
#     ✓ minibus overlap constraints built | 986,319   [3.11s]
#     ✓ build_pyomo_model complete | total=278.70s   [1.58s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=10,692 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 12375970 rows; 641537 cols; 25331379 nonzeros; 566693 integer variables (566693 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 6e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 1660073 rows, 236146 cols, 3513005 nonzeros 22s
# 505393 rows, 208137 cols, 2264237 nonzeros 125s
# 505393 rows, 208137 cols, 2264240 nonzeros 242s
# Presolve reductions: rows 505393(-11870577); columns 208137(-433400); nonzeros 2264240(-23067139)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    505393 rows
#    208137 cols (186281 binary, 0 integer, 21856 implied int., 0 continuous, 0 domain fixed)
#    2264240 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            4337492298.826     Large        0      0      0         0   280.0s
#  R       0       0         0   0.00%   5267399.972603  917258291.3881    99.43%        0      0      0    100529   673.7s
#          0       0         0   0.00%   5267399.972603  917258291.3881    99.43%      945     24      0    101766   694.2s
#          0       0         0   0.00%   5267399.972603  917258291.3881    99.43%     1164     34      0    103497   712.8s
#          0       0         0   0.00%   5267399.972603  917258291.3881    99.43%     1218     39      0    104226   723.6s
#          0       0         0   0.00%   5267399.972603  917258291.3881    99.43%     1240     45      0    105571   736.5s
#  C       0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     1273     51      0    107258   756.2s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     1353     56      0    107933   764.6s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     1377     60      0    109575   780.0s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     1433     65      0    110718   794.7s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     1480     70      0    112137   811.5s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     1526     74      0    113419   822.0s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     1551     79      0    142991  1044.8s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     2554     85      0    143438  1055.5s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     2607     90      0    146044  1085.4s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     2667     96      0    147527  1098.2s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     2737     90      0    148559  1107.9s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     2953     96      0    150485  1129.9s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     2975    101      0    151850  1142.7s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     2990    107      0    154589  1163.5s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     3012    113      0    156530  1180.9s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     3246    116      0    158759  1199.1s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     3666    123      0    160667  1218.5s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     3710    133      0    161651  1229.7s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     3779    140      0    162380  1237.1s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     3795    146      0    163296  1246.0s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     3924    138      0    164644  1260.1s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     4218    144      0    165507  1267.3s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     4350    150      0    166114  1276.7s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     4481    155      0    166605  1282.4s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     4670    160      0    167499  1292.8s
#          0       0         0   0.00%   5267399.972603  605261491.2968    99.13%     4515    166      0    167777  1298.2s
#  L       0       0         0   0.00%   5267399.972603  5267491.296804     0.00%     4515    166      0    167777  2133.9s
#          1       0         1 100.00%   5267399.972603  5267491.296804     0.00%     4322    166      0    274583  2135.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      5267491.2968
#   Dual bound        5267399.9726
#   Gap               0.00173% (tolerance: 0.5%)
#   P-D integral      1840.23729327
#   Solution status   feasible
#                     5267491.2968 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            2134.99
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     274583
#                     0 (strong br.)
#                     67248 (separation)
#                     106806 (heuristics)
#     ✓ P90 optimisation complete   [2741.81s]
#
# [P90 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     4
# 2                            0                   9                     7
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      4               0                   0              0
# 2                      7               0                   2              0
# 3                      3               0                   0              0
#
# [P90] Fleet expansion triggered because: Vehicle shortfall exists
#
# [P90] Testing 1 total future minibus candidate(s)
#
# [P90] Running scenario p90_future_total_1_MB_EV_18_1 with allocation {'MB_EV_10': 0, 'MB_EV_18': 1}
#     ✓ prepare_model_data started | flights=10,692   [0.00s]
#     ✓ vehicle expansion complete | vehicles=18   [0.06s]
#     ✓ ambulift intervals built | flights=10,692 ambulifts=14   [1.36s]
#     ✓ minibus intervals built | minibuses=4   [0.12s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=10,683,954   [2.37s]
#     ✓ minibus overlaps built | overlaps=1,315,092   [0.38s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.05s]
#     ✓ prepare_model_data complete | total=4.36s   [0.00s]
#     ✓ sets built | F=10,692 AMB=14 MINI=4   [0.02s]
#     ✓ variables built | x=53,460 amb=449,064 mini=85,536   [0.42s]
#     ✓ ambulift overlap constraints built | 10,683,954   [260.64s]
#     ✓ minibus overlap constraints built | 1,315,092   [8.93s]
#     ✓ build_pyomo_model complete | total=272.05s   [2.03s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=10,692 Vehicles=18
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 12768896 rows; 662923 cols; 26159999 nonzeros; 588079 integer variables (588079 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 1851081 rows, 250800 cols, 3911274 nonzeros 21s
# 542256 rows, 218831 cols, 2390385 nonzeros 127s
# 542256 rows, 218831 cols, 2390385 nonzeros 241s
# Presolve reductions: rows 542256(-12226640); columns 218831(-444092); nonzeros 2390385(-23769614)
#
# Solving MIP model with:
#    542256 rows
#    218831 cols (196975 binary, 0 integer, 21856 implied int., 0 continuous, 0 domain fixed)
#    2390385 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            4365492028.826     Large        0      0      0         0   286.1s
#  R       0       0         0   0.00%   2449384.200913  1020439337.032    99.76%        0      0      0    199105  1110.6s
#          0       0         0   0.00%   2449384.200913  1020439337.032    99.76%     1002      3      0    201336  1157.9s
#          0       0         0   0.00%   2449384.200913  1020439337.032    99.76%     2004     32      0    204894  1194.9s
#          0       0         0   0.00%   2449384.200913  1020439337.032    99.76%     2100     43      0    206566  1211.0s
#          0       0         0   0.00%   2449384.200913  1020439337.032    99.76%     2159     48      0    207801  1223.9s
#  C       0       0         0   0.00%   2449384.200913  896440585.5251    99.73%     2174     57      0    209663  1245.1s
#          0       0         0   0.00%   2449384.200913  896440585.5251    99.73%     2339     62      0    210355  1258.3s
#          0       0         0   0.00%   2449384.200913  896440585.5251    99.73%     2471     68      0    211624  1278.2s
#          0       0         0   0.00%   2449384.200913  896440585.5251    99.73%     2624     74      0    216296  1347.3s
#          0       0         0   0.00%   2449384.200913  896440585.5251    99.73%     2982     80      0    217504  1510.2s
#          0       0         0   0.00%   2449384.200913  896440585.5251    99.73%     3305     88      0    255822  1846.1s
#          0       0         0   0.00%   2449384.200913  896440585.5251    99.73%     4307     93      0    258579  1889.2s
#          0       0         0   0.00%   2449384.200913  896440585.5251    99.73%     4477     99      0    260117  1906.8s
#          0       0         0   0.00%   2449384.200913  896440585.5251    99.73%     4636    106      0    276578  2029.4s
#          0       0         0   0.00%   2449384.200913  896440585.5251    99.73%     5477    124      0    278859  2053.3s
#          0       0         0   0.00%   2449384.200913  896440585.5251    99.73%     5777    125      0    346363  2623.3s
#          0       0         0   0.00%   2449384.200913  896440585.5251    99.73%     6805    134      0    357314  2742.0s
#          0       0         0   0.00%   2449384.200913  896440585.5251    99.73%     7274    142      0    360243  2825.3s
#          0       0         0   0.00%   2449384.200913  896440585.5251    99.73%     7531    150      0    368930  2926.3s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   2449384.200913  896440585.5251    99.73%     7831    162      0    374725  2993.1s
#          0       0         0   0.00%   2449384.200913  896440585.5251    99.73%     7880    149      0    377777  3033.8s
#          0       0         0   0.00%   2449384.200913  896440585.5251    99.73%     7976    159      0    379980  3076.6s
#          0       0         0   0.00%   2449384.200913  896440585.5251    99.73%     8083    167      0    382638  3118.9s
#  L       0       0         0   0.00%   2449384.200913  2449789.278539     0.02%     8083    167      0    382638  4075.5s
#          1       0         1 100.00%   2449384.200913  2449789.278539     0.02%     8083    167      0    482679  4076.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      2449789.27854
#   Dual bound        2449384.20091
#   Gap               0.0165% (tolerance: 0.5%)
#   P-D integral      3780.17787251
#   Solution status   feasible
#                     2449789.27854 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            4076.28
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     482679
#                     0 (strong br.)
#                     183533 (separation)
#                     100041 (heuristics)
# [P90] Scenario passes: SLA 99.92%, shortfall 0.00, future vehicles bought 1
# [P90] Recommended scenario: p90_future_total_1_MB_EV_18_1
#     ✓ P90 fleet expansion search complete   [4737.22s]
#     ✓ Excel outputs written to outputs\prm_combined_new\monthly\2026_09_v2.xlsx   [22.06s]
#
# Completed month: 2026_09
# Workbook: outputs\prm_combined_new\monthly\2026_09_combined.xlsx
#    S1_PeakAmb  S1_PeakMini  S1_PeakDrivers  S1_PeakVehAgents  S2_PeakAmb  \
# 0          12            2              12                12          10
# 1          10            2              11                11          10
#
#    S2_PeakMini  S2_PeakDrivers  S2_PeakVehAgents  V2_arrival_sla_pct  \
# 0           14              22                22           99.845456
# 1           13              21                21           99.919808
#
#    V2_PeakAmb  V2_PeakMini
# 0          11            3
# 1          12            3

# %%
oct_result = run_combined_month(
    2026,
    10,
)

pd.DataFrame(oct_result["month_rows"])
# Out:
# ================================================================================
# RUNNING COMBINED MONTH: 2026_10
# ================================================================================
#
# Running S1 P100
#
# ================================================================================
# [DEBUG A] Future flights loaded & Pax computed
# ================================================================================
# df_flights rows: 11365
# Airlines (sample): ['KL' 'BA' 'U2' 'FR' 'LS' 'AY' 'EI' 'UA' 'LM' 'RK']
# Countries (sample): ['NETHERLANDS' 'GREAT BRITAIN' 'ITALY' 'FRANCE' 'MOROCCO' 'SPAIN'
#  'FINLAND' 'IRISH REPUBLIC' 'UNITED STATES OF AMERICA' 'DENMARK']
#
# Pax describe:
# count    11365.000000
# mean       149.346502
# std         57.121136
# min          0.000000
# 25%        123.000000
# 50%        165.000000
# 75%        184.000000
# max        397.000000
# Name: Pax, dtype: float64
#
# Top 10 rows (Airline, CountryName, Sector, dir, Pax):
#    Airline               CountryName         Sector dir    Pax
# 0       KL               NETHERLANDS  International   D  123.0
# 1       BA             GREAT BRITAIN       Domestic   D   83.0
# 2       U2                     ITALY  International   D  138.0
# 3       FR                     ITALY  International   D  184.0
# 4       BA             GREAT BRITAIN       Domestic   D  116.0
# 5       U2                    FRANCE  International   D  148.0
# 6       U2                   MOROCCO  International   D  155.0
# 7       LS                     SPAIN  International   D  226.0
# 8       AY                   FINLAND  International   D   74.0
# 9       U2             GREAT BRITAIN       Domestic   D  118.0
# 10      EI            IRISH REPUBLIC            CTA   D   58.0
# 11      FR                     SPAIN  International   D  177.0
# 12      UA  UNITED STATES OF AMERICA  International   D  176.0
# 13      U2                   DENMARK  International   D  136.0
# 14      U2             GREAT BRITAIN       Domestic   D  130.0
#
# ================================================================================
# [DEBUG B] Penetration lookup match rate
# ================================================================================
# Penetration keys available: 117
# Flights with penetration match: 10,689 / 11,365 (94.1%)
#
# Top missing (Airline, CountryName) combos in future flights:
#    Airline     CountryName  flight_rows
# 8       EC           ITALY          110
# 6       EC          FRANCE           82
# 1       CJ   GREAT BRITAIN           82
# 10      EC           SPAIN           72
# 5       EA  IRISH REPUBLIC           70
# 9       EC     NETHERLANDS           62
# 3       DS     SWITZERLAND           54
# 4       EA   GREAT BRITAIN           52
# 12      LG      LUXEMBOURG           18
# 15      RK           MALTA           16
# 18      U2        SLOVENIA           14
# 11      IB           SPAIN           14
# 0       BA           ITALY            8
# 16      RK         ROMANIA            8
# 7       EC         GERMANY            4
#
# Example missing keys:
#     Airline  CountryName    Pax
# 34       EC        SPAIN  152.0
# 67       EC       FRANCE  149.0
# 77       EC        ITALY  137.0
# 115      EC       FRANCE  215.0
# 122      EC        ITALY  144.0
# 163      DS  SWITZERLAND  133.0
# 165      EC  NETHERLANDS  163.0
# 198      RK        MALTA  183.0
# 260      U2     SLOVENIA  146.0
# 270      EC        ITALY  146.0
# 296      EC        SPAIN  179.0
# 342      DS  SWITZERLAND  109.0
# 363      IB        SPAIN  185.0
# 418      EC        ITALY  160.0
# 461      EC       FRANCE  185.0
#
# ================================================================================
# [DEBUG C] Expected PRMs vs rounding
# ================================================================================
# Total expected PRMs (raw sum, BEFORE rounding): 18825.72308628109
# Total PRMs after rounding: 19080
#
# Raw PRM demand distribution (prm_raw):
# count    11365.000000
# mean         1.656465
# std          1.402571
# min          0.000000
# 25%          0.830373
# 50%          1.298443
# 75%          1.821259
# max          8.986591
# Name: _prm_raw, dtype: float64
#
# Top flights by raw PRM demand:
#       Airline CountryName    Pax  _pen_used  _prm_raw  _prm_round
# 276        QR       QATAR  311.0   0.028896  8.986591           9
# 1356       QR       QATAR  311.0   0.028896  8.986591           9
# 10563      QR       QATAR  311.0   0.028896  8.986591           9
# 3137       QR       QATAR  311.0   0.028896  8.986591           9
# 10206      QR       QATAR  311.0   0.028896  8.986591           9
# 1902       QR       QATAR  311.0   0.028896  8.986591           9
# 341        QR       QATAR  311.0   0.028896  8.986591           9
# 1638       QR       QATAR  311.0   0.028896  8.986591           9
# 1440       QR       QATAR  311.0   0.028896  8.986591           9
# 63         QR       QATAR  311.0   0.028896  8.986591           9
# 5333       QR       QATAR  311.0   0.028896  8.986591           9
# 987        QR       QATAR  311.0   0.028896  8.986591           9
# 3988       QR       QATAR  311.0   0.028896  8.986591           9
# 4180       QR       QATAR  311.0   0.028896  8.986591           9
# 1547       QR       QATAR  311.0   0.028896  8.986591           9
# [DEBUG flight] Airline=KL | Country=NETHERLANDS | Pax=123.0 | Pen=0.00898 | Pax*Pen=1.104 | PRMs=1
# [DEBUG flight] Airline=BA | Country=GREAT BRITAIN | Pax=83.0 | Pen=0.01039 | Pax*Pen=0.862 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=ITALY | Pax=138.0 | Pen=0.00941 | Pax*Pen=1.299 | PRMs=1
# [DEBUG flight] Airline=FR | Country=ITALY | Pax=184.0 | Pen=0.00591 | Pax*Pen=1.088 | PRMs=1
# [DEBUG flight] Airline=BA | Country=GREAT BRITAIN | Pax=116.0 | Pen=0.01039 | Pax*Pen=1.205 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=FRANCE | Pax=148.0 | Pen=0.00907 | Pax*Pen=1.342 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=MOROCCO | Pax=155.0 | Pen=0.01289 | Pax*Pen=1.997 | PRMs=2
# [DEBUG flight] Airline=LS | Country=SPAIN | Pax=226.0 | Pen=0.02780 | Pax*Pen=6.284 | PRMs=6
# [DEBUG flight] Airline=AY | Country=FINLAND | Pax=74.0 | Pen=0.00569 | Pax*Pen=0.421 | PRMs=0
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=118.0 | Pen=0.00990 | Pax*Pen=1.168 | PRMs=1
# [DEBUG flight] Airline=EI | Country=IRISH REPUBLIC | Pax=58.0 | Pen=0.01119 | Pax*Pen=0.649 | PRMs=1
# [DEBUG flight] Airline=FR | Country=SPAIN | Pax=177.0 | Pen=0.01043 | Pax*Pen=1.846 | PRMs=2
# [DEBUG flight] Airline=UA | Country=UNITED STATES OF AMERICA | Pax=176.0 | Pen=0.01681 | Pax*Pen=2.958 | PRMs=3
# [DEBUG flight] Airline=U2 | Country=DENMARK | Pax=136.0 | Pen=0.00907 | Pax*Pen=1.234 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=130.0 | Pen=0.00990 | Pax*Pen=1.287 | PRMs=1
#
# [DEBUG ingest_s26]
# Total PRM jobs (rows): 19080
# Columns: ['Passenger ID', 'Airline Code', 'Flight Number', 'A/D', 'Sector', 'CountryName', 'Stand', 'Scheduled Flight DT', 'Chocks DT', 'Minutes on Chocks', 'ScheduledDateTime_Local', 'Chocks_Est', 'Departure Gate', 'SSR Code', 'Has Own Chair', 'IsEffectiveRemote', 'PRM Flight Count', 'Concurrent Stress', 'Turnaround PRM Count', 'Turnaround Vertical Count', 'IsArrival', 'Adhoc Or Planned', 'IsAdhoc', 'Job Start Time', 'Job End Time', 'tau_amb_mins', 'tau_mini_mins', 'tau_push_mins']
# SSR Code present: True
# SSR Code distribution:
# SSR Code
# WCHR     9945
# WCHS     7933
# WCHC     1062
# OTHER     140
# Name: count, dtype: int64
# Running S2 P100
#
# Running S1 P90
#
# ================================================================================
# [DEBUG A] Future flights loaded & Pax computed
# ================================================================================
# df_flights rows: 11365
# Airlines (sample): ['U2' 'AF' 'FR' 'KL' 'BA' 'LS' 'LH' 'LM' 'RK' 'QR']
# Countries (sample): ['ITALY' 'FRANCE' 'LATVIA' 'NETHERLANDS' 'GREAT BRITAIN' 'PORTUGAL'
#  'SPAIN' 'GREECE' 'GERMANY' 'POLAND']
#
# Pax describe:
# count    11365.000000
# mean       149.346502
# std         57.121136
# min          0.000000
# 25%        123.000000
# 50%        165.000000
# 75%        184.000000
# max        397.000000
# Name: Pax, dtype: float64
#
# Top 10 rows (Airline, CountryName, Sector, dir, Pax):
#    Airline    CountryName         Sector dir    Pax
# 0       U2          ITALY  International   D  171.0
# 1       AF         FRANCE  International   D   94.0
# 2       FR         LATVIA  International   D  186.0
# 3       KL    NETHERLANDS  International   D  123.0
# 4       BA  GREAT BRITAIN       Domestic   D   83.0
# 5       U2       PORTUGAL  International   D  162.0
# 6       U2          ITALY  International   D  138.0
# 7       FR          SPAIN  International   D  168.0
# 8       LS         GREECE  International   D  196.0
# 9       U2  GREAT BRITAIN       Domestic   D  120.0
# 10      U2  GREAT BRITAIN       Domestic   D   82.0
# 11      U2         FRANCE  International   D  181.0
# 12      LH        GERMANY  International   D  114.0
# 13      FR          ITALY  International   D  184.0
# 14      LM  GREAT BRITAIN       Domestic   D   15.0
#
# ================================================================================
# [DEBUG B] Penetration lookup match rate
# ================================================================================
# Penetration keys available: 117
# Flights with penetration match: 10,689 / 11,365 (94.1%)
#
# Top missing (Airline, CountryName) combos in future flights:
#    Airline     CountryName  flight_rows
# 8       EC           ITALY          110
# 6       EC          FRANCE           82
# 1       CJ   GREAT BRITAIN           82
# 10      EC           SPAIN           72
# 5       EA  IRISH REPUBLIC           70
# 9       EC     NETHERLANDS           62
# 3       DS     SWITZERLAND           54
# 4       EA   GREAT BRITAIN           52
# 12      LG      LUXEMBOURG           18
# 15      RK           MALTA           16
# 18      U2        SLOVENIA           14
# 11      IB           SPAIN           14
# 0       BA           ITALY            8
# 16      RK         ROMANIA            8
# 7       EC         GERMANY            4
#
# Example missing keys:
#     Airline  CountryName    Pax
# 44       EC        ITALY  161.0
# 49       DS  SWITZERLAND   74.0
# 110      EC        ITALY  120.0
# 119      EC       FRANCE  183.0
# 145      RK        MALTA  175.0
# 166      IB        SPAIN  142.0
# 174      DS  SWITZERLAND   69.0
# 179      EC       FRANCE  182.0
# 183      EC        SPAIN  132.0
# 191      EC        SPAIN  152.0
# 238      EC       FRANCE  149.0
# 251      EC        ITALY  137.0
# 260      EC        ITALY  119.0
# 298      EC       FRANCE  215.0
# 307      EC        ITALY  144.0
#
# ================================================================================
# [DEBUG C] Expected PRMs vs rounding
# ================================================================================
# Total expected PRMs (raw sum, BEFORE rounding): 18825.723086281087
# Total PRMs after rounding: 19080
#
# Raw PRM demand distribution (prm_raw):
# count    11365.000000
# mean         1.656465
# std          1.402571
# min          0.000000
# 25%          0.830373
# 50%          1.298443
# 75%          1.821259
# max          8.986591
# Name: _prm_raw, dtype: float64
#
# Top flights by raw PRM demand:
#      Airline CountryName    Pax  _pen_used  _prm_raw  _prm_round
# 2864      QR       QATAR  311.0   0.028896  8.986591           9
# 1440      QR       QATAR  311.0   0.028896  8.986591           9
# 3059      QR       QATAR  311.0   0.028896  8.986591           9
# 5499      QR       QATAR  311.0   0.028896  8.986591           9
# 5396      QR       QATAR  311.0   0.028896  8.986591           9
# 2955      QR       QATAR  311.0   0.028896  8.986591           9
# 1356      QR       QATAR  311.0   0.028896  8.986591           9
# 1547      QR       QATAR  311.0   0.028896  8.986591           9
# 4528      QR       QATAR  311.0   0.028896  8.986591           9
# 5559      QR       QATAR  311.0   0.028896  8.986591           9
# 2570      QR       QATAR  311.0   0.028896  8.986591           9
# 3137      QR       QATAR  311.0   0.028896  8.986591           9
# 505       QR       QATAR  311.0   0.028896  8.986591           9
# 4373      QR       QATAR  311.0   0.028896  8.986591           9
# 1742      QR       QATAR  311.0   0.028896  8.986591           9
# [DEBUG flight] Airline=U2 | Country=ITALY | Pax=171.0 | Pen=0.00941 | Pax*Pen=1.610 | PRMs=2
# [DEBUG flight] Airline=AF | Country=FRANCE | Pax=94.0 | Pen=0.00815 | Pax*Pen=0.766 | PRMs=1
# [DEBUG flight] Airline=FR | Country=LATVIA | Pax=186.0 | Pen=0.00430 | Pax*Pen=0.801 | PRMs=1
# [DEBUG flight] Airline=KL | Country=NETHERLANDS | Pax=123.0 | Pen=0.00898 | Pax*Pen=1.104 | PRMs=1
# [DEBUG flight] Airline=BA | Country=GREAT BRITAIN | Pax=83.0 | Pen=0.01039 | Pax*Pen=0.862 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=PORTUGAL | Pax=162.0 | Pen=0.00848 | Pax*Pen=1.373 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=ITALY | Pax=138.0 | Pen=0.00941 | Pax*Pen=1.299 | PRMs=1
# [DEBUG flight] Airline=FR | Country=SPAIN | Pax=168.0 | Pen=0.01043 | Pax*Pen=1.752 | PRMs=2
# [DEBUG flight] Airline=LS | Country=GREECE | Pax=196.0 | Pen=0.01888 | Pax*Pen=3.700 | PRMs=4
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=120.0 | Pen=0.00990 | Pax*Pen=1.188 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=GREAT BRITAIN | Pax=82.0 | Pen=0.00990 | Pax*Pen=0.812 | PRMs=1
# [DEBUG flight] Airline=U2 | Country=FRANCE | Pax=181.0 | Pen=0.00907 | Pax*Pen=1.642 | PRMs=2
# [DEBUG flight] Airline=LH | Country=GERMANY | Pax=114.0 | Pen=0.00614 | Pax*Pen=0.700 | PRMs=1
# [DEBUG flight] Airline=FR | Country=ITALY | Pax=184.0 | Pen=0.00591 | Pax*Pen=1.088 | PRMs=1
# [DEBUG flight] Airline=LM | Country=GREAT BRITAIN | Pax=15.0 | Pen=0.02140 | Pax*Pen=0.321 | PRMs=0
#
# [DEBUG ingest_s26]
# Total PRM jobs (rows): 19080
# Columns: ['Passenger ID', 'Airline Code', 'Flight Number', 'A/D', 'Sector', 'CountryName', 'Stand', 'Scheduled Flight DT', 'Chocks DT', 'Minutes on Chocks', 'ScheduledDateTime_Local', 'Chocks_Est', 'Departure Gate', 'SSR Code', 'Has Own Chair', 'IsEffectiveRemote', 'PRM Flight Count', 'Concurrent Stress', 'Turnaround PRM Count', 'Turnaround Vertical Count', 'IsArrival', 'Adhoc Or Planned', 'IsAdhoc', 'Job Start Time', 'Job End Time', 'tau_amb_mins', 'tau_mini_mins', 'tau_push_mins']
# SSR Code present: True
# SSR Code distribution:
# SSR Code
# WCHR     9987
# WCHS     7909
# WCHC     1061
# OTHER     123
# Name: count, dtype: int64
# [BUILD_JOBS] Applying stratified percentile cap: q=0.90 | strata=['SSR Code', 'Has Own Chair', 'A/D']
# [BUILD_JOBS] Dropped 1897 PRM jobs via stratified percentile cap
# Running S2 P90
#
# Running V2 optimiser
#     ✓ Passenger dataset combined (19,158 passenger rows)   [70.57s]
#     ✓ P100 built (10,608 flights)   [0.28s]
#     P100 demand summary: 19,158 PRMs across 10,608 flights
#     ✓ prepare_model_data started | flights=10,608   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.09s]
#     ✓ ambulift intervals built | flights=10,608 ambulifts=14   [1.43s]
#     ✓ minibus intervals built | minibuses=3   [0.12s]
#     ✓ staff intervals built   [0.05s]
#     ✓ ambulift overlaps built | overlaps=10,326,117   [2.95s]
#     ✓ minibus overlaps built | overlaps=951,162   [0.27s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.14s]
#     ✓ prepare_model_data complete | total=5.04s   [0.00s]
#     ✓ sets built | F=10,608 AMB=14 MINI=3   [0.14s]
#     ✓ variables built | x=53,040 amb=445,536 mini=63,648   [0.59s]
#     ✓ ambulift overlap constraints built | 10,326,117   [383.09s]
#     ✓ minibus overlap constraints built | 951,162   [3.62s]
#     ✓ build_pyomo_model complete | total=389.55s   [2.10s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=10,608 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 11977460 rows; 636497 cols; 24529817 nonzeros; 562241 integer variables (562241 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 9e+00]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -1
# Presolving model
# 1708394 rows, 243079 cols, 3609384 nonzeros 18s
# 519691 rows, 213722 cols, 2337234 nonzeros 135s
# 519691 rows, 213722 cols, 2337234 nonzeros 260s
# Presolve reductions: rows 519691(-11457769); columns 213722(-422775); nonzeros 2337234(-22192583)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    519691 rows
#    213722 cols (191538 binary, 0 integer, 22184 implied int., 0 continuous, 0 domain fixed)
#    2337234 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            4520548078.653     Large        0      0      0         0   305.1s
#  R       0       0         0   0.00%   9134027.910568  1390038923.466    99.34%        0      0      0     73880   708.7s
#          0       0         0   0.00%   12800828.2439   1390038923.466    99.08%     1205    134      0     77292   765.6s
#          0       0         0   0.00%   12801279.91057  1390038923.466    99.08%     1450    254      0     78686   784.7s
#          0       0         0   0.00%   12802243.38676  1390038923.466    99.08%     1566    359      0     80392   808.4s
#          0       0         0   0.00%   12802670.92009  1390038923.466    99.08%     1637    410      0     80620   815.6s
#  C       0       0         0   0.00%   12802721.92009  1156540468.297    98.89%     1638    422      0     81701   827.1s
#          0       0         0   0.00%   12802726.92009  1156540468.297    98.89%     1735    425      0     82590   880.7s
#          0       0         0   0.00%   12802726.92009  1156540468.297    98.89%     1810    427      0     90139   963.1s
#          0       0         0   0.00%   12802780.92009  1156540468.297    98.89%     2221    434      0     91292  1025.8s
#          0       0         0   0.00%   12802825.58676  1156540468.297    98.89%     2291    438      0     91415  1044.5s
#          0       0         0   0.00%   12802825.58676  1156540468.297    98.89%     2366    440      0     91452  1072.5s
#          0       0         0   0.00%   12802825.58676  1156540468.297    98.89%     2438    442      0     92455  1098.0s
#          0       0         0   0.00%   12802825.58676  1156540468.297    98.89%     2584    445      0     93516  1149.5s
#          0       0         0   0.00%   12802825.58676  1156540468.297    98.89%     2687    447      0     94338  1169.1s
#          0       0         0   0.00%   12802827.05651  1156540468.297    98.89%     2842    452      0    116438  1376.1s
#          0       0         0   0.00%   12803033.38984  1156540468.297    98.89%     3844    407      0    118017  1405.9s
#          0       0         0   0.00%   12803202.88984  1156540468.297    98.89%     3951    412      0    118730  1474.9s
#          0       0         0   0.00%   12803205.88984  1156540468.297    98.89%     3988    416      0    119499  1511.6s
#          0       0         0   0.00%   12803205.88984  1156540468.297    98.89%     4097    419      0    121235  1567.4s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   12803205.88984  1156540468.297    98.89%     4113    421      0    122245  1589.6s
#          0       0         0   0.00%   12803205.88984  1156540468.297    98.89%     4203    417      0    122949  1671.0s
#          0       0         0   0.00%   12803205.88984  1156540468.297    98.89%     4286    420      0    124402  1738.9s
#          0       0         0   0.00%   12803205.88984  1156540468.297    98.89%     4407    422      0    124786  1799.4s
#          0       0         0   0.00%   12803205.88984  1156540468.297    98.89%     4412    424      0    124957  1810.4s
#  L       0       0         0   0.00%   12803205.88984  12803289.2968      0.00%     4412    424      0    124957  4260.7s
#          1       0         1 100.00%   12803205.88984  12803289.2968      0.00%     4412    424      0    274763  4261.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      12803289.2968
#   Dual bound        12803205.8904
#   Gap               0.000651% (tolerance: 0.5%)
#   P-D integral      3915.33506094
#   Solution status   feasible
#                     12803289.2968 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            4261.13
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     274763
#                     0 (strong br.)
#                     51077 (separation)
#                     149806 (heuristics)
#     ✓ P100 optimisation complete   [4976.97s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     3
# 2                            0                   9                     9
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      3               0                   1              0
# 2                      9               0                   0              0
# 3                      3               0                   0              0
#
# [P100] Fleet expansion triggered because: Vehicle shortfall exists
#
# [P100] Testing 1 total future minibus candidate(s)
#
# [P100] Running scenario p100_future_total_1_MB_EV_18_1 with allocation {'MB_EV_10': 0, 'MB_EV_18': 1}
#     ✓ prepare_model_data started | flights=10,608   [0.00s]
#     ✓ vehicle expansion complete | vehicles=18   [0.06s]
#     ✓ ambulift intervals built | flights=10,608 ambulifts=14   [1.36s]
#     ✓ minibus intervals built | minibuses=4   [0.13s]
#     ✓ staff intervals built   [0.03s]
#     ✓ ambulift overlaps built | overlaps=10,326,117   [2.28s]
#     ✓ minibus overlaps built | overlaps=1,268,216   [0.26s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.05s]
#     ✓ prepare_model_data complete | total=4.19s   [0.00s]
#     ✓ sets built | F=10,608 AMB=14 MINI=4   [0.02s]
#     ✓ variables built | x=53,040 amb=445,536 mini=84,864   [0.56s]
#     ✓ ambulift overlap constraints built | 10,326,117   [261.21s]
#     ✓ minibus overlap constraints built | 1,268,216   [4.00s]
#     ✓ build_pyomo_model complete | total=272.49s   [6.70s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=10,608 Vehicles=18
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 12358163 rows; 657715 cols; 25333655 nonzeros; 583459 integer variables (583459 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -1
# Presolving model
# 1898618 rows, 257838 cols, 4006251 nonzeros 20s
# 555445 rows, 224332 cols, 2456250 nonzeros 134s
# 555445 rows, 224332 cols, 2456250 nonzeros 265s
# Presolve reductions: rows 555445(-11802718); columns 224332(-433383); nonzeros 2456250(-22877405)
#
# Solving MIP model with:
#    555445 rows
#    224332 cols (202148 binary, 0 integer, 22184 implied int., 0 continuous, 0 domain fixed)
#    2456250 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            4514548038.653     Large        0      0      0         0   306.1s
#  R       0       0         0   0.00%   4979625.43585   1092219349.694    99.54%        0      0      0     75045   729.8s
#          0       0         0   0.00%   4979625.43585   1092219349.694    99.54%      868      2      0     75792   771.9s
#          0       0         0   0.00%   4979625.43585   1092219349.694    99.54%      902      5      0     76560   788.0s
#          0       0         0   0.00%   4979625.43585   1092219349.694    99.54%      914      8      0     77166   815.9s
#          0       0         0   0.00%   4979667.43585   1092219349.694    99.54%      922     43      0     78173   853.9s
#  C       0       0         0   0.00%   4979693.352517  676973272.5251    99.26%      975     71      0     79304   868.1s
#          0       0         0   0.00%   4979786.657278  676973272.5251    99.26%      999     95      0     79839   876.9s
#          0       0         0   0.00%   4979915.979501  676973272.5251    99.26%     1018    112      0     80812   891.3s
#          0       0         0   0.00%   4979940.646167  676973272.5251    99.26%     1031    128      0     88384   958.8s
#          0       0         0   0.00%   4980085.535056  676973272.5251    99.26%     1185    142      0     89031   971.3s
#          0       0         0   0.00%   4980138.312834  676973272.5251    99.26%     1231    148      0     89349   990.9s
#          0       0         0   0.00%   4980138.312834  676973272.5251    99.26%     1297    151      0     97651  1108.1s
#          0       0         0   0.00%   4980138.312834  676973272.5251    99.26%     1802    159      0     99733  1150.6s
#          0       0         0   0.00%   4980138.312834  676973272.5251    99.26%     1849    165      0    100925  1188.7s
#          0       0         0   0.00%   4980138.312834  676973272.5251    99.26%     1923    169      0    102101  1223.2s
#          0       0         0   0.00%   4980138.312834  676973272.5251    99.26%     1991    170      0    102554  1262.6s
#          0       0         0   0.00%   4980202.312834  676973272.5251    99.26%     2077    179      0    103796  1286.9s
#          0       0         0   0.00%   4980202.312834  676973272.5251    99.26%     2146    184      0    112367  1367.1s
#          0       0         0   0.00%   4980205.646167  676973272.5251    99.26%     2961    189      0    113090  1461.9s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   4980223.512834  676973272.5251    99.26%     3002    195      0    115304  1515.1s
#          0       0         0   0.00%   4980223.512834  676973272.5251    99.26%     3115    173      0    120540  1590.3s
#          0       0         0   0.00%   4980227.979501  676973272.5251    99.26%     3185    178      0    120913  1621.5s
#          0       0         0   0.00%   4980240.312834  676973272.5251    99.26%     3222    183      0    123309  1667.7s
#          0       0         0   0.00%   4980240.312834  676973272.5251    99.26%     3308    188      0    124047  1703.5s
#          0       0         0   0.00%   4980240.312834  676973272.5251    99.26%     3377    191      0    124927  1741.5s
#          0       0         0   0.00%   4980240.312834  676973272.5251    99.26%     3508    189      0    125707  1805.1s
#          0       0         0   0.00%   4980240.312834  676973272.5251    99.26%     3578    194      0    136007  1901.5s
#          0       0         0   0.00%   4980240.312834  676973272.5251    99.26%     4373    198      0    137438  1946.0s
#          0       0         0   0.00%   4980240.312834  676973272.5251    99.26%     4506    202      0    139219  1992.7s
#          0       0         0   0.00%   4980240.312834  676973272.5251    99.26%     4685    206      0    140785  2039.9s
#          0       0         0   0.00%   4980240.312834  676973272.5251    99.26%     4864    185      0    142841  2097.0s
#  L       0       0         0   0.00%   4980240.312834  4980823.694064     0.01%     4864    185      0    142841  3695.3s
#          1       0         1 100.00%   4980240.312834  4980823.694064     0.01%     4739    185      0    348546  3695.7s
#
# Solving report
#   Status            Optimal
#   Primal bound      4980823.69406
#   Dual bound        4980240.31283
#   Gap               0.0117% (tolerance: 0.5%)
#   P-D integral      3366.51128237
#   Solution status   feasible
#                     4980823.69406 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            3695.68
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     348546
#                     0 (strong br.)
#                     67796 (separation)
#                     205705 (heuristics)
# [P100] Scenario passes: SLA 99.83%, shortfall 0.00, future vehicles bought 1
# [P100] Recommended scenario: p100_future_total_1_MB_EV_18_1
#     ✓ P100 fleet expansion search complete   [4315.34s]
#     ✓ P90 built (10,608 flights)   [0.73s]
#     P90 demand summary: 17,274 PRMs across 10,608 flights
#     ✓ prepare_model_data started | flights=10,608   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.06s]
#     ✓ ambulift intervals built | flights=10,608 ambulifts=14   [1.32s]
#     ✓ minibus intervals built | minibuses=3   [0.16s]
#     ✓ staff intervals built   [0.04s]
#     ✓ ambulift overlaps built | overlaps=10,246,230   [2.48s]
#     ✓ minibus overlaps built | overlaps=951,285   [0.28s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.07s]
#     ✓ prepare_model_data complete | total=4.39s   [0.00s]
#     ✓ sets built | F=10,608 AMB=14 MINI=3   [0.08s]
#     ✓ variables built | x=53,040 amb=445,536 mini=63,648   [0.61s]
#     ✓ ambulift overlap constraints built | 10,246,230   [257.47s]
#     ✓ minibus overlap constraints built | 951,285   [7.33s]
#     ✓ build_pyomo_model complete | total=267.32s   [1.83s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=10,608 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 11897660 rows; 636497 cols; 24370253 nonzeros; 562241 integer variables (562241 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 6e+00]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 1701968 rows, 243639 cols, 3607287 nonzeros 18s
# 521904 rows, 214283 cols, 2344159 nonzeros 119s
# 521904 rows, 214283 cols, 2344160 nonzeros 234s
# Presolve reductions: rows 521904(-11375756); columns 214283(-422214); nonzeros 2344160(-22026093)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    521904 rows
#    214283 cols (192064 binary, 0 integer, 22219 implied int., 0 continuous, 0 domain fixed)
#    2344160 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            4721499617.826     Large        0      0      0         0   274.3s
#  R       0       0         0   0.00%   4280363.813166  1124019215.05     99.62%        0      0      0    272881  1297.0s
#          0       0         0   0.00%   4280363.813166  1124019215.05     99.62%     1012      4      0    275551  1358.0s
#          0       0         0   0.00%   4280363.813166  1124019215.05     99.62%     2015     30      0    280167  1411.2s
#          0       0         0   0.00%   4280363.813166  1124019215.05     99.62%     2070     41      0    282730  1466.3s
#          0       0         0   0.00%   4280364.484624  1124019215.05     99.62%     2103     52      0    350325  2018.9s
#  C       0       0         0   0.00%   4280365.71353   1082019669.297    99.60%     3110     84      0    459279  2650.2s
#          0       0         0   0.00%   4280365.73572   1082019669.297    99.60%     4112    124      0    464017  2709.4s
#          0       0         0   0.00%   4280365.73572   1082019669.297    99.60%     4165    138      0    468346  2769.8s
#          0       0         0   0.00%   4280365.73572   1082019669.297    99.60%     4206    149      0    470738  2802.3s
#          0       0         0   0.00%   4280365.73572   1082019669.297    99.60%     4228    158      0    475141  2860.6s
#          0       0         0   0.00%   4280365.73572   1082019669.297    99.60%     4258    166      0    478162  2896.8s
#          0       0         0   0.00%   4280365.73572   1082019669.297    99.60%     4296    174      0    480906  2941.6s
#          0       0         0   0.00%   4280366.011866  1082019669.297    99.60%     4309    184      0    535955  3393.1s
#          0       0         0   0.00%   4280366.345816  1082019669.297    99.60%     5311    216      0    598444  3846.8s
#          0       0         0   0.00%   4280366.394828  1082019669.297    99.60%     6325    238      0    651162  4260.6s
#          0       0         0   0.00%   4280366.394828  1082019669.297    99.60%     6908    236      0    657271  4352.3s
#          0       0         0   0.00%   4280366.394828  1082019669.297    99.60%     6971    254      0    660298  4401.2s
#          0       0         0   0.00%   4280366.408755  1082019669.297    99.60%     6996    263      0    669385  4520.4s
#          0       0         0   0.00%   4280366.411612  1082019669.297    99.60%     7177    275      0    675065  4594.1s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   4280366.42999   1082019669.297    99.60%     7230    287      0    684370  4718.9s
#          0       0         0   0.00%   4280366.42999   1082019669.297    99.60%     7388    277      0    686319  4746.4s
#          0       0         0   0.00%   4280366.461951  1082019669.297    99.60%     7471    296      0    726949  5085.5s
#          0       0         0   0.00%   4280366.807734  1082019669.297    99.60%     8477    324      0    863375  5887.2s
#          0       0         0   0.00%   4280366.871602  1082019669.297    99.60%     9485    361      0    939122  6490.9s
#          0       0         0   0.00%   4280367.381234  1082019669.297    99.60%    10492    405      0     1157k  7588.4s
#          0       0         0   0.00%   4280367.643343  1082019669.297    99.60%     9280    350      0     1218k  8027.6s
#          0       0         0   0.00%   4280367.644741  1082019669.297    99.60%    10184    379      0     1222k  8092.9s
#          0       0         0   0.00%   4280368.006199  1082019669.297    99.60%    11186    398      0     1296k  8714.4s
#          0       0         0   0.00%   4280368.006199  1082019669.297    99.60%     9660    414      0     1306k  8817.7s
#          0       0         0   0.00%   4280368.143651  1082019669.297    99.60%    10667    466      0     1343k  9089.1s
#          0       0         0   0.00%   4280368.161091  1082019669.297    99.60%    10077    447      0     1363k  9302.1s
#          0       0         0   0.00%   4280368.297367  1082019669.297    99.60%    10532    473      0     1413k  9699.4s
#          0       0         0   0.00%   4280368.297367  1082019669.297    99.60%    10119    488      0     1415k  9739.9s
#          0       0         0   0.00%   4280368.512405  1082019669.297    99.60%    11125    510      0     1554k 10396.1s
#          0       0         0   0.00%   4280368.512405  1082019669.297    99.60%     7766    522      0     1557k 10445.5s
#          0       0         0   0.00%   4280368.512405  1082019669.297    99.60%     8769    428      0     1563k 10511.0s
#          0       0         0   0.00%   4280368.512405  1082019669.297    99.60%     8912    453      0     1570k 10599.8s
#          0       0         0   0.00%   4280368.512405  1082019669.297    99.60%     8968    469      0     1574k 10645.8s
#  L       0       0         0   0.00%   4280368.512405  4280449.296804     0.00%     8968    469      0     1574k 12097.2s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          1       0         1 100.00%   4280368.512405  4280449.296804     0.00%     8968    469      0     1793k 12097.6s
#
# Solving report
#   Status            Optimal
#   Primal bound      4280449.2968
#   Dual bound        4280368.51598
#   Gap               0.00189% (tolerance: 0.5%)
#   P-D integral      11778.858648
#   Solution status   feasible
#                     4280449.2968 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            12097.65
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1793798
#                     0 (strong br.)
#                     1301328 (separation)
#                     219589 (heuristics)
#     ✓ P90 optimisation complete   [12665.12s]
#
# [P90 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     4
# 2                            0                   9                     7
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      4               0                   0              0
# 2                      7               0                   2              0
# 3                      3               0                   0              0
#
# [P90] Fleet expansion triggered because: Vehicle shortfall exists
#
# [P90] Testing 1 total future minibus candidate(s)
#
# [P90] Running scenario p90_future_total_1_MB_EV_18_1 with allocation {'MB_EV_10': 0, 'MB_EV_18': 1}
#     ✓ prepare_model_data started | flights=10,608   [0.00s]
#     ✓ vehicle expansion complete | vehicles=18   [0.06s]
#     ✓ ambulift intervals built | flights=10,608 ambulifts=14   [1.29s]
#     ✓ minibus intervals built | minibuses=4   [0.11s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=10,246,230   [2.05s]
#     ✓ minibus overlaps built | overlaps=1,268,380   [0.31s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.05s]
#     ✓ prepare_model_data complete | total=3.89s   [0.00s]
#     ✓ sets built | F=10,608 AMB=14 MINI=4   [0.03s]
#     ✓ variables built | x=53,040 amb=445,536 mini=84,864   [0.54s]
#     ✓ ambulift overlap constraints built | 10,246,230   [230.16s]
#     ✓ minibus overlap constraints built | 1,268,380   [4.02s]
#     ✓ build_pyomo_model complete | total=240.98s   [6.23s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=10,608 Vehicles=18
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 12278404 rows; 657715 cols; 25174173 nonzeros; 583459 integer variables (583459 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 2e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 1892211 rows, 258398 cols, 4004192 nonzeros 17s
# 557680 rows, 224893 cols, 2463673 nonzeros 121s
# 557680 rows, 224893 cols, 2463673 nonzeros 237s
# Presolve reductions: rows 557680(-11720724); columns 224893(-432822); nonzeros 2463673(-22710500)
#
# Solving MIP model with:
#    557680 rows
#    224893 cols (202674 binary, 0 integer, 22219 implied int., 0 continuous, 0 domain fixed)
#    2463673 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            4484684238.055     Large        0      0      0         0   280.7s
#  R       0       0         0   0.00%   2462216.51741   1090201377.863    99.77%        0      0      0    249846  1285.8s
#          0       0         0   0.00%   2462216.51741   1090201377.863    99.77%      465      3      0    252469  1353.8s
#          0       0         0   0.00%   2462216.51741   1090201377.863    99.77%     1466     22      0    258573  1429.9s
#          0       0         0   0.00%   2462216.51741   1090201377.863    99.77%     1500     28      0    261449  1463.3s
#          0       0         0   0.00%   2462216.51741   1090201377.863    99.77%     1518     32      0    264586  1505.8s
#          0       0         0   0.00%   2462216.51741   1090201377.863    99.77%     1559     37   8744    268041  1586.8s
#          0       0         0   0.00%   2462216.51741   1090201377.863    99.77%     1589     42   8744    270872  1625.8s
#          0       0         0   0.00%   2462216.51741   1090201377.863    99.77%     1605     45   8744    272812  1663.9s
#          0       0         0   0.00%   2462216.51741   1090201377.863    99.77%     1618     49   8744    274148  1692.3s
#          0       0         0   0.00%   2462216.51741   1090201377.863    99.77%     1630     52   8744    275628  1727.3s
#          0       0         0   0.00%   2462216.51741   1090201377.863    99.77%     1647     55   8744    277470  1762.3s
#          0       0         0   0.00%   2462216.51741   1090201377.863    99.77%     1673     59   8744    279553  1823.0s
#          0       0         0   0.00%   2462216.51741   1090201377.863    99.77%     1695     62   8744    282464  1871.2s
#          0       0         0   0.00%   2462216.51741   1090201377.863    99.77%     1733     69   8744    285650  1919.0s
#          0       0         0   0.00%   2462216.786682  1090201377.863    99.77%     1809     74   8744    342600  2383.1s
#          0       0         0   0.00%   2462216.786682  1090201377.863    99.77%     2815     91   8744    348787  2459.2s
#          0       0         0   0.00%   2462216.786682  1090201377.863    99.77%     2936    104   8744    354854  2532.6s
#          0       0         0   0.00%   2462217.156635  1090201377.863    99.77%     3007    113   8744    400507  2960.0s
#          0       0         0   0.00%   2462217.156635  1090201377.863    99.77%     4010    128   8744    405017  3031.2s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   2462217.156635  1090201377.863    99.77%     4040    135   8744    408256  3078.3s
#          0       0         0   0.00%   2462217.239312  1090201377.863    99.77%     4051    145   8744    439405  3356.9s
#          0       0         0   0.00%   2462218.184921  1090201377.863    99.77%     4117    153   8744    552382  4285.1s
#          0       0         0   0.00%   2462218.184921  1090201377.863    99.77%     5127    176   8744    558433  4359.8s
#          0       0         0   0.00%   2462218.184921  1090201377.863    99.77%     5194    186   8744    560756  4399.3s
#          0       0         0   0.00%   2462218.184921  1090201377.863    99.77%     5205    196   8744    565058  4449.7s
#          0       0         0   0.00%   2462218.184921  1090201377.863    99.77%     5238    194   8744    569941  4508.5s
#          0       0         0   0.00%   2462218.184921  1090201377.863    99.77%     5468    209   8744    573744  4556.7s
#          0       0         0   0.00%   2462218.184921  1090201377.863    99.77%     5484    219   8744    575979  4590.8s
#          0       0         0   0.00%   2462218.184921  1090201377.863    99.77%     5492    227   8744    580323  4647.4s
#          0       0         0   0.00%   2462218.184921  1090201377.863    99.77%     5557    234   8744    584746  4698.3s
#          0       0         0   0.00%   2462218.184921  1090201377.863    99.77%     5577    219   8744    587627  4734.8s
#  L       0       0         0   0.00%   2462218.184921  2462688.694064     0.02%     5577    219   8744    587627  6198.1s
#          1       0         1 100.00%   2462218.184921  2462688.694064     0.02%     5373    219   8744    774292  6198.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      2462688.69406
#   Dual bound        2462218.18492
#   Gap               0.0191% (tolerance: 0.5%)
#   P-D integral      5904.74289024
#   Solution status   feasible
#                     2462688.69406 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            6198.34
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     774292
#                     0 (strong br.)
#                     337781 (separation)
#                     186665 (heuristics)
# [P90] Scenario passes: SLA 99.92%, shortfall 0.00, future vehicles bought 1
# [P90] Recommended scenario: p90_future_total_1_MB_EV_18_1
#     ✓ P90 fleet expansion search complete   [6732.34s]
#     ✓ Excel outputs written to outputs\prm_combined_new\monthly\2026_10_v2.xlsx   [23.91s]
#
# Completed month: 2026_10
# Workbook: outputs\prm_combined_new\monthly\2026_10_combined.xlsx
#    S1_PeakAmb  S1_PeakMini  S1_PeakDrivers  S1_PeakVehAgents  S2_PeakAmb  \
# 0          11            2              12                12          11
# 1          14            3              17                17          11
#
#    S2_PeakMini  S2_PeakDrivers  S2_PeakVehAgents  V2_arrival_sla_pct  \
# 0           16              26                26           99.825085
# 1           15              25                25           99.920482
#
#    V2_PeakAmb  V2_PeakMini
# 0          13            3
# 1          12            3
