# %%
# ==========================================================
# JUNE 2025 BUFFER TEST
# ==========================================================

import sys
from pathlib import Path

# Add repo root to PYTHONPATH
HERE = Path().resolve()
PROJECT_ROOT = HERE.parents[0]
sys.path.insert(0, str(PROJECT_ROOT))

from prm_opt.run_s25_s26_v2 import run_s25_s26_v2
from prm_opt.optimise_prm_fleet_v2 import OptimiserConfig

VEHICLE_MODELS = {
    # ---------------- Ambulifts (current fleet) ----------------
    "AMB_14111": {"type": "Amb", "seatcap": 6, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_14112": {"type": "Amb", "seatcap": 6, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_OMN135": {"type": "Amb", "seatcap": 3, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_OMN079": {"type": "Amb", "seatcap": 6, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_OMN080": {"type": "Amb", "seatcap": 6, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_14161": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_14162": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_14163": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79803": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79802": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79801": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79804": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79805": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79900": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},

    # ---------------- Minibuses (current fleet) ----------------
    "MB_WJ160DR": {"type": "Mini", "seatcap": 6, "wccap": 2, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": False},
    "MB_WJ160DT": {"type": "Mini", "seatcap": 6, "wccap": 2, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": False},
    "MB_WJ160FD": {"type": "Mini", "seatcap": 6, "wccap": 2, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": False},

    # ---------------- Future purchase options ----------------
    "MB_EV_10": {"type": "Mini", "seatcap": 10, "wccap": 1, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": True},
    "MB_EV_18": {"type": "Mini", "seatcap": 18, "wccap": 1, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": True},
}

# ----------------------------------------------------------
# UPDATED SERVICE DURATIONS
# ----------------------------------------------------------

config = OptimiserConfig(
    tau_amb_solo_mins=31,   # 19 + 12
    tau_amb_comb_mins=26,   # 14 + 12
    tau_mini_mins=23,       # 14 + 9
    tau_push_mins=35,       #15 + 20

    handover_buffer_mins=5,

    arrival_sla_target_pct=0.98,
    arrival_sla_target_mins=20,

    boarding_offset_mins=40,

    staff_amb=2,
    staff_mini=2,
    staff_per_prm_push=1,

    max_future_copies_per_model=5,

    solver_relative_gap=0.005,
)

# ----------------------------------------------------------
# RUN JUNE ONLY
# ----------------------------------------------------------

results = run_s25_s26_v2(
    run_s25=True,
    s25_start="2025-06-01",
    s25_end="2025-06-30",

    run_s26=False,

    vehicle_models=VEHICLE_MODELS,
    config=config,

    output_dir="outputs/prm_v2/june_buffer_test",

    output_xlsx_name="2025_06_buffer_test.xlsx",

    run_p100=True,
    run_p90=True,

    run_fleet_report=True,

    fleet_report_policy="if_needed",
    current_fleet_only_first=True,

    max_ev10=5,
    max_ev18=5,
)

print(
    results["output_workbook_path"]
)

results["output_workbook_path"]
# Out:
#     ✓ S25 ingest complete (16,899 passengers)   [110.53s]
#     ✓ Passenger dataset combined (16,899 passenger rows)   [0.00s]
#     ✓ P100 built (6,692 flights)   [0.28s]
#     P100 demand summary: 16,899 PRMs across 6,692 flights
#     ✓ prepare_model_data started | flights=6,692   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.03s]
#     ✓ ambulift intervals built | flights=6,692 ambulifts=14   [0.50s]
#     ✓ minibus intervals built | minibuses=3   [0.07s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=5,200,685   [495.06s]
#     ✓ minibus overlaps built | overlaps=401,802   [38.96s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.03s]
#     ✓ prepare_model_data complete | total=534.67s   [0.00s]
#     ✓ sets built | F=6,692 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=33,460 amb=281,064 mini=40,152   [0.78s]
#     ✓ ambulift overlap constraints built | 5,200,685   [33.26s]
#     ✓ minibus overlap constraints built | 401,802   [1.48s]
#     ✓ build_pyomo_model complete | total=35.61s   [0.09s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,692 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 6044159 rows; 401537 cols; 12452404 nonzeros; 354693 integer variables (354693 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 814435 rows, 142890 cols, 1753019 nonzeros 9s
# 291947 rows, 125876 cols, 1231277 nonzeros 43s
# 291947 rows, 125876 cols, 1231277 nonzeros 77s
# Presolve reductions: rows 291947(-5752212); columns 125876(-275661); nonzeros 1231277(-11221127)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    291947 rows
#    125876 cols (111830 binary, 0 integer, 14046 implied int., 0 continuous, 0 domain fixed)
#    1231277 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2587645218.653     Large        0      0      0         0    84.4s
#  R       0       0         0   0.00%   458060.044144   1137454337.219    99.96%        0      0      0    113267   217.0s
#          0       0         0   0.00%   459120.410811   1137454337.219    99.96%     1366    213      0    114787   230.6s
#          0       0         0   0.00%   465987.02032    1137454337.219    99.96%     2660    551      0    117004   240.8s
#  C       0       0         0   0.00%   468521.059209   624454628.2968    99.92%     2745    670      0    119480   253.0s
#          0       0         0   0.00%   468587.559209   624454628.2968    99.92%     2810    677      0    120112   258.2s
#          0       0         0   0.00%   468587.559209   624454628.2968    99.92%     2821    681      0    121412   270.5s
#          0       0         0   0.00%   468690.67032    624454628.2968    99.92%     2849    684      0    121495   275.8s
#          0       0         0   0.00%   468690.67032    624454628.2968    99.92%     2958    686      0    121551   349.9s
#          0       0         0   0.00%   469329.906543   624454628.2968    99.92%     3054    734      0    124976   431.8s
#          0       0         0   0.00%   469437.019512   624454628.2968    99.92%     3240    763      0    128759   443.6s
#          0       0         0   0.00%   469970.792005   624454628.2968    99.92%     3438    789      0    136384   466.4s
#          0       0         0   0.00%   470180.36962    624454628.2968    99.92%     3901    808      0    137268   473.2s
#          0       0         0   0.00%   470219.61962    624454628.2968    99.92%     3929    704      0    137623   483.4s
#          0       0         0   0.00%   470264.286287   624454628.2968    99.92%     3991    714      0    137924   492.0s
#          0       0         0   0.00%   470284.86962    624454628.2968    99.92%     4054    718      0    138033   504.6s
#          0       0         0   0.00%   470304.536287   624454628.2968    99.92%     4117    723      0    138374   518.4s
#          0       0         0   0.00%   470306.689902   624454628.2968    99.92%     4124    729      0    147022   555.8s
#          0       0         0   0.00%   470379.77175    624454628.2968    99.92%     4759    728      0    153185   580.7s
#          0       0         0   0.00%   470387.105084   624454628.2968    99.92%     5031    744      0    153819   593.6s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   470387.493789   624454628.2968    99.92%     5068    751      0    167528   635.6s
#          0       0         0   0.00%   470436.493789   624454628.2968    99.92%     5776    765      0    168486   643.1s
#          0       0         0   0.00%   470436.500169   624454628.2968    99.92%     5823    771      0    170114   661.7s
#          0       0         0   0.00%   470436.775126   624454628.2968    99.92%     5878    748      0    190837   723.6s
#          0       0         0   0.00%   470436.801536   624454628.2968    99.92%     5933    755      0    195932   744.4s
#          0       0         0   0.00%   470436.801536   624454628.2968    99.92%     6506    759      0    196102   759.8s
#          0       0         0   0.00%   470436.801536   624454628.2968    99.92%     6515    763      0    196234   766.6s
#          0       0         0   0.00%   470436.839141   624454628.2968    99.92%     6551    767      0    203129   803.7s
#          0       0         0   0.00%   470436.974781   624454628.2968    99.92%     6979    757      0    213496   836.4s
#          0       0         0   0.00%   470436.98859    624454628.2968    99.92%     6268    771      0    215938   850.1s
#          0       0         0   0.00%   470436.98859    624454628.2968    99.92%     5841    776      0    216105   858.2s
#          0       0         0   0.00%   470436.98859    624454628.2968    99.92%     5579    780      0    216169   866.8s
#  L       0       0         0   0.00%   470436.98859    623145.465753     24.51%     5579    780      0    216169  1054.1s
#          0       0         0   0.00%   470436.98859    623145.465753     24.51%     5509    743      0    298391  1070.2s
#
# 0.1% inactive integer columns, restarting
# Model after restart has 289101 rows, 110283 cols (110283 bin., 0 int., 0 impl., 0 cont., 0 dom.fix.), and 1208272 nonzeros
#
#          0       0         0   0.00%   470436.98859    623145.465753     24.51%      616      0      0    298391  1085.4s
#          0       0         0   0.00%   470436.98859    623145.465753     24.51%      616    304      5    451506  1268.2s
#          0       0         0   0.00%   470437.308756   623145.465753     24.51%     1102    318      5    460410  1301.5s
#          0       0         0   0.00%   470437.721063   623145.465753     24.51%     2132    341      5    469644  1340.0s
#          0       0         0   0.00%   470437.98025    623145.465753     24.51%     3142    360      5    476259  1363.7s
#          0       0         0   0.00%   470438.31417    623145.465753     24.51%     4146    390      5    486147  1391.6s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   470438.361818   623145.465753     24.51%     4683    419      5    490495  1406.3s
#          0       0         0   0.00%   470438.590869   623145.465753     24.51%     5182    433      5    497295  1437.2s
#          0       0         0   0.00%   470438.832082   623145.465753     24.51%     5679    456      5    503497  1456.1s
#          0       0         0   0.00%   470438.832925   623145.465753     24.51%     5943    480      5    505180  1466.0s
#          0       0         0   0.00%   470439.067653   623145.465753     24.51%     6063    490      5    510302  1488.1s
#          0       0         0   0.00%   470439.260078   623145.465753     24.51%     6269    510      5    518585  1513.5s
#          0       0         0   0.00%   470439.369575   623145.465753     24.51%     6653    533      5    522910  1530.8s
#          0       0         0   0.00%   470439.54354    623145.465753     24.51%     6896    556      5    525299  1551.0s
#          0       0         0   0.00%   470439.57265    623145.465753     24.51%     6968    568      5    528216  1560.3s
#
# Symmetry detection completed in 21.0s
# Found 6 generator(s) and 392 full orbitope(s) acting on 3497 columns
#
#  T       0       0         0   0.00%   470439.57265    470483.050228      0.01%     6968    399     10    528216  2843.5s
#        120       0         1 100.00%   470439.57265    470483.050228      0.01%     6969    399     10    953468  2843.7s
#
# Solving report
#   Status            Optimal
#   Primal bound      470483.050228
#   Dual bound        470439.575342
#   Gap               0.00924% (tolerance: 0.5%)
#   P-D integral      1407.06691679
#   Solution status   feasible
#                     470483.050228 (objective)
#                     0 (bound viol.)
#                     1.1745509829e-13 (int. viol.)
#                     0 (row viol.)
#   Timing            2843.68
#   Max sub-MIP depth 3
#   Nodes             120
#   Repair LPs        0
#   LP iterations     953468
#                     357101 (strong br.)
#                     179672 (separation)
#                     82162 (heuristics)
#     ✓ P100 optimisation complete   [3598.08s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   0                     0
# 1                            0                   3                     3
# 2                            0                   8                     8
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      0               0                   1              0
# 1                      3               0                   1              0
# 2                      8               0                   1              0
# 3                      3               0                   0              0
#
# [P100] Current fleet meets SLA and has no current-fleet gap. Skipping fleet expansion search.
#     ✓ P90 built (6,692 flights)   [0.63s]
#     P90 demand summary: 15,678 PRMs across 6,692 flights
#     ✓ prepare_model_data started | flights=6,692   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.04s]
#     ✓ ambulift intervals built | flights=6,692 ambulifts=14   [0.38s]
#     ✓ minibus intervals built | minibuses=3   [0.07s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=5,030,194   [541.42s]
#     ✓ minibus overlaps built | overlaps=402,513   [38.21s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=580.15s   [0.00s]
#     ✓ sets built | F=6,692 AMB=14 MINI=3   [0.02s]
#     ✓ variables built | x=33,460 amb=281,064 mini=40,152   [0.23s]
#     ✓ ambulift overlap constraints built | 5,030,194   [79.62s]
#     ✓ minibus overlap constraints built | 402,513   [1.61s]
#     ✓ build_pyomo_model complete | total=81.61s   [0.13s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,692 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 5874379 rows; 401537 cols; 12112844 nonzeros; 354693 integer variables (354693 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 1e+01]
#   Cost    [2e+00, 1e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# Presolving model
# 799481 rows, 142890 cols, 1723111 nonzeros 9s
# 290881 rows, 125876 cols, 1212646 nonzeros 42s
# 290881 rows, 125876 cols, 1212646 nonzeros 78s
# Presolve reductions: rows 290881(-5583498); columns 125876(-275661); nonzeros 1212646(-10900198)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    290881 rows
#    125876 cols (111830 binary, 0 integer, 14046 implied int., 0 continuous, 0 domain fixed)
#    1212646 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2562602692.479     Large        0      0      0         0    84.8s
#  R       0       0         0   0.00%   436977.670357   767435096.2192    99.94%        0      0      0    111724   195.7s
#          0       0         0   0.00%   437540.158453   767435096.2192    99.94%     1198    128      0    112384   206.7s
#          0       0         0   0.00%   440489.608453   767435096.2192    99.94%     2373    343      0    113371   212.0s
#  C       0       0         0   0.00%   442228.029881   459434996.2968    99.90%     2397    427      0    113827   217.3s
#          0       0         0   0.00%   442787.896548   459434996.2968    99.90%     2434    467      0    114446   228.1s
#          0       0         0   0.00%   442889.844185   459434996.2968    99.90%     2473    488      0    124329   260.0s
#          0       0         0   0.00%   443174.617148   459434996.2968    99.90%     2727    503      0    127579   274.1s
#          0       0         0   0.00%   443190.902862   459434996.2968    99.90%     3016    511      0    127823   280.5s
#          0       0         0   0.00%   443207.688576   459434996.2968    99.90%     3035    518      0    127948   285.8s
#          0       0         0   0.00%   443239.783814   459434996.2968    99.90%     3105    523      0    128107   297.4s
#          0       0         0   0.00%   443247.276434   459434996.2968    99.90%     3138    436      0    141269   337.8s
#          0       0         0   0.00%   443247.276434   459434996.2968    99.90%     3418    449      0    141677   344.3s
#          0       0         0   0.00%   443247.83475    459434996.2968    99.90%     3435    455      0    151323   379.0s
#          0       0         0   0.00%   443247.83475    459434996.2968    99.90%     3952    443      0    152181   386.4s
#          0       0         0   0.00%   443247.83475    459434996.2968    99.90%     3970    451      0    152840   391.8s
#  L       0       0         0   0.00%   443247.83475    443458.634703      0.05%     3970    451      0    152840   542.0s
#          1       0         1 100.00%   443247.83475    443458.634703      0.05%     3970    451      0    225777   542.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      443458.634703
#   Dual bound        443247.835616
#   Gap               0.0475% (tolerance: 0.5%)
#   P-D integral      456.29718829
#   Solution status   feasible
#                     443458.634703 (objective)
#                     0 (bound viol.)
#                     1.99840144433e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            542.14
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     225777
#                     0 (strong br.)
#                     41116 (separation)
#                     72937 (heuristics)
#     ✓ P90 optimisation complete   [1356.38s]
#
# [P90 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   0                     0
# 1                            0                   4                     4
# 2                            0                   6                     6
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      0               0                   1              0
# 1                      4               0                   0              0
# 2                      6               0                   3              0
# 3                      3               0                   0              0
#
# [P90] Current fleet meets SLA and has no current-fleet gap. Skipping fleet expansion search.
#     ✓ Excel outputs written to outputs\prm_v2\june_buffer_test\2025_06_buffer_test.xlsx   [24.71s]
# outputs\prm_v2\june_buffer_test\2025_06_buffer_test.xlsx
# 'outputs\\prm_v2\\june_buffer_test\\2025_06_buffer_test.xlsx'

# %%
# ==========================================================
# JUNE 2025 DIAGNOSTIC RUN
# ==========================================================

import sys
from pathlib import Path

# Add repo root to PYTHONPATH
HERE = Path().resolve()
PROJECT_ROOT = HERE.parents[0]
sys.path.insert(0, str(PROJECT_ROOT))

from prm_opt.run_s25_s26_v2 import run_s25_s26_v2
from prm_opt.optimise_prm_fleet_v2 import OptimiserConfig

import prm_opt.build_flights_v2
import prm_opt.optimise_prm_fleet_v2
import prm_opt.run_s25_s26_v2

VEHICLE_MODELS = {
    # ---------------- Ambulifts (current fleet) ----------------
    "AMB_14111": {"type": "Amb", "seatcap": 6, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_14112": {"type": "Amb", "seatcap": 6, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_OMN135": {"type": "Amb", "seatcap": 3, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_OMN079": {"type": "Amb", "seatcap": 6, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_OMN080": {"type": "Amb", "seatcap": 6, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_14161": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_14162": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_14163": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79803": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79802": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79801": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79804": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79805": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79900": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},

    # ---------------- Minibuses (current fleet) ----------------
    "MB_WJ160DR": {"type": "Mini", "seatcap": 6, "wccap": 2, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": False},
    "MB_WJ160DT": {"type": "Mini", "seatcap": 6, "wccap": 2, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": False},
    "MB_WJ160FD": {"type": "Mini", "seatcap": 6, "wccap": 2, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": False},

    # ---------------- Future purchase options ----------------
    "MB_EV_10": {"type": "Mini", "seatcap": 10, "wccap": 1, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": True},
    "MB_EV_18": {"type": "Mini", "seatcap": 18, "wccap": 1, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": True},
}


config_buffer_test = OptimiserConfig(
    tau_amb_solo_mins=31,
    tau_amb_comb_mins=26,
    tau_mini_mins=23,
    tau_push_mins=20,

    handover_buffer_mins=5,

    arrival_sla_target_pct=0.98,
    arrival_sla_target_mins=20,

    boarding_offset_mins=40,

    staff_amb=2,
    staff_mini=2,
    staff_per_prm_push=1,

    max_future_copies_per_model=5,

    solver_relative_gap=0.005,
)

results_june_buffer = run_s25_s26_v2(
    run_s25=True,
    s25_start="2025-06-01",
    s25_end="2025-06-30",

    run_s26=False,

    vehicle_models=VEHICLE_MODELS,
    config=config_buffer_test,

    output_dir="outputs/prm_v2/june_buffer_test",

    output_xlsx_name="2025_06_buffer_test.xlsx",

    run_p100=True,
    run_p90=True,

    run_fleet_report=True,

    fleet_report_policy="if_needed",
    current_fleet_only_first=True,

    max_ev10=5,
    max_ev18=5,
)

print(results_june_buffer["output_workbook_path"])
# Out:
#     ✓ S25 ingest complete (16,899 passengers)   [60.95s]
#     ✓ Passenger dataset combined (16,899 passenger rows)   [0.00s]
#     ✓ P100 built (6,692 flights)   [0.14s]
#     P100 demand summary: 16,899 PRMs across 6,692 flights
#     ✓ prepare_model_data started | flights=6,692   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.02s]
#     ✓ ambulift intervals built | flights=6,692 ambulifts=14   [0.92s]
#     ✓ minibus intervals built | minibuses=3   [0.05s]
#     ✓ staff intervals built   [0.01s]
#     ✓ ambulift overlaps built | overlaps=4,482,108   [381.90s]
#     ✓ minibus overlaps built | overlaps=404,241   [29.04s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.02s]
#     ✓ prepare_model_data complete | total=411.97s   [0.00s]
#     ✓ sets built | F=6,692 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=33,460 amb=281,064 mini=40,152   [0.71s]
#     ✓ ambulift overlap constraints built | 4,482,108   [23.47s]
#     ✓ minibus overlap constraints built | 404,241   [1.14s]
#     ✓ build_pyomo_model complete | total=26.01s   [0.68s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,692 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 5328021 rows; 401537 cols; 11020128 nonzeros; 354693 integer variables (354693 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 7e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 694518 rows, 142890 cols, 1513185 nonzeros 6s
# 284240 rows, 125734 cols, 1090813 nonzeros 26s
# 284240 rows, 125734 cols, 1090813 nonzeros 54s
# Presolve reductions: rows 284240(-5043781); columns 125734(-275803); nonzeros 1090813(-9929315)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    284240 rows
#    125734 cols (111694 binary, 0 integer, 14040 implied int., 0 continuous, 0 domain fixed)
#    1090813 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2577409537.479     Large        0      0      0         0    64.0s
#  R       0       0         0   0.00%   28687243.64774  1225369568.635    97.66%        0      0      0     34814   180.6s
#          0       0         0   0.00%   28687435.01354  1225369568.635    97.66%     1329    228      0     36547   192.5s
#          0       0         0   0.00%   28839277.86672  1225369568.635    97.65%     1565    442      0     58895   294.5s
#          0       0         0   0.00%   29132254.87203  1225369568.635    97.62%     2617    634      0     69332   330.0s
#          0       0         0   0.00%   29133606.84981  1225369568.635    97.62%     2942    743      0     74063   346.2s
#  C       0       0         0   0.00%   29133889.84981  1225118414.297    97.62%     3072    771      0     78146   366.9s
#          0       0         0   0.00%   29134015.33747  1225118414.297    97.62%     3163    779      0     80156   380.5s
#          0       0         0   0.00%   29134049.58747  1225118414.297    97.62%     3358    785      0     82438   418.0s
#          0       0         0   0.00%   29134049.58747  1225118414.297    97.62%     3610    788      0     84801   459.7s
#          0       0         0   0.00%   29134160.61888  1225118414.297    97.62%     3848    816      0    101035   567.2s
#          0       0         0   0.00%   29134189.95484  1225118414.297    97.62%     4585    848      0    108272   619.8s
#          0       0         0   0.00%   29134207.08817  1225118414.297    97.62%     4806    862      0    112196   641.1s
#          0       0         0   0.00%   29134208.15484  1225118414.297    97.62%     4963    871      0    114728   654.8s
#          0       0         0   0.00%   29134213.07084  1225118414.297    97.62%     5098    880      0    130000   750.5s
#          0       0         0   0.00%   29134217.9324   1225118414.297    97.62%     5671    908      0    156650   905.3s
#          0       0         0   0.00%   29134218.13497  1225118414.297    97.62%     6679    789      0    170645   981.6s
#          0       0         0   0.00%   29134231.63927  1225118414.297    97.62%     7665    800      0    178468  1018.2s
#          0       0         0   0.00%   29134231.63927  1225118414.297    97.62%     8044    809      0    181029  1032.9s
#          0       0         0   0.00%   29134231.63927  1225118414.297    97.62%     8238    817      0    181620  1044.0s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   29134231.63927  1225118414.297    97.62%     8298    824      0    183670  1054.8s
#  L       0       0         0   0.00%   29134231.63927  29134762.6347      0.00%     8298    824      0    183670  1341.4s
#          1       0         1 100.00%   29134231.63927  29134762.6347      0.00%     8298    824      0    233500  1341.7s
#
# Solving report
#   Status            Optimal
#   Primal bound      29134762.6347
#   Dual bound        29134231.6393
#   Gap               0.00182% (tolerance: 0.5%)
#   P-D integral      1249.26547129
#   Solution status   feasible
#                     29134762.6347 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            1341.67
#   Max sub-MIP depth 3
#   Nodes             1
#   Repair LPs        0
#   LP iterations     233500
#                     0 (strong br.)
#                     148856 (separation)
#                     49830 (heuristics)
#     ✓ P100 optimisation complete   [1891.85s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   2                     2
# 2                            0                   7                     7
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      2               0                   2              0
# 2                      7               0                   2              0
# 3                      3               0                   0              0
#
# [P100] Running fleet expansion scenario: +1 future copy per future model
#     ✓ prepare_model_data started | flights=6,692   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.04s]
#     ✓ ambulift intervals built | flights=6,692 ambulifts=14   [0.97s]
#     ✓ minibus intervals built | minibuses=5   [0.08s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=4,482,108   [566.54s]
#     ✓ minibus overlaps built | overlaps=673,735   [89.37s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.04s]
#     ✓ prepare_model_data complete | total=657.07s   [0.00s]
#     ✓ sets built | F=6,692 AMB=14 MINI=5   [0.03s]
#     ✓ variables built | x=33,460 amb=281,064 mini=66,920   [0.32s]
#     ✓ ambulift overlap constraints built | 4,482,108   [77.80s]
#     ✓ minibus overlap constraints built | 673,735   [3.56s]
#     ✓ build_pyomo_model complete | total=83.42s   [1.71s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,692 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 5677821 rows; 428309 cols; 11773264 nonzeros; 381465 integer variables (381465 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 7e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 864250 rows, 160962 cols, 1875005 nonzeros 7s
# 330517 rows, 139122 cols, 1235070 nonzeros 37s
# 330517 rows, 139122 cols, 1235070 nonzeros 74s
# Presolve reductions: rows 330517(-5347304); columns 139122(-289187); nonzeros 1235070(-10538194)
#
# Solving MIP model with:
#    330517 rows
#    139122 cols (125082 binary, 0 integer, 14040 implied int., 0 continuous, 0 domain fixed)
#    1235070 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2645591905.881     Large        0      0      0         0    89.5s
#  R       0       0         0   0.00%   27507512.06489  1547546869.447    98.22%        0      0      0     37608   257.2s
#          0       0         0   0.00%   27552970.33484  1547546869.447    98.22%     1315    258      0     41087   286.2s
#          0       0         0   0.00%   27553108.12751  1547546869.447    98.22%     1464    356      0     42906   300.1s
#          0       0         0   0.00%   27553575.30435  1547546869.447    98.22%     1536    441      0     51943   351.0s
#          0       0         0   0.00%   27553842.2334   1547546869.447    98.22%     1918    509      0     61724   423.8s
#  C       0       0         0   0.00%   27553959.2207   654981487.9269    95.79%     2224    548      0     64502   449.4s
#          0       0         0   0.00%   27554145.64451  654981487.9269    95.79%     2252    567      0     68783   474.3s
#          0       0         0   0.00%   27554175.47784  654981487.9269    95.79%     2293    574      0     72647   500.3s
#          0       0         0   0.00%   27554200.81118  654981487.9269    95.79%     2331    581      0     73583   511.6s
#          0       0         0   0.00%   27554205.81118  654981487.9269    95.79%     2509    587      0     75171   605.5s
#          0       0         0   0.00%   27554205.81118  654981487.9269    95.79%     2567    591      0     76319   633.7s
#          0       0         0   0.00%   27554222.81118  654981487.9269    95.79%     2610    595      0     77095   668.5s
#          0       0         0   0.00%   27554227.81118  654981487.9269    95.79%     2624    599      0     79914   699.5s
#          0       0         0   0.00%   27554232.81118  654981487.9269    95.79%     2840    604      0     84196   805.9s
#          0       0         0   0.00%   27554242.81118  654981487.9269    95.79%     2956    610      0     89382   863.1s
#          0       0         0   0.00%   27554242.81118  654981487.9269    95.79%     3157    458      0     93138   907.5s
#          0       0         0   0.00%   27554248.81118  654981487.9269    95.79%     3594    465      0     94843   950.3s
#          0       0         0   0.00%   27554272.58041  654981487.9269    95.79%     3795    470      0     99254  1000.7s
#  L       0       0         0   0.00%   27554272.58041  27554677.44749     0.00%     3795    470      0     99254  1248.0s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          1       0         1 100.00%   27554272.58041  27554677.44749     0.00%     3795    470      0    145716  1248.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      27554677.4475
#   Dual bound        27554272.5804
#   Gap               0.00147% (tolerance: 0.5%)
#   P-D integral      1120.70869594
#   Solution status   feasible
#                     27554677.4475 (objective)
#                     0 (bound viol.)
#                     9.32587340685e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            1248.21
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     145716
#                     0 (strong br.)
#                     61646 (separation)
#                     46462 (heuristics)
# [P100] Stopping fleet expansion: scenario +1 meets SLA and has no shortfall.
#     ✓ P100 fleet expansion search complete   [2140.68s]
#     ✓ P90 built (6,692 flights)   [0.54s]
#     P90 demand summary: 15,678 PRMs across 6,692 flights
#     ✓ prepare_model_data started | flights=6,692   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.04s]
#     ✓ ambulift intervals built | flights=6,692 ambulifts=14   [0.81s]
#     ✓ minibus intervals built | minibuses=3   [0.06s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=4,402,380   [615.71s]
#     ✓ minibus overlaps built | overlaps=404,379   [46.59s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.04s]
#     ✓ prepare_model_data complete | total=663.26s   [0.00s]
#     ✓ sets built | F=6,692 AMB=14 MINI=3   [0.03s]
#     ✓ variables built | x=33,460 amb=281,064 mini=40,152   [0.29s]
#     ✓ ambulift overlap constraints built | 4,402,380   [82.47s]
#     ✓ minibus overlap constraints built | 404,379   [3.50s]
#     ✓ build_pyomo_model complete | total=87.53s   [1.23s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,692 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 5248431 rows; 401537 cols; 10860948 nonzeros; 354693 integer variables (354693 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 1e+01]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -2
# Presolving model
# 682824 rows, 142890 cols, 1489797 nonzeros 7s
# 283606 rows, 125835 cols, 1079018 nonzeros 40s
# 283606 rows, 125835 cols, 1079018 nonzeros 82s
# Presolve reductions: rows 283606(-4964825); columns 125835(-275702); nonzeros 1079018(-9781930)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    283606 rows
#    125835 cols (111790 binary, 0 integer, 14045 implied int., 0 continuous, 0 domain fixed)
#    1079018 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2575383768.653     Large        0      0      0         0    96.9s
#  R       0       0         0   0.00%   22113389.48565  1094604685.881    97.98%        0      0      0     28201   178.0s
#          0       0         0   0.00%   22113456.43803  1094604685.881    97.98%     1246    130      0     29073   191.7s
#          0       0         0   0.00%   22114109.96184  1094604685.881    97.98%     1463    256      0     37832   225.1s
#          0       0         0   0.00%   22115475.72374  1094604685.881    97.98%     1901    364      0     41114   240.4s
#          0       0         0   0.00%   22116337.89041  1094604685.881    97.98%     2051    435      0     41910   247.8s
#  C       0       0         0   0.00%   22116436.75708  1094353848.297    97.98%     2161    445      0     42946   256.4s
#          0       0         0   0.00%   22116466.55708  1094353848.297    97.98%     2239    453      0     43060   273.1s
#          0       0         0   0.00%   22116475.55708  1094353848.297    97.98%     2407    455      0     43080   347.0s
#          0       0         0   0.00%   22116475.55708  1094353848.297    97.98%     2555    456      0     43082   380.2s
#          0       0         0   0.00%   22116475.55708  1094353848.297    97.98%     2623    457      0     43084   417.4s
#          0       0         0   0.00%   22116475.55708  1094353848.297    97.98%     2649    459      0     43145   429.5s
#          0       0         0   0.00%   22116475.55708  1094353848.297    97.98%     2798    460      0     43182   463.8s
#          0       0         0   0.00%   22116475.55708  1094353848.297    97.98%     2880    462      0     43232   484.1s
#          0       0         0   0.00%   22116475.55708  1094353848.297    97.98%     2991    464      0     43484   525.9s
#  L       0       0         0   0.00%   22116475.55708  22116765.2968      0.00%     2991    464      0     43484  1012.2s
#          1       0         1 100.00%   22116475.55708  22116765.2968      0.00%     2991    464      0     83294  1012.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      22116765.2968
#   Dual bound        22116475.5571
#   Gap               0.00131% (tolerance: 0.5%)
#   P-D integral      897.817705604
#   Solution status   feasible
#                     22116765.2968 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            1012.37
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     83294
#                     0 (strong br.)
#                     15283 (separation)
#                     39810 (heuristics)
#     ✓ P90 optimisation complete   [1898.96s]
#
# [P90 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     3
# 2                            0                   9                     7
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      3               0                   1              0
# 2                      7               0                   2              0
# 3                      3               0                   0              0
#
# [P90] Current fleet meets SLA and has no current-fleet gap. Skipping fleet expansion search.
#     ✓ Excel outputs written to outputs\prm_v2\june_buffer_test\2025_06_buffer_test.xlsx   [41.93s]
# outputs\prm_v2\june_buffer_test\2025_06_buffer_test.xlsx

# %%
# ==========================================================
# JUNE 2025 DIAGNOSTIC RUN
# ==========================================================

import sys
from pathlib import Path

# Add repo root to PYTHONPATH
HERE = Path().resolve()
PROJECT_ROOT = HERE.parents[0]
sys.path.insert(0, str(PROJECT_ROOT))

from prm_opt.run_s25_s26_v2 import run_s25_s26_v2
from prm_opt.optimise_prm_fleet_v2 import OptimiserConfig

import prm_opt.build_flights_v2
import prm_opt.optimise_prm_fleet_v2
import prm_opt.run_s25_s26_v2

VEHICLE_MODELS = {
    # ---------------- Ambulifts (current fleet) ----------------
    "AMB_14111": {"type": "Amb", "seatcap": 6, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_14112": {"type": "Amb", "seatcap": 6, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_OMN135": {"type": "Amb", "seatcap": 3, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_OMN079": {"type": "Amb", "seatcap": 6, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_OMN080": {"type": "Amb", "seatcap": 6, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_14161": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_14162": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_14163": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79803": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79802": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79801": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79804": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79805": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},
    "AMB_79900": {"type": "Amb", "seatcap": 7, "wccap": 1, "staff": 2, "capex_hr": 500000 / (5 * 365 * 24), "is_future": False},

    # ---------------- Minibuses (current fleet) ----------------
    "MB_WJ160DR": {"type": "Mini", "seatcap": 6, "wccap": 2, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": False},
    "MB_WJ160DT": {"type": "Mini", "seatcap": 6, "wccap": 2, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": False},
    "MB_WJ160FD": {"type": "Mini", "seatcap": 6, "wccap": 2, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": False},

    # ---------------- Future purchase options ----------------
    "MB_EV_10": {"type": "Mini", "seatcap": 10, "wccap": 1, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": True},
    "MB_EV_18": {"type": "Mini", "seatcap": 18, "wccap": 1, "staff": 2, "capex_hr": 80000 / (5 * 365 * 24), "is_future": True},
}


config_buffer_test = OptimiserConfig(
    tau_amb_solo_mins=31,
    tau_amb_comb_mins=26,
    tau_mini_mins=23,
    tau_push_mins=20,

    handover_buffer_mins=5,

    arrival_sla_target_pct=0.98,
    arrival_sla_target_mins=20,

    boarding_offset_mins=40,

    staff_amb=2,
    staff_mini=2,
    staff_per_prm_push=1,

    max_future_copies_per_model=5,

    solver_relative_gap=0.005,
)

results_june_buffer = run_s25_s26_v2(
    run_s25=True,
    s25_start="2025-06-01",
    s25_end="2025-06-30",

    run_s26=False,

    vehicle_models=VEHICLE_MODELS,
    config=config_buffer_test,

    output_dir="outputs/prm_v2/june_buffer_test",

    output_xlsx_name="2025_06_test_ambulogic.xlsx",

    run_p100=True,
    run_p90=True,

    run_fleet_report=True,

    fleet_report_policy="if_needed",
    current_fleet_only_first=True,

    max_ev10=5,
    max_ev18=5,
)

print(results_june_buffer["output_workbook_path"])
# Out:
#     ✓ S25 ingest complete (16,899 passengers)   [67.35s]
#     ✓ Passenger dataset combined (16,899 passenger rows)   [0.00s]
#     ✓ P100 built (6,692 flights)   [0.22s]
#     P100 demand summary: 16,899 PRMs across 6,692 flights
#     ✓ prepare_model_data started | flights=6,692   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.07s]
#     ✓ ambulift intervals built | flights=6,692 ambulifts=14   [1.16s]
#     ✓ minibus intervals built | minibuses=3   [0.08s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=4,482,108   [1.20s]
#     ✓ minibus overlaps built | overlaps=404,241   [0.12s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.03s]
#     ✓ prepare_model_data complete | total=2.68s   [0.00s]
#     ✓ sets built | F=6,692 AMB=14 MINI=3   [0.00s]
#     ✓ variables built | x=33,460 amb=281,064 mini=40,152   [0.88s]
#     ✓ ambulift overlap constraints built | 4,482,108   [37.52s]
#     ✓ minibus overlap constraints built | 404,241   [1.95s]
#     ✓ build_pyomo_model complete | total=41.12s   [0.77s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,692 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 5328322 rows; 401537 cols; 11020429 nonzeros; 354693 integer variables (354693 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 7e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 694518 rows, 141338 cols, 1495194 nonzeros 14s
# 278732 rows, 124306 cols, 1067533 nonzeros 65s
# 258652 rows, 124287 cols, 1017474 nonzeros 114s
# Presolve reductions: rows 258652(-5069670); columns 124287(-277250); nonzeros 1017474(-10002955)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    258652 rows
#    124287 cols (110343 binary, 0 integer, 13944 implied int., 0 continuous, 0 domain fixed)
#    1017474 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2625437762.479     Large        0      0      0         0   127.3s
#  R       0       0         0   0.00%   17395517.28887  1226387465.635    98.58%        0      0      0     32237   376.6s
#          0       0         0   0.00%   19396234.3116   1226387465.635    98.42%     1399    242      0     32809   385.9s
#          0       0         0   0.00%   19399655.06738  1226387465.635    98.42%     1739    623      0     35310   400.0s
#          0       0         0   0.00%   19400695.07393  1226387465.635    98.42%     1781    710      0     41850   432.3s
#  C       0       0         0   0.00%   19401713.61433  1088387257.297    98.22%     1998    747      0     42961   441.2s
#          0       0         0   0.00%   19401869.84766  1088387257.297    98.22%     2051    763      0     43362   448.5s
#          0       0         0   0.00%   19401913.34766  1088387257.297    98.22%     2066    773      0     43656   457.6s
#          0       0         0   0.00%   19401948.12544  1088387257.297    98.22%     2120    784      0     44560   476.8s
#          0       0         0   0.00%   19401948.12544  1088387257.297    98.22%     2166    787      0     44638   486.4s
#          0       0         0   0.00%   19401948.12544  1088387257.297    98.22%     2184    790      0     45397   504.7s
#          0       0         0   0.00%   19401948.12544  1088387257.297    98.22%     2198    793      0     45645   517.4s
#          0       0         0   0.00%   19401948.12544  1088387257.297    98.22%     2198    796      0     46034   531.4s
#          0       0         0   0.00%   19401948.12544  1088387257.297    98.22%     2205    799      0     46518   544.4s
#  L       0       0         0   0.00%   19401948.12544  19403471.2968      0.01%     2205    799      0     46518   884.5s
#          1       0         1 100.00%   19401948.12544  19403471.2968      0.01%     2205    799      0     89894   885.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      19403471.2968
#   Dual bound        19401948.1279
#   Gap               0.00785% (tolerance: 0.5%)
#   P-D integral      747.552687596
#   Solution status   feasible
#                     19403471.2968 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            885.00
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     89894
#                     0 (strong br.)
#                     14281 (separation)
#                     43376 (heuristics)
#     ✓ P100 optimisation complete   [1135.24s]
#
# [P100 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     4
# 2                            0                   9                     6
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      4               0                   0              0
# 2                      6               0                   3              0
# 3                      3               0                   0              0
#
# [P100] Running fleet expansion scenario: +1 future copy per future model
#     ✓ prepare_model_data started | flights=6,692   [0.00s]
#     ✓ vehicle expansion complete | vehicles=19   [0.14s]
#     ✓ ambulift intervals built | flights=6,692 ambulifts=14   [1.90s]
#     ✓ minibus intervals built | minibuses=5   [0.15s]
#     ✓ staff intervals built   [0.04s]
#     ✓ ambulift overlaps built | overlaps=4,482,108   [2.08s]
#     ✓ minibus overlaps built | overlaps=673,735   [0.39s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.06s]
#     ✓ prepare_model_data complete | total=4.77s   [0.00s]
#     ✓ sets built | F=6,692 AMB=14 MINI=5   [0.03s]
#     ✓ variables built | x=33,460 amb=281,064 mini=66,920   [0.69s]
#     ✓ ambulift overlap constraints built | 4,482,108   [109.85s]
#     ✓ minibus overlap constraints built | 673,735   [4.18s]
#     ✓ build_pyomo_model complete | total=116.26s   [1.52s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,692 Vehicles=19
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 5678122 rows; 428309 cols; 11773565 nonzeros; 381465 integer variables (381465 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 3e+01]
#   Cost    [2e+00, 7e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -3
# Presolving model
# 864250 rows, 159410 cols, 1857014 nonzeros 15s
# 324811 rows, 137695 cols, 1210894 nonzeros 74s
# 324811 rows, 137695 cols, 1210894 nonzeros 153s
# Presolve reductions: rows 324811(-5353311); columns 137695(-290614); nonzeros 1210894(-10562671)
#
# Solving MIP model with:
#    324811 rows
#    137695 cols (123746 binary, 0 integer, 13949 implied int., 0 continuous, 0 domain fixed)
#    1210894 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2627802862.936     Large        0      0      0         0   180.7s
#  R       0       0         0   0.00%   523386.889502   1435562814.279    99.96%        0      0      0     54951   445.9s
#          0       0         0   0.00%   568739.605875   1435562814.279    99.96%     1336    271      0     57386   468.6s
#          0       0         0   0.00%   568933.599309   1435562814.279    99.96%     1493    382      0     58162   474.2s
#          0       0         0   0.00%   569565.0543     1435562814.279    99.96%     1553    477      0     59602   481.6s
#          0       0         0   0.00%   569836.35137    1435562814.279    99.96%     1590    531      0     60459   488.0s
#  C       0       0         0   0.00%   569998.629148   843745510.9269    99.93%     1633    564      0     61723   497.4s
#          0       0         0   0.00%   570056.462481   843745510.9269    99.93%     1644    576      0     63348   508.9s
#          0       0         0   0.00%   570077.795814   843745510.9269    99.93%     1655    584      0     64331   516.6s
#          0       0         0   0.00%   570091.795814   843745510.9269    99.93%     1658    589      0     68729   536.1s
#          0       0         0   0.00%   570096.795814   843745510.9269    99.93%     1747    598      0     69142   545.5s
#          0       0         0   0.00%   570101.830822   843745510.9269    99.93%     1762    604      0     73486   574.6s
#          0       0         0   0.00%   570107.330822   843745510.9269    99.93%     1849    612      0     73727   582.6s
#          0       0         0   0.00%   570109.664156   843745510.9269    99.93%     1852    618      0     74143   591.0s
#          0       0         0   0.00%   570110.145556   843745510.9269    99.93%     1853    623      0     77092   612.0s
#          0       0         0   0.00%   570138.145556   843745510.9269    99.93%     2100    632      0     77654   671.8s
#          0       0         0   0.00%   570155.405118   843745510.9269    99.93%     2272    497      0     83982   768.2s
#          0       0         0   0.00%   570273.119404   843745510.9269    99.93%     2562    515      0     84439   773.3s
#          0       0         0   0.00%   570343.664779   843745510.9269    99.93%     2586    521      0     94130   832.5s
#          0       0         0   0.00%   570350.331446   843745510.9269    99.93%     3021    528      0     94185   853.6s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   570350.331446   843745510.9269    99.93%     3027    511      0     94302   859.5s
#          0       0         0   0.00%   570350.331446   843745510.9269    99.93%     3060    513      0     94599   876.8s
#          0       0         0   0.00%   570350.331446   843745510.9269    99.93%     3067    515      0     94610   891.3s
#          0       0         0   0.00%   570350.331446   843745510.9269    99.93%     3072    517      0     94634   906.8s
#  L       0       0         0   0.00%   570350.331446   570750.447489      0.07%     3072    517      0     94634  1102.0s
#          1       0         1 100.00%   570350.331446   570750.447489      0.07%     3072    517      0    133127  1102.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      570750.447489
#   Dual bound        570350.331446
#   Gap               0.0701% (tolerance: 0.5%)
#   P-D integral      919.04783688
#   Solution status   feasible
#                     570750.447489 (objective)
#                     0 (bound viol.)
#                     3.77475828373e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            1102.17
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     133127
#                     0 (strong br.)
#                     39683 (separation)
#                     38493 (heuristics)
# [P100] Stopping fleet expansion: scenario +1 meets SLA and has no shortfall.
#     ✓ P100 fleet expansion search complete   [1542.89s]
#     ✓ P90 built (6,692 flights)   [0.77s]
#     P90 demand summary: 15,678 PRMs across 6,692 flights
#     ✓ prepare_model_data started | flights=6,692   [0.00s]
#     ✓ vehicle expansion complete | vehicles=17   [0.05s]
#     ✓ ambulift intervals built | flights=6,692 ambulifts=14   [1.12s]
#     ✓ minibus intervals built | minibuses=3   [0.09s]
#     ✓ staff intervals built   [0.02s]
#     ✓ ambulift overlaps built | overlaps=4,402,380   [1.26s]
#     ✓ minibus overlaps built | overlaps=404,379   [0.12s]
#     ✓ staff event matrix skipped; staff cost will use mode-level staff minutes   [0.00s]
#     ✓ staff requirements and staff-minutes calculated   [0.03s]
#     ✓ prepare_model_data complete | total=2.69s   [0.00s]
#     ✓ sets built | F=6,692 AMB=14 MINI=3   [0.02s]
#     ✓ variables built | x=33,460 amb=281,064 mini=40,152   [0.33s]
#     ✓ ambulift overlap constraints built | 4,402,380   [97.03s]
#     ✓ minibus overlap constraints built | 404,379   [1.89s]
#     ✓ build_pyomo_model complete | total=100.16s   [0.89s]
#
# ================================================================================
# Starting HiGHS solve
# ================================================================================
# Flights=6,692 Vehicles=17
# Running HiGHS 1.14.0 (git hash: 7df0786): Copyright (c) 2026 under MIT licence terms
# MIP has 5248638 rows; 401537 cols; 10861155 nonzeros; 354693 integer variables (354693 binary)
# Coefficient ranges:
#   Matrix  [1e+00, 1e+01]
#   Cost    [2e+00, 2e+06]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e+00, 1e+00]
# WARNING: Problem has some excessively large costs
# WARNING:    Consider scaling the objective by 1e-1, or setting the user_objective_scale option to -2
# Presolving model
# 682824 rows, 141690 cols, 1476068 nonzeros 8s
# 278943 rows, 124662 cols, 1059005 nonzeros 40s
# 278943 rows, 124662 cols, 1059005 nonzeros 82s
# Presolve reductions: rows 278943(-4969695); columns 124662(-276875); nonzeros 1059005(-9802150)
# Objective function is integral with scale 219
#
# Solving MIP model with:
#    278943 rows
#    124662 cols (110691 binary, 0 integer, 13971 implied int., 0 continuous, 0 domain fixed)
#    1059005 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2627405146.479     Large        0      0      0         0    97.6s
#  R       0       0         0   0.00%   377669.676125   1237367653.297    99.97%        0      0      0     54395   507.6s
#          0       0         0   0.00%   378050.199935   1237367653.297    99.97%     1097    143      0     60449   549.0s
#          0       0         0   0.00%   379040.440411   1237367653.297    99.97%     1512    270      0     61740   559.0s
#          0       0         0   0.00%   380324.390411   1237367653.297    99.97%     1672    379      0     62587   567.1s
#          0       0         0   0.00%   381247.557078   1237367653.297    99.97%     1781    454      0     63357   577.3s
#          0       0         0   0.00%   381325.557078   1237367653.297    99.97%     1926    463   2771     63902   596.2s
#          0       0         0   0.00%   381406.757078   1237367653.297    99.97%     2098    471   2771     63933   632.7s
#          0       0         0   0.00%   381413.557078   1237367653.297    99.97%     2168    475   2771     63981   643.3s
#          0       0         0   0.00%   381413.557078   1237367653.297    99.97%     2236    478   2771     64284   654.6s
#          0       0         0   0.00%   381728.557078   1237367653.297    99.97%     2316    484   2771     65212   668.5s
#          0       0         0   0.00%   381728.557078   1237367653.297    99.97%     2459    486   2771     65285   680.1s
#          0       0         0   0.00%   381735.557078   1237367653.297    99.97%     2543    489   2771     65349   693.2s
#          0       0         0   0.00%   381735.557078   1237367653.297    99.97%     2591    491   2771     65408   706.7s
#          0       0         0   0.00%   381913.057078   1237367653.297    99.97%     2661    494   2771     66047   729.5s
#          0       0         0   0.00%   381913.057078   1237367653.297    99.97%     2714    496   2771     66226   743.4s
#          0       0         0   0.00%   381923.057078   1237367653.297    99.97%     2724    411   2771     66311   758.3s
#          0       0         0   0.00%   381942.890411   1237367653.297    99.97%     2756    415   2771     67081   774.7s
#          0       0         0   0.00%   381953.890411   1237367653.297    99.97%     2940    418   2771     67128   855.8s
#          0       0         0   0.00%   381972.557078   1237367653.297    99.97%     3037    421   2771     67823   947.8s
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   381972.557078   1237367653.297    99.97%     3154    423   2771     67857  1023.2s
#          0       0         0   0.00%   381972.557078   1237367653.297    99.97%     3280    413   2771     67906  1120.2s
#          0       0         0   0.00%   381972.557078   1237367653.297    99.97%     3392    414   2771     67929  1210.5s
#  L       0       0         0   0.00%   381972.557078   382271.296804      0.08%     3392    414   2771     67929  1977.9s
#          1       0         1 100.00%   381972.557078   382271.296804      0.08%     3392    414   2771     93719  1978.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      382271.296804
#   Dual bound        381972.557078
#   Gap               0.0781% (tolerance: 0.5%)
#   P-D integral      1879.02333387
#   Solution status   feasible
#                     382271.296804 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            1978.25
#   Max sub-MIP depth 2
#   Nodes             1
#   Repair LPs        0
#   LP iterations     93719
#                     0 (strong br.)
#                     13534 (separation)
#                     25790 (heuristics)
#     ✓ P90 optimisation complete   [2257.49s]
#
# [P90 fleet utilisation]
#     vehicle_group vehicle_type  seatcap  wccap  current_available  \
# 0   Amb_3seat_1wc          Amb        3      1                  1
# 1   Amb_6seat_1wc          Amb        6      1                  4
# 2   Amb_7seat_1wc          Amb        7      1                  9
# 3  Mini_6seat_2wc         Mini        6      2                  3
#
#    future_candidates_available  used_at_least_once  peak_concurrent_used  \
# 0                            0                   1                     1
# 1                            0                   4                     3
# 2                            0                   9                     7
# 3                            0                   3                     3
#
#    required_for_schedule  gap_vs_current  surplus_vs_current  future_bought
# 0                      1               0                   0              0
# 1                      3               0                   1              0
# 2                      7               0                   2              0
# 3                      3               0                   0              0
#
# [P90] Current fleet meets SLA and has no current-fleet gap. Skipping fleet expansion search.
#     ✓ Excel outputs written to outputs\prm_v2\june_buffer_test\2025_06_test_ambulogic.xlsx   [43.65s]
# outputs\prm_v2\june_buffer_test\2025_06_test_ambulogic.xlsx
